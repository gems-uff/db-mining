# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
from util import SEQ_PATTERNS_DIR

# %%
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT = SEQ_PATTERNS_DIR + os.sep + 'output_init_tam4_SSID.txt' #add in util.py output_init_tam4_sid_2
HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT = SEQ_PATTERNS_DIR + os.sep + 'testes/output_init_tam4_sid_7.txt' #'testes/output_init_tam4_sid_2.txt'
df = pd.read_csv(HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT, sep= '#', header=None) #não funcionou sep=" | , #",  engine = "python",
df
# Out:
#                                                          0        1  \
# 0                                           INSnowflake |   SUP: 5
# 1                                 INSnowflake Snowflake |   SUP: 5
# 2                  INSnowflake Snowflake AmazonRedshift |   SUP: 4
# 3        INSnowflake Snowflake AmazonRedshift PostgreSQ...  SUP: 4
# 4        INSnowflake Snowflake AmazonRedshift MS_SQL_Se...  SUP: 4
# ...                                                    ...      ...
# 5077730        OUTIBM_DB2 | INInformix | MySQL | SQLite |   SUP: 2
# 5077731    OUTIBM_DB2 | INInformix | MySQL | PostgreSQL |   SUP: 2
# 5077732  OUTIBM_DB2 | INInformix | MySQL | MS_SQL_Serve...  SUP: 2
# 5077733  OUTIBM_DB2 | INInformix | MySQL | SAPAdaptiveS...  SUP: 2
# 5077734         OUTIBM_DB2 | INInformix | MySQL | MySQL |   SUP: 2
#
#                             2
# 0        SID: 17 21 57 74 145
# 1        SID: 17 21 57 74 145
# 2           SID: 17 57 74 145
# 3           SID: 17 57 74 145
# 4           SID: 17 57 74 145
# ...                       ...
# 5077730            SID: 17 35
# 5077731            SID: 17 35
# 5077732            SID: 17 35
# 5077733            SID: 17 35
# 5077734            SID: 17 35
#
# [5077735 rows x 3 columns]

# %%
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df.columns = ['Pattern','SUP_ABCD','SID']
df.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
df.replace({'SID:': ''}, regex=True, inplace=True) #ordf['SID'] = df['SID'].str.replace('SID:','')
df
# Out:
#                                                    Pattern SUP_ABCD  \
# 0                                           INSnowflake |        5
# 1                                 INSnowflake Snowflake |        5
# 2                  INSnowflake Snowflake AmazonRedshift |        4
# 3        INSnowflake Snowflake AmazonRedshift PostgreSQ...       4
# 4        INSnowflake Snowflake AmazonRedshift MS_SQL_Se...       4
# ...                                                    ...      ...
# 5077730        OUTIBM_DB2 | INInformix | MySQL | SQLite |        2
# 5077731    OUTIBM_DB2 | INInformix | MySQL | PostgreSQL |        2
# 5077732  OUTIBM_DB2 | INInformix | MySQL | MS_SQL_Serve...       2
# 5077733  OUTIBM_DB2 | INInformix | MySQL | SAPAdaptiveS...       2
# 5077734         OUTIBM_DB2 | INInformix | MySQL | MySQL |        2
#
#                       SID
# 0         17 21 57 74 145
# 1         17 21 57 74 145
# 2            17 57 74 145
# 3            17 57 74 145
# 4            17 57 74 145
# ...                   ...
# 5077730             17 35
# 5077731             17 35
# 5077732             17 35
# 5077733             17 35
# 5077734             17 35
#
# [5077735 rows x 3 columns]

# %%
df2 = df.copy()

# %%
select_pattern = df2[(df2['Pattern'].str.contains('IN') & df2['Pattern'].str.contains('OUT'))] #df2['Pattern'].str.contains('INIT') |
select_pattern
# Out:
#                                                    Pattern SUP_ABCD     SID
# 22558        Memcached Redis INCassandra | OUTCassandra |        2    9 119
# 22561             Memcached Redis INCassandra | OUTSolr |        2    9 119
# 22569        Memcached Redis INCassandra | OUTMemcached |        2    9 119
# 22570            Memcached Redis INCassandra | OUTHBase |        2    9 119
# 23344    Memcached INMS_SQL_Server MySQL | OUTMemcached |        2    9 119
# ...                                                    ...      ...     ...
# 5077730        OUTIBM_DB2 | INInformix | MySQL | SQLite |        2    17 35
# 5077731    OUTIBM_DB2 | INInformix | MySQL | PostgreSQL |        2    17 35
# 5077732  OUTIBM_DB2 | INInformix | MySQL | MS_SQL_Serve...       2    17 35
# 5077733  OUTIBM_DB2 | INInformix | MySQL | SAPAdaptiveS...       2    17 35
# 5077734         OUTIBM_DB2 | INInformix | MySQL | MySQL |        2    17 35
#
# [332042 rows x 3 columns]

# %%
df3 = select_pattern.copy()
df3
# Out:
#                                                    Pattern SUP_ABCD     SID
# 22558        Memcached Redis INCassandra | OUTCassandra |        2    9 119
# 22561             Memcached Redis INCassandra | OUTSolr |        2    9 119
# 22569        Memcached Redis INCassandra | OUTMemcached |        2    9 119
# 22570            Memcached Redis INCassandra | OUTHBase |        2    9 119
# 23344    Memcached INMS_SQL_Server MySQL | OUTMemcached |        2    9 119
# ...                                                    ...      ...     ...
# 5077730        OUTIBM_DB2 | INInformix | MySQL | SQLite |        2    17 35
# 5077731    OUTIBM_DB2 | INInformix | MySQL | PostgreSQL |        2    17 35
# 5077732  OUTIBM_DB2 | INInformix | MySQL | MS_SQL_Serve...       2    17 35
# 5077733  OUTIBM_DB2 | INInformix | MySQL | SAPAdaptiveS...       2    17 35
# 5077734         OUTIBM_DB2 | INInformix | MySQL | MySQL |        2    17 35
#
# [332042 rows x 3 columns]

# %%
#df3['Pattern'].replace({r"|": '#|#'}, regex=True, inplace=True)
df3['Pattern'].replace({' | ': '#|#'}, regex=True, inplace=True)
df3
# Out:
#                                                    Pattern SUP_ABCD     SID
# 22558    Memcached#/#Redis#/#INCassandra#|#|#|#OUTCassa...       2    9 119
# 22561    Memcached#/#Redis#/#INCassandra#|#|#|#OUTSolr#...       2    9 119
# 22569    Memcached#/#Redis#/#INCassandra#|#|#|#OUTMemca...       2    9 119
# 22570    Memcached#/#Redis#/#INCassandra#|#|#|#OUTHBase...       2    9 119
# 23344    Memcached#/#INMS_SQL_Server#/#MySQL#|#|#|#OUTM...       2    9 119
# ...                                                    ...      ...     ...
# 5077730  OUTIBM_DB2#|#|#|#INInformix#|#|#|#MySQL#|#|#|#...       2    17 35
# 5077731  OUTIBM_DB2#|#|#|#INInformix#|#|#|#MySQL#|#|#|#...       2    17 35
# 5077732  OUTIBM_DB2#|#|#|#INInformix#|#|#|#MySQL#|#|#|#...       2    17 35
# 5077733  OUTIBM_DB2#|#|#|#INInformix#|#|#|#MySQL#|#|#|#...       2    17 35
# 5077734  OUTIBM_DB2#|#|#|#INInformix#|#|#|#MySQL#|#|#|#...       2    17 35
#
# [332042 rows x 3 columns]

# %%
df3['Pattern'].replace({r"(?<=\w)\s+(?=\w)": '#/#'}, regex=True, inplace=True)
df3
# Out:
#                                                    Pattern SUP_ABCD     SID
# 22558    Memcached#/#Redis#/#INCassandra | OUTCassandra |        2    9 119
# 22561         Memcached#/#Redis#/#INCassandra | OUTSolr |        2    9 119
# 22569    Memcached#/#Redis#/#INCassandra | OUTMemcached |        2    9 119
# 22570        Memcached#/#Redis#/#INCassandra | OUTHBase |        2    9 119
# 23344    Memcached#/#INMS_SQL_Server#/#MySQL | OUTMemca...       2    9 119
# ...                                                    ...      ...     ...
# 5077730        OUTIBM_DB2 | INInformix | MySQL | SQLite |        2    17 35
# 5077731    OUTIBM_DB2 | INInformix | MySQL | PostgreSQL |        2    17 35
# 5077732  OUTIBM_DB2 | INInformix | MySQL | MS_SQL_Serve...       2    17 35
# 5077733  OUTIBM_DB2 | INInformix | MySQL | SAPAdaptiveS...       2    17 35
# 5077734         OUTIBM_DB2 | INInformix | MySQL | MySQL |        2    17 35
#
# [332042 rows x 3 columns]

# %%
df3['Pattern'].replace({r"(?<=|)\s+(?=|)": '#'}, regex=True, inplace=True)
df3
# Out:
#                                                    Pattern SUP_ABCD     SID
# 22558    Memcached#/#Redis#/#INCassandra#|#OUTCassandra#|#       2    9 119
# 22561         Memcached#/#Redis#/#INCassandra#|#OUTSolr#|#       2    9 119
# 22569    Memcached#/#Redis#/#INCassandra#|#OUTMemcached#|#       2    9 119
# 22570        Memcached#/#Redis#/#INCassandra#|#OUTHBase#|#       2    9 119
# 23344    Memcached#/#INMS_SQL_Server#/#MySQL#|#OUTMemca...       2    9 119
# ...                                                    ...      ...     ...
# 5077730        OUTIBM_DB2#|#INInformix#|#MySQL#|#SQLite#|#       2    17 35
# 5077731    OUTIBM_DB2#|#INInformix#|#MySQL#|#PostgreSQL#|#       2    17 35
# 5077732  OUTIBM_DB2#|#INInformix#|#MySQL#|#MS_SQL_Serve...       2    17 35
# 5077733  OUTIBM_DB2#|#INInformix#|#MySQL#|#SAPAdaptiveS...       2    17 35
# 5077734         OUTIBM_DB2#|#INInformix#|#MySQL#|#MySQL#|#       2    17 35
#
# [332042 rows x 3 columns]

# %%
df3[['A','AB','B','BC','C','CD','D','DE']] = df3['Pattern'].str.split("[#]", expand=True, n=7)
#df2['Pattern'].str.split('|', expand=True)
df3
# Out:
#                                                    Pattern SUP_ABCD     SID  \
# 22558    Memcached#/#Redis#/#INCassandra#|#OUTCassandra#|#       2    9 119
# 22561         Memcached#/#Redis#/#INCassandra#|#OUTSolr#|#       2    9 119
# 22569    Memcached#/#Redis#/#INCassandra#|#OUTMemcached#|#       2    9 119
# 22570        Memcached#/#Redis#/#INCassandra#|#OUTHBase#|#       2    9 119
# 23344    Memcached#/#INMS_SQL_Server#/#MySQL#|#OUTMemca...       2    9 119
# ...                                                    ...      ...     ...
# 5077730        OUTIBM_DB2#|#INInformix#|#MySQL#|#SQLite#|#       2    17 35
# 5077731    OUTIBM_DB2#|#INInformix#|#MySQL#|#PostgreSQL#|#       2    17 35
# 5077732  OUTIBM_DB2#|#INInformix#|#MySQL#|#MS_SQL_Serve...       2    17 35
# 5077733  OUTIBM_DB2#|#INInformix#|#MySQL#|#SAPAdaptiveS...       2    17 35
# 5077734         OUTIBM_DB2#|#INInformix#|#MySQL#|#MySQL#|#       2    17 35
#
#                   A AB                B BC            C CD                  D  \
# 22558     Memcached  /            Redis  /  INCassandra  |       OUTCassandra
# 22561     Memcached  /            Redis  /  INCassandra  |            OUTSolr
# 22569     Memcached  /            Redis  /  INCassandra  |       OUTMemcached
# 22570     Memcached  /            Redis  /  INCassandra  |           OUTHBase
# 23344     Memcached  /  INMS_SQL_Server  /        MySQL  |       OUTMemcached
# ...             ... ..              ... ..          ... ..                ...
# 5077730  OUTIBM_DB2  |       INInformix  |        MySQL  |             SQLite
# 5077731  OUTIBM_DB2  |       INInformix  |        MySQL  |         PostgreSQL
# 5077732  OUTIBM_DB2  |       INInformix  |        MySQL  |      MS_SQL_Server
# 5077733  OUTIBM_DB2  |       INInformix  |        MySQL  |  SAPAdaptiveServer
# 5077734  OUTIBM_DB2  |       INInformix  |        MySQL  |              MySQL
#
#          DE
# 22558    |#
# 22561    |#
# 22569    |#
# 22570    |#
# 23344    |#
# ...      ..
# 5077730  |#
# 5077731  |#
# 5077732  |#
# 5077733  |#
# 5077734  |#
#
# [332042 rows x 11 columns]

# %%
df4 = df3[(df3['AB'].str.startswith('|') & (df3['BC'].str.startswith('/'))) | (df3['AB'].str.startswith('|') & (df3['CD'].str.startswith('/')))]
df4
# Out:
#                                                    Pattern SUP_ABCD     SID  \
# 38140    Memcached#|#Memcached#/#INMariaDB#|#OUTCassand...       2    9 119
# 38146       Memcached#|#Memcached#/#INMariaDB#|#OUTSolr#|#       2    9 119
# 38154    Memcached#|#Memcached#/#INMariaDB#|#OUTMemcach...       2    9 119
# 38155      Memcached#|#Memcached#/#INMariaDB#|#OUTHBase#|#       2    9 119
# 38316    Memcached#|#Memcached#/#INCassandra#|#OUTCassa...       2    9 119
# ...                                                    ...      ...     ...
# 5077683  OUTIBM_DB2#|#INInformix#|#PostgreSQL#/#MS_SQL_...       2    17 35
# 5077684  OUTIBM_DB2#|#INInformix#|#PostgreSQL#/#SAPAdap...       2    17 35
# 5077697  OUTIBM_DB2#|#INInformix#|#MS_SQL_Server#/#MySQ...       2    17 35
# 5077698  OUTIBM_DB2#|#INInformix#|#MS_SQL_Server#/#SAPA...       2    17 35
# 5077711  OUTIBM_DB2#|#INInformix#|#SAPAdaptiveServer#/#...       2    17 35
#
#                   A AB           B BC                  C CD  \
# 38140     Memcached  |   Memcached  /          INMariaDB  |
# 38146     Memcached  |   Memcached  /          INMariaDB  |
# 38154     Memcached  |   Memcached  /          INMariaDB  |
# 38155     Memcached  |   Memcached  /          INMariaDB  |
# 38316     Memcached  |   Memcached  /        INCassandra  |
# ...             ... ..         ... ..                ... ..
# 5077683  OUTIBM_DB2  |  INInformix  |         PostgreSQL  /
# 5077684  OUTIBM_DB2  |  INInformix  |         PostgreSQL  /
# 5077697  OUTIBM_DB2  |  INInformix  |      MS_SQL_Server  /
# 5077698  OUTIBM_DB2  |  INInformix  |      MS_SQL_Server  /
# 5077711  OUTIBM_DB2  |  INInformix  |  SAPAdaptiveServer  /
#
#                          D  DE
# 38140         OUTCassandra  |#
# 38146              OUTSolr  |#
# 38154         OUTMemcached  |#
# 38155             OUTHBase  |#
# 38316         OUTCassandra  |#
# ...                    ...  ..
# 5077683      MS_SQL_Server  |#
# 5077684  SAPAdaptiveServer  |#
# 5077697              MySQL  |#
# 5077698  SAPAdaptiveServer  |#
# 5077711              MySQL  |#
#
# [134390 rows x 11 columns]

# %%
select_pattern2 = df4[(df4.apply(lambda x: str(x['C']) in str(x['A']),axis=1) & (df4['D'].values.astype(str) == ''))]
select_pattern3 = df4[(df4.apply(lambda x: str(x['C']) in str(x['A']),axis=1) & (df4.apply(lambda x: str(x['D']) in str(x['A']),axis=1)))]
df_concat1 = pd.concat([select_pattern2, select_pattern3]).drop_duplicates()
df_concat1
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer#|#INElasticsearch#/#SAPAd...       2
# 53463    OUTSAPAdaptiveServer#|#INFirebird#/#SAPAdaptiv...       2
# 53760    OUTSAPAdaptiveServer#|#INMS_SQL_Server#/#SAPAd...       3
# 56930    OUTSAPAdaptiveServer#|#INMariaDB#/#SAPAdaptive...       2
# 60060    OUTSAPAdaptiveServer#|#INCassandra#/#SAPAdapti...       2
# ...                                                    ...      ...
# 5071755     OUTIBM_DB2#|#INFirebird#/#IBM_DB2#|#IBM_DB2#|#       2
# 5076246       OUTIBM_DB2#|#INOracle#/#IBM_DB2#|#IBM_DB2#|#       2
# 5076600      OUTIBM_DB2#|#INIBM_DB2#/#IBM_DB2#|#IBM_DB2#|#       2
# 5077058           OUTIBM_DB2#|#INH2#/#IBM_DB2#|#IBM_DB2#|#       2
# 5077433     OUTIBM_DB2#|#INInformix#/#IBM_DB2#|#IBM_DB2#|#       2
#
#                 SID                     A AB                B BC  \
# 52360        17 129  OUTSAPAdaptiveServer  |  INElasticsearch  /
# 53463         17 35  OUTSAPAdaptiveServer  |       INFirebird  /
# 53760     17 35 129  OUTSAPAdaptiveServer  |  INMS_SQL_Server  /
# 56930        35 129  OUTSAPAdaptiveServer  |        INMariaDB  /
# 60060        17 129  OUTSAPAdaptiveServer  |      INCassandra  /
# ...             ...                   ... ..              ... ..
# 5071755       17 35            OUTIBM_DB2  |       INFirebird  /
# 5076246       17 35            OUTIBM_DB2  |         INOracle  /
# 5076600       17 35            OUTIBM_DB2  |        INIBM_DB2  /
# 5077058       17 35            OUTIBM_DB2  |             INH2  /
# 5077433       17 35            OUTIBM_DB2  |       INInformix  /
#
#                          C CD        D    DE
# 52360    SAPAdaptiveServer  |           None
# 53463    SAPAdaptiveServer  |           None
# 53760    SAPAdaptiveServer  |           None
# 56930    SAPAdaptiveServer  |           None
# 60060    SAPAdaptiveServer  |           None
# ...                    ... ..      ...   ...
# 5071755            IBM_DB2  |  IBM_DB2    |#
# 5076246            IBM_DB2  |  IBM_DB2    |#
# 5076600            IBM_DB2  |  IBM_DB2    |#
# 5077058            IBM_DB2  |  IBM_DB2    |#
# 5077433            IBM_DB2  |  IBM_DB2    |#
#
# [395 rows x 11 columns]

# %%
#select_pattern31 = (df4['C'].values.astype(str) != '') & (df4['D'].values.astype(str) != '')
#select_pattern2 =df4[(df4['A'].str.extract(r'INIT(.*)', expand=False) == df4['C'].str.extract(r'OUT(.*)', expand=False)) & (df4['A'].str.extract(r'INIT(.*)', expand=False) != df4['B'].str.extract(r'IN(.*)', expand=False)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))]
select_pattern4 =df4[(df4['A'].str.extract(r'IN(.*)', expand=False) == df4['C'].str.extract(r'OUT(.*)', expand=False)) & (df4['A'].str.extract(r'IN(.*)', expand=False) != df4['B'].str.extract(r'IN(.*)', expand=False)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1)) &
(df3['B'].str.startswith('IN'))] #
#select_pattern4 =df4[(df4.apply(lambda x: str(x['A']) in str(x['C']),axis=1)) & (df4['A'].str.extract(r'IN(.*)', expand=False) != df4['B'].str.extract(r'IN(.*)', expand=False)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))] #147 padrões
select_pattern5 = df4[(df4.apply(lambda x: str(x['A']) in str(x['C']),axis=1)) & (df4.apply(lambda x: str(x['A']) not in str(x['B']),axis=1)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1)) & (df3['B'].str.startswith('IN'))]

#select_pattern5
#select_pattern3
df_concat2 = pd.concat([select_pattern4,select_pattern5]).drop_duplicates()
df_concat2
#df_concat = pd.concat([df_concat1,df_concat2]).drop_duplicates
#df_concat2
# Out:
# /home/raquelmax/.virtualenvs/db-mining-pBhgzAM8/lib/python3.7/site-packages/ipykernel_launcher.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   after removing the cwd from sys.path.
# /home/raquelmax/.virtualenvs/db-mining-pBhgzAM8/lib/python3.7/site-packages/ipykernel_launcher.py:6: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                                    Pattern SUP_ABCD  \
# 3476373          INOracle#|#INMySQL#|#OUTOracle#/#MySQL#|#       2
# 3775070                INEhcache#|#INRedis#/#OUTEhcache#|#       2
# 3775073        INEhcache#|#INRedis#/#OUTEhcache#|#Redis#|#       2
# 4040118                    INMySQL#|#INRedis#/#OUTMySQL#|#       2
# 4040119            INMySQL#|#INRedis#/#OUTMySQL#|#Redis#|#       2
# 4150561    INMS_SQL_Server#|#INRedis#/#OUTMS_SQL_Server#|#       2
# 4150562  INMS_SQL_Server#|#INRedis#/#OUTMS_SQL_Server#|...       2
# 4658110        INPostgreSQL#|#INMariaDB#/#OUTPostgreSQL#|#       2
# 4658113  INPostgreSQL#|#INMariaDB#/#OUTPostgreSQL#|#Mar...       2
# 372430   GoogleCloudDatastore#|#INMySQL#|#OUTGoogleClou...       2
# 680440                           H2#|#INMariaDB#/#OUTH2#|#       2
# 680441                 H2#|#INMariaDB#/#OUTH2#|#MariaDB#|#       2
# 740197                     H2#|#INMySQL#|#OUTH2#/#MySQL#|#       2
# 1459677          Oracle#|#INSQLite#|#OUTOracle#/#SQLite#|#       2
# 1468965            Oracle#|#INMySQL#|#OUTOracle#/#MySQL#|#       3
# 1479666  Oracle#|#INPostgreSQL#|#OUTOracle#/#PostgreSQL#|#       2
# 2517472          PostgreSQL#|#INMariaDB#/#OUTPostgreSQL#|#       3
# 2517475  PostgreSQL#|#INMariaDB#/#OUTPostgreSQL#|#Maria...       3
# 2587795           PostgreSQL#|#INOracle#/#OUTPostgreSQL#|#       2
# 2587798  PostgreSQL#|#INOracle#/#OUTPostgreSQL#|#Oracle#|#       2
# 2600576    PostgreSQL#|#INMySQL#|#OUTPostgreSQL#/#MySQL#|#       2
# 2606689  PostgreSQL#|#INCassandra#|#OUTPostgreSQL#/#Cas...       2
# 2856871      MS_SQL_Server#|#INRedis#/#OUTMS_SQL_Server#|#       2
# 2856872  MS_SQL_Server#|#INRedis#/#OUTMS_SQL_Server#|#R...       2
# 2912325                  Ehcache#|#INRedis#/#OUTEhcache#|#       2
# 2912328          Ehcache#|#INRedis#/#OUTEhcache#|#Redis#|#       2
# 3262618                    MySQL#|#INMariaDB#/#OUTMySQL#|#       2
# 3339896                      MySQL#|#INRedis#/#OUTMySQL#|#       2
# 3339897              MySQL#|#INRedis#/#OUTMySQL#|#Redis#|#       2
# 3374890                         MySQL#|#INH2#/#OUTMySQL#|#       2
#
#                  SID                     A AB             B BC  \
# 3476373      136 195              INOracle  |       INMySQL  |
# 3775070        40 93             INEhcache  |       INRedis  /
# 3775073        40 93             INEhcache  |       INRedis  /
# 4040118        16 96               INMySQL  |       INRedis  /
# 4040119        16 96               INMySQL  |       INRedis  /
# 4150561        16 93       INMS_SQL_Server  |       INRedis  /
# 4150562        16 93       INMS_SQL_Server  |       INRedis  /
# 4658110       37 122          INPostgreSQL  |     INMariaDB  /
# 4658113       37 122          INPostgreSQL  |     INMariaDB  /
# 372430        24 122  GoogleCloudDatastore  |       INMySQL  |
# 680440       116 140                    H2  |     INMariaDB  /
# 680441       116 140                    H2  |     INMariaDB  /
# 740197       122 172                    H2  |       INMySQL  |
# 1459677      184 195                Oracle  |      INSQLite  |
# 1468965    2 136 195                Oracle  |       INMySQL  |
# 1479666        2 136                Oracle  |  INPostgreSQL  |
# 2517472   37 122 140            PostgreSQL  |     INMariaDB  /
# 2517475   37 122 140            PostgreSQL  |     INMariaDB  /
# 2587795       37 136            PostgreSQL  |      INOracle  /
# 2587798       37 136            PostgreSQL  |      INOracle  /
# 2600576       24 115            PostgreSQL  |       INMySQL  |
# 2606689       28 140            PostgreSQL  |   INCassandra  |
# 2856871        16 93         MS_SQL_Server  |       INRedis  /
# 2856872        16 93         MS_SQL_Server  |       INRedis  /
# 2912325        40 93               Ehcache  |       INRedis  /
# 2912328        40 93               Ehcache  |       INRedis  /
# 3262618      140 187                 MySQL  |     INMariaDB  /
# 3339896        16 96                 MySQL  |       INRedis  /
# 3339897        16 96                 MySQL  |       INRedis  /
# 3374890       44 170                 MySQL  |          INH2  /
#
#                                C CD           D    DE
# 3476373                OUTOracle  /       MySQL    |#
# 3775070               OUTEhcache  |              None
# 3775073               OUTEhcache  |       Redis    |#
# 4040118                 OUTMySQL  |              None
# 4040119                 OUTMySQL  |       Redis    |#
# 4150561         OUTMS_SQL_Server  |              None
# 4150562         OUTMS_SQL_Server  |       Redis    |#
# 4658110            OUTPostgreSQL  |              None
# 4658113            OUTPostgreSQL  |     MariaDB    |#
# 372430   OUTGoogleCloudDatastore  /       MySQL    |#
# 680440                     OUTH2  |              None
# 680441                     OUTH2  |     MariaDB    |#
# 740197                     OUTH2  /       MySQL    |#
# 1459677                OUTOracle  /      SQLite    |#
# 1468965                OUTOracle  /       MySQL    |#
# 1479666                OUTOracle  /  PostgreSQL    |#
# 2517472            OUTPostgreSQL  |              None
# 2517475            OUTPostgreSQL  |     MariaDB    |#
# 2587795            OUTPostgreSQL  |              None
# 2587798            OUTPostgreSQL  |      Oracle    |#
# 2600576            OUTPostgreSQL  /       MySQL    |#
# 2606689            OUTPostgreSQL  /   Cassandra    |#
# 2856871         OUTMS_SQL_Server  |              None
# 2856872         OUTMS_SQL_Server  |       Redis    |#
# 2912325               OUTEhcache  |              None
# 2912328               OUTEhcache  |       Redis    |#
# 3262618                 OUTMySQL  |              None
# 3339896                 OUTMySQL  |              None
# 3339897                 OUTMySQL  |       Redis    |#
# 3374890                 OUTMySQL  |              None

# %%
df_concat3 = pd.concat([select_pattern2, select_pattern3,select_pattern4,select_pattern5]).drop_duplicates()
df_concat3
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer#|#INElasticsearch#/#SAPAd...       2
# 53463    OUTSAPAdaptiveServer#|#INFirebird#/#SAPAdaptiv...       2
# 53760    OUTSAPAdaptiveServer#|#INMS_SQL_Server#/#SAPAd...       3
# 56930    OUTSAPAdaptiveServer#|#INMariaDB#/#SAPAdaptive...       2
# 60060    OUTSAPAdaptiveServer#|#INCassandra#/#SAPAdapti...       2
# ...                                                    ...      ...
# 2912328          Ehcache#|#INRedis#/#OUTEhcache#|#Redis#|#       2
# 3262618                    MySQL#|#INMariaDB#/#OUTMySQL#|#       2
# 3339896                      MySQL#|#INRedis#/#OUTMySQL#|#       2
# 3339897              MySQL#|#INRedis#/#OUTMySQL#|#Redis#|#       2
# 3374890                         MySQL#|#INH2#/#OUTMySQL#|#       2
#
#                 SID                     A AB                B BC  \
# 52360        17 129  OUTSAPAdaptiveServer  |  INElasticsearch  /
# 53463         17 35  OUTSAPAdaptiveServer  |       INFirebird  /
# 53760     17 35 129  OUTSAPAdaptiveServer  |  INMS_SQL_Server  /
# 56930        35 129  OUTSAPAdaptiveServer  |        INMariaDB  /
# 60060        17 129  OUTSAPAdaptiveServer  |      INCassandra  /
# ...             ...                   ... ..              ... ..
# 2912328       40 93               Ehcache  |          INRedis  /
# 3262618     140 187                 MySQL  |        INMariaDB  /
# 3339896       16 96                 MySQL  |          INRedis  /
# 3339897       16 96                 MySQL  |          INRedis  /
# 3374890      44 170                 MySQL  |             INH2  /
#
#                          C CD      D    DE
# 52360    SAPAdaptiveServer  |         None
# 53463    SAPAdaptiveServer  |         None
# 53760    SAPAdaptiveServer  |         None
# 56930    SAPAdaptiveServer  |         None
# 60060    SAPAdaptiveServer  |         None
# ...                    ... ..    ...   ...
# 2912328         OUTEhcache  |  Redis    |#
# 3262618           OUTMySQL  |         None
# 3339896           OUTMySQL  |         None
# 3339897           OUTMySQL  |  Redis    |#
# 3374890           OUTMySQL  |         None
#
# [425 rows x 11 columns]

# %%
df5 = df_concat3[(~df_concat3['A'].str.startswith('OUT'))]
df5
# Out:
#                                              Pattern SUP_ABCD           SID  \
# 111850   INITMySQL#|#OUTSAPAdaptiveServer#/#MySQL#|#       2          9 179
# 115022              INITMySQL#|#OUTOracle#/#MySQL#|#       3    132 136 184
# 133530           INITMySQL#|#OUTCassandra#/#MySQL#|#       2          9 119
# 149690                INITMySQL#|#OUTSolr#/#MySQL#|#       2          9 119
# 168286             INITMySQL#|#OUTMongoDB#/#MySQL#|#       2        111 119
# ...                                              ...      ...           ...
# 2912328    Ehcache#|#INRedis#/#OUTEhcache#|#Redis#|#       2          40 93
# 3262618              MySQL#|#INMariaDB#/#OUTMySQL#|#       2        140 187
# 3339896                MySQL#|#INRedis#/#OUTMySQL#|#       2          16 96
# 3339897        MySQL#|#INRedis#/#OUTMySQL#|#Redis#|#       2          16 96
# 3374890                   MySQL#|#INH2#/#OUTMySQL#|#       2         44 170
#
#                  A AB                     B BC           C CD      D    DE
# 111850   INITMySQL  |  OUTSAPAdaptiveServer  /       MySQL  |         None
# 115022   INITMySQL  |             OUTOracle  /       MySQL  |         None
# 133530   INITMySQL  |          OUTCassandra  /       MySQL  |         None
# 149690   INITMySQL  |               OUTSolr  /       MySQL  |         None
# 168286   INITMySQL  |            OUTMongoDB  /       MySQL  |         None
# ...            ... ..                   ... ..         ... ..    ...   ...
# 2912328    Ehcache  |               INRedis  /  OUTEhcache  |  Redis    |#
# 3262618      MySQL  |             INMariaDB  /    OUTMySQL  |         None
# 3339896      MySQL  |               INRedis  /    OUTMySQL  |         None
# 3339897      MySQL  |               INRedis  /    OUTMySQL  |  Redis    |#
# 3374890      MySQL  |                  INH2  /    OUTMySQL  |         None
#
# [216 rows x 11 columns]

# %%
df5['SUP_ABCD'] = df5['SUP_ABCD'].astype(int)
#df13['SUP_ABCD'] = df13['SUP_ABCD'].astype(int)
# Out:
# /home/raquelmax/.virtualenvs/db-mining-pBhgzAM8/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df6 = df5[(df5['SUP_ABCD'] > 2)]
df6
# Out:
#                                                    Pattern  SUP_ABCD  \
# 115022                    INITMySQL#|#OUTOracle#/#MySQL#|#         3
# 177880                INITMySQL#|#OUTPostgreSQL#/#MySQL#|#         4
# 181614             INITMySQL#|#OUTMS_SQL_Server#/#MySQL#|#         5
# 181955                     INITMySQL#|#OUTHBase#/#MySQL#|#         6
# 186669                 INITMySQL#|#OUTHazelcast#/#MySQL#|#         3
# ...                                                    ...       ...
# 4827130                       INH2#|#OUTRedis#/#H2#|#H2#|#         4
# 4829045                     INH2#|#OUTHBase#|#INH2#/#H2#|#         3
# 1468965            Oracle#|#INMySQL#|#OUTOracle#/#MySQL#|#         3
# 2517472          PostgreSQL#|#INMariaDB#/#OUTPostgreSQL#|#         3
# 2517475  PostgreSQL#|#INMariaDB#/#OUTPostgreSQL#|#Maria...         3
#
#                           SID           A AB                 B BC  \
# 115022            132 136 184   INITMySQL  |         OUTOracle  /
# 177880          24 42 102 183   INITMySQL  |     OUTPostgreSQL  /
# 181614        42 61 79 93 184   INITMySQL  |  OUTMS_SQL_Server  /
# 181955    9 24 74 119 140 170   INITMySQL  |          OUTHBase  /
# 186669              73 93 101   INITMySQL  |      OUTHazelcast  /
# ...                       ...         ... ..               ... ..
# 4827130         15 18 119 124        INH2  |          OUTRedis  /
# 4829045             17 24 170        INH2  |          OUTHBase  |
# 1468965             2 136 195      Oracle  |           INMySQL  |
# 2517472            37 122 140  PostgreSQL  |         INMariaDB  /
# 2517475            37 122 140  PostgreSQL  |         INMariaDB  /
#
#                      C CD        D    DE
# 115022           MySQL  |           None
# 177880           MySQL  |           None
# 181614           MySQL  |           None
# 181955           MySQL  |           None
# 186669           MySQL  |           None
# ...                ... ..      ...   ...
# 4827130             H2  |       H2    |#
# 4829045           INH2  /       H2    |#
# 1468965      OUTOracle  /    MySQL    |#
# 2517472  OUTPostgreSQL  |           None
# 2517475  OUTPostgreSQL  |  MariaDB    |#
#
# [69 rows x 11 columns]

# %%
df6 = df5[(df5['SUP_ABCD'] == 2)]
df6
# Out:
#                                              Pattern  SUP_ABCD       SID  \
# 111850   INITMySQL#|#OUTSAPAdaptiveServer#/#MySQL#|#         2     9 179
# 133530           INITMySQL#|#OUTCassandra#/#MySQL#|#         2     9 119
# 149690                INITMySQL#|#OUTSolr#/#MySQL#|#         2     9 119
# 168286             INITMySQL#|#OUTMongoDB#/#MySQL#|#         2   111 119
# 188562             INITMySQL#|#OUTSapHana#/#MySQL#|#         2    74 121
# ...                                              ...       ...       ...
# 2912328    Ehcache#|#INRedis#/#OUTEhcache#|#Redis#|#         2     40 93
# 3262618              MySQL#|#INMariaDB#/#OUTMySQL#|#         2   140 187
# 3339896                MySQL#|#INRedis#/#OUTMySQL#|#         2     16 96
# 3339897        MySQL#|#INRedis#/#OUTMySQL#|#Redis#|#         2     16 96
# 3374890                   MySQL#|#INH2#/#OUTMySQL#|#         2    44 170
#
#                  A AB                     B BC           C CD      D    DE
# 111850   INITMySQL  |  OUTSAPAdaptiveServer  /       MySQL  |         None
# 133530   INITMySQL  |          OUTCassandra  /       MySQL  |         None
# 149690   INITMySQL  |               OUTSolr  /       MySQL  |         None
# 168286   INITMySQL  |            OUTMongoDB  /       MySQL  |         None
# 188562   INITMySQL  |            OUTSapHana  /       MySQL  |         None
# ...            ... ..                   ... ..         ... ..    ...   ...
# 2912328    Ehcache  |               INRedis  /  OUTEhcache  |  Redis    |#
# 3262618      MySQL  |             INMariaDB  /    OUTMySQL  |         None
# 3339896      MySQL  |               INRedis  /    OUTMySQL  |         None
# 3339897      MySQL  |               INRedis  /    OUTMySQL  |  Redis    |#
# 3374890      MySQL  |                  INH2  /    OUTMySQL  |         None
#
# [147 rows x 11 columns]

# %%
#join padroes out nas colunas B e C
df_concat3.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_initin_select_8.xlsx",index=True)

# %%
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT_TAM1 = SEQ_PATTERNS_DIR + os.sep + 'output_seq_in_out.txt' #add in util.py
df5 = pd.read_csv(SEQ_PATTERNS_DIR + os.sep + 'testes/output_init_tam1_7.txt', sep= '#', header=None) #não funcionou sep=" | , #",  engine = "python",
df5
# Out:
#                            0        1
# 0             INSnowflake |    SUP: 5
# 1               Memcached |    SUP: 8
# 2       INITElasticsearch |    SUP: 4
# 3    OUTSAPAdaptiveServer |    SUP: 8
# 4                    Hive |   SUP: 11
# ..                       ...      ...
# 131            INInformix |    SUP: 6
# 132           INITNetezza |    SUP: 2
# 133          INClickHouse |    SUP: 7
# 134               INNeo4j |    SUP: 4
# 135            OUTIBM_DB2 |    SUP: 7
#
# [136 rows x 2 columns]

# %%
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df5.columns = ['Pattern_v1','SUP_v1',]
df5.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
#df5.replace({'|': ''}, regex=True, inplace=True) #ordf['Pattern_v1'] = df['Pattern_v1'].str.replace('|','')
df5['Pattern_v1'] = df5['Pattern_v1'].str.replace('[ | ]','')
#df4['Pattern_v1'] = df4['Pattern_v1'].str.replace(' ','')
df5
# Out:
#                Pattern_v1 SUP_v1
# 0             INSnowflake      5
# 1               Memcached      8
# 2       INITElasticsearch      4
# 3    OUTSAPAdaptiveServer      8
# 4                    Hive     11
# ..                    ...    ...
# 131            INInformix      6
# 132           INITNetezza      2
# 133          INClickHouse      7
# 134               INNeo4j      4
# 135            OUTIBM_DB2      7
#
# [136 rows x 2 columns]

# %%
df8 = df_concat3.copy()

# %%
#df13.drop("ConfA->_BCD", axis=1, inplace=True)
#df13.drop("ConfB->A_CD", axis=1, inplace=True)
#df13.drop("ConfC->AB_D", axis=1, inplace=True)
#df13.drop("ConfD->ABC_", axis=1, inplace=True)

# %%
df8.insert(4,"SUP_A",'0',False)#True)
df8.insert(7,"SUP_B",'0',False)#True)
df8.insert(10,"SUP_C",'0',False)#True)
df8.insert(13,"SUP_D",'0',False)#True)
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer#|#INElasticsearch#/#SAPAd...       2
# 53463    OUTSAPAdaptiveServer#|#INFirebird#/#SAPAdaptiv...       2
# 53760    OUTSAPAdaptiveServer#|#INMS_SQL_Server#/#SAPAd...       3
# 56930    OUTSAPAdaptiveServer#|#INMariaDB#/#SAPAdaptive...       2
# 60060    OUTSAPAdaptiveServer#|#INCassandra#/#SAPAdapti...       2
# ...                                                    ...      ...
# 2912328          Ehcache#|#INRedis#/#OUTEhcache#|#Redis#|#       2
# 3262618                    MySQL#|#INMariaDB#/#OUTMySQL#|#       2
# 3339896                      MySQL#|#INRedis#/#OUTMySQL#|#       2
# 3339897              MySQL#|#INRedis#/#OUTMySQL#|#Redis#|#       2
# 3374890                         MySQL#|#INH2#/#OUTMySQL#|#       2
#
#                 SID                     A SUP_A AB                B SUP_B BC  \
# 52360        17 129  OUTSAPAdaptiveServer     0  |  INElasticsearch     0  /
# 53463         17 35  OUTSAPAdaptiveServer     0  |       INFirebird     0  /
# 53760     17 35 129  OUTSAPAdaptiveServer     0  |  INMS_SQL_Server     0  /
# 56930        35 129  OUTSAPAdaptiveServer     0  |        INMariaDB     0  /
# 60060        17 129  OUTSAPAdaptiveServer     0  |      INCassandra     0  /
# ...             ...                   ...   ... ..              ...   ... ..
# 2912328       40 93               Ehcache     0  |          INRedis     0  /
# 3262618     140 187                 MySQL     0  |        INMariaDB     0  /
# 3339896       16 96                 MySQL     0  |          INRedis     0  /
# 3339897       16 96                 MySQL     0  |          INRedis     0  /
# 3374890      44 170                 MySQL     0  |             INH2     0  /
#
#                          C SUP_C CD      D SUP_D    DE
# 52360    SAPAdaptiveServer     0  |            0  None
# 53463    SAPAdaptiveServer     0  |            0  None
# 53760    SAPAdaptiveServer     0  |            0  None
# 56930    SAPAdaptiveServer     0  |            0  None
# 60060    SAPAdaptiveServer     0  |            0  None
# ...                    ...   ... ..    ...   ...   ...
# 2912328         OUTEhcache     0  |  Redis     0    |#
# 3262618           OUTMySQL     0  |            0  None
# 3339896           OUTMySQL     0  |            0  None
# 3339897           OUTMySQL     0  |  Redis     0    |#
# 3374890           OUTMySQL     0  |            0  None
#
# [425 rows x 15 columns]

# %%
for index, row in df8.iterrows():
    for j, rowj in df5.iterrows():
        if row['A'] == rowj['Pattern_v1']:
            df8.loc[index,'SUP_A'] =  df8.loc[index,'SUP_A'].replace(df8.loc[index,'SUP_A'],df5.loc[j,'SUP_v1'])
            #print(row['DB_1'],':', rowj['Pattern_v1'])
        if row['B'] == rowj['Pattern_v1']:
         #   print(row['Pattern_v2'], rowj['Pattern_v1'])
            df8.loc[index,'SUP_B'] =  df8.loc[index,'SUP_B'].replace(df8.loc[index,'SUP_B'],df5.loc[j,'SUP_v1'])
        #print(row['Pattern_v3'],':')
        if row['C'] != ' ' or row['C'] != '':
            #print(row['Pattern_v3'],':', rowj['Pattern_v1'])
            if row['C'] == rowj['Pattern_v1']:
                #print(row['DB_3'],'!', rowj['Pattern_v1'])
                df8.loc[index,'SUP_C'] =  df8.loc[index,'SUP_C'].replace(df8.loc[index,'SUP_C'],df5.loc[j,'SUP_v1'])
        #elif row['DB_3'].isnull():
         #   df8.loc[index,'SUP_DB3'] =  df8.loc[index,'SUP_DB3'].replace(df8.loc[index,'SUP_DB3'], '0')
          #  print('vazio')
        if (row['D'] is not None) or (row['D'] != ' ') or (row['D'] != '') :
            if row['D']  == rowj['Pattern_v1']:
                #print(row['Pattern_v3'],'!', rowj['Pattern_v1'])
                df8.loc[index,'SUP_D'] =  df8.loc[index,'SUP_D'].replace(df8.loc[index,'SUP_D'],df5.loc[j,'SUP_v1'])

# %%
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer#|#INElasticsearch#/#SAPAd...       2
# 53463    OUTSAPAdaptiveServer#|#INFirebird#/#SAPAdaptiv...       2
# 53760    OUTSAPAdaptiveServer#|#INMS_SQL_Server#/#SAPAd...       3
# 56930    OUTSAPAdaptiveServer#|#INMariaDB#/#SAPAdaptive...       2
# 60060    OUTSAPAdaptiveServer#|#INCassandra#/#SAPAdapti...       2
# ...                                                    ...      ...
# 2912328          Ehcache#|#INRedis#/#OUTEhcache#|#Redis#|#       2
# 3262618                    MySQL#|#INMariaDB#/#OUTMySQL#|#       2
# 3339896                      MySQL#|#INRedis#/#OUTMySQL#|#       2
# 3339897              MySQL#|#INRedis#/#OUTMySQL#|#Redis#|#       2
# 3374890                         MySQL#|#INH2#/#OUTMySQL#|#       2
#
#                 SID                     A SUP_A AB                B SUP_B BC  \
# 52360        17 129  OUTSAPAdaptiveServer     8  |  INElasticsearch    23  /
# 53463         17 35  OUTSAPAdaptiveServer     8  |       INFirebird     5  /
# 53760     17 35 129  OUTSAPAdaptiveServer     8  |  INMS_SQL_Server    31  /
# 56930        35 129  OUTSAPAdaptiveServer     8  |        INMariaDB    39  /
# 60060        17 129  OUTSAPAdaptiveServer     8  |      INCassandra    17  /
# ...             ...                   ...   ... ..              ...   ... ..
# 2912328       40 93               Ehcache    57  |          INRedis    53  /
# 3262618     140 187                 MySQL   107  |        INMariaDB    39  /
# 3339896       16 96                 MySQL   107  |          INRedis    53  /
# 3339897       16 96                 MySQL   107  |          INRedis    53  /
# 3374890      44 170                 MySQL   107  |             INH2    47  /
#
#                          C SUP_C CD      D SUP_D    DE
# 52360    SAPAdaptiveServer    17  |            0  None
# 53463    SAPAdaptiveServer    17  |            0  None
# 53760    SAPAdaptiveServer    17  |            0  None
# 56930    SAPAdaptiveServer    17  |            0  None
# 60060    SAPAdaptiveServer    17  |            0  None
# ...                    ...   ... ..    ...   ...   ...
# 2912328         OUTEhcache    17  |  Redis    61    |#
# 3262618           OUTMySQL    31  |            0  None
# 3339896           OUTMySQL    31  |            0  None
# 3339897           OUTMySQL    31  |  Redis    61    |#
# 3374890           OUTMySQL    31  |            0  None
#
# [425 rows x 15 columns]

# %%
#df3['Pattern'].replace({r"|": '#|#'}, regex=True, inplace=True)
df8['Pattern'].replace({'#': ''}, regex=True, inplace=True)
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID                     A SUP_A AB                B SUP_B BC  \
# 52360        17 129  OUTSAPAdaptiveServer     8  |  INElasticsearch    23  /
# 53463         17 35  OUTSAPAdaptiveServer     8  |       INFirebird     5  /
# 53760     17 35 129  OUTSAPAdaptiveServer     8  |  INMS_SQL_Server    31  /
# 56930        35 129  OUTSAPAdaptiveServer     8  |        INMariaDB    39  /
# 60060        17 129  OUTSAPAdaptiveServer     8  |      INCassandra    17  /
# ...             ...                   ...   ... ..              ...   ... ..
# 2912328       40 93               Ehcache    57  |          INRedis    53  /
# 3262618     140 187                 MySQL   107  |        INMariaDB    39  /
# 3339896       16 96                 MySQL   107  |          INRedis    53  /
# 3339897       16 96                 MySQL   107  |          INRedis    53  /
# 3374890      44 170                 MySQL   107  |             INH2    47  /
#
#                          C SUP_C CD      D SUP_D    DE
# 52360    SAPAdaptiveServer    17  |            0  None
# 53463    SAPAdaptiveServer    17  |            0  None
# 53760    SAPAdaptiveServer    17  |            0  None
# 56930    SAPAdaptiveServer    17  |            0  None
# 60060    SAPAdaptiveServer    17  |            0  None
# ...                    ...   ... ..    ...   ...   ...
# 2912328         OUTEhcache    17  |  Redis    61    |#
# 3262618           OUTMySQL    31  |            0  None
# 3339896           OUTMySQL    31  |            0  None
# 3339897           OUTMySQL    31  |  Redis    61    |#
# 3374890           OUTMySQL    31  |            0  None
#
# [425 rows x 15 columns]

# %%
#Generating excel with all INIT patterns
df8.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_general_selection8.xlsx",index=True)

# %%
#Primeiro tem que gerar saida com INIT tam 3
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT_TAM1 = SEQ_PATTERNS_DIR + os.sep + 'output_seq_in_out.txt' #add in util.py
df10 = pd.read_csv(SEQ_PATTERNS_DIR + os.sep + 'testes/output_init_tam3_7.txt', sep= '#', header=None) #testes/output_init_tam3_2.txt'#não funcionou sep=" | , #",  engine = "python",
df10
# Out:
#                                                      0       1
# 0                                       INSnowflake |   SUP: 5
# 1                             INSnowflake Snowflake |   SUP: 5
# 2              INSnowflake Snowflake AmazonRedshift |   SUP: 4
# 3                  INSnowflake Snowflake PostgreSQL |   SUP: 5
# 4                   INSnowflake Snowflake Cassandra |   SUP: 2
# ...                                                ...     ...
# 223906             OUTIBM_DB2 | INInformix | SQLite |   SUP: 2
# 223907         OUTIBM_DB2 | INInformix | PostgreSQL |   SUP: 2
# 223908      OUTIBM_DB2 | INInformix | MS_SQL_Server |   SUP: 2
# 223909  OUTIBM_DB2 | INInformix | SAPAdaptiveServer |   SUP: 2
# 223910              OUTIBM_DB2 | INInformix | MySQL |   SUP: 2
#
# [223911 rows x 2 columns]

# %%
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df10.columns = ['Pattern_v2','SUP_v2']
df10.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
#df10.replace({'SID:': ''}, regex=True, inplace=True)
#df5.replace({'|': ''}, regex=True, inplace=True) #ordf['Pattern_v1'] = df['Pattern_v1'].str.replace('|','')
#df10['Pattern_v2'] = df10['Pattern_v2'].str.replace('[ | ]','')
#df4['Pattern_v1'] = df4['Pattern_v1'].str.replace(' ','')
df10
# Out:
#                                             Pattern_v2 SUP_v2
# 0                                       INSnowflake |       5
# 1                             INSnowflake Snowflake |       5
# 2              INSnowflake Snowflake AmazonRedshift |       4
# 3                  INSnowflake Snowflake PostgreSQL |       5
# 4                   INSnowflake Snowflake Cassandra |       2
# ...                                                ...    ...
# 223906             OUTIBM_DB2 | INInformix | SQLite |       2
# 223907         OUTIBM_DB2 | INInformix | PostgreSQL |       2
# 223908      OUTIBM_DB2 | INInformix | MS_SQL_Server |       2
# 223909  OUTIBM_DB2 | INInformix | SAPAdaptiveServer |       2
# 223910              OUTIBM_DB2 | INInformix | MySQL |       2
#
# [223911 rows x 2 columns]

# %%
df10['Pattern_v2'].replace({r"(?<=\w)\s+(?=\w)": '/'}, regex=True, inplace=True)
df10
# Out:
#                                             Pattern_v2 SUP_v2
# 0                                       INSnowflake |       5
# 1                             INSnowflake/Snowflake |       5
# 2              INSnowflake/Snowflake/AmazonRedshift |       4
# 3                  INSnowflake/Snowflake/PostgreSQL |       5
# 4                   INSnowflake/Snowflake/Cassandra |       2
# ...                                                ...    ...
# 223906             OUTIBM_DB2 | INInformix | SQLite |       2
# 223907         OUTIBM_DB2 | INInformix | PostgreSQL |       2
# 223908      OUTIBM_DB2 | INInformix | MS_SQL_Server |       2
# 223909  OUTIBM_DB2 | INInformix | SAPAdaptiveServer |       2
# 223910              OUTIBM_DB2 | INInformix | MySQL |       2
#
# [223911 rows x 2 columns]

# %%
df10['Pattern_v2'] = df10['Pattern_v2'].str.replace(' ','')
df10
# Out:
#                                       Pattern_v2 SUP_v2
# 0                                   INSnowflake|      5
# 1                         INSnowflake/Snowflake|      5
# 2          INSnowflake/Snowflake/AmazonRedshift|      4
# 3              INSnowflake/Snowflake/PostgreSQL|      5
# 4               INSnowflake/Snowflake/Cassandra|      2
# ...                                          ...    ...
# 223906             OUTIBM_DB2|INInformix|SQLite|      2
# 223907         OUTIBM_DB2|INInformix|PostgreSQL|      2
# 223908      OUTIBM_DB2|INInformix|MS_SQL_Server|      2
# 223909  OUTIBM_DB2|INInformix|SAPAdaptiveServer|      2
# 223910              OUTIBM_DB2|INInformix|MySQL|      2
#
# [223911 rows x 2 columns]

# %%
df11 =  df10[(df10['Pattern_v2'].str.startswith('IN') & (~df10['Pattern_v2'].str.startswith('INIT'))) | (df10['Pattern_v2'].str.contains('OUT'))]   #& df3['B'].str.contains('OUT') & ~df3['C'].str.contains('IN'))]
df11
# Out:
#                                       Pattern_v2 SUP_v2
# 0                                   INSnowflake|      5
# 1                         INSnowflake/Snowflake|      5
# 2          INSnowflake/Snowflake/AmazonRedshift|      4
# 3              INSnowflake/Snowflake/PostgreSQL|      5
# 4               INSnowflake/Snowflake/Cassandra|      2
# ...                                          ...    ...
# 223906             OUTIBM_DB2|INInformix|SQLite|      2
# 223907         OUTIBM_DB2|INInformix|PostgreSQL|      2
# 223908      OUTIBM_DB2|INInformix|MS_SQL_Server|      2
# 223909  OUTIBM_DB2|INInformix|SAPAdaptiveServer|      2
# 223910              OUTIBM_DB2|INInformix|MySQL|      2
#
# [93491 rows x 2 columns]

# %%
#df10 = df10[(df10['Pattern_v2'].str.contains('OUT'))]#~df10['Pattern_v2'].str.startswith('OUT')) && (~df10['Pattern_v2'].str.startswith('INIT'))    #& df3['B'].str.contains('OUT') & ~df3['C'].str.contains('IN'))]
df10 =  df10[(df10['Pattern_v2'].str.startswith('IN') & (~df10['Pattern_v2'].str.startswith('INIT'))) | (df10['Pattern_v2'].str.contains('OUT'))] 
df10
# Out:
#                                       Pattern_v2 SUP_v2
# 0                                   INSnowflake|      5
# 1                         INSnowflake/Snowflake|      5
# 2          INSnowflake/Snowflake/AmazonRedshift|      4
# 3              INSnowflake/Snowflake/PostgreSQL|      5
# 4               INSnowflake/Snowflake/Cassandra|      2
# ...                                          ...    ...
# 223906             OUTIBM_DB2|INInformix|SQLite|      2
# 223907         OUTIBM_DB2|INInformix|PostgreSQL|      2
# 223908      OUTIBM_DB2|INInformix|MS_SQL_Server|      2
# 223909  OUTIBM_DB2|INInformix|SAPAdaptiveServer|      2
# 223910              OUTIBM_DB2|INInformix|MySQL|      2
#
# [93491 rows x 2 columns]

# %%
#df10
#Generating excel with selected patterns and support of each DB
df10.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes\output_init_tam3_8_selection8.xlsx",index=True) # "testes\output_init_tam3_2_selection.xlsx
#df12.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes\output_init_tam3_7_selection6.xlsx",index=True) # "testes\output_init_tam3_2_selection.xlsx

# %%
df13 = df8.copy()
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID                     A SUP_A AB                B SUP_B BC  \
# 52360        17 129  OUTSAPAdaptiveServer     8  |  INElasticsearch    23  /
# 53463         17 35  OUTSAPAdaptiveServer     8  |       INFirebird     5  /
# 53760     17 35 129  OUTSAPAdaptiveServer     8  |  INMS_SQL_Server    31  /
# 56930        35 129  OUTSAPAdaptiveServer     8  |        INMariaDB    39  /
# 60060        17 129  OUTSAPAdaptiveServer     8  |      INCassandra    17  /
# ...             ...                   ...   ... ..              ...   ... ..
# 2912328       40 93               Ehcache    57  |          INRedis    53  /
# 3262618     140 187                 MySQL   107  |        INMariaDB    39  /
# 3339896       16 96                 MySQL   107  |          INRedis    53  /
# 3339897       16 96                 MySQL   107  |          INRedis    53  /
# 3374890      44 170                 MySQL   107  |             INH2    47  /
#
#                          C SUP_C CD      D SUP_D    DE
# 52360    SAPAdaptiveServer    17  |            0  None
# 53463    SAPAdaptiveServer    17  |            0  None
# 53760    SAPAdaptiveServer    17  |            0  None
# 56930    SAPAdaptiveServer    17  |            0  None
# 60060    SAPAdaptiveServer    17  |            0  None
# ...                    ...   ... ..    ...   ...   ...
# 2912328         OUTEhcache    17  |  Redis    61    |#
# 3262618           OUTMySQL    31  |            0  None
# 3339896           OUTMySQL    31  |            0  None
# 3339897           OUTMySQL    31  |  Redis    61    |#
# 3374890           OUTMySQL    31  |            0  None
#
# [425 rows x 15 columns]

# %%
df13.insert(3,'SUP_BC','0',False)
df13.insert(4,'SUP_BCD','0',False)
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID SUP_BC SUP_BCD                     A SUP_A AB  \
# 52360        17 129      0       0  OUTSAPAdaptiveServer     8  |
# 53463         17 35      0       0  OUTSAPAdaptiveServer     8  |
# 53760     17 35 129      0       0  OUTSAPAdaptiveServer     8  |
# 56930        35 129      0       0  OUTSAPAdaptiveServer     8  |
# 60060        17 129      0       0  OUTSAPAdaptiveServer     8  |
# ...             ...    ...     ...                   ...   ... ..
# 2912328       40 93      0       0               Ehcache    57  |
# 3262618     140 187      0       0                 MySQL   107  |
# 3339896       16 96      0       0                 MySQL   107  |
# 3339897       16 96      0       0                 MySQL   107  |
# 3374890      44 170      0       0                 MySQL   107  |
#
#                        B SUP_B BC                  C SUP_C CD      D SUP_D  \
# 52360    INElasticsearch    23  /  SAPAdaptiveServer    17  |            0
# 53463         INFirebird     5  /  SAPAdaptiveServer    17  |            0
# 53760    INMS_SQL_Server    31  /  SAPAdaptiveServer    17  |            0
# 56930          INMariaDB    39  /  SAPAdaptiveServer    17  |            0
# 60060        INCassandra    17  /  SAPAdaptiveServer    17  |            0
# ...                  ...   ... ..                ...   ... ..    ...   ...
# 2912328          INRedis    53  /         OUTEhcache    17  |  Redis    61
# 3262618        INMariaDB    39  /           OUTMySQL    31  |            0
# 3339896          INRedis    53  /           OUTMySQL    31  |            0
# 3339897          INRedis    53  /           OUTMySQL    31  |  Redis    61
# 3374890             INH2    47  /           OUTMySQL    31  |            0
#
#            DE
# 52360    None
# 53463    None
# 53760    None
# 56930    None
# 60060    None
# ...       ...
# 2912328    |#
# 3262618  None
# 3339896  None
# 3339897    |#
# 3374890  None
#
# [425 rows x 17 columns]

# %%
#Removing blank spaces
df13['Pattern'] = df13['Pattern'].str.replace(' ','')
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID SUP_BC SUP_BCD                     A SUP_A AB  \
# 52360        17 129      0       0  OUTSAPAdaptiveServer     8  |
# 53463         17 35      0       0  OUTSAPAdaptiveServer     8  |
# 53760     17 35 129      0       0  OUTSAPAdaptiveServer     8  |
# 56930        35 129      0       0  OUTSAPAdaptiveServer     8  |
# 60060        17 129      0       0  OUTSAPAdaptiveServer     8  |
# ...             ...    ...     ...                   ...   ... ..
# 2912328       40 93      0       0               Ehcache    57  |
# 3262618     140 187      0       0                 MySQL   107  |
# 3339896       16 96      0       0                 MySQL   107  |
# 3339897       16 96      0       0                 MySQL   107  |
# 3374890      44 170      0       0                 MySQL   107  |
#
#                        B SUP_B BC                  C SUP_C CD      D SUP_D  \
# 52360    INElasticsearch    23  /  SAPAdaptiveServer    17  |            0
# 53463         INFirebird     5  /  SAPAdaptiveServer    17  |            0
# 53760    INMS_SQL_Server    31  /  SAPAdaptiveServer    17  |            0
# 56930          INMariaDB    39  /  SAPAdaptiveServer    17  |            0
# 60060        INCassandra    17  /  SAPAdaptiveServer    17  |            0
# ...                  ...   ... ..                ...   ... ..    ...   ...
# 2912328          INRedis    53  /         OUTEhcache    17  |  Redis    61
# 3262618        INMariaDB    39  /           OUTMySQL    31  |            0
# 3339896          INRedis    53  /           OUTMySQL    31  |            0
# 3339897          INRedis    53  /           OUTMySQL    31  |  Redis    61
# 3374890             INH2    47  /           OUTMySQL    31  |            0
#
#            DE
# 52360    None
# 53463    None
# 53760    None
# 56930    None
# 60060    None
# ...       ...
# 2912328    |#
# 3262618  None
# 3339896  None
# 3339897    |#
# 3374890  None
#
# [425 rows x 17 columns]

# %%
##Removing blank spaces in collumn C
df13['D'] = df13['D'].str.replace(' ','')
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID SUP_BC SUP_BCD                     A SUP_A AB  \
# 52360        17 129      0       0  OUTSAPAdaptiveServer     8  |
# 53463         17 35      0       0  OUTSAPAdaptiveServer     8  |
# 53760     17 35 129      0       0  OUTSAPAdaptiveServer     8  |
# 56930        35 129      0       0  OUTSAPAdaptiveServer     8  |
# 60060        17 129      0       0  OUTSAPAdaptiveServer     8  |
# ...             ...    ...     ...                   ...   ... ..
# 2912328       40 93      0       0               Ehcache    57  |
# 3262618     140 187      0       0                 MySQL   107  |
# 3339896       16 96      0       0                 MySQL   107  |
# 3339897       16 96      0       0                 MySQL   107  |
# 3374890      44 170      0       0                 MySQL   107  |
#
#                        B SUP_B BC                  C SUP_C CD      D SUP_D  \
# 52360    INElasticsearch    23  /  SAPAdaptiveServer    17  |            0
# 53463         INFirebird     5  /  SAPAdaptiveServer    17  |            0
# 53760    INMS_SQL_Server    31  /  SAPAdaptiveServer    17  |            0
# 56930          INMariaDB    39  /  SAPAdaptiveServer    17  |            0
# 60060        INCassandra    17  /  SAPAdaptiveServer    17  |            0
# ...                  ...   ... ..                ...   ... ..    ...   ...
# 2912328          INRedis    53  /         OUTEhcache    17  |  Redis    61
# 3262618        INMariaDB    39  /           OUTMySQL    31  |            0
# 3339896          INRedis    53  /           OUTMySQL    31  |            0
# 3339897          INRedis    53  /           OUTMySQL    31  |  Redis    61
# 3374890             INH2    47  /           OUTMySQL    31  |            0
#
#            DE
# 52360    None
# 53463    None
# 53760    None
# 56930    None
# 60060    None
# ...       ...
# 2912328    |#
# 3262618  None
# 3339896  None
# 3339897    |#
# 3374890  None
#
# [425 rows x 17 columns]

# %%
#Converting to string because replace
df13['SUP_BC'] = df13['SUP_BC'].astype(str)
df13['SUP_BCD'] = df13['SUP_BCD'].astype(str)
#To resolve "can only concatenate str (not "NoneType") to str" error after suports iteration 
#df13['D'].replace({'None': ''}, regex=True, inplace=True)
#df13['C'].replace({'None': ''}, regex=True, inplace=True)
#df['COL1'] = ['COL1'].fillna(' ')
#df13
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID SUP_BC SUP_BCD                     A SUP_A AB  \
# 52360        17 129      0       0  OUTSAPAdaptiveServer     8  |
# 53463         17 35      0       0  OUTSAPAdaptiveServer     8  |
# 53760     17 35 129      0       0  OUTSAPAdaptiveServer     8  |
# 56930        35 129      0       0  OUTSAPAdaptiveServer     8  |
# 60060        17 129      0       0  OUTSAPAdaptiveServer     8  |
# ...             ...    ...     ...                   ...   ... ..
# 2912328       40 93      0       0               Ehcache    57  |
# 3262618     140 187      0       0                 MySQL   107  |
# 3339896       16 96      0       0                 MySQL   107  |
# 3339897       16 96      0       0                 MySQL   107  |
# 3374890      44 170      0       0                 MySQL   107  |
#
#                        B SUP_B BC                  C SUP_C CD      D SUP_D  \
# 52360    INElasticsearch    23  /  SAPAdaptiveServer    17  |            0
# 53463         INFirebird     5  /  SAPAdaptiveServer    17  |            0
# 53760    INMS_SQL_Server    31  /  SAPAdaptiveServer    17  |            0
# 56930          INMariaDB    39  /  SAPAdaptiveServer    17  |            0
# 60060        INCassandra    17  /  SAPAdaptiveServer    17  |            0
# ...                  ...   ... ..                ...   ... ..    ...   ...
# 2912328          INRedis    53  /         OUTEhcache    17  |  Redis    61
# 3262618        INMariaDB    39  /           OUTMySQL    31  |            0
# 3339896          INRedis    53  /           OUTMySQL    31  |            0
# 3339897          INRedis    53  /           OUTMySQL    31  |  Redis    61
# 3374890             INH2    47  /           OUTMySQL    31  |            0
#
#            DE
# 52360    None
# 53463    None
# 53760    None
# 56930    None
# 60060    None
# ...       ...
# 2912328    |#
# 3262618  None
# 3339896  None
# 3339897    |#
# 3374890  None
#
# [425 rows x 17 columns]

# %%
#Ajuste lift 2
for index, row in df13.iterrows():   
    for j, rowj in df10.iterrows():
        #if (row['C'] is None) or (row['C'] == ''):#(row['C'] is NoneType):
            #print('entrou1', row['A'], row['B'], row['C'], row['D'])
        if (row['C'] is not None) or (row['C'] != ' ') or (row['C'] != ''): #and ((row['DB_4'] is None) or (row['DB_4'] == ' ') or (row['DB_4'] == '')):
            #print('entrou1')
            #print('entrou1', row['A'], row['B'], row['C'], row['D'])
            if (row['B']+'|'+row['C'])+'|' == rowj['Pattern_v2'] and (row['B']+'|'+row['C']+'|' in row['Pattern']) :
            #df9.loc[index,'LiftA->BC'] = (df9.loc[index,'SUP']/200)/((df9.loc[index,'SUP_DB1']/200)*((df10.loc[,'SUP_v2']/200)
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'|' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'/' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])  
            if (row['B']+'|'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'/' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])  
        if (row['D'] is not None) or (row['D'] != ' ') or (row['D'] != ''):
            #print('entrou2')
            if (row['B']+'|'+row['C']+'|'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'|'+row['D']+'|' in row['Pattern']):
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'|'+row['D']+'|' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'|'+row['C']+'/'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'/'+row['D']+'|' in row['Pattern']):
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'/'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'/'+row['D']+'|' in row['Pattern']):
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
#135m 59s-exec in 22out2022

# %%
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID SUP_BC SUP_BCD                     A SUP_A AB  \
# 52360        17 129      6       0  OUTSAPAdaptiveServer     8  |
# 53463         17 35      3       0  OUTSAPAdaptiveServer     8  |
# 53760     17 35 129     11       0  OUTSAPAdaptiveServer     8  |
# 56930        35 129     10       0  OUTSAPAdaptiveServer     8  |
# 60060        17 129      4       0  OUTSAPAdaptiveServer     8  |
# ...             ...    ...     ...                   ...   ... ..
# 2912328       40 93      2       2               Ehcache    57  |
# 3262618     140 187      2       0                 MySQL   107  |
# 3339896       16 96      2       0                 MySQL   107  |
# 3339897       16 96      2       2                 MySQL   107  |
# 3374890      44 170      2       0                 MySQL   107  |
#
#                        B SUP_B BC                  C SUP_C CD      D SUP_D  \
# 52360    INElasticsearch    23  /  SAPAdaptiveServer    17  |            0
# 53463         INFirebird     5  /  SAPAdaptiveServer    17  |            0
# 53760    INMS_SQL_Server    31  /  SAPAdaptiveServer    17  |            0
# 56930          INMariaDB    39  /  SAPAdaptiveServer    17  |            0
# 60060        INCassandra    17  /  SAPAdaptiveServer    17  |            0
# ...                  ...   ... ..                ...   ... ..    ...   ...
# 2912328          INRedis    53  /         OUTEhcache    17  |  Redis    61
# 3262618        INMariaDB    39  /           OUTMySQL    31  |            0
# 3339896          INRedis    53  /           OUTMySQL    31  |            0
# 3339897          INRedis    53  /           OUTMySQL    31  |  Redis    61
# 3374890             INH2    47  /           OUTMySQL    31  |            0
#
#            DE
# 52360    None
# 53463    None
# 53760    None
# 56930    None
# 60060    None
# ...       ...
# 2912328    |#
# 3262618  None
# 3339896  None
# 3339897    |#
# 3374890  None
#
# [425 rows x 17 columns]

# %%
df13.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_initin_selection8_2.xlsx",index=True) #testes/pattern_supABCD_initin_selection2.xlsx"
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...       2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...       2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...       3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|       2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...       2
# ...                                                    ...      ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|       2
# 3262618                          MySQL|INMariaDB/OUTMySQL|       2
# 3339896                            MySQL|INRedis/OUTMySQL|       2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|       2
# 3374890                               MySQL|INH2/OUTMySQL|       2
#
#                 SID SUP_BC SUP_BCD                     A SUP_A AB  \
# 52360        17 129      6       0  OUTSAPAdaptiveServer     8  |
# 53463         17 35      3       0  OUTSAPAdaptiveServer     8  |
# 53760     17 35 129     11       0  OUTSAPAdaptiveServer     8  |
# 56930        35 129     10       0  OUTSAPAdaptiveServer     8  |
# 60060        17 129      4       0  OUTSAPAdaptiveServer     8  |
# ...             ...    ...     ...                   ...   ... ..
# 2912328       40 93      2       2               Ehcache    57  |
# 3262618     140 187      2       0                 MySQL   107  |
# 3339896       16 96      2       0                 MySQL   107  |
# 3339897       16 96      2       2                 MySQL   107  |
# 3374890      44 170      2       0                 MySQL   107  |
#
#                        B SUP_B BC                  C SUP_C CD      D SUP_D  \
# 52360    INElasticsearch    23  /  SAPAdaptiveServer    17  |            0
# 53463         INFirebird     5  /  SAPAdaptiveServer    17  |            0
# 53760    INMS_SQL_Server    31  /  SAPAdaptiveServer    17  |            0
# 56930          INMariaDB    39  /  SAPAdaptiveServer    17  |            0
# 60060        INCassandra    17  /  SAPAdaptiveServer    17  |            0
# ...                  ...   ... ..                ...   ... ..    ...   ...
# 2912328          INRedis    53  /         OUTEhcache    17  |  Redis    61
# 3262618        INMariaDB    39  /           OUTMySQL    31  |            0
# 3339896          INRedis    53  /           OUTMySQL    31  |            0
# 3339897          INRedis    53  /           OUTMySQL    31  |  Redis    61
# 3374890             INH2    47  /           OUTMySQL    31  |            0
#
#            DE
# 52360    None
# 53463    None
# 53760    None
# 56930    None
# 60060    None
# ...       ...
# 2912328    |#
# 3262618  None
# 3339896  None
# 3339897    |#
# 3374890  None
#
# [425 rows x 17 columns]

# %% [markdown]
# Calculateding confidence and lift to each pattern generated.

# %%
#Converting to integer
df13['SUP_A'] = df13['SUP_A'].astype(int)
df13['SUP_B'] = df13['SUP_B'].astype(int)
df13['SUP_C'] = df13['SUP_C'].astype(int)
df13['SUP_D'] = df13['SUP_D'].astype(int)
df13['SUP_BC'] = df13['SUP_BC'].astype(int)
df13['SUP_BCD'] = df13['SUP_BCD'].astype(int)
df13['SUP_ABCD'] = df13['SUP_ABCD'].astype(int)

# %%
#Inserting collums to confidence measure
df13.insert(7,'ConfA->_BCD','0',False) 
df13.insert(11,'ConfB->A_CD','0',False)
df13.insert(15,'ConfC->AB_D','0',False)
df13.insert(19,'ConfD->ABC_','0',False)
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...         2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...         2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...         3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|         2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...         2
# ...                                                    ...       ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|         2
# 3262618                          MySQL|INMariaDB/OUTMySQL|         2
# 3339896                            MySQL|INRedis/OUTMySQL|         2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|         2
# 3374890                               MySQL|INH2/OUTMySQL|         2
#
#                 SID  SUP_BC  SUP_BCD                     A  SUP_A ConfA->_BCD  \
# 52360        17 129       6        0  OUTSAPAdaptiveServer      8           0
# 53463         17 35       3        0  OUTSAPAdaptiveServer      8           0
# 53760     17 35 129      11        0  OUTSAPAdaptiveServer      8           0
# 56930        35 129      10        0  OUTSAPAdaptiveServer      8           0
# 60060        17 129       4        0  OUTSAPAdaptiveServer      8           0
# ...             ...     ...      ...                   ...    ...         ...
# 2912328       40 93       2        2               Ehcache     57           0
# 3262618     140 187       2        0                 MySQL    107           0
# 3339896       16 96       2        0                 MySQL    107           0
# 3339897       16 96       2        2                 MySQL    107           0
# 3374890      44 170       2        0                 MySQL    107           0
#
#         AB                B  ...  ConfB->A_CD BC                  C SUP_C  \
# 52360    |  INElasticsearch  ...            0  /  SAPAdaptiveServer    17
# 53463    |       INFirebird  ...            0  /  SAPAdaptiveServer    17
# 53760    |  INMS_SQL_Server  ...            0  /  SAPAdaptiveServer    17
# 56930    |        INMariaDB  ...            0  /  SAPAdaptiveServer    17
# 60060    |      INCassandra  ...            0  /  SAPAdaptiveServer    17
# ...     ..              ...  ...          ... ..                ...   ...
# 2912328  |          INRedis  ...            0  /         OUTEhcache    17
# 3262618  |        INMariaDB  ...            0  /           OUTMySQL    31
# 3339896  |          INRedis  ...            0  /           OUTMySQL    31
# 3339897  |          INRedis  ...            0  /           OUTMySQL    31
# 3374890  |             INH2  ...            0  /           OUTMySQL    31
#
#          ConfC->AB_D CD      D SUP_D  ConfD->ABC_    DE
# 52360              0  |            0            0  None
# 53463              0  |            0            0  None
# 53760              0  |            0            0  None
# 56930              0  |            0            0  None
# 60060              0  |            0            0  None
# ...              ... ..    ...   ...          ...   ...
# 2912328            0  |  Redis    61            0    |#
# 3262618            0  |            0            0  None
# 3339896            0  |            0            0  None
# 3339897            0  |  Redis    61            0    |#
# 3374890            0  |            0            0  None
#
# [425 rows x 21 columns]

# %%
#Converting to integer
df13['ConfA->_BCD'] = df13['ConfA->_BCD'].astype(int)
df13['ConfB->A_CD'] = df13['ConfB->A_CD'].astype(int)
df13['ConfC->AB_D'] = df13['ConfC->AB_D'].astype(int)
df13['ConfD->ABC_'] = df13['ConfD->ABC_'].astype(int)
#df13['SUP_ABCD'] = df13['SUP_ABCD'].astype(int)

# %%
df13['ConfA->_BCD'] = (df13['SUP_ABCD'])/df13['SUP_A']
df13['ConfB->A_CD'] = (df13['SUP_ABCD'])/df13['SUP_B']
df13['ConfC->AB_D'] = (df13['SUP_ABCD'])/df13['SUP_C']
df13['ConfD->ABC_'] = (df13['SUP_ABCD'])/df13['SUP_D']
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...         2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...         2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...         3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|         2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...         2
# ...                                                    ...       ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|         2
# 3262618                          MySQL|INMariaDB/OUTMySQL|         2
# 3339896                            MySQL|INRedis/OUTMySQL|         2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|         2
# 3374890                               MySQL|INH2/OUTMySQL|         2
#
#                 SID  SUP_BC  SUP_BCD                     A  SUP_A  \
# 52360        17 129       6        0  OUTSAPAdaptiveServer      8
# 53463         17 35       3        0  OUTSAPAdaptiveServer      8
# 53760     17 35 129      11        0  OUTSAPAdaptiveServer      8
# 56930        35 129      10        0  OUTSAPAdaptiveServer      8
# 60060        17 129       4        0  OUTSAPAdaptiveServer      8
# ...             ...     ...      ...                   ...    ...
# 2912328       40 93       2        2               Ehcache     57
# 3262618     140 187       2        0                 MySQL    107
# 3339896       16 96       2        0                 MySQL    107
# 3339897       16 96       2        2                 MySQL    107
# 3374890      44 170       2        0                 MySQL    107
#
#          ConfA->_BCD AB                B  ...  ConfB->A_CD  BC  \
# 52360       0.250000  |  INElasticsearch  ...     0.086957   /
# 53463       0.250000  |       INFirebird  ...     0.400000   /
# 53760       0.375000  |  INMS_SQL_Server  ...     0.096774   /
# 56930       0.250000  |        INMariaDB  ...     0.051282   /
# 60060       0.250000  |      INCassandra  ...     0.117647   /
# ...              ... ..              ...  ...          ...  ..
# 2912328     0.035088  |          INRedis  ...     0.037736   /
# 3262618     0.018692  |        INMariaDB  ...     0.051282   /
# 3339896     0.018692  |          INRedis  ...     0.037736   /
# 3339897     0.018692  |          INRedis  ...     0.037736   /
# 3374890     0.018692  |             INH2  ...     0.042553   /
#
#                          C SUP_C  ConfC->AB_D  CD      D SUP_D  ConfD->ABC_  \
# 52360    SAPAdaptiveServer    17     0.117647   |            0          inf
# 53463    SAPAdaptiveServer    17     0.117647   |            0          inf
# 53760    SAPAdaptiveServer    17     0.176471   |            0          inf
# 56930    SAPAdaptiveServer    17     0.117647   |            0          inf
# 60060    SAPAdaptiveServer    17     0.117647   |            0          inf
# ...                    ...   ...          ...  ..    ...   ...          ...
# 2912328         OUTEhcache    17     0.117647   |  Redis    61     0.032787
# 3262618           OUTMySQL    31     0.064516   |            0          inf
# 3339896           OUTMySQL    31     0.064516   |            0          inf
# 3339897           OUTMySQL    31     0.064516   |  Redis    61     0.032787
# 3374890           OUTMySQL    31     0.064516   |            0          inf
#
#            DE
# 52360    None
# 53463    None
# 53760    None
# 56930    None
# 60060    None
# ...       ...
# 2912328    |#
# 3262618  None
# 3339896  None
# 3339897    |#
# 3374890  None
#
# [425 rows x 21 columns]

# %% [markdown]
# Calculeting the lift measures

# %%
df13['LiftA->B'] = (df13['SUP_ABCD']/200)/((df13['SUP_A']/200)*(df13['SUP_B']/200))
df13['LiftA->BC'] = (df13['SUP_ABCD']/200)/((df13['SUP_A']/200)*(df13['SUP_BC']/200))
df13['LiftA->BCD'] = (df13['SUP_ABCD']/200)/((df13['SUP_A']/200)*(df13['SUP_BCD']/200))
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 52360    OUTSAPAdaptiveServer|INElasticsearch/SAPAdapti...         2
# 53463    OUTSAPAdaptiveServer|INFirebird/SAPAdaptiveSer...         2
# 53760    OUTSAPAdaptiveServer|INMS_SQL_Server/SAPAdapti...         3
# 56930    OUTSAPAdaptiveServer|INMariaDB/SAPAdaptiveServer|         2
# 60060    OUTSAPAdaptiveServer|INCassandra/SAPAdaptiveSe...         2
# ...                                                    ...       ...
# 2912328                  Ehcache|INRedis/OUTEhcache|Redis|         2
# 3262618                          MySQL|INMariaDB/OUTMySQL|         2
# 3339896                            MySQL|INRedis/OUTMySQL|         2
# 3339897                      MySQL|INRedis/OUTMySQL|Redis|         2
# 3374890                               MySQL|INH2/OUTMySQL|         2
#
#                 SID  SUP_BC  SUP_BCD                     A  SUP_A  \
# 52360        17 129       6        0  OUTSAPAdaptiveServer      8
# 53463         17 35       3        0  OUTSAPAdaptiveServer      8
# 53760     17 35 129      11        0  OUTSAPAdaptiveServer      8
# 56930        35 129      10        0  OUTSAPAdaptiveServer      8
# 60060        17 129       4        0  OUTSAPAdaptiveServer      8
# ...             ...     ...      ...                   ...    ...
# 2912328       40 93       2        2               Ehcache     57
# 3262618     140 187       2        0                 MySQL    107
# 3339896       16 96       2        0                 MySQL    107
# 3339897       16 96       2        2                 MySQL    107
# 3374890      44 170       2        0                 MySQL    107
#
#          ConfA->_BCD AB                B  ...  SUP_C  ConfC->AB_D CD      D  \
# 52360       0.250000  |  INElasticsearch  ...     17     0.117647  |
# 53463       0.250000  |       INFirebird  ...     17     0.117647  |
# 53760       0.375000  |  INMS_SQL_Server  ...     17     0.176471  |
# 56930       0.250000  |        INMariaDB  ...     17     0.117647  |
# 60060       0.250000  |      INCassandra  ...     17     0.117647  |
# ...              ... ..              ...  ...    ...          ... ..    ...
# 2912328     0.035088  |          INRedis  ...     17     0.117647  |  Redis
# 3262618     0.018692  |        INMariaDB  ...     31     0.064516  |
# 3339896     0.018692  |          INRedis  ...     31     0.064516  |
# 3339897     0.018692  |          INRedis  ...     31     0.064516  |  Redis
# 3374890     0.018692  |             INH2  ...     31     0.064516  |
#
#          SUP_D  ConfD->ABC_    DE   LiftA->B  LiftA->BC  LiftA->BCD
# 52360        0          inf  None   2.173913   8.333333         inf
# 53463        0          inf  None  10.000000  16.666667         inf
# 53760        0          inf  None   2.419355   6.818182         inf
# 56930        0          inf  None   1.282051   5.000000         inf
# 60060        0          inf  None   2.941176  12.500000         inf
# ...        ...          ...   ...        ...        ...         ...
# 2912328     61     0.032787    |#   0.132406   3.508772    3.508772
# 3262618      0          inf  None   0.095854   1.869159         inf
# 3339896      0          inf  None   0.070534   1.869159         inf
# 3339897     61     0.032787    |#   0.070534   1.869159    1.869159
# 3374890      0          inf  None   0.079539   1.869159         inf
#
# [425 rows x 24 columns]

# %%
df13.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_initin_selection_measure8.xlsx",index=True) #"testes/pattern_supABCD_initin_selection_measure2.xlsx

# %%
df14 = df13[(df13['SUP_BC']== 0)]
df14
# Out:
# Empty DataFrame
# Columns: [Pattern, SUP_ABCD, SID, SUP_BC, SUP_BCD, A, SUP_A, ConfA->_BCD, AB, B, SUP_B, ConfB->A_CD, BC, C, SUP_C, ConfC->AB_D, CD, D, SUP_D, ConfD->ABC_, DE, LiftA->B, LiftA->BC, LiftA->BCD]
# Index: []
#
# [0 rows x 24 columns]

# %% [markdown]
# Filtering the patterns (X->INY, OUTX -> Y) with higher supports

# %%
df14 = df13[(df13['BC'] == '/') & (~df3['A'].str.startswith('OUT')) & (~df3['A'].str.startswith('IN'))  & 
((df13['A'].str.extract(r'IN(.*)', expand=False) != df13['B'].str.extract(r'OUT(.*)', expand=False)) &
(df13['A'].str.extract(r'OUT(.*)', expand=False) != df13['B'].str.extract(r'IN(.*)', expand=False)))]#(df14.apply(lambda x: str(x['A']) not in str(x['B']),axis=1))]
#select_pattern4 =df4[(df4['A'].str.extract(r'IN(.*)', expand=False) == df4['C'].str.extract(r'OUT(.*)'
df_sup_order = df14.sort_values(by='SUP_ABCD', ascending=False)
df_sup_order
# Out:
# /home/raquelmax/.virtualenvs/db-mining-pBhgzAM8/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                Pattern  SUP_ABCD          SID  \
# 2517472            PostgreSQL|INMariaDB/OUTPostgreSQL|         3   37 122 140
# 2517475    PostgreSQL|INMariaDB/OUTPostgreSQL|MariaDB|         3   37 122 140
# 680440                             H2|INMariaDB/OUTH2|         2      116 140
# 680441                     H2|INMariaDB/OUTH2|MariaDB|         2      116 140
# 2587795             PostgreSQL|INOracle/OUTPostgreSQL|         2       37 136
# 2587798      PostgreSQL|INOracle/OUTPostgreSQL|Oracle|         2       37 136
# 2856871        MS_SQL_Server|INRedis/OUTMS_SQL_Server|         2        16 93
# 2856872  MS_SQL_Server|INRedis/OUTMS_SQL_Server|Redis|         2        16 93
# 2912325                    Ehcache|INRedis/OUTEhcache|         2        40 93
# 2912328              Ehcache|INRedis/OUTEhcache|Redis|         2        40 93
# 3262618                      MySQL|INMariaDB/OUTMySQL|         2      140 187
# 3339896                        MySQL|INRedis/OUTMySQL|         2        16 96
# 3339897                  MySQL|INRedis/OUTMySQL|Redis|         2        16 96
# 3374890                           MySQL|INH2/OUTMySQL|         2       44 170
#
#          SUP_BC  SUP_BCD              A  SUP_A  ConfA->_BCD AB          B  \
# 2517472       3        0     PostgreSQL     74     0.040541  |  INMariaDB
# 2517475       3        3     PostgreSQL     74     0.040541  |  INMariaDB
# 680440        2        0             H2     74     0.027027  |  INMariaDB
# 680441        2        2             H2     74     0.027027  |  INMariaDB
# 2587795       2        0     PostgreSQL     74     0.027027  |   INOracle
# 2587798       2        2     PostgreSQL     74     0.027027  |   INOracle
# 2856871       2        0  MS_SQL_Server     37     0.054054  |    INRedis
# 2856872       2        2  MS_SQL_Server     37     0.054054  |    INRedis
# 2912325       2        0        Ehcache     57     0.035088  |    INRedis
# 2912328       2        2        Ehcache     57     0.035088  |    INRedis
# 3262618       2        0          MySQL    107     0.018692  |  INMariaDB
# 3339896       2        0          MySQL    107     0.018692  |    INRedis
# 3339897       2        2          MySQL    107     0.018692  |    INRedis
# 3374890       2        0          MySQL    107     0.018692  |       INH2
#
#          ...  SUP_C  ConfC->AB_D CD        D  SUP_D  ConfD->ABC_    DE  \
# 2517472  ...     22     0.136364  |               0          inf  None
# 2517475  ...     22     0.136364  |  MariaDB     42     0.071429    |#
# 680440   ...     23     0.086957  |               0          inf  None
# 680441   ...     23     0.086957  |  MariaDB     42     0.047619    |#
# 2587795  ...     22     0.090909  |               0          inf  None
# 2587798  ...     22     0.090909  |   Oracle     66     0.030303    |#
# 2856871  ...     11     0.181818  |               0          inf  None
# 2856872  ...     11     0.181818  |    Redis     61     0.032787    |#
# 2912325  ...     17     0.117647  |               0          inf  None
# 2912328  ...     17     0.117647  |    Redis     61     0.032787    |#
# 3262618  ...     31     0.064516  |               0          inf  None
# 3339896  ...     31     0.064516  |               0          inf  None
# 3339897  ...     31     0.064516  |    Redis     61     0.032787    |#
# 3374890  ...     31     0.064516  |               0          inf  None
#
#          LiftA->B  LiftA->BC  LiftA->BCD
# 2517472  0.207900   2.702703         inf
# 2517475  0.207900   2.702703    2.702703
# 680440   0.138600   2.702703         inf
# 680441   0.138600   2.702703    2.702703
# 2587795  0.125707   2.702703         inf
# 2587798  0.125707   2.702703    2.702703
# 2856871  0.203978   5.405405         inf
# 2856872  0.203978   5.405405    5.405405
# 2912325  0.132406   3.508772         inf
# 2912328  0.132406   3.508772    3.508772
# 3262618  0.095854   1.869159         inf
# 3339896  0.070534   1.869159         inf
# 3339897  0.070534   1.869159    1.869159
# 3374890  0.079539   1.869159         inf
#
# [14 rows x 24 columns]

# %% [markdown]
# Filtering the patterns (X->INY, OUTX -> Y) with higher lifts

# %%
#df14 = df13[(df13['BC'] == '/') & (~df3['A'].str.startswith('OUT')) & (~df3['A'].str.startswith('IN'))  & 
#((df13['A'].str.extract(r'IN(.*)', expand=False) != df13['B'].str.extract(r'OUT(.*)', expand=False)) &
#(df13['A'].str.extract(r'OUT(.*)', expand=False) != df13['B'].str.extract(r'IN(.*)', expand=False)))]#(df14.apply(lambda x: str(x['A']) not in str(x['B']),axis=1))]
#select_pattern4 =df4[(df4['A'].str.extract(r'IN(.*)', expand=False) == df4['C'].str.extract(r'OUT(.*)'
df_lift_order = df14.sort_values(by= ['LiftA->BCD','LiftA->BC','LiftA->B'], ascending=False)
df_lift_order
# Out:
#                                                Pattern  SUP_ABCD          SID  \
# 2856871        MS_SQL_Server|INRedis/OUTMS_SQL_Server|         2        16 93
# 2912325                    Ehcache|INRedis/OUTEhcache|         2        40 93
# 2517472            PostgreSQL|INMariaDB/OUTPostgreSQL|         3   37 122 140
# 680440                             H2|INMariaDB/OUTH2|         2      116 140
# 2587795             PostgreSQL|INOracle/OUTPostgreSQL|         2       37 136
# 3262618                      MySQL|INMariaDB/OUTMySQL|         2      140 187
# 3374890                           MySQL|INH2/OUTMySQL|         2       44 170
# 3339896                        MySQL|INRedis/OUTMySQL|         2        16 96
# 2856872  MS_SQL_Server|INRedis/OUTMS_SQL_Server|Redis|         2        16 93
# 2912328              Ehcache|INRedis/OUTEhcache|Redis|         2        40 93
# 2517475    PostgreSQL|INMariaDB/OUTPostgreSQL|MariaDB|         3   37 122 140
# 680441                     H2|INMariaDB/OUTH2|MariaDB|         2      116 140
# 2587798      PostgreSQL|INOracle/OUTPostgreSQL|Oracle|         2       37 136
# 3339897                  MySQL|INRedis/OUTMySQL|Redis|         2        16 96
#
#          SUP_BC  SUP_BCD              A  SUP_A  ConfA->_BCD AB          B  \
# 2856871       2        0  MS_SQL_Server     37     0.054054  |    INRedis
# 2912325       2        0        Ehcache     57     0.035088  |    INRedis
# 2517472       3        0     PostgreSQL     74     0.040541  |  INMariaDB
# 680440        2        0             H2     74     0.027027  |  INMariaDB
# 2587795       2        0     PostgreSQL     74     0.027027  |   INOracle
# 3262618       2        0          MySQL    107     0.018692  |  INMariaDB
# 3374890       2        0          MySQL    107     0.018692  |       INH2
# 3339896       2        0          MySQL    107     0.018692  |    INRedis
# 2856872       2        2  MS_SQL_Server     37     0.054054  |    INRedis
# 2912328       2        2        Ehcache     57     0.035088  |    INRedis
# 2517475       3        3     PostgreSQL     74     0.040541  |  INMariaDB
# 680441        2        2             H2     74     0.027027  |  INMariaDB
# 2587798       2        2     PostgreSQL     74     0.027027  |   INOracle
# 3339897       2        2          MySQL    107     0.018692  |    INRedis
#
#          ...  SUP_C  ConfC->AB_D CD        D  SUP_D  ConfD->ABC_    DE  \
# 2856871  ...     11     0.181818  |               0          inf  None
# 2912325  ...     17     0.117647  |               0          inf  None
# 2517472  ...     22     0.136364  |               0          inf  None
# 680440   ...     23     0.086957  |               0          inf  None
# 2587795  ...     22     0.090909  |               0          inf  None
# 3262618  ...     31     0.064516  |               0          inf  None
# 3374890  ...     31     0.064516  |               0          inf  None
# 3339896  ...     31     0.064516  |               0          inf  None
# 2856872  ...     11     0.181818  |    Redis     61     0.032787    |#
# 2912328  ...     17     0.117647  |    Redis     61     0.032787    |#
# 2517475  ...     22     0.136364  |  MariaDB     42     0.071429    |#
# 680441   ...     23     0.086957  |  MariaDB     42     0.047619    |#
# 2587798  ...     22     0.090909  |   Oracle     66     0.030303    |#
# 3339897  ...     31     0.064516  |    Redis     61     0.032787    |#
#
#          LiftA->B  LiftA->BC  LiftA->BCD
# 2856871  0.203978   5.405405         inf
# 2912325  0.132406   3.508772         inf
# 2517472  0.207900   2.702703         inf
# 680440   0.138600   2.702703         inf
# 2587795  0.125707   2.702703         inf
# 3262618  0.095854   1.869159         inf
# 3374890  0.079539   1.869159         inf
# 3339896  0.070534   1.869159         inf
# 2856872  0.203978   5.405405    5.405405
# 2912328  0.132406   3.508772    3.508772
# 2517475  0.207900   2.702703    2.702703
# 680441   0.138600   2.702703    2.702703
# 2587798  0.125707   2.702703    2.702703
# 3339897  0.070534   1.869159    1.869159
#
# [14 rows x 24 columns]

# %%
df_lift_order2 = df14.sort_values(by= ['LiftA->BC','LiftA->BCD','LiftA->B'], ascending=False) #'
df_lift_order2
# Out:
#                                                Pattern  SUP_ABCD          SID  \
# 2856871        MS_SQL_Server|INRedis/OUTMS_SQL_Server|         2        16 93
# 2856872  MS_SQL_Server|INRedis/OUTMS_SQL_Server|Redis|         2        16 93
# 2912325                    Ehcache|INRedis/OUTEhcache|         2        40 93
# 2912328              Ehcache|INRedis/OUTEhcache|Redis|         2        40 93
# 2517472            PostgreSQL|INMariaDB/OUTPostgreSQL|         3   37 122 140
# 2517475    PostgreSQL|INMariaDB/OUTPostgreSQL|MariaDB|         3   37 122 140
# 680440                             H2|INMariaDB/OUTH2|         2      116 140
# 2587795             PostgreSQL|INOracle/OUTPostgreSQL|         2       37 136
# 680441                     H2|INMariaDB/OUTH2|MariaDB|         2      116 140
# 2587798      PostgreSQL|INOracle/OUTPostgreSQL|Oracle|         2       37 136
# 3262618                      MySQL|INMariaDB/OUTMySQL|         2      140 187
# 3374890                           MySQL|INH2/OUTMySQL|         2       44 170
# 3339896                        MySQL|INRedis/OUTMySQL|         2        16 96
# 3339897                  MySQL|INRedis/OUTMySQL|Redis|         2        16 96
#
#          SUP_BC  SUP_BCD              A  SUP_A  ConfA->_BCD AB          B  \
# 2856871       2        0  MS_SQL_Server     37     0.054054  |    INRedis
# 2856872       2        2  MS_SQL_Server     37     0.054054  |    INRedis
# 2912325       2        0        Ehcache     57     0.035088  |    INRedis
# 2912328       2        2        Ehcache     57     0.035088  |    INRedis
# 2517472       3        0     PostgreSQL     74     0.040541  |  INMariaDB
# 2517475       3        3     PostgreSQL     74     0.040541  |  INMariaDB
# 680440        2        0             H2     74     0.027027  |  INMariaDB
# 2587795       2        0     PostgreSQL     74     0.027027  |   INOracle
# 680441        2        2             H2     74     0.027027  |  INMariaDB
# 2587798       2        2     PostgreSQL     74     0.027027  |   INOracle
# 3262618       2        0          MySQL    107     0.018692  |  INMariaDB
# 3374890       2        0          MySQL    107     0.018692  |       INH2
# 3339896       2        0          MySQL    107     0.018692  |    INRedis
# 3339897       2        2          MySQL    107     0.018692  |    INRedis
#
#          ...  SUP_C  ConfC->AB_D CD        D  SUP_D  ConfD->ABC_    DE  \
# 2856871  ...     11     0.181818  |               0          inf  None
# 2856872  ...     11     0.181818  |    Redis     61     0.032787    |#
# 2912325  ...     17     0.117647  |               0          inf  None
# 2912328  ...     17     0.117647  |    Redis     61     0.032787    |#
# 2517472  ...     22     0.136364  |               0          inf  None
# 2517475  ...     22     0.136364  |  MariaDB     42     0.071429    |#
# 680440   ...     23     0.086957  |               0          inf  None
# 2587795  ...     22     0.090909  |               0          inf  None
# 680441   ...     23     0.086957  |  MariaDB     42     0.047619    |#
# 2587798  ...     22     0.090909  |   Oracle     66     0.030303    |#
# 3262618  ...     31     0.064516  |               0          inf  None
# 3374890  ...     31     0.064516  |               0          inf  None
# 3339896  ...     31     0.064516  |               0          inf  None
# 3339897  ...     31     0.064516  |    Redis     61     0.032787    |#
#
#          LiftA->B  LiftA->BC  LiftA->BCD
# 2856871  0.203978   5.405405         inf
# 2856872  0.203978   5.405405    5.405405
# 2912325  0.132406   3.508772         inf
# 2912328  0.132406   3.508772    3.508772
# 2517472  0.207900   2.702703         inf
# 2517475  0.207900   2.702703    2.702703
# 680440   0.138600   2.702703         inf
# 2587795  0.125707   2.702703         inf
# 680441   0.138600   2.702703    2.702703
# 2587798  0.125707   2.702703    2.702703
# 3262618  0.095854   1.869159         inf
# 3374890  0.079539   1.869159         inf
# 3339896  0.070534   1.869159         inf
# 3339897  0.070534   1.869159    1.869159
#
# [14 rows x 24 columns]

# %%
df_lift_order2.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/filter_pattern__X_INYOUTX_Y.xlsx",index=True)

# %% [markdown]
# Filtering the patterns (X->INY -> OUTX, Y) with higher supports

# %%
df15 = df13[(df13['CD'] == '/') & (~df3['A'].str.startswith('OUT')) & (~df3['A'].str.startswith('IN'))  & 
((df13['A'].str.extract(r'IN(.*)', expand=False) != df13['B'].str.extract(r'OUT(.*)', expand=False)) &
(df13['A'].str.extract(r'OUT(.*)', expand=False) != df13['B'].str.extract(r'IN(.*)', expand=False)))]#(df14.apply(lambda x: str(x['A']) not in str(x['B']),axis=1))]
#select_pattern4 =df4[(df4['A'].str.extract(r'IN(.*)', expand=False) == df4['C'].str.extract(r'OUT(.*)'
df_sup_order2 = df15.sort_values(by='SUP_ABCD', ascending=False)
df_sup_order2
# Out:
# /home/raquelmax/.virtualenvs/db-mining-pBhgzAM8/lib/python3.7/site-packages/ipykernel_launcher.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                                    Pattern  SUP_ABCD  \
# 1468965                    Oracle|INMySQL|OUTOracle/MySQL|         3
# 372430   GoogleCloudDatastore|INMySQL|OUTGoogleCloudDat...         2
# 740197                             H2|INMySQL|OUTH2/MySQL|         2
# 1459677                  Oracle|INSQLite|OUTOracle/SQLite|         2
# 1479666          Oracle|INPostgreSQL|OUTOracle/PostgreSQL|         2
# 2600576            PostgreSQL|INMySQL|OUTPostgreSQL/MySQL|         2
# 2606689    PostgreSQL|INCassandra|OUTPostgreSQL/Cassandra|         2
#
#                 SID  SUP_BC  SUP_BCD                     A  SUP_A  \
# 1468965   2 136 195       7        5                Oracle     66
# 372430       24 122       4        4  GoogleCloudDatastore     22
# 740197      122 172       7        5                    H2     74
# 1459677     184 195       4        3                Oracle     66
# 1479666       2 136       6        3                Oracle     66
# 2600576      24 115       6        5            PostgreSQL     74
# 2606689      28 140       3        2            PostgreSQL     74
#
#          ConfA->_BCD AB             B  ...  SUP_C  ConfC->AB_D CD           D  \
# 1468965     0.045455  |       INMySQL  ...     18     0.166667  /       MySQL
# 372430      0.090909  |       INMySQL  ...     10     0.200000  /       MySQL
# 740197      0.027027  |       INMySQL  ...     23     0.086957  /       MySQL
# 1459677     0.030303  |      INSQLite  ...     18     0.111111  /      SQLite
# 1479666     0.030303  |  INPostgreSQL  ...     18     0.111111  /  PostgreSQL
# 2600576     0.027027  |       INMySQL  ...     22     0.090909  /       MySQL
# 2606689     0.027027  |   INCassandra  ...     22     0.090909  /   Cassandra
#
#          SUP_D  ConfD->ABC_  DE  LiftA->B  LiftA->BC  LiftA->BCD
# 1468965    107     0.028037  |#  0.165289   1.298701    1.818182
# 372430     107     0.018692  |#  0.330579   4.545455    4.545455
# 740197     107     0.018692  |#  0.098280   0.772201    1.081081
# 1459677     36     0.055556  |#  0.263505   1.515152    2.020202
# 1479666     74     0.027027  |#  0.137741   1.010101    2.020202
# 2600576    107     0.018692  |#  0.098280   0.900901    1.081081
# 2606689     18     0.111111  |#  0.317965   1.801802    2.702703
#
# [7 rows x 24 columns]

# %% [markdown]
# Filtering patterns (X->INY -> OUTX, Y) with higher lifts

# %%
df_lift_order3 = df15.sort_values(by= ['LiftA->BCD','LiftA->BC','LiftA->B'], ascending=False)
df_lift_order3
# Out:
#                                                    Pattern  SUP_ABCD  \
# 372430   GoogleCloudDatastore|INMySQL|OUTGoogleCloudDat...         2
# 2606689    PostgreSQL|INCassandra|OUTPostgreSQL/Cassandra|         2
# 1459677                  Oracle|INSQLite|OUTOracle/SQLite|         2
# 1479666          Oracle|INPostgreSQL|OUTOracle/PostgreSQL|         2
# 1468965                    Oracle|INMySQL|OUTOracle/MySQL|         3
# 2600576            PostgreSQL|INMySQL|OUTPostgreSQL/MySQL|         2
# 740197                             H2|INMySQL|OUTH2/MySQL|         2
#
#                 SID  SUP_BC  SUP_BCD                     A  SUP_A  \
# 372430       24 122       4        4  GoogleCloudDatastore     22
# 2606689      28 140       3        2            PostgreSQL     74
# 1459677     184 195       4        3                Oracle     66
# 1479666       2 136       6        3                Oracle     66
# 1468965   2 136 195       7        5                Oracle     66
# 2600576      24 115       6        5            PostgreSQL     74
# 740197      122 172       7        5                    H2     74
#
#          ConfA->_BCD AB             B  ...  SUP_C  ConfC->AB_D CD           D  \
# 372430      0.090909  |       INMySQL  ...     10     0.200000  /       MySQL
# 2606689     0.027027  |   INCassandra  ...     22     0.090909  /   Cassandra
# 1459677     0.030303  |      INSQLite  ...     18     0.111111  /      SQLite
# 1479666     0.030303  |  INPostgreSQL  ...     18     0.111111  /  PostgreSQL
# 1468965     0.045455  |       INMySQL  ...     18     0.166667  /       MySQL
# 2600576     0.027027  |       INMySQL  ...     22     0.090909  /       MySQL
# 740197      0.027027  |       INMySQL  ...     23     0.086957  /       MySQL
#
#          SUP_D  ConfD->ABC_  DE  LiftA->B  LiftA->BC  LiftA->BCD
# 372430     107     0.018692  |#  0.330579   4.545455    4.545455
# 2606689     18     0.111111  |#  0.317965   1.801802    2.702703
# 1459677     36     0.055556  |#  0.263505   1.515152    2.020202
# 1479666     74     0.027027  |#  0.137741   1.010101    2.020202
# 1468965    107     0.028037  |#  0.165289   1.298701    1.818182
# 2600576    107     0.018692  |#  0.098280   0.900901    1.081081
# 740197     107     0.018692  |#  0.098280   0.772201    1.081081
#
# [7 rows x 24 columns]

# %%
df_lift_order4 = df15.sort_values(by= ['LiftA->BC','LiftA->BCD','LiftA->B'], ascending=False) #'
df_lift_order4
# Out:
#                                                    Pattern  SUP_ABCD  \
# 372430   GoogleCloudDatastore|INMySQL|OUTGoogleCloudDat...         2
# 2606689    PostgreSQL|INCassandra|OUTPostgreSQL/Cassandra|         2
# 1459677                  Oracle|INSQLite|OUTOracle/SQLite|         2
# 1468965                    Oracle|INMySQL|OUTOracle/MySQL|         3
# 1479666          Oracle|INPostgreSQL|OUTOracle/PostgreSQL|         2
# 2600576            PostgreSQL|INMySQL|OUTPostgreSQL/MySQL|         2
# 740197                             H2|INMySQL|OUTH2/MySQL|         2
#
#                 SID  SUP_BC  SUP_BCD                     A  SUP_A  \
# 372430       24 122       4        4  GoogleCloudDatastore     22
# 2606689      28 140       3        2            PostgreSQL     74
# 1459677     184 195       4        3                Oracle     66
# 1468965   2 136 195       7        5                Oracle     66
# 1479666       2 136       6        3                Oracle     66
# 2600576      24 115       6        5            PostgreSQL     74
# 740197      122 172       7        5                    H2     74
#
#          ConfA->_BCD AB             B  ...  SUP_C  ConfC->AB_D CD           D  \
# 372430      0.090909  |       INMySQL  ...     10     0.200000  /       MySQL
# 2606689     0.027027  |   INCassandra  ...     22     0.090909  /   Cassandra
# 1459677     0.030303  |      INSQLite  ...     18     0.111111  /      SQLite
# 1468965     0.045455  |       INMySQL  ...     18     0.166667  /       MySQL
# 1479666     0.030303  |  INPostgreSQL  ...     18     0.111111  /  PostgreSQL
# 2600576     0.027027  |       INMySQL  ...     22     0.090909  /       MySQL
# 740197      0.027027  |       INMySQL  ...     23     0.086957  /       MySQL
#
#          SUP_D  ConfD->ABC_  DE  LiftA->B  LiftA->BC  LiftA->BCD
# 372430     107     0.018692  |#  0.330579   4.545455    4.545455
# 2606689     18     0.111111  |#  0.317965   1.801802    2.702703
# 1459677     36     0.055556  |#  0.263505   1.515152    2.020202
# 1468965    107     0.028037  |#  0.165289   1.298701    1.818182
# 1479666     74     0.027027  |#  0.137741   1.010101    2.020202
# 2600576    107     0.018692  |#  0.098280   0.900901    1.081081
# 740197     107     0.018692  |#  0.098280   0.772201    1.081081
#
# [7 rows x 24 columns]

# %%
df_lift_order4.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/filter_pattern__X_INY_OUTXY.xlsx",index=True)
