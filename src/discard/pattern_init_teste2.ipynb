# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
from util import SEQ_PATTERNS_DIR

# %%
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT = SEQ_PATTERNS_DIR + os.sep + 'output_init_tam4_SSID.txt' #add in util.py output_init_tam4_sid_2
HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT = SEQ_PATTERNS_DIR + os.sep + 'testes/output_init_tam4_sid_3.txt' #'testes/output_init_tam4_sid_2.txt'
df = pd.read_csv(HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT, sep= '#', header=None) #não funcionou sep=" | , #",  engine = "python",
df
# Out:
#                                                          0        1  \
# 0                                           INSnowflake |   SUP: 5
# 1                                 INSnowflake Snowflake |   SUP: 5
# 2                  INSnowflake Snowflake AmazonRedshift |   SUP: 4
# 3        INSnowflake Snowflake AmazonRedshift PostgreSQ...  SUP: 4
# 4        INSnowflake Snowflake AmazonRedshift MS_SQL_Se...  SUP: 4
# ...                                                    ...      ...
# 1615590             OUTIBM_DB2 | INH2 | MySQL | MariaDB |   SUP: 3
# 1615591              OUTIBM_DB2 | INH2 | MySQL | Oracle |   SUP: 3
# 1615592          OUTIBM_DB2 | INH2 | MySQL | PostgreSQL |   SUP: 3
# 1615593       OUTIBM_DB2 | INH2 | MySQL | MS_SQL_Server |   SUP: 3
# 1615594               OUTIBM_DB2 | INH2 | MySQL | MySQL |   SUP: 3
#
#                             2
# 0        SID: 17 21 57 75 149
# 1        SID: 17 21 57 75 149
# 2           SID: 17 57 75 149
# 3           SID: 17 57 75 149
# 4           SID: 17 57 75 149
# ...                       ...
# 1615590        SID: 17 35 182
# 1615591        SID: 17 35 182
# 1615592        SID: 17 35 182
# 1615593        SID: 17 35 182
# 1615594        SID: 17 35 182
#
# [1615595 rows x 3 columns]

# %%
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df.columns = ['Pattern','SUP_ABCD','SID']
df.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
df.replace({'SID:': ''}, regex=True, inplace=True) #ordf['SID'] = df['SID'].str.replace('SID:','')
df
# Out:
#                                                    Pattern SUP_ABCD  \
# 0                                           INSnowflake |        5
# 1                                 INSnowflake Snowflake |        5
# 2                  INSnowflake Snowflake AmazonRedshift |        4
# 3        INSnowflake Snowflake AmazonRedshift PostgreSQ...       4
# 4        INSnowflake Snowflake AmazonRedshift MS_SQL_Se...       4
# ...                                                    ...      ...
# 1615590             OUTIBM_DB2 | INH2 | MySQL | MariaDB |        3
# 1615591              OUTIBM_DB2 | INH2 | MySQL | Oracle |        3
# 1615592          OUTIBM_DB2 | INH2 | MySQL | PostgreSQL |        3
# 1615593       OUTIBM_DB2 | INH2 | MySQL | MS_SQL_Server |        3
# 1615594               OUTIBM_DB2 | INH2 | MySQL | MySQL |        3
#
#                       SID
# 0         17 21 57 75 149
# 1         17 21 57 75 149
# 2            17 57 75 149
# 3            17 57 75 149
# 4            17 57 75 149
# ...                   ...
# 1615590         17 35 182
# 1615591         17 35 182
# 1615592         17 35 182
# 1615593         17 35 182
# 1615594         17 35 182
#
# [1615595 rows x 3 columns]

# %%
df2 = df.copy()

# %%
select_pattern = df2[(df2['Pattern'].str.contains('INIT') | df2['Pattern'].str.contains('IN') & df2['Pattern'].str.contains('OUT'))]
select_pattern
# Out:
#                                                    Pattern SUP_ABCD  \
# 17168                                 INITElasticsearch |        7
# 17169                       INITElasticsearch INITMySQL |        4
# 17170                 INITElasticsearch INITMySQL MySQL |        4
# 17171         INITElasticsearch INITMySQL MySQL | Redis |        4
# 17172    INITElasticsearch INITMySQL MySQL | Elasticsea...       4
# ...                                                    ...      ...
# 1615590             OUTIBM_DB2 | INH2 | MySQL | MariaDB |        3
# 1615591              OUTIBM_DB2 | INH2 | MySQL | Oracle |        3
# 1615592          OUTIBM_DB2 | INH2 | MySQL | PostgreSQL |        3
# 1615593       OUTIBM_DB2 | INH2 | MySQL | MS_SQL_Server |        3
# 1615594               OUTIBM_DB2 | INH2 | MySQL | MySQL |        3
#
#                             SID
# 17168     14 17 47 62 67 76 132
# 17169              14 17 62 132
# 17170              14 17 62 132
# 17171              14 17 62 132
# 17172              14 17 62 132
# ...                         ...
# 1615590               17 35 182
# 1615591               17 35 182
# 1615592               17 35 182
# 1615593               17 35 182
# 1615594               17 35 182
#
# [383738 rows x 3 columns]

# %%
df3 = select_pattern.copy()
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 17168                                 INITElasticsearch |        7
# 17169                       INITElasticsearch INITMySQL |        4
# 17170                 INITElasticsearch INITMySQL MySQL |        4
# 17171         INITElasticsearch INITMySQL MySQL | Redis |        4
# 17172    INITElasticsearch INITMySQL MySQL | Elasticsea...       4
# ...                                                    ...      ...
# 1615590             OUTIBM_DB2 | INH2 | MySQL | MariaDB |        3
# 1615591              OUTIBM_DB2 | INH2 | MySQL | Oracle |        3
# 1615592          OUTIBM_DB2 | INH2 | MySQL | PostgreSQL |        3
# 1615593       OUTIBM_DB2 | INH2 | MySQL | MS_SQL_Server |        3
# 1615594               OUTIBM_DB2 | INH2 | MySQL | MySQL |        3
#
#                             SID
# 17168     14 17 47 62 67 76 132
# 17169              14 17 62 132
# 17170              14 17 62 132
# 17171              14 17 62 132
# 17172              14 17 62 132
# ...                         ...
# 1615590               17 35 182
# 1615591               17 35 182
# 1615592               17 35 182
# 1615593               17 35 182
# 1615594               17 35 182
#
# [383738 rows x 3 columns]

# %%
df3['Pattern'].replace({r"(?<=\w)\s+(?=\w)": '/'}, regex=True, inplace=True)
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 17168                                 INITElasticsearch |        7
# 17169                       INITElasticsearch/INITMySQL |        4
# 17170                 INITElasticsearch/INITMySQL/MySQL |        4
# 17171         INITElasticsearch/INITMySQL/MySQL | Redis |        4
# 17172    INITElasticsearch/INITMySQL/MySQL | Elasticsea...       4
# ...                                                    ...      ...
# 1615590             OUTIBM_DB2 | INH2 | MySQL | MariaDB |        3
# 1615591              OUTIBM_DB2 | INH2 | MySQL | Oracle |        3
# 1615592          OUTIBM_DB2 | INH2 | MySQL | PostgreSQL |        3
# 1615593       OUTIBM_DB2 | INH2 | MySQL | MS_SQL_Server |        3
# 1615594               OUTIBM_DB2 | INH2 | MySQL | MySQL |        3
#
#                             SID
# 17168     14 17 47 62 67 76 132
# 17169              14 17 62 132
# 17170              14 17 62 132
# 17171              14 17 62 132
# 17172              14 17 62 132
# ...                         ...
# 1615590               17 35 182
# 1615591               17 35 182
# 1615592               17 35 182
# 1615593               17 35 182
# 1615594               17 35 182
#
# [383738 rows x 3 columns]

# %%
df4 = df3[(df3['Pattern'].str.contains('/'))]

df4
# Out:
#                                                    Pattern SUP_ABCD  \
# 20595                 INITElasticsearch/INElasticsearch |        7
# 20596         INITElasticsearch/INElasticsearch/INMySQL |        4
# 20597    INITElasticsearch/INElasticsearch/INMySQL/MySQ...       4
# 20598    INITElasticsearch/INElasticsearch/INMySQL | Re...       4
# 20599    INITElasticsearch/INElasticsearch/INMySQL | El...       4
# ...                                                    ...      ...
# 2276110        OUTIBM_DB2 | INH2 | Oracle/MS_SQL_Server |        3
# 2276111                OUTIBM_DB2 | INH2 | Oracle/MySQL |        3
# 2276118            OUTIBM_DB2 | INH2 | PostgreSQL/MySQL |        3
# 2276119    OUTIBM_DB2 | INH2 | PostgreSQL/MS_SQL_Server |        3
# 2276126         OUTIBM_DB2 | INH2 | MS_SQL_Server/MySQL |        3
#
#                             SID
# 20595     14 17 47 62 67 76 132
# 20596              14 17 62 132
# 20597              14 17 62 132
# 20598              14 17 62 132
# 20599              14 17 62 132
# ...                         ...
# 2276110               17 35 182
# 2276111               17 35 182
# 2276118               17 35 182
# 2276119               17 35 182
# 2276126               17 35 182
#
# [432164 rows x 3 columns]

# %% [markdown]
# Separating the BDs found in each pattern

# %%
df3[['A','B','C','D']] = df3['Pattern'].str.split("[|/]", expand=True, n=3)
#df2['Pattern'].str.split('|', expand=True)
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 17168                                 INITElasticsearch |        7
# 17169                       INITElasticsearch/INITMySQL |        4
# 17170                 INITElasticsearch/INITMySQL/MySQL |        4
# 17171         INITElasticsearch/INITMySQL/MySQL | Redis |        4
# 17172    INITElasticsearch/INITMySQL/MySQL | Elasticsea...       4
# ...                                                    ...      ...
# 1615590             OUTIBM_DB2 | INH2 | MySQL | MariaDB |        3
# 1615591              OUTIBM_DB2 | INH2 | MySQL | Oracle |        3
# 1615592          OUTIBM_DB2 | INH2 | MySQL | PostgreSQL |        3
# 1615593       OUTIBM_DB2 | INH2 | MySQL | MS_SQL_Server |        3
# 1615594               OUTIBM_DB2 | INH2 | MySQL | MySQL |        3
#
#                             SID                   A           B        C  \
# 17168     14 17 47 62 67 76 132  INITElasticsearch                  None
# 17169              14 17 62 132   INITElasticsearch  INITMySQL
# 17170              14 17 62 132   INITElasticsearch   INITMySQL   MySQL
# 17171              14 17 62 132   INITElasticsearch   INITMySQL   MySQL
# 17172              14 17 62 132   INITElasticsearch   INITMySQL   MySQL
# ...                         ...                 ...         ...      ...
# 1615590               17 35 182         OUTIBM_DB2        INH2    MySQL
# 1615591               17 35 182         OUTIBM_DB2        INH2    MySQL
# 1615592               17 35 182         OUTIBM_DB2        INH2    MySQL
# 1615593               17 35 182         OUTIBM_DB2        INH2    MySQL
# 1615594               17 35 182         OUTIBM_DB2        INH2    MySQL
#
#                          D
# 17168                 None
# 17169                 None
# 17170
# 17171             Redis |
# 17172     Elasticsearch |
# ...                    ...
# 1615590         MariaDB |
# 1615591          Oracle |
# 1615592      PostgreSQL |
# 1615593   MS_SQL_Server |
# 1615594           MySQL |
#
# [383738 rows x 7 columns]

# %% [markdown]
# Removing the spaces and | of DB columns

# %%
df3['A'].replace({'[ |]':''},regex=True, inplace=True)
df3['B'].replace({'[ |]':''},regex=True, inplace=True)
df3['C'].replace({'[ |]':''},regex=True, inplace=True)
df3['D'].replace({'[ |]':''},regex=True, inplace=True)
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 17168                                 INITElasticsearch |        7
# 17169                       INITElasticsearch/INITMySQL |        4
# 17170                 INITElasticsearch/INITMySQL/MySQL |        4
# 17171         INITElasticsearch/INITMySQL/MySQL | Redis |        4
# 17172    INITElasticsearch/INITMySQL/MySQL | Elasticsea...       4
# ...                                                    ...      ...
# 1615590             OUTIBM_DB2 | INH2 | MySQL | MariaDB |        3
# 1615591              OUTIBM_DB2 | INH2 | MySQL | Oracle |        3
# 1615592          OUTIBM_DB2 | INH2 | MySQL | PostgreSQL |        3
# 1615593       OUTIBM_DB2 | INH2 | MySQL | MS_SQL_Server |        3
# 1615594               OUTIBM_DB2 | INH2 | MySQL | MySQL |        3
#
#                             SID                  A          B      C  \
# 17168     14 17 47 62 67 76 132  INITElasticsearch              None
# 17169              14 17 62 132  INITElasticsearch  INITMySQL
# 17170              14 17 62 132  INITElasticsearch  INITMySQL  MySQL
# 17171              14 17 62 132  INITElasticsearch  INITMySQL  MySQL
# 17172              14 17 62 132  INITElasticsearch  INITMySQL  MySQL
# ...                         ...                ...        ...    ...
# 1615590               17 35 182         OUTIBM_DB2       INH2  MySQL
# 1615591               17 35 182         OUTIBM_DB2       INH2  MySQL
# 1615592               17 35 182         OUTIBM_DB2       INH2  MySQL
# 1615593               17 35 182         OUTIBM_DB2       INH2  MySQL
# 1615594               17 35 182         OUTIBM_DB2       INH2  MySQL
#
#                      D
# 17168             None
# 17169             None
# 17170
# 17171            Redis
# 17172    Elasticsearch
# ...                ...
# 1615590        MariaDB
# 1615591         Oracle
# 1615592     PostgreSQL
# 1615593  MS_SQL_Server
# 1615594          MySQL
#
# [383738 rows x 7 columns]

# %%
df4 = df3[(df3['C'].str.contains('OUT') & df3['B'].str.contains('IN'))] #& (df13['A'].str.contains(str(df13['C'].values)))] #& df13['Pattern'].str.contains('OUT'))]
df4
# Out:
#                                                    Pattern SUP_ABCD  \
# 46436      INITMySQL | INMariaDB | OUTSAPAdaptiveServer |        3
# 46469                 INITMySQL | INMariaDB | OUTOracle |        4
# 46470       INITMySQL | INMariaDB | OUTOracle | MariaDB |        3
# 46471        INITMySQL | INMariaDB | OUTOracle | SQLite |        3
# 46472    INITMySQL | INMariaDB | OUTOracle | PostgreSQL |        3
# ...                                                    ...      ...
# 1559972  INITSQLite/INITMySQL | OUTMS_SQL_Server | INIB...       3
# 1569979                  INITSQLite | INMariaDB | OUTH2 |        3
# 1569980        INITSQLite | INMariaDB | OUTH2 | MariaDB |        3
# 1569981         INITSQLite | INMariaDB | OUTH2 | SQLite |        3
# 1569982          INITSQLite | INMariaDB | OUTH2 | MySQL |        3
#
#                     SID           A          B                     C  \
# 46436           9 17 35   INITMySQL  INMariaDB  OUTSAPAdaptiveServer
# 46469     17 35 110 139   INITMySQL  INMariaDB             OUTOracle
# 46470         17 35 139   INITMySQL  INMariaDB             OUTOracle
# 46471         17 35 139   INITMySQL  INMariaDB             OUTOracle
# 46472         17 35 139   INITMySQL  INMariaDB             OUTOracle
# ...                 ...         ...        ...                   ...
# 1559972        17 35 61  INITSQLite  INITMySQL      OUTMS_SQL_Server
# 1569979       17 35 123  INITSQLite  INMariaDB                 OUTH2
# 1569980       17 35 123  INITSQLite  INMariaDB                 OUTH2
# 1569981       17 35 123  INITSQLite  INMariaDB                 OUTH2
# 1569982       17 35 123  INITSQLite  INMariaDB                 OUTH2
#
#                   D
# 46436
# 46469
# 46470       MariaDB
# 46471        SQLite
# 46472    PostgreSQL
# ...             ...
# 1559972   INIBM_DB2
# 1569979
# 1569980     MariaDB
# 1569981      SQLite
# 1569982       MySQL
#
# [3097 rows x 7 columns]

# %%
select_pattern2 = df3[(df3.apply(lambda x: str(x['C']) in str(x['A']),axis=1) & (df3['D'].values.astype(str) == ''))]
select_pattern3 = df3[(df3.apply(lambda x: str(x['C']) in str(x['A']),axis=1) & (df3.apply(lambda x: str(x['D']) in str(x['B']),axis=1)))]
df_concat = pd.concat([select_pattern2, select_pattern3]).drop_duplicates()
df_concat
# Out:
#                                                    Pattern SUP_ABCD  \
# 20595                 INITElasticsearch/INElasticsearch |        7
# 20616    INITElasticsearch/INElasticsearch/Elasticsearc...       4
# 20617    INITElasticsearch/INElasticsearch/Elasticsearc...       4
# 20618    INITElasticsearch/INElasticsearch/Elasticsearc...       4
# 20619    INITElasticsearch/INElasticsearch/Elasticsearc...       4
# ...                                                    ...      ...
# 2244979                 INInformix/INITMySQL | Informix |        3
# 2251216                INInformix/INITSQLite | Informix |        3
# 2252090            INInformix/INITPostgreSQL | Informix |        4
# 2254662               INInformix/INITIBM_DB2 | Informix |        3
# 2276051                  OUTIBM_DB2 | INIBM_DB2/IBM_DB2 |        3
#
#                             SID                  A                B  \
# 20595     14 17 47 62 67 76 132  INITElasticsearch  INElasticsearch
# 20616              14 17 62 132  INITElasticsearch  INElasticsearch
# 20617              14 17 62 132  INITElasticsearch  INElasticsearch
# 20618              14 17 62 132  INITElasticsearch  INElasticsearch
# 20619              14 17 62 132  INITElasticsearch  INElasticsearch
# ...                         ...                ...              ...
# 2244979               35 57 149         INInformix        INITMySQL
# 2251216               35 57 149         INInformix       INITSQLite
# 2252090            35 57 84 149         INInformix   INITPostgreSQL
# 2254662               35 57 149         INInformix      INITIBM_DB2
# 2276051               17 35 116         OUTIBM_DB2        INIBM_DB2
#
#                      C          D
# 20595                        None
# 20616    Elasticsearch    INMySQL
# 20617    Elasticsearch  INITMySQL
# 20618    Elasticsearch      MySQL
# 20619    Elasticsearch      Redis
# ...                ...        ...
# 2244979       Informix
# 2251216       Informix
# 2252090       Informix
# 2254662       Informix
# 2276051        IBM_DB2
#
# [37696 rows x 7 columns]

# %%
#teste = df['Item 1'].str.extract('.*d.+ (.*)', expand=False) == df['Item 3'].str.extract('.*d.+ (.*)', expand=False)
#teste = df3['A'].str.extract(r'(IN)', expand=False) 
#select_pattern2 = (df4['C'].values.astype(str) != '') & (df4['D'].values.astype(str) != '')
select_pattern2 =df4[(df4['A'].str.extract(r'INIT(.*)', expand=False) == df4['C'].str.extract(r'OUT(.*)', expand=False)) & (df4['A'].str.extract(r'INIT(.*)', expand=False) != df4['B'].str.extract(r'IN(.*)', expand=False)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))]
select_pattern3 =df4[(df4['A'].str.extract(r'IN(.*)', expand=False) == df4['C'].str.extract(r'OUT(.*)', expand=False)) & (df4['A'].str.extract(r'IN(.*)', expand=False) != df4['B'].str.extract(r'IN(.*)', expand=False)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))]
select_pattern4 =df4[(df4.apply(lambda x: str(x['A']) in str(x['C']),axis=1)) & (df4['A'].str.extract(r'IN(.*)', expand=False) != df4['B'].str.extract(r'IN(.*)', expand=False)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))] #147 padrões
select_pattern5 = df4[(df4.apply(lambda x: str(x['A']) in str(x['C']),axis=1)) & (df4.apply(lambda x: str(x['A']) not in str(x['B']),axis=1)) & (df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))]
#teste2 = ~(df3['C'].values.astype(str) == '') # or ~df3['C'].fillna() ) #& df['C'].str.extract(r'(OUT)', expand=False)
#teste4 = df3[df3['A'].str.split('IN')[1][1]]# == dados['Item 3'].str.split('do ')[1][1]]
#teste4 = df3['A'].str.split("INIT")[0]
#df4['teste5'] = df3['A'].str.split('IN ').apply(lambda x: x[1])

#select_pattern5
df_concat = pd.concat([select_pattern2, select_pattern3,select_pattern4,select_pattern5]).drop_duplicates()
df_concat
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                       INITMySQL | INH2 | OUTMySQL |        3
# 769008                 INITOracle/INITMySQL | OUTOracle |        5
# 780614            INITOracle/INITPostgreSQL | OUTOracle |        4
# 781867               INITOracle/INITEhcache | OUTOracle |        3
# 786290                 INITOracle | INMySQL | OUTOracle |        3
# ...                                                    ...      ...
# 994473           Ehcache/INITMySQL | OUTEhcache | MySQL |        6
# 1040652  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       4
# 1040660  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       3
# 1157867                         MySQL | INH2 | OUTMySQL |        3
# 1422184                            OUTH2 | INH2 | OUTH2 |        3
#
#                            SID                  A               B  \
# 88032               44 110 173          INITMySQL            INH2
# 769008         0 35 62 110 187         INITOracle       INITMySQL
# 780614             0 35 62 110         INITOracle  INITPostgreSQL
# 781867                2 62 110         INITOracle     INITEhcache
# 786290               2 110 199         INITOracle         INMySQL
# ...                        ...                ...             ...
# 994473    41 44 94 103 110 130            Ehcache       INITMySQL
# 1040652          35 62 130 182  SAPAdaptiveServer       INITMySQL
# 1040660             35 130 182  SAPAdaptiveServer       INITMySQL
# 1157867             44 110 173              MySQL            INH2
# 1422184             24 110 173              OUTH2            INH2
#
#                             C      D
# 88032                OUTMySQL
# 769008              OUTOracle
# 780614              OUTOracle
# 781867              OUTOracle
# 786290              OUTOracle
# ...                       ...    ...
# 994473             OUTEhcache  MySQL
# 1040652  OUTSAPAdaptiveServer
# 1040660  OUTSAPAdaptiveServer  MySQL
# 1157867              OUTMySQL
# 1422184                 OUTH2
#
# [130 rows x 7 columns]

# %%
df_concat.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_initin_select_2.xlsx",index=True)

# %% [markdown]
# Loading the size 1 sequential patterns

# %%
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT_TAM1 = SEQ_PATTERNS_DIR + os.sep + 'output_seq_in_out.txt' #add in util.py
df5 = pd.read_csv(SEQ_PATTERNS_DIR + os.sep + 'testes/output_init_tam1_3.txt', sep= '#', header=None) #não funcionou sep=" | , #",  engine = "python",
df5
# Out:
#                            0        1
# 0             INSnowflake |    SUP: 5
# 1               Memcached |    SUP: 8
# 2       INITElasticsearch |    SUP: 7
# 3    OUTSAPAdaptiveServer |    SUP: 8
# 4                    Hive |   SUP: 11
# ..                       ...      ...
# 120            OUTMariaDB |    SUP: 8
# 121            INInformix |    SUP: 6
# 122          INClickHouse |    SUP: 7
# 123               INNeo4j |    SUP: 4
# 124            OUTIBM_DB2 |    SUP: 7
#
# [125 rows x 2 columns]

# %%
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df5.columns = ['Pattern_v1','SUP_v1',]
df5.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
#df5.replace({'|': ''}, regex=True, inplace=True) #ordf['Pattern_v1'] = df['Pattern_v1'].str.replace('|','')
df5['Pattern_v1'] = df5['Pattern_v1'].str.replace('[ | ]','')
#df4['Pattern_v1'] = df4['Pattern_v1'].str.replace(' ','')
df5
# Out:
#                Pattern_v1 SUP_v1
# 0             INSnowflake      5
# 1               Memcached      8
# 2       INITElasticsearch      7
# 3    OUTSAPAdaptiveServer      8
# 4                    Hive     11
# ..                    ...    ...
# 120            OUTMariaDB      8
# 121            INInformix      6
# 122          INClickHouse      7
# 123               INNeo4j      4
# 124            OUTIBM_DB2      7
#
# [125 rows x 2 columns]

# %%
df6 = df_concat.copy()

# %% [markdown]
# Inserting the columns that will contain the support of each DB

# %%
df6.insert(4,"SUP_A",'0',False)#True)
df6.insert(6,"SUP_B",'0',False)#True)
df6.insert(8,"SUP_C",'0',False)#True)
df6.insert(10,"SUP_D",'0',False)#True)
df6
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                       INITMySQL | INH2 | OUTMySQL |        3
# 769008                 INITOracle/INITMySQL | OUTOracle |        5
# 780614            INITOracle/INITPostgreSQL | OUTOracle |        4
# 781867               INITOracle/INITEhcache | OUTOracle |        3
# 786290                 INITOracle | INMySQL | OUTOracle |        3
# ...                                                    ...      ...
# 994473           Ehcache/INITMySQL | OUTEhcache | MySQL |        6
# 1040652  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       4
# 1040660  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       3
# 1157867                         MySQL | INH2 | OUTMySQL |        3
# 1422184                            OUTH2 | INH2 | OUTH2 |        3
#
#                            SID                  A SUP_A               B SUP_B  \
# 88032               44 110 173          INITMySQL     0            INH2     0
# 769008         0 35 62 110 187         INITOracle     0       INITMySQL     0
# 780614             0 35 62 110         INITOracle     0  INITPostgreSQL     0
# 781867                2 62 110         INITOracle     0     INITEhcache     0
# 786290               2 110 199         INITOracle     0         INMySQL     0
# ...                        ...                ...   ...             ...   ...
# 994473    41 44 94 103 110 130            Ehcache     0       INITMySQL     0
# 1040652          35 62 130 182  SAPAdaptiveServer     0       INITMySQL     0
# 1040660             35 130 182  SAPAdaptiveServer     0       INITMySQL     0
# 1157867             44 110 173              MySQL     0            INH2     0
# 1422184             24 110 173              OUTH2     0            INH2     0
#
#                             C SUP_C      D SUP_D
# 88032                OUTMySQL     0            0
# 769008              OUTOracle     0            0
# 780614              OUTOracle     0            0
# 781867              OUTOracle     0            0
# 786290              OUTOracle     0            0
# ...                       ...   ...    ...   ...
# 994473             OUTEhcache     0  MySQL     0
# 1040652  OUTSAPAdaptiveServer     0            0
# 1040660  OUTSAPAdaptiveServer     0  MySQL     0
# 1157867              OUTMySQL     0            0
# 1422184                 OUTH2     0            0
#
# [130 rows x 11 columns]

# %%
df8 = df6.copy()
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                       INITMySQL | INH2 | OUTMySQL |        3
# 769008                 INITOracle/INITMySQL | OUTOracle |        5
# 780614            INITOracle/INITPostgreSQL | OUTOracle |        4
# 781867               INITOracle/INITEhcache | OUTOracle |        3
# 786290                 INITOracle | INMySQL | OUTOracle |        3
# ...                                                    ...      ...
# 994473           Ehcache/INITMySQL | OUTEhcache | MySQL |        6
# 1040652  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       4
# 1040660  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       3
# 1157867                         MySQL | INH2 | OUTMySQL |        3
# 1422184                            OUTH2 | INH2 | OUTH2 |        3
#
#                            SID                  A SUP_A               B SUP_B  \
# 88032               44 110 173          INITMySQL     0            INH2     0
# 769008         0 35 62 110 187         INITOracle     0       INITMySQL     0
# 780614             0 35 62 110         INITOracle     0  INITPostgreSQL     0
# 781867                2 62 110         INITOracle     0     INITEhcache     0
# 786290               2 110 199         INITOracle     0         INMySQL     0
# ...                        ...                ...   ...             ...   ...
# 994473    41 44 94 103 110 130            Ehcache     0       INITMySQL     0
# 1040652          35 62 130 182  SAPAdaptiveServer     0       INITMySQL     0
# 1040660             35 130 182  SAPAdaptiveServer     0       INITMySQL     0
# 1157867             44 110 173              MySQL     0            INH2     0
# 1422184             24 110 173              OUTH2     0            INH2     0
#
#                             C SUP_C      D SUP_D
# 88032                OUTMySQL     0            0
# 769008              OUTOracle     0            0
# 780614              OUTOracle     0            0
# 781867              OUTOracle     0            0
# 786290              OUTOracle     0            0
# ...                       ...   ...    ...   ...
# 994473             OUTEhcache     0  MySQL     0
# 1040652  OUTSAPAdaptiveServer     0            0
# 1040660  OUTSAPAdaptiveServer     0  MySQL     0
# 1157867              OUTMySQL     0            0
# 1422184                 OUTH2     0            0
#
# [130 rows x 11 columns]

# %% [markdown]
# Iteration to fetch the support corresponding to each DB

# %%
for index, row in df8.iterrows():
    for j, rowj in df5.iterrows():
        if row['A'] == rowj['Pattern_v1']:
            df8.loc[index,'SUP_A'] =  df8.loc[index,'SUP_A'].replace(df8.loc[index,'SUP_A'],df5.loc[j,'SUP_v1'])
            #print(row['DB_1'],':', rowj['Pattern_v1'])
        if row['B'] == rowj['Pattern_v1']:
         #   print(row['Pattern_v2'], rowj['Pattern_v1'])
            df8.loc[index,'SUP_B'] =  df8.loc[index,'SUP_B'].replace(df8.loc[index,'SUP_B'],df5.loc[j,'SUP_v1'])
        #print(row['Pattern_v3'],':')
        if row['C'] != ' ' or row['C'] != '':
            #print(row['Pattern_v3'],':', rowj['Pattern_v1'])
            if row['C'] == rowj['Pattern_v1']:
                #print(row['DB_3'],'!', rowj['Pattern_v1'])
                df8.loc[index,'SUP_C'] =  df8.loc[index,'SUP_C'].replace(df8.loc[index,'SUP_C'],df5.loc[j,'SUP_v1'])
        #elif row['DB_3'].isnull():
         #   df8.loc[index,'SUP_DB3'] =  df8.loc[index,'SUP_DB3'].replace(df8.loc[index,'SUP_DB3'], '0')
          #  print('vazio')
        if (row['D'] is not None) or (row['D'] != ' ') or (row['D'] != '') :
            if row['D']  == rowj['Pattern_v1']:
                #print(row['Pattern_v3'],'!', rowj['Pattern_v1'])
                df8.loc[index,'SUP_D'] =  df8.loc[index,'SUP_D'].replace(df8.loc[index,'SUP_D'],df5.loc[j,'SUP_v1'])

# %%
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                       INITMySQL | INH2 | OUTMySQL |        3
# 769008                 INITOracle/INITMySQL | OUTOracle |        5
# 780614            INITOracle/INITPostgreSQL | OUTOracle |        4
# 781867               INITOracle/INITEhcache | OUTOracle |        3
# 786290                 INITOracle | INMySQL | OUTOracle |        3
# ...                                                    ...      ...
# 994473           Ehcache/INITMySQL | OUTEhcache | MySQL |        6
# 1040652  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       4
# 1040660  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       3
# 1157867                         MySQL | INH2 | OUTMySQL |        3
# 1422184                            OUTH2 | INH2 | OUTH2 |        3
#
#                            SID                  A SUP_A               B SUP_B  \
# 88032               44 110 173          INITMySQL    82            INH2    41
# 769008         0 35 62 110 187         INITOracle    35       INITMySQL    82
# 780614             0 35 62 110         INITOracle    35  INITPostgreSQL    37
# 781867                2 62 110         INITOracle    35     INITEhcache    32
# 786290               2 110 199         INITOracle    35         INMySQL    38
# ...                        ...                ...   ...             ...   ...
# 994473    41 44 94 103 110 130            Ehcache    57       INITMySQL    82
# 1040652          35 62 130 182  SAPAdaptiveServer    17       INITMySQL    82
# 1040660             35 130 182  SAPAdaptiveServer    17       INITMySQL    82
# 1157867             44 110 173              MySQL   110            INH2    41
# 1422184             24 110 173              OUTH2    24            INH2    41
#
#                             C SUP_C      D SUP_D
# 88032                OUTMySQL    33            0
# 769008              OUTOracle    18            0
# 780614              OUTOracle    18            0
# 781867              OUTOracle    18            0
# 786290              OUTOracle    18            0
# ...                       ...   ...    ...   ...
# 994473             OUTEhcache    17  MySQL   110
# 1040652  OUTSAPAdaptiveServer     8            0
# 1040660  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867              OUTMySQL    33            0
# 1422184                 OUTH2    24            0
#
# [130 rows x 11 columns]

# %%
#Generating excel with all INIT patterns
df8.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_general_selection2.xlsx",index=True)

# %% [markdown]
# Loading the size 3 sequential patterns

# %%
#Primeiro tem que gerar saida com INIT tam 3
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT_TAM1 = SEQ_PATTERNS_DIR + os.sep + 'output_seq_in_out.txt' #add in util.py
df10 = pd.read_csv(SEQ_PATTERNS_DIR + os.sep + 'testes/output_init_tam3_3.txt', sep= '#', header=None) #testes/output_init_tam3_2.txt'#não funcionou sep=" | , #",  engine = "python",
df10
# Out:
#                                               0       1
# 0                                INSnowflake |   SUP: 5
# 1                      INSnowflake Snowflake |   SUP: 5
# 2       INSnowflake Snowflake AmazonRedshift |   SUP: 4
# 3           INSnowflake Snowflake PostgreSQL |   SUP: 5
# 4        INSnowflake Snowflake MS_SQL_Server |   SUP: 4
# ...                                         ...     ...
# 101121           OUTIBM_DB2 | INH2 | MariaDB |   SUP: 3
# 101122            OUTIBM_DB2 | INH2 | Oracle |   SUP: 3
# 101123        OUTIBM_DB2 | INH2 | PostgreSQL |   SUP: 3
# 101124     OUTIBM_DB2 | INH2 | MS_SQL_Server |   SUP: 3
# 101125             OUTIBM_DB2 | INH2 | MySQL |   SUP: 3
#
# [101126 rows x 2 columns]

# %%
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df10.columns = ['Pattern_v2','SUP_v2']
df10.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
#df10.replace({'SID:': ''}, regex=True, inplace=True)
#df5.replace({'|': ''}, regex=True, inplace=True) #ordf['Pattern_v1'] = df['Pattern_v1'].str.replace('|','')
#df10['Pattern_v2'] = df10['Pattern_v2'].str.replace('[ | ]','')
#df4['Pattern_v1'] = df4['Pattern_v1'].str.replace(' ','')
df10
# Out:
#                                      Pattern_v2 SUP_v2
# 0                                INSnowflake |       5
# 1                      INSnowflake Snowflake |       5
# 2       INSnowflake Snowflake AmazonRedshift |       4
# 3           INSnowflake Snowflake PostgreSQL |       5
# 4        INSnowflake Snowflake MS_SQL_Server |       4
# ...                                         ...    ...
# 101121           OUTIBM_DB2 | INH2 | MariaDB |       3
# 101122            OUTIBM_DB2 | INH2 | Oracle |       3
# 101123        OUTIBM_DB2 | INH2 | PostgreSQL |       3
# 101124     OUTIBM_DB2 | INH2 | MS_SQL_Server |       3
# 101125             OUTIBM_DB2 | INH2 | MySQL |       3
#
# [101126 rows x 2 columns]

# %% [markdown]
# Identifying with "/" the BD clues in the same version

# %%
df10['Pattern_v2'].replace({r"(?<=\w)\s+(?=\w)": '/'}, regex=True, inplace=True)
df10
# Out:
#                                      Pattern_v2 SUP_v2
# 0                                INSnowflake |       5
# 1                      INSnowflake/Snowflake |       5
# 2       INSnowflake/Snowflake/AmazonRedshift |       4
# 3           INSnowflake/Snowflake/PostgreSQL |       5
# 4        INSnowflake/Snowflake/MS_SQL_Server |       4
# ...                                         ...    ...
# 101121           OUTIBM_DB2 | INH2 | MariaDB |       3
# 101122            OUTIBM_DB2 | INH2 | Oracle |       3
# 101123        OUTIBM_DB2 | INH2 | PostgreSQL |       3
# 101124     OUTIBM_DB2 | INH2 | MS_SQL_Server |       3
# 101125             OUTIBM_DB2 | INH2 | MySQL |       3
#
# [101126 rows x 2 columns]

# %% [markdown]
# Removing blank spaces

# %%
df10['Pattern_v2'] = df10['Pattern_v2'].str.replace(' ','')
df10
# Out:
#                                    Pattern_v2 SUP_v2
# 0                                INSnowflake|      5
# 1                      INSnowflake/Snowflake|      5
# 2       INSnowflake/Snowflake/AmazonRedshift|      4
# 3           INSnowflake/Snowflake/PostgreSQL|      5
# 4        INSnowflake/Snowflake/MS_SQL_Server|      4
# ...                                       ...    ...
# 101121               OUTIBM_DB2|INH2|MariaDB|      3
# 101122                OUTIBM_DB2|INH2|Oracle|      3
# 101123            OUTIBM_DB2|INH2|PostgreSQL|      3
# 101124         OUTIBM_DB2|INH2|MS_SQL_Server|      3
# 101125                 OUTIBM_DB2|INH2|MySQL|      3
#
# [101126 rows x 2 columns]

# %% [markdown]
# Filtering only patterns that nit stating with output and input in first version

# %%
df10 = df10[(~df10['Pattern_v2'].str.startswith('OUT')) & (df10['Pattern_v2'].str.contains('OUT'))]#& (~df10['Pattern_v2'].str.startswith('INIT'))    #& df3['B'].str.contains('OUT') & ~df3['C'].str.contains('IN'))]
df10
# Out:
#                                               Pattern_v2 SUP_v2
# 904                               Memcached/OUTDynamoDB|      3
# 905                     Memcached/OUTDynamoDB|Memcached|      3
# 1322   INITElasticsearch/Elasticsearch|OUTElasticsearch|      3
# 1356   INITElasticsearch|Elasticsearch|OUTElasticsearch|      3
# 1389                 INITElasticsearch|OUTElasticsearch|      3
# ...                                                  ...    ...
# 99306                INITSQLite|OUTMS_SQL_Server|SQLite|      3
# 99307            INITSQLite|OUTMS_SQL_Server|PostgreSQL|      3
# 99308         INITSQLite|OUTMS_SQL_Server|MS_SQL_Server|      3
# 99309                 INITSQLite|OUTMS_SQL_Server|MySQL|      3
# 99310             INITSQLite|OUTMS_SQL_Server|INIBM_DB2|      3
#
# [8224 rows x 2 columns]

# %%
#df11 = df10['Pattern_v2'].str.startswith('INIT')
#df11

# %%
#df10
#Generating excel with selected patterns and support of each DB
df10.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes\output_init_tam3_3_selection.xlsx",index=True) # "testes\output_init_tam3_2_selection.xlsx

# %%
df13 = df8.copy()
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                       INITMySQL | INH2 | OUTMySQL |        3
# 769008                 INITOracle/INITMySQL | OUTOracle |        5
# 780614            INITOracle/INITPostgreSQL | OUTOracle |        4
# 781867               INITOracle/INITEhcache | OUTOracle |        3
# 786290                 INITOracle | INMySQL | OUTOracle |        3
# ...                                                    ...      ...
# 994473           Ehcache/INITMySQL | OUTEhcache | MySQL |        6
# 1040652  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       4
# 1040660  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       3
# 1157867                         MySQL | INH2 | OUTMySQL |        3
# 1422184                            OUTH2 | INH2 | OUTH2 |        3
#
#                            SID                  A SUP_A               B SUP_B  \
# 88032               44 110 173          INITMySQL    82            INH2    41
# 769008         0 35 62 110 187         INITOracle    35       INITMySQL    82
# 780614             0 35 62 110         INITOracle    35  INITPostgreSQL    37
# 781867                2 62 110         INITOracle    35     INITEhcache    32
# 786290               2 110 199         INITOracle    35         INMySQL    38
# ...                        ...                ...   ...             ...   ...
# 994473    41 44 94 103 110 130            Ehcache    57       INITMySQL    82
# 1040652          35 62 130 182  SAPAdaptiveServer    17       INITMySQL    82
# 1040660             35 130 182  SAPAdaptiveServer    17       INITMySQL    82
# 1157867             44 110 173              MySQL   110            INH2    41
# 1422184             24 110 173              OUTH2    24            INH2    41
#
#                             C SUP_C      D SUP_D
# 88032                OUTMySQL    33            0
# 769008              OUTOracle    18            0
# 780614              OUTOracle    18            0
# 781867              OUTOracle    18            0
# 786290              OUTOracle    18            0
# ...                       ...   ...    ...   ...
# 994473             OUTEhcache    17  MySQL   110
# 1040652  OUTSAPAdaptiveServer     8            0
# 1040660  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867              OUTMySQL    33            0
# 1422184                 OUTH2    24            0
#
# [130 rows x 11 columns]

# %% [markdown]
# Inserting the columns that will contain the DB combinations support

# %%
df13.insert(3,'SUP_BC','0',False)
df13.insert(4,'SUP_BCD','0',False)
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                       INITMySQL | INH2 | OUTMySQL |        3
# 769008                 INITOracle/INITMySQL | OUTOracle |        5
# 780614            INITOracle/INITPostgreSQL | OUTOracle |        4
# 781867               INITOracle/INITEhcache | OUTOracle |        3
# 786290                 INITOracle | INMySQL | OUTOracle |        3
# ...                                                    ...      ...
# 994473           Ehcache/INITMySQL | OUTEhcache | MySQL |        6
# 1040652  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       4
# 1040660  SAPAdaptiveServer/INITMySQL | OUTSAPAdaptiveSe...       3
# 1157867                         MySQL | INH2 | OUTMySQL |        3
# 1422184                            OUTH2 | INH2 | OUTH2 |        3
#
#                            SID SUP_BC SUP_BCD                  A SUP_A  \
# 88032               44 110 173      0       0          INITMySQL    82
# 769008         0 35 62 110 187      0       0         INITOracle    35
# 780614             0 35 62 110      0       0         INITOracle    35
# 781867                2 62 110      0       0         INITOracle    35
# 786290               2 110 199      0       0         INITOracle    35
# ...                        ...    ...     ...                ...   ...
# 994473    41 44 94 103 110 130      0       0            Ehcache    57
# 1040652          35 62 130 182      0       0  SAPAdaptiveServer    17
# 1040660             35 130 182      0       0  SAPAdaptiveServer    17
# 1157867             44 110 173      0       0              MySQL   110
# 1422184             24 110 173      0       0              OUTH2    24
#
#                       B SUP_B                     C SUP_C      D SUP_D
# 88032              INH2    41              OUTMySQL    33            0
# 769008        INITMySQL    82             OUTOracle    18            0
# 780614   INITPostgreSQL    37             OUTOracle    18            0
# 781867      INITEhcache    32             OUTOracle    18            0
# 786290          INMySQL    38             OUTOracle    18            0
# ...                 ...   ...                   ...   ...    ...   ...
# 994473        INITMySQL    82            OUTEhcache    17  MySQL   110
# 1040652       INITMySQL    82  OUTSAPAdaptiveServer     8            0
# 1040660       INITMySQL    82  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867            INH2    41              OUTMySQL    33            0
# 1422184            INH2    41                 OUTH2    24            0
#
# [130 rows x 13 columns]

# %%
#Removing blank spaces
df13['Pattern'] = df13['Pattern'].str.replace(' ','')
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|       3
# 769008                     INITOracle/INITMySQL|OUTOracle|       5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|       4
# 781867                   INITOracle/INITEhcache|OUTOracle|       3
# 786290                       INITOracle|INMySQL|OUTOracle|       3
# ...                                                    ...      ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|       6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|       4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...       3
# 1157867                               MySQL|INH2|OUTMySQL|       3
# 1422184                                  OUTH2|INH2|OUTH2|       3
#
#                            SID SUP_BC SUP_BCD                  A SUP_A  \
# 88032               44 110 173      0       0          INITMySQL    82
# 769008         0 35 62 110 187      0       0         INITOracle    35
# 780614             0 35 62 110      0       0         INITOracle    35
# 781867                2 62 110      0       0         INITOracle    35
# 786290               2 110 199      0       0         INITOracle    35
# ...                        ...    ...     ...                ...   ...
# 994473    41 44 94 103 110 130      0       0            Ehcache    57
# 1040652          35 62 130 182      0       0  SAPAdaptiveServer    17
# 1040660             35 130 182      0       0  SAPAdaptiveServer    17
# 1157867             44 110 173      0       0              MySQL   110
# 1422184             24 110 173      0       0              OUTH2    24
#
#                       B SUP_B                     C SUP_C      D SUP_D
# 88032              INH2    41              OUTMySQL    33            0
# 769008        INITMySQL    82             OUTOracle    18            0
# 780614   INITPostgreSQL    37             OUTOracle    18            0
# 781867      INITEhcache    32             OUTOracle    18            0
# 786290          INMySQL    38             OUTOracle    18            0
# ...                 ...   ...                   ...   ...    ...   ...
# 994473        INITMySQL    82            OUTEhcache    17  MySQL   110
# 1040652       INITMySQL    82  OUTSAPAdaptiveServer     8            0
# 1040660       INITMySQL    82  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867            INH2    41              OUTMySQL    33            0
# 1422184            INH2    41                 OUTH2    24            0
#
# [130 rows x 13 columns]

# %%
##Removing blank spaces in collumn C
df13['D'] = df13['D'].str.replace(' ','')
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|       3
# 769008                     INITOracle/INITMySQL|OUTOracle|       5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|       4
# 781867                   INITOracle/INITEhcache|OUTOracle|       3
# 786290                       INITOracle|INMySQL|OUTOracle|       3
# ...                                                    ...      ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|       6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|       4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...       3
# 1157867                               MySQL|INH2|OUTMySQL|       3
# 1422184                                  OUTH2|INH2|OUTH2|       3
#
#                            SID SUP_BC SUP_BCD                  A SUP_A  \
# 88032               44 110 173      0       0          INITMySQL    82
# 769008         0 35 62 110 187      0       0         INITOracle    35
# 780614             0 35 62 110      0       0         INITOracle    35
# 781867                2 62 110      0       0         INITOracle    35
# 786290               2 110 199      0       0         INITOracle    35
# ...                        ...    ...     ...                ...   ...
# 994473    41 44 94 103 110 130      0       0            Ehcache    57
# 1040652          35 62 130 182      0       0  SAPAdaptiveServer    17
# 1040660             35 130 182      0       0  SAPAdaptiveServer    17
# 1157867             44 110 173      0       0              MySQL   110
# 1422184             24 110 173      0       0              OUTH2    24
#
#                       B SUP_B                     C SUP_C      D SUP_D
# 88032              INH2    41              OUTMySQL    33            0
# 769008        INITMySQL    82             OUTOracle    18            0
# 780614   INITPostgreSQL    37             OUTOracle    18            0
# 781867      INITEhcache    32             OUTOracle    18            0
# 786290          INMySQL    38             OUTOracle    18            0
# ...                 ...   ...                   ...   ...    ...   ...
# 994473        INITMySQL    82            OUTEhcache    17  MySQL   110
# 1040652       INITMySQL    82  OUTSAPAdaptiveServer     8            0
# 1040660       INITMySQL    82  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867            INH2    41              OUTMySQL    33            0
# 1422184            INH2    41                 OUTH2    24            0
#
# [130 rows x 13 columns]

# %%
#Converting to string because replace
df13['SUP_BC'] = df13['SUP_BC'].astype(str)
df13['SUP_BCD'] = df13['SUP_BCD'].astype(str)
#To resolve "can only concatenate str (not "NoneType") to str" error after suports iteration 
#df13['D'].replace({'None': ''}, regex=True, inplace=True)
#df13['C'].replace({'None': ''}, regex=True, inplace=True)
#df['COL1'] = ['COL1'].fillna(' ')
#df13
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|       3
# 769008                     INITOracle/INITMySQL|OUTOracle|       5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|       4
# 781867                   INITOracle/INITEhcache|OUTOracle|       3
# 786290                       INITOracle|INMySQL|OUTOracle|       3
# ...                                                    ...      ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|       6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|       4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...       3
# 1157867                               MySQL|INH2|OUTMySQL|       3
# 1422184                                  OUTH2|INH2|OUTH2|       3
#
#                            SID SUP_BC SUP_BCD                  A SUP_A  \
# 88032               44 110 173      0       0          INITMySQL    82
# 769008         0 35 62 110 187      0       0         INITOracle    35
# 780614             0 35 62 110      0       0         INITOracle    35
# 781867                2 62 110      0       0         INITOracle    35
# 786290               2 110 199      0       0         INITOracle    35
# ...                        ...    ...     ...                ...   ...
# 994473    41 44 94 103 110 130      0       0            Ehcache    57
# 1040652          35 62 130 182      0       0  SAPAdaptiveServer    17
# 1040660             35 130 182      0       0  SAPAdaptiveServer    17
# 1157867             44 110 173      0       0              MySQL   110
# 1422184             24 110 173      0       0              OUTH2    24
#
#                       B SUP_B                     C SUP_C      D SUP_D
# 88032              INH2    41              OUTMySQL    33            0
# 769008        INITMySQL    82             OUTOracle    18            0
# 780614   INITPostgreSQL    37             OUTOracle    18            0
# 781867      INITEhcache    32             OUTOracle    18            0
# 786290          INMySQL    38             OUTOracle    18            0
# ...                 ...   ...                   ...   ...    ...   ...
# 994473        INITMySQL    82            OUTEhcache    17  MySQL   110
# 1040652       INITMySQL    82  OUTSAPAdaptiveServer     8            0
# 1040660       INITMySQL    82  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867            INH2    41              OUTMySQL    33            0
# 1422184            INH2    41                 OUTH2    24            0
#
# [130 rows x 13 columns]

# %% [markdown]
# Iteration to fetch support corresponding to pieces of patterns (Sup_BC and Sup_BCD)

# %%
#Ajuste lift 2
for index, row in df13.iterrows():   
    for j, rowj in df10.iterrows():
        #if (row['C'] is None) or (row['C'] == ''):#(row['C'] is NoneType):
            #print('entrou1', row['A'], row['B'], row['C'], row['D'])
        if (row['C'] is not None) or (row['C'] != ' ') or (row['C'] != ''): #and ((row['DB_4'] is None) or (row['DB_4'] == ' ') or (row['DB_4'] == '')):
            #print('entrou1')
            #print('entrou1', row['A'], row['B'], row['C'], row['D'])
            if (row['B']+'|'+row['C'])+'|' == rowj['Pattern_v2'] and (row['B']+'|'+row['C']+'|' in row['Pattern']) :
            #df9.loc[index,'LiftA->BC'] = (df9.loc[index,'SUP']/200)/((df9.loc[index,'SUP_DB1']/200)*((df10.loc[,'SUP_v2']/200)
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'|' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'/' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])  
            if (row['B']+'|'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'/' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])  
        if (row['D'] is not None) or (row['D'] != ' ') or (row['D'] != ''):
            #print('entrou2')
            if (row['B']+'|'+row['C']+'|'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'|'+row['D']+'|' in row['Pattern']):
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'|'+row['D']+'|' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'|'+row['C']+'/'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'/'+row['D']+'|' in row['Pattern']):
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'/'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'/'+row['D']+'|' in row['Pattern']):
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])

# %%
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|       3
# 769008                     INITOracle/INITMySQL|OUTOracle|       5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|       4
# 781867                   INITOracle/INITEhcache|OUTOracle|       3
# 786290                       INITOracle|INMySQL|OUTOracle|       3
# ...                                                    ...      ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|       6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|       4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...       3
# 1157867                               MySQL|INH2|OUTMySQL|       3
# 1422184                                  OUTH2|INH2|OUTH2|       3
#
#                            SID SUP_BC SUP_BCD                  A SUP_A  \
# 88032               44 110 173      4       0          INITMySQL    82
# 769008         0 35 62 110 187      9       0         INITOracle    35
# 780614             0 35 62 110      6       0         INITOracle    35
# 781867                2 62 110      5       0         INITOracle    35
# 786290               2 110 199      6       0         INITOracle    35
# ...                        ...    ...     ...                ...   ...
# 994473    41 44 94 103 110 130     11       9            Ehcache    57
# 1040652          35 62 130 182      7       0  SAPAdaptiveServer    17
# 1040660             35 130 182      7       4  SAPAdaptiveServer    17
# 1157867             44 110 173      4       0              MySQL   110
# 1422184             24 110 173     12       0              OUTH2    24
#
#                       B SUP_B                     C SUP_C      D SUP_D
# 88032              INH2    41              OUTMySQL    33            0
# 769008        INITMySQL    82             OUTOracle    18            0
# 780614   INITPostgreSQL    37             OUTOracle    18            0
# 781867      INITEhcache    32             OUTOracle    18            0
# 786290          INMySQL    38             OUTOracle    18            0
# ...                 ...   ...                   ...   ...    ...   ...
# 994473        INITMySQL    82            OUTEhcache    17  MySQL   110
# 1040652       INITMySQL    82  OUTSAPAdaptiveServer     8            0
# 1040660       INITMySQL    82  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867            INH2    41              OUTMySQL    33            0
# 1422184            INH2    41                 OUTH2    24            0
#
# [130 rows x 13 columns]

# %%
#df13 =  pd.read_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_initin_selection2.xlsx", keep_default_na=False)
#Generating excel with selected patterns and support of each DB
df13.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_initin_selection3.xlsx",index=True) #testes/pattern_supABCD_initin_selection2.xlsx"
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|       3
# 769008                     INITOracle/INITMySQL|OUTOracle|       5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|       4
# 781867                   INITOracle/INITEhcache|OUTOracle|       3
# 786290                       INITOracle|INMySQL|OUTOracle|       3
# ...                                                    ...      ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|       6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|       4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...       3
# 1157867                               MySQL|INH2|OUTMySQL|       3
# 1422184                                  OUTH2|INH2|OUTH2|       3
#
#                            SID SUP_BC SUP_BCD                  A SUP_A  \
# 88032               44 110 173      4       0          INITMySQL    82
# 769008         0 35 62 110 187      9       0         INITOracle    35
# 780614             0 35 62 110      6       0         INITOracle    35
# 781867                2 62 110      5       0         INITOracle    35
# 786290               2 110 199      6       0         INITOracle    35
# ...                        ...    ...     ...                ...   ...
# 994473    41 44 94 103 110 130     11       9            Ehcache    57
# 1040652          35 62 130 182      7       0  SAPAdaptiveServer    17
# 1040660             35 130 182      7       4  SAPAdaptiveServer    17
# 1157867             44 110 173      4       0              MySQL   110
# 1422184             24 110 173     12       0              OUTH2    24
#
#                       B SUP_B                     C SUP_C      D SUP_D
# 88032              INH2    41              OUTMySQL    33            0
# 769008        INITMySQL    82             OUTOracle    18            0
# 780614   INITPostgreSQL    37             OUTOracle    18            0
# 781867      INITEhcache    32             OUTOracle    18            0
# 786290          INMySQL    38             OUTOracle    18            0
# ...                 ...   ...                   ...   ...    ...   ...
# 994473        INITMySQL    82            OUTEhcache    17  MySQL   110
# 1040652       INITMySQL    82  OUTSAPAdaptiveServer     8            0
# 1040660       INITMySQL    82  OUTSAPAdaptiveServer     8  MySQL   110
# 1157867            INH2    41              OUTMySQL    33            0
# 1422184            INH2    41                 OUTH2    24            0
#
# [130 rows x 13 columns]

# %% [markdown]
# Reopening the dataframe to resolve the error ("Unsupported operand type(s) for /: 'str' and 'int') when trying to calculate the measures of interest

# %%
#df13 =  pd.read_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_initin_selection.xlsx", keep_default_na=False)
#df13

# %%
#Renaming collumn 
#df13.columns.rename("unnamed: 0","")
#df13.drop("unnamed: 0", axis=0, inplace=True)
#df13.rename(columns = {'Unnamed: 0':'PID'}, inplace = True)
#df13

# %% [markdown]
# Calculateding confidence and lift to each pattern generated.

# %%
#Converting to integer
df13['SUP_A'] = df13['SUP_A'].astype(int)
df13['SUP_B'] = df13['SUP_B'].astype(int)
df13['SUP_C'] = df13['SUP_C'].astype(int)
df13['SUP_D'] = df13['SUP_D'].astype(int)
df13['SUP_BC'] = df13['SUP_BC'].astype(int)
df13['SUP_BCD'] = df13['SUP_BCD'].astype(int)
df13['SUP_ABCD'] = df13['SUP_ABCD'].astype(int)

# %%
#df13.drop("ConfA->_BCD", axis=1, inplace=True)
#df13.drop("ConfB->A_CD", axis=1, inplace=True)
#df13.drop("ConfC->AB_D", axis=1, inplace=True)
#df13.drop("ConfD->ABC_", axis=1, inplace=True)

# %%
#Inserting collums to confidence measure
df13.insert(7,'ConfA->_BCD','0',False) 
df13.insert(10,'ConfB->A_CD','0',False)
df13.insert(13,'ConfC->AB_D','0',False)
df13.insert(16,'ConfD->ABC_','0',False)
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|         3
# 769008                     INITOracle/INITMySQL|OUTOracle|         5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|         4
# 781867                   INITOracle/INITEhcache|OUTOracle|         3
# 786290                       INITOracle|INMySQL|OUTOracle|         3
# ...                                                    ...       ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|         6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|         4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...         3
# 1157867                               MySQL|INH2|OUTMySQL|         3
# 1422184                                  OUTH2|INH2|OUTH2|         3
#
#                            SID  SUP_BC  SUP_BCD                  A  SUP_A  \
# 88032               44 110 173       4        0          INITMySQL     82
# 769008         0 35 62 110 187       9        0         INITOracle     35
# 780614             0 35 62 110       6        0         INITOracle     35
# 781867                2 62 110       5        0         INITOracle     35
# 786290               2 110 199       6        0         INITOracle     35
# ...                        ...     ...      ...                ...    ...
# 994473    41 44 94 103 110 130      11        9            Ehcache     57
# 1040652          35 62 130 182       7        0  SAPAdaptiveServer     17
# 1040660             35 130 182       7        4  SAPAdaptiveServer     17
# 1157867             44 110 173       4        0              MySQL    110
# 1422184             24 110 173      12        0              OUTH2     24
#
#         ConfA->_BCD               B  SUP_B ConfB->A_CD                     C  \
# 88032             0            INH2     41           0              OUTMySQL
# 769008            0       INITMySQL     82           0             OUTOracle
# 780614            0  INITPostgreSQL     37           0             OUTOracle
# 781867            0     INITEhcache     32           0             OUTOracle
# 786290            0         INMySQL     38           0             OUTOracle
# ...             ...             ...    ...         ...                   ...
# 994473            0       INITMySQL     82           0            OUTEhcache
# 1040652           0       INITMySQL     82           0  OUTSAPAdaptiveServer
# 1040660           0       INITMySQL     82           0  OUTSAPAdaptiveServer
# 1157867           0            INH2     41           0              OUTMySQL
# 1422184           0            INH2     41           0                 OUTH2
#
#          SUP_C ConfC->AB_D      D  SUP_D ConfD->ABC_
# 88032       33           0             0           0
# 769008      18           0             0           0
# 780614      18           0             0           0
# 781867      18           0             0           0
# 786290      18           0             0           0
# ...        ...         ...    ...    ...         ...
# 994473      17           0  MySQL    110           0
# 1040652      8           0             0           0
# 1040660      8           0  MySQL    110           0
# 1157867     33           0             0           0
# 1422184     24           0             0           0
#
# [130 rows x 17 columns]

# %%
#Converting to integer
df13['ConfA->_BCD'] = df13['ConfA->_BCD'].astype(int)
df13['ConfB->A_CD'] = df13['ConfB->A_CD'].astype(int)
df13['ConfC->AB_D'] = df13['ConfC->AB_D'].astype(int)
df13['ConfD->ABC_'] = df13['ConfD->ABC_'].astype(int)
#df13['SUP_ABCD'] = df13['SUP_ABCD'].astype(int)

# %% [markdown]
# Calculeting the confidence measures

# %%
df13['ConfA->_BCD'] = (df13['SUP_ABCD'])/df13['SUP_A']
df13['ConfB->A_CD'] = (df13['SUP_ABCD'])/df13['SUP_B']
df13['ConfC->AB_D'] = (df13['SUP_ABCD'])/df13['SUP_C']
df13['ConfD->ABC_'] = (df13['SUP_ABCD'])/df13['SUP_D']
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|         3
# 769008                     INITOracle/INITMySQL|OUTOracle|         5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|         4
# 781867                   INITOracle/INITEhcache|OUTOracle|         3
# 786290                       INITOracle|INMySQL|OUTOracle|         3
# ...                                                    ...       ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|         6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|         4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...         3
# 1157867                               MySQL|INH2|OUTMySQL|         3
# 1422184                                  OUTH2|INH2|OUTH2|         3
#
#                            SID  SUP_BC  SUP_BCD                  A  SUP_A  \
# 88032               44 110 173       4        0          INITMySQL     82
# 769008         0 35 62 110 187       9        0         INITOracle     35
# 780614             0 35 62 110       6        0         INITOracle     35
# 781867                2 62 110       5        0         INITOracle     35
# 786290               2 110 199       6        0         INITOracle     35
# ...                        ...     ...      ...                ...    ...
# 994473    41 44 94 103 110 130      11        9            Ehcache     57
# 1040652          35 62 130 182       7        0  SAPAdaptiveServer     17
# 1040660             35 130 182       7        4  SAPAdaptiveServer     17
# 1157867             44 110 173       4        0              MySQL    110
# 1422184             24 110 173      12        0              OUTH2     24
#
#          ConfA->_BCD               B  SUP_B  ConfB->A_CD  \
# 88032       0.036585            INH2     41     0.073171
# 769008      0.142857       INITMySQL     82     0.060976
# 780614      0.114286  INITPostgreSQL     37     0.108108
# 781867      0.085714     INITEhcache     32     0.093750
# 786290      0.085714         INMySQL     38     0.078947
# ...              ...             ...    ...          ...
# 994473      0.105263       INITMySQL     82     0.073171
# 1040652     0.235294       INITMySQL     82     0.048780
# 1040660     0.176471       INITMySQL     82     0.036585
# 1157867     0.027273            INH2     41     0.073171
# 1422184     0.125000            INH2     41     0.073171
#
#                             C  SUP_C  ConfC->AB_D      D  SUP_D  ConfD->ABC_
# 88032                OUTMySQL     33     0.090909             0          inf
# 769008              OUTOracle     18     0.277778             0          inf
# 780614              OUTOracle     18     0.222222             0          inf
# 781867              OUTOracle     18     0.166667             0          inf
# 786290              OUTOracle     18     0.166667             0          inf
# ...                       ...    ...          ...    ...    ...          ...
# 994473             OUTEhcache     17     0.352941  MySQL    110     0.054545
# 1040652  OUTSAPAdaptiveServer      8     0.500000             0          inf
# 1040660  OUTSAPAdaptiveServer      8     0.375000  MySQL    110     0.027273
# 1157867              OUTMySQL     33     0.090909             0          inf
# 1422184                 OUTH2     24     0.125000             0          inf
#
# [130 rows x 17 columns]

# %% [markdown]
# Calculeting the lift measures

# %%
df13['LiftA->B'] = (df13['SUP_ABCD']/200)/((df13['SUP_A']/200)*(df13['SUP_B']/200))
df13['LiftA->BC'] = (df13['SUP_ABCD']/200)/((df13['SUP_A']/200)*(df13['SUP_BC']/200))
df13['LiftA->BCD'] = (df13['SUP_ABCD']/200)/((df13['SUP_A']/200)*(df13['SUP_BCD']/200))
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 88032                             INITMySQL|INH2|OUTMySQL|         3
# 769008                     INITOracle/INITMySQL|OUTOracle|         5
# 780614                INITOracle/INITPostgreSQL|OUTOracle|         4
# 781867                   INITOracle/INITEhcache|OUTOracle|         3
# 786290                       INITOracle|INMySQL|OUTOracle|         3
# ...                                                    ...       ...
# 994473                 Ehcache/INITMySQL|OUTEhcache|MySQL|         6
# 1040652  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServer|         4
# 1040660  SAPAdaptiveServer/INITMySQL|OUTSAPAdaptiveServ...         3
# 1157867                               MySQL|INH2|OUTMySQL|         3
# 1422184                                  OUTH2|INH2|OUTH2|         3
#
#                            SID  SUP_BC  SUP_BCD                  A  SUP_A  \
# 88032               44 110 173       4        0          INITMySQL     82
# 769008         0 35 62 110 187       9        0         INITOracle     35
# 780614             0 35 62 110       6        0         INITOracle     35
# 781867                2 62 110       5        0         INITOracle     35
# 786290               2 110 199       6        0         INITOracle     35
# ...                        ...     ...      ...                ...    ...
# 994473    41 44 94 103 110 130      11        9            Ehcache     57
# 1040652          35 62 130 182       7        0  SAPAdaptiveServer     17
# 1040660             35 130 182       7        4  SAPAdaptiveServer     17
# 1157867             44 110 173       4        0              MySQL    110
# 1422184             24 110 173      12        0              OUTH2     24
#
#          ConfA->_BCD               B  SUP_B  ConfB->A_CD  \
# 88032       0.036585            INH2     41     0.073171
# 769008      0.142857       INITMySQL     82     0.060976
# 780614      0.114286  INITPostgreSQL     37     0.108108
# 781867      0.085714     INITEhcache     32     0.093750
# 786290      0.085714         INMySQL     38     0.078947
# ...              ...             ...    ...          ...
# 994473      0.105263       INITMySQL     82     0.073171
# 1040652     0.235294       INITMySQL     82     0.048780
# 1040660     0.176471       INITMySQL     82     0.036585
# 1157867     0.027273            INH2     41     0.073171
# 1422184     0.125000            INH2     41     0.073171
#
#                             C  SUP_C  ConfC->AB_D      D  SUP_D  ConfD->ABC_  \
# 88032                OUTMySQL     33     0.090909             0          inf
# 769008              OUTOracle     18     0.277778             0          inf
# 780614              OUTOracle     18     0.222222             0          inf
# 781867              OUTOracle     18     0.166667             0          inf
# 786290              OUTOracle     18     0.166667             0          inf
# ...                       ...    ...          ...    ...    ...          ...
# 994473             OUTEhcache     17     0.352941  MySQL    110     0.054545
# 1040652  OUTSAPAdaptiveServer      8     0.500000             0          inf
# 1040660  OUTSAPAdaptiveServer      8     0.375000  MySQL    110     0.027273
# 1157867              OUTMySQL     33     0.090909             0          inf
# 1422184                 OUTH2     24     0.125000             0          inf
#
#          LiftA->B  LiftA->BC  LiftA->BCD
# 88032    0.178465   1.829268         inf
# 769008   0.348432   3.174603         inf
# 780614   0.617761   3.809524         inf
# 781867   0.535714   3.428571         inf
# 786290   0.451128   2.857143         inf
# ...           ...        ...         ...
# 994473   0.256739   1.913876    2.339181
# 1040652  0.573888   6.722689         inf
# 1040660  0.430416   5.042017    8.823529
# 1157867  0.133038   1.363636         inf
# 1422184  0.609756   2.083333         inf
#
# [130 rows x 20 columns]

# %%
#Generating excel with selected IN patterns and interest measures
df13.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_initin_selection_measure3.xlsx",index=True) #"testes/pattern_supABCD_initin_selection_measure2.xlsx
