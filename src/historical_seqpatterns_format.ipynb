# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
from util import HISTORICAL_FILE_JOIN, RESOURCE_DIR, SEQ_PATTERNS_DIR

# %% [markdown]
# This script converts the historical_join dataset to the file format required by the SPMF library. At the end, it gives instructions for generating sequential patterns using the SPMF.jar file located in db-mining/resources/seq_patterns.

# %%
df = pd.read_excel(HISTORICAL_FILE_JOIN, keep_default_na=False)
#df = pd.read_excel( SEQ_PATTERNS_DIR + os.sep +'testes/teste_historical_init.xlsx', keep_default_na=False)# 24/09/2022

#df = pd.read_excel('hist_sample_teste6.xlsx', keep_default_na=False)
#df = pd.read_excel('hist_sample_teste5.xlsx', keep_default_na=False)
#df = pd.read_excel('hist_sample_teste4.xlsx', keep_default_na=False)
#df = pd.read_excel('hist_sample_teste3.xlsx', keep_default_na=False)
#df = pd.read_excel('hist_sample_teste2.xlsx', keep_default_na=False)
#df3 = pd.read_excel('historical_sample_join2.xlsx',keep_default_na=False)
#df4 = pd.read_excel('historical_tests_2proj.xlsx',keep_default_na=False)
#reads projects from Excel file

len(df)
# Out:
# 3170

# %%
#df['PROJECTS'].unique()
selecao = df['PROJECTS'] == 'android'
dfteste = df[selecao]
dfteste
# Out:
#     PROJECTS  COMMITS  Memcached  Microsoft Azure Table Storage  FileMaker  \
# 800  android        1          0                              0          0
# 801  android        2          0                              0          0
# 802  android        3          0                              0          0
# 803  android        4          0                              0          0
# 804  android        5          0                              0          0
# 805  android        6          0                              0          0
# 806  android        7          0                              0          0
# 807  android        8          0                              0          0
# 808  android        9          0                              0          0
# 809  android       10          0                              0          0
#
#      Riak KV  Hive  Redis  Aerospike  Google Cloud Datastore  ...  Teradata  \
# 800        0     0      0          0                       0  ...         0
# 801        0     0      0          0                       0  ...         0
# 802        0     0      0          0                       0  ...         0
# 803        0     0      0          0                       0  ...         0
# 804        0     0      0          0                       0  ...         0
# 805        0     0      0          0                       0  ...         0
# 806        0     0      0          0                       0  ...         0
# 807        0     0      0          0                       0  ...         0
# 808        0     0      0          0                       0  ...         0
# 809        0     0      0          0                       0  ...         0
#
#      PostGIS  Etcd  MySQL  Join_Ignite-Sql  Join_Ignite-NoSql  \
# 800        0     0      0                0                  0
# 801        0     0      0                0                  0
# 802        0     0      0                0                  0
# 803        0     0      0                0                  0
# 804        0     0      0                0                  0
# 805        0     0      0                0                  0
# 806        0     0      0                0                  0
# 807        0     0      0                0                  0
# 808        0     0      0                0                  0
# 809        0     0      0                0                  0
#
#      Join_MarkLogic-Sql  Join_MarkLogic-NoSql  Join_Virtuoso-Sql  \
# 800                   0                     0                  0
# 801                   0                     0                  0
# 802                   0                     0                  0
# 803                   0                     0                  0
# 804                   0                     0                  0
# 805                   0                     0                  0
# 806                   0                     0                  0
# 807                   0                     0                  0
# 808                   0                     0                  0
# 809                   0                     0                  0
#
#      Join_Virtuoso-NoSql
# 800                    0
# 801                    0
# 802                    0
# 803                    0
# 804                    0
# 805                    0
# 806                    0
# 807                    0
# 808                    0
# 809                    0
#
# [10 rows x 55 columns]

# %%
df.columns
# Out:
# Index(['PROJECTS', 'COMMITS', 'Memcached', 'Microsoft Azure Table Storage',
#        'FileMaker', 'Riak KV', 'Hive', 'Redis', 'Aerospike',
#        'Google Cloud Datastore', 'MariaDB', 'Neo4j', 'H2', 'Google BigQuery',
#        'HBase', 'Netezza', 'Elasticsearch', 'SapHana', 'Oracle', 'OrientDB',
#        'DynamoDB', 'Firebird', 'Informix', 'IBM DB2', 'Couchbase',
#        'Firebase Realtime', 'MongoDB', 'Hazelcast', 'Impala', 'Influx DB',
#        'SQLite', 'Solr', 'Snowflake', 'Amazon Redshift', 'PostgreSQL', 'Realm',
#        'Cassandra', 'MS SQL Server', 'Ehcache', 'Microsoft Azure CosmosDB',
#        'MS Access', 'SAP Adaptive Server', 'CouchDB', 'ClickHouse', 'Vertica',
#        'Teradata', 'PostGIS', 'Etcd', 'MySQL', 'Join_Ignite-Sql',
#        'Join_Ignite-NoSql', 'Join_MarkLogic-Sql', 'Join_MarkLogic-NoSql',
#        'Join_Virtuoso-Sql', 'Join_Virtuoso-NoSql'],
#       dtype='object')

# %%
#df2.rename(columns={'MS Access': 'MS_Access', 'IBM DB2': 'IBM_DB2','Cosmos BD':'Cosmos_BD','MS SQL Server':'MS_SQL_Server'}, inplace=True)
df.rename(columns={'Join_Ignite-Sql':'Join_Ignite_Sql','Join_Ignite-NoSql':'Join_Ignite_NoSql','Join_MarkLogic-Sql':'Join_MarkLogic_Sql',
                    'Join_MarkLogic-NoSql':'Join_MarkLogic_NoSql','Join_Virtuoso-Sql':'Join_Virtuoso_Sql','Join_Virtuoso-NoSql':'Join_Virtuoso_NoSql'}, inplace=True)
df.rename(columns={'Microsoft Azure Table Storage': 'MicrosoftAzureTableStorage'}, inplace=True)
df.rename(columns={'IBM DB2':'IBM_DB2','Firebase Realtime':'FirebaseRealtime'}, inplace=True)
df.rename(columns={'Influx DB':'Influx_DB', 'Amazon Redshift':'AmazonRedshift','MS SQL Server': 'MS_SQL_Server'}, inplace=True)
df.rename(columns={'Microsoft Azure CosmosDB':'MicrosoftAzureCosmosDB', 'MS Access':'MS_Access','SAP Adaptive Server':'SAPAdaptiveServer'}, inplace=True)
df.rename(columns={'Google Cloud Datastore': 'GoogleCloudDatastore','Riak KV':'Riak_KV', 'Google BigQuery':'GoogleBigQuery'}, inplace=True)
print(df.columns)
# Out:
# Index(['PROJECTS', 'COMMITS', 'Memcached', 'MicrosoftAzureTableStorage',
#        'FileMaker', 'Riak_KV', 'Hive', 'Redis', 'Aerospike',
#        'GoogleCloudDatastore', 'MariaDB', 'Neo4j', 'H2', 'GoogleBigQuery',
#        'HBase', 'Netezza', 'Elasticsearch', 'SapHana', 'Oracle', 'OrientDB',
#        'DynamoDB', 'Firebird', 'Informix', 'IBM_DB2', 'Couchbase',
#        'FirebaseRealtime', 'MongoDB', 'Hazelcast', 'Impala', 'Influx_DB',
#        'SQLite', 'Solr', 'Snowflake', 'AmazonRedshift', 'PostgreSQL', 'Realm',
#        'Cassandra', 'MS_SQL_Server', 'Ehcache', 'MicrosoftAzureCosmosDB',
#        'MS_Access', 'SAPAdaptiveServer', 'CouchDB', 'ClickHouse', 'Vertica',
#        'Teradata', 'PostGIS', 'Etcd', 'MySQL', 'Join_Ignite_Sql',
#        'Join_Ignite_NoSql', 'Join_MarkLogic_Sql', 'Join_MarkLogic_NoSql',
#        'Join_Virtuoso_Sql', 'Join_Virtuoso_NoSql'],
#       dtype='object')

# %%
df2 = df.copy()
print(df2.columns)
# Out:
# Index(['PROJECTS', 'COMMITS', 'Memcached', 'MicrosoftAzureTableStorage',
#        'FileMaker', 'Riak_KV', 'Hive', 'Redis', 'Aerospike',
#        'GoogleCloudDatastore', 'MariaDB', 'Neo4j', 'H2', 'GoogleBigQuery',
#        'HBase', 'Netezza', 'Elasticsearch', 'SapHana', 'Oracle', 'OrientDB',
#        'DynamoDB', 'Firebird', 'Informix', 'IBM_DB2', 'Couchbase',
#        'FirebaseRealtime', 'MongoDB', 'Hazelcast', 'Impala', 'Influx_DB',
#        'SQLite', 'Solr', 'Snowflake', 'AmazonRedshift', 'PostgreSQL', 'Realm',
#        'Cassandra', 'MS_SQL_Server', 'Ehcache', 'MicrosoftAzureCosmosDB',
#        'MS_Access', 'SAPAdaptiveServer', 'CouchDB', 'ClickHouse', 'Vertica',
#        'Teradata', 'PostGIS', 'Etcd', 'MySQL', 'Join_Ignite_Sql',
#        'Join_Ignite_NoSql', 'Join_MarkLogic_Sql', 'Join_MarkLogic_NoSql',
#        'Join_Virtuoso_Sql', 'Join_Virtuoso_NoSql'],
#       dtype='object')

# %% [markdown]
# Generating the dictionary with the names of the databases

# %%
dict_col=[]
#for row in df2.itertuples():
    #print(row.index()) 
    #print((col)
linha=[]
for col in df2.columns:
    #linha=[]
    if df2.columns.get_loc(col) == 0:
        #linha.append(df2.PROJECTS)
        linha.append('@CONVERTED_FROM_TEXT')
    elif df2.columns.get_loc(col) > 1: #@ITEM=1=apple
        #linha=[]
        linha.append('@ITEM='+ str(df2.columns.get_loc(col)*10000)+ '=INIT' + col)
        linha.append('@ITEM='+ str(df2.columns.get_loc(col)*1000)+ '=IN' + col)
        linha.append('@ITEM='+ str(df2.columns.get_loc(col))+ '=' + col)
        #linha.append('@ITEM='+ str(df2.columns.get_loc(col)*10000)+ '=INIT' + col + df2.PROJECTS)
        #linha.append('@ITEM='+ str(df2.columns.get_loc(col)*1000)+ '=IN' + col + df2.PROJECTS)
        #linha.append('@ITEM='+ str(df2.columns.get_loc(col))+ '=' + col + df2.PROJECTS)
        #dict_col.append(linha)
        #linha=[]
        #Da forma como mudei aqui, os projetos ainda irão se perder, talvez eu tenha que add o id dos projetos ao final da concatenação.
        #Assim teríamos: @ITEM=20000IDProjeto=INITMemcachedActiviti
        linha.append('@ITEM='+ str(df2.columns.get_loc(col)*100)+ '=OUT' + col)
        
linha.append('@ITEM=-1=|')
dict_col.append(linha)
print(dict_col)
# Out:
# [['@CONVERTED_FROM_TEXT', '@ITEM=20000=INITMemcached', '@ITEM=2000=INMemcached', '@ITEM=2=Memcached', '@ITEM=200=OUTMemcached', '@ITEM=30000=INITMicrosoftAzureTableStorage', '@ITEM=3000=INMicrosoftAzureTableStorage', '@ITEM=3=MicrosoftAzureTableStorage', '@ITEM=300=OUTMicrosoftAzureTableStorage', '@ITEM=40000=INITFileMaker', '@ITEM=4000=INFileMaker', '@ITEM=4=FileMaker', '@ITEM=400=OUTFileMaker', '@ITEM=50000=INITRiak_KV', '@ITEM=5000=INRiak_KV', '@ITEM=5=Riak_KV', '@ITEM=500=OUTRiak_KV', '@ITEM=60000=INITHive', '@ITEM=6000=INHive', '@ITEM=6=Hive', '@ITEM=600=OUTHive', '@ITEM=70000=INITRedis', '@ITEM=7000=INRedis', '@ITEM=7=Redis', '@ITEM=700=OUTRedis', '@ITEM=80000=INITAerospike', '@ITEM=8000=INAerospike', '@ITEM=8=Aerospike', '@ITEM=800=OUTAerospike', '@ITEM=90000=INITGoogleCloudDatastore', '@ITEM=9000=INGoogleCloudDatastore', '@ITEM=9=GoogleCloudDatastore', '@ITEM=900=OUTGoogleCloudDatastore', '@ITEM=100000=INITMariaDB', '@ITEM=10000=INMariaDB', '@ITEM=10=MariaDB', '@ITEM=1000=OUTMariaDB', '@ITEM=110000=INITNeo4j', '@ITEM=11000=INNeo4j', '@ITEM=11=Neo4j', '@ITEM=1100=OUTNeo4j', '@ITEM=120000=INITH2', '@ITEM=12000=INH2', '@ITEM=12=H2', '@ITEM=1200=OUTH2', '@ITEM=130000=INITGoogleBigQuery', '@ITEM=13000=INGoogleBigQuery', '@ITEM=13=GoogleBigQuery', '@ITEM=1300=OUTGoogleBigQuery', '@ITEM=140000=INITHBase', '@ITEM=14000=INHBase', '@ITEM=14=HBase', '@ITEM=1400=OUTHBase', '@ITEM=150000=INITNetezza', '@ITEM=15000=INNetezza', '@ITEM=15=Netezza', '@ITEM=1500=OUTNetezza', '@ITEM=160000=INITElasticsearch', '@ITEM=16000=INElasticsearch', '@ITEM=16=Elasticsearch', '@ITEM=1600=OUTElasticsearch', '@ITEM=170000=INITSapHana', '@ITEM=17000=INSapHana', '@ITEM=17=SapHana', '@ITEM=1700=OUTSapHana', '@ITEM=180000=INITOracle', '@ITEM=18000=INOracle', '@ITEM=18=Oracle', '@ITEM=1800=OUTOracle', '@ITEM=190000=INITOrientDB', '@ITEM=19000=INOrientDB', '@ITEM=19=OrientDB', '@ITEM=1900=OUTOrientDB', '@ITEM=200000=INITDynamoDB', '@ITEM=20000=INDynamoDB', '@ITEM=20=DynamoDB', '@ITEM=2000=OUTDynamoDB', '@ITEM=210000=INITFirebird', '@ITEM=21000=INFirebird', '@ITEM=21=Firebird', '@ITEM=2100=OUTFirebird', '@ITEM=220000=INITInformix', '@ITEM=22000=INInformix', '@ITEM=22=Informix', '@ITEM=2200=OUTInformix', '@ITEM=230000=INITIBM_DB2', '@ITEM=23000=INIBM_DB2', '@ITEM=23=IBM_DB2', '@ITEM=2300=OUTIBM_DB2', '@ITEM=240000=INITCouchbase', '@ITEM=24000=INCouchbase', '@ITEM=24=Couchbase', '@ITEM=2400=OUTCouchbase', '@ITEM=250000=INITFirebaseRealtime', '@ITEM=25000=INFirebaseRealtime', '@ITEM=25=FirebaseRealtime', '@ITEM=2500=OUTFirebaseRealtime', '@ITEM=260000=INITMongoDB', '@ITEM=26000=INMongoDB', '@ITEM=26=MongoDB', '@ITEM=2600=OUTMongoDB', '@ITEM=270000=INITHazelcast', '@ITEM=27000=INHazelcast', '@ITEM=27=Hazelcast', '@ITEM=2700=OUTHazelcast', '@ITEM=280000=INITImpala', '@ITEM=28000=INImpala', '@ITEM=28=Impala', '@ITEM=2800=OUTImpala', '@ITEM=290000=INITInflux_DB', '@ITEM=29000=INInflux_DB', '@ITEM=29=Influx_DB', '@ITEM=2900=OUTInflux_DB', '@ITEM=300000=INITSQLite', '@ITEM=30000=INSQLite', '@ITEM=30=SQLite', '@ITEM=3000=OUTSQLite', '@ITEM=310000=INITSolr', '@ITEM=31000=INSolr', '@ITEM=31=Solr', '@ITEM=3100=OUTSolr', '@ITEM=320000=INITSnowflake', '@ITEM=32000=INSnowflake', '@ITEM=32=Snowflake', '@ITEM=3200=OUTSnowflake', '@ITEM=330000=INITAmazonRedshift', '@ITEM=33000=INAmazonRedshift', '@ITEM=33=AmazonRedshift', '@ITEM=3300=OUTAmazonRedshift', '@ITEM=340000=INITPostgreSQL', '@ITEM=34000=INPostgreSQL', '@ITEM=34=PostgreSQL', '@ITEM=3400=OUTPostgreSQL', '@ITEM=350000=INITRealm', '@ITEM=35000=INRealm', '@ITEM=35=Realm', '@ITEM=3500=OUTRealm', '@ITEM=360000=INITCassandra', '@ITEM=36000=INCassandra', '@ITEM=36=Cassandra', '@ITEM=3600=OUTCassandra', '@ITEM=370000=INITMS_SQL_Server', '@ITEM=37000=INMS_SQL_Server', '@ITEM=37=MS_SQL_Server', '@ITEM=3700=OUTMS_SQL_Server', '@ITEM=380000=INITEhcache', '@ITEM=38000=INEhcache', '@ITEM=38=Ehcache', '@ITEM=3800=OUTEhcache', '@ITEM=390000=INITMicrosoftAzureCosmosDB', '@ITEM=39000=INMicrosoftAzureCosmosDB', '@ITEM=39=MicrosoftAzureC ...

# %%
# Function to check if the DBMS exists
def verify_BD (db, list):
    try:
        BD = list.index(db)
    except:
        BD = -1
    return BD

# %%
#Function to divide the lists
def separate_list(list):
    list1=[]
    list2=[]
    start = 0
    limit_pos =[]
    final = len(list)
    #print(final)
    
    for i,l in enumerate (list):
        if l == '-1':
            limit_pos.append(i)
        #print(limit_pos)
        
    # list = lista.reverse
    # print (list)
    if final > 0 and len(limit_pos) > 0:
        for j,p in enumerate (limit_pos[::-1]): #[::-1]
            if len(limit_pos) == 1 and final > p:
                 list1 = list[:p]
                 list2 = list[p+1:]
            elif len(limit_pos) <= 2 and (list[final-1] == '-1' or list[final-1] == '-1 -2') :
                start = limit_pos[j-2]
                list1 = list[start+1:p]
                if list[final-1] == '-1 -2':
                    list2 = list[p+1:j-1]  
                else:                     
                    list2 = list[p+1:]           
                #print('entrou no 1',  j, p, start, j-1, j-2)
                break#return list1,list2   
            else:
                start = limit_pos[j-2]
                list1 = list[start+1:p]  
                if list[final-1] == '-1 -2':
                    #print('entrou no 1 do else', j, p, start, j-1, list[67], final)
                    list2 = list[p+1:j-1]
                else: 
                    #print('entrou no 2', j, p, start, j-1, list[67], final)                    
                    list2 = list[p+1:]
                #print('entrou no 2', j, p, start, j-1, list[67], final)
                break
    else:
        list1 = ['-1']
        #list1 = list.copy()
        list2 = list.copy()
    return list1 , list2
linha = [6000,3000,40,50,'-1']
#'-1', 6, 8, 32, 36, 49000, '-1',6, 8, 32, 36, 49, 50000, 6, 8, 32, 36, 49, 50000, '-1', 6, 8, 32, 36, 4900, 5000, '-1', 6, 8, 32, 36, 49000, '-1', 6, 8, 32, 36, 4900, '-1', 6, 8, 32, 36, 4900, 50000, '-1', 6, 8, 32, 36, 49000, '-1', 6, 8, 32, 36, 4900, '-1', 6, 8, 32, 36, 5400, '-1 -2'] 
print(separate_list(linha))
line1,line2 = separate_list(linha)
print(line1)
print(line2)
# Out:
# ([6000, 3000, 40, 50], [])
# [6000, 3000, 40, 50]
# []

# %% [markdown]
# Iteration to generate the categorical data to be used in the sequential patterns algorithm
# Adjusts to considering only INIT without IN on first version, but only DB that starting in first version

# %%
coluna=[]

proj = 0
projant = 'xxxx'
#commitant = 0
linha=[]
linhaproj=[]
linhaant = []
contproj = 0
#noBD = -2
#noBDant = -2
for row in df2.itertuples():
    #print(row.Index) 
    #print((col)
    commitant = 0
    for col in df2.columns:
        if col == "PROJECTS":
            #proj = proj + 1
            #linha.append(getattr(row, col))
            #print(getattr(row, col))
            projatual = getattr(row, col)
            #print('atual novo:', projatual, 'anterior:', projant)
            
        elif col == "COMMITS":
            commitatual = getattr(row, col)
            #commitant = commitatual
            #linha.append(getattr(row, col))
            #print('Commit:',getattr(row, col))
        # Only enter if it is traversing the lines7of the same project or if it is the first line of the dataframe
        elif projatual == projant or row.Index == 0:# projant == 'xxxx':
            # Only enter if you are in the same version
            if (commitatual == commitant) :
                #If the value of column(BD) == 1, then this DB exists
                if (getattr(row, col) == 1):
                    line1 = []
                    line2 = []           
                    #Split the list into two lists        
                    line1,line2 = separate_list(linha)
                    #Only enter if the first list is not null and if the second list is greater than the first
                    if len(line1)!= 0 and len(line2) > len(line1):# >=
                        #initBD =  verify_BD(df2.columns.get_loc(col)*10000,line2)
                        inBD = verify_BD(df2.columns.get_loc(col)*1000,line2)
                        BD = verify_BD(df2.columns.get_loc(col),line2)
                        outBD= verify_BD(df2.columns.get_loc(col)*100,line2)
                        #If there is no DB in the second list, check the first list
                        if inBD < 0 and BD < 0 and outBD < 0:
                            inBD = verify_BD(df2.columns.get_loc(col)*1000,line1)
                            BD = verify_BD(df2.columns.get_loc(col),line1)
                            outBD= verify_BD(df2.columns.get_loc(col)*100,line1)
                    else:
                        #So list 1 is bigger than list 2, look for the DB in the first list
                        #initBD =  verify_BD(df2.columns.get_loc(col)*10000,line1)
                        inBD = verify_BD(df2.columns.get_loc(col)*1000,line1)
                        BD = verify_BD(df2.columns.get_loc(col),line1)
                        outBD= verify_BD(df2.columns.get_loc(col)*100,line1)

                    #Inserts the DB entry since it doesn't exist in any of the lists or left one of them
                    if (outBD >=0) or (BD < 0 and inBD < 0):
                        if commitatual == 1: # or (commitatual != 1 and '-1' not in linha): #INIT in first version #1
                            #print(commitatual,commitant, "entrou1")
                            linha.append(df2.columns.get_loc(col)*10000)
                            print(commitatual,commitant,"entrou 1 if",linha)
                        else:#if (df2.columns.get_loc(col) not in linha):         
                            linha.append(df2.columns.get_loc(col)*1000) #IN  including DB for correct count when generating sequential pattern
                            print(commitatual,commitant,"entrou 1 else",linha)
                        linha.append(df2.columns.get_loc(col))    
                        linhaant.append(df2.columns.get_loc(col)*1000)
                        linhaant.append(df2.columns.get_loc(col))
                        print(commitatual,commitant,"total 1",linha)
                    else:
                        #Insert the permanence of the DB
                        #linha.append('No'+col)
                        #linha.append(-df2.columns.get_loc(col))
                        linha.append(df2.columns.get_loc(col))
                        linhaant.append(df2.columns.get_loc(col))     
                    commitant = commitatual
                #If the value of column(BD) == 0, then this DB does not exist.  
                elif getattr(row, col) == 0:
                    #If it is the first column and the lineant had DB
                    if len(linha) == 0 and len(linhaant) != 0:
                        #Check the existence of the DB in the entire list
                        #initBD =  verify_BD(df2.columns.get_loc(col)*10000,linha)
                        inBD = verify_BD(df2.columns.get_loc(col)*1000, linha)
                        BD = verify_BD(df2.columns.get_loc(col), linha)
                        outBD =  verify_BD(df2.columns.get_loc(col)*100, linha)
                        # If the DB exists on the line, then insert the output
                        if BD >= 0 or (inBD >= 0 and BD >= 0 and outBD < 0): # Added BD>=0 with inBD to correct init split
                            linha.append(df2.columns.get_loc(col)*100)
                            linhaant.append(df2.columns.get_loc(col)*100)
                            print(commitatual,commitant,"entrou 1 elif 1",df2.columns.get_loc(col)*100,linha)
                        commitant = commitatual
                    elif len(linha) != 0 and len(linhaant) != 0:  
                        line1 = []
                        line2 = []  
                        #Split the list into two lists                
                        line1,line2 = separate_list(linha)
                        #Only enter if the first list is not null and if the second list is greater than the first
                        if len(line1)!= 0 and len(line2) > len(line1):# >=
                            inBD = verify_BD(df2.columns.get_loc(col)*1000,line2)
                            BD = verify_BD(df2.columns.get_loc(col),line2)
                            outBD= verify_BD(df2.columns.get_loc(col)*100,line2)
                            #If there is no DB in the second list, check the first list
                            if inBD < 0 and BD < 0 and outBD < 0:
                                inBD = verify_BD(df2.columns.get_loc(col)*1000,line1)
                                BD = verify_BD(df2.columns.get_loc(col),line1)
                                outBD= verify_BD(df2.columns.get_loc(col)*100,line1)
                        else:
                            #So list 1 is bigger than list 2, look for the DB in the first list
                            inBD = verify_BD(df2.columns.get_loc(col)*1000,line1)
                            BD = verify_BD(df2.columns.get_loc(col),line1)
                            outBD= verify_BD(df2.columns.get_loc(col)*100,line1)    

                        #Inserts the BD output since it exists in one of the lists
                        if BD >= 0 or (inBD >= 0 and BD >= 0 and outBD < 0): #Added BD>=0 with inBD to correct init split
                            linha.append(df2.columns.get_loc(col)*100)
                            linhaant.append(df2.columns.get_loc(col)*100)
                            print(commitatual,commitant,"entrou 1 elif 2",df2.columns.get_loc(col),linha, BD, inBD, outBD)
                        commitant = commitatual   
            # Only enter if it is in a different version from the previous one (different versions)        
            elif (commitatual != commitant):
                #If the value of column(BD) == 1, then this DB exists
                if getattr(row, col) == 1:
                    #Only enter if it is on the first line of the dataframe or if the list is empty
                    if row.Index == 0 or len(linha) == 0:
                        #Check the existence of the DB in the entire list
                        inBD = verify_BD(df2.columns.get_loc(col)*1000,linha)
                        outBD= verify_BD(df2.columns.get_loc(col)*100,linha)
                        
                        # If the DB does not exist on the line, then insert the entry
                        if inBD < 0 or outBD >=0:
                            if commitatual == 1:  # or (commitatual != 1 and '-1' not in linha): #INIT in first version#len(linha)== 0: #2
                                #print(commitatual,commitant, "entrou 2")
                                linhaproj.append(projatual)
                                linha.append(df2.columns.get_loc(col)*10000)
                                #print(commitatual,commitant,"entrou 2 if",linha)
                            else:  
                                linha.append(df2.columns.get_loc(col)*1000) #IN other versions #incluindo o BD para contagem correta ao gerar o padrão sequencial)
                            linha.append(df2.columns.get_loc(col))      #including DB for correct count when generating sequential pattern)
                            linhaant.append(df2.columns.get_loc(col)*1000)
                            linhaant.append(df2.columns.get_loc(col))
                            #print(commitatual,commitant,"total 2 if",linha)
                        else: 
                            # Else insert the permanence of the DB
                            linha.append(df2.columns.get_loc(col))
                            linhaant.append(df2.columns.get_loc(col))
                    #Enter the other lines or the list is not empty  
                    else:
                        line1 = []
                        line2 = []   
                        #Split the list into two lists                
                        line1,line2 = separate_list(linha)
                        diff = []
                        #New version
                        linha.append('-1')
                        linhaant.append('-1')
                        #linhaant.append(col)
                        #linhaant.append(df2.columns.get_loc(col))
                        
                        #Only enter if the first list is not null and if the second list is greater than or equal to the first
                        if len(line1)!= 0 and len(line2) >= len(line1):# >= this signal was included to resolve situation 12 on line1 and 1200 on line2
                            inBD = verify_BD(df2.columns.get_loc(col)*1000,line2)
                            BD = verify_BD(df2.columns.get_loc(col),line2)
                            outBD= verify_BD(df2.columns.get_loc(col)*100,line2)
                            #If there is no DB in the second list, check the first list
                            if inBD < 0 and BD < 0 and outBD < 0:
                                inBD = verify_BD(df2.columns.get_loc(col)*1000,line1)
                                BD = verify_BD(df2.columns.get_loc(col),line1)
                                outBD= verify_BD(df2.columns.get_loc(col)*100,line1)
                        else:
                            #So list 1 is bigger than list 2, look for the DB in the first list 
                            inBD = verify_BD(df2.columns.get_loc(col)*1000,line1)
                            BD = verify_BD(df2.columns.get_loc(col),line1)
                            outBD= verify_BD(df2.columns.get_loc(col)*100,line1)
                            #If in list 1 the DB left or if there was no DB, check the second list
                            if (inBD >= 0 or BD >= 0 or outBD >= 0) or (inBD < 0 and BD < 0 and outBD < 0): #Included to force you to look at the latest version, you may need to compare BDline1 with BDline2
                                inBD = verify_BD(df2.columns.get_loc(col)*1000,line2)
                                BD = verify_BD(df2.columns.get_loc(col),line2)
                                outBD= verify_BD(df2.columns.get_loc(col)*100,line2)        
                                                                                  
                        # If DB exited or does not exist, then insert entry    
                        if outBD >=0 or (BD < 0 and inBD < 0):
                            if commitatual == 1: # or (commitatual != 1 and '-1' not in linha): #INIT in first version#len(linha) == 0:#3
                                #print(commitatual,commitant,"entrou 3")
                                linha.append(df2.columns.get_loc(col)*10000)
                                #print(commitatual,commitant,"entrou 3 if",linha)
                            else:   
                                linha.append(df2.columns.get_loc(col)*1000)#IN other versions #including DB for correct count when generating sequential pattern)
                                #print(commitatual,commitant,"entrou 3 else",linha)
                            linha.append(df2.columns.get_loc(col))      
                            linhaant.append(df2.columns.get_loc(col)*1000)
                            linhaant.append(df2.columns.get_loc(col))
                            #print(commitatual,commitant,"entrou 3 total",linha)
                        else:
                            #Else insert the permanence of the DB
                            linha.append(df2.columns.get_loc(col))
                            linhaant.append(df2.columns.get_loc(col))                        
                    commitant = commitatual
                
                #If the value of column(DB) == 0, then this DB does not exist.
                elif getattr(row, col) == 0: 
                    list1 = []
                    list2 = []
                    newList = [] 
                    newList2 = []
                    #if len(linha)>0 and type(linha[0]) == str:
                        #linhaproj.append(linha[0])
                        #print("__________________________________________________")
                        #print("ListaProj")
                        #print(linhaproj)
                        #print("__________________________________________________")
                        #print("Lista")
                        #linha.pop(0)
                        #print(linha) 
                    #Split the list into two lists 
                    list1,list2 = separate_list(linha) 
                    # Only enter if list1 or line is not empty
                    if len(list1) != 0 and len(linha) != 0: #and list1 != '-1' 
                        delim ='-1'
                        #Only enter if you don't have the value "-1" in any of the lists
                        if delim not in list1 and delim not in list2:
                            #Insert the value if it is in list1 and not in list2
                            newList = [int (l) for l in list1 if l not in list2 ]
                            #If newList is not empty
                            if len(newList) != 0:
                                # Cycling through the values ​​of newList
                                for i,n in enumerate (newList):
                                    #If the value is a multiple of 1000 and is not in list1, that is,
                                    #if DB entry and permanence do not exist in list1
                                    if  n % 1000 == 0 and (n not in list1) and (int(n/1000) not in list1):
                                        #Insert value in newList
                                        newList[i] = int (n/1000)
                                    #If the value is a multiple of 100, that is, if it is an output
                                    elif n % 100 == 0:
                                        #Insert value in newList
                                        newList[i] = int(n/100) 
                                #Multiply by 100 the values ​​that do not refer to DB entries      
                                newList = [int (i) *100 if i %1000 != 0 else int(i/1000) for i in newList ]
                        #If newList is still populated       
                        if len(newList) != 0:# or len(newList2) != 0 : #
                            #Inserts the value in newList2, the value of newList if it is in list1 and not in list2
                            newList2 = [int (l) for l in newList if (int(l/100) in list1 and l not in list2)]
                            #Calculate position to insert
                            pos = len(linha)-len(newList2) 
                            #linha.insert(pos,newList2)
                            #Cycling through the values ​​of newList2
                            for i,l in enumerate (newList2):
                                #If it is the first value and the position does not have "-1"
                                if i == 0 and linha[pos] != '-1':    #or linha[pos] != -1
                                    #Inserts the DB output at position
                                    linha.insert(pos,l)
                                    linhaant.insert(pos,l)
                                    print(commitatual, commitant, 'entrou  if diferença', df2.columns.get_loc(col), linha)
                                else:
                                    #Else insert the DB output in the next position
                                    linha.insert(pos+1,l) 
                                    linhaant.insert(pos+1,l)
                                    print(commitatual, commitant, 'entrou else diferença', df2.columns.get_loc(col), linha)
                        #If one of the two newLists is empty and list2 is not empty, that is,
                        #if no differences were found between split and scrolled lists from left to right
                        if (len(newList) == 0 or len(newList2) == 0) and len(list2) != 0:
                            #If the value of column(BD) == 0, then this DB does not exist.
                            if getattr(row, col) == 0:
                                inBD = verify_BD(df2.columns.get_loc(col)*1000,list2)
                                BD = verify_BD(df2.columns.get_loc(col),list2)
                                outBD= verify_BD(df2.columns.get_loc(col)*100,list2)
                                #Insert the DB output already if it exists in list2
                                if BD >= 0 and outBD < 0: 
                                    linha.append('-1')
                                    linhaant.append('-1')
                                    linha.append(df2.columns.get_loc(col)*100)
                                    linhaant.append(df2.columns.get_loc(col)*100)   
                                    print(commitatual, commitant, 'entrou newlist', df2.columns.get_loc(col), linha)                                       
                                    commitant = commitatual
        #Different projects, i.e. project of the new line is different from the project of the previous line
        elif projatual != projant:
            #If the value of column(BD) == 1, then this DB exists
            if getattr(row, col) == 1:# and commitatual == 10:
                #Finish the line with all versions of the project
                linha.append('-1 -2')
                linhaproj.append(projatual)
                #linhaant.append(linha)
                coluna.append(linha)
                linha=[]
                linhaant=[]
                #Inserts the DB entry that exists in the column
                #print("Versão1",projatual,commitatual)
                #linha.append(df2.columns.get_loc(col)+1000)
                #print(len(linha),projatual,commitatual)
                if commitatual == 1: #or (commitatual != 1 and '-1' not in linha): #INIT in first version#len(linha)== 0: #4
                    #print(commitatual,commitant, "entrou 4")
                    #linha.append(projatual)
                    linha.append(df2.columns.get_loc(col)*10000)
                    print(commitatual,commitant, "entrou 4 if",linha)
                else:   
                    linha.append(df2.columns.get_loc(col)*1000)# IN other versions
                    print(commitatual,commitant, "entrou 4 else",linha)
                linha.append(df2.columns.get_loc(col))
                #print("Versão1",projatual,commitatual,linha)
                #linhaant.append(df2.columns.get_loc(col)+1000)
                linhaant.append(df2.columns.get_loc(col)*1000)
                linhaant.append(df2.columns.get_loc(col))  
                print(commitatual,commitant, "total 4",linha)            
                #contproj = contproj + 1
                projant = projatual
                commitant = commitatual
             #Enter if the value of column(BD) == 0, that is, BD does not exist and the versions are different
            elif getattr(row, col) == 0 and (commitatual != commitant):
                #If the line is filled
                if len(linha) != 0:
                    diff=[]
                    #count_versions=[]
                    #Check versions
                    #for i,l in enumerate (linha):
                            #if l == '-1':
                               #count_versions.append(i)
                    #Split the list into two lists
                    line1,line2 = separate_list(linha)
                    #If list 2 is filled
                    if len(line2) != 0:
                            #Returns the difference between the lists
                            diff = list(set(line1).difference(line2))
                            #Calculate the position to insert the difference
                            pos = len(linha)-1
                            #Check if the DB or DB entry does not exist in list 1
                            diff2 = [int (l) for l in diff if l not in line1 and l/1000 not in line1]  #Check again as it may bring up an inBD. ex: 28000                                                                          
                            #If diff2 is not empty
                            if len(diff2) != 0:
                                #Insert in diff2 the value that is in diff, but not in list2
                                diff2 = [int (l) for l in diff if l and l/1000 not in line2]
                            else:
                                 #Insert into diff2 the value that is in diff2, but not in list2
                                diff2 = [int (l) for l in diff2 if l and l/1000 not in line2]

                            #Cycling through the values ​​of diff2
                            for i,l in enumerate (diff2):
                                #If it is the first value and the position does not have "-1"
                                if i == 0 and linha[pos] != '-1':    #or linha[pos] != -1
                                    #Inserts the DB difference in the position
                                    linha.insert(pos,l)
                                    linhaant.insert(pos,l)
                                else:
                                    #Else insert the DB difference in the next position
                                    linha.insert(pos+1,l) 
                                    linhaant.insert(pos+1,l)  
                    #Finish the line with all versions of the project                                     
                    linha.append('-1 -2')
                    linhaproj.append(projatual)
                    #linhaant.append(col)
                    coluna.append(linha)
                    linha=[]
                    linhaant=[]
                projant = projatual
                commitant = commitatual
            #Enter if the value of column(BD) == 0, that is, BD does not exist and is in the same version
            #elif getattr(row, col) == 0 and (commitatual == commitant):
             #   print("Entrou", linha)
              #  if len(linha) != 0:
               #     #linha.append('-1 -2')
                #    #linhaant.append(col)
                 #   #coluna.append(linha)
                  #  #linha=[]
                   # linhaant=[]
                #projant = projatual
                #commitant = commitatual
            contproj = contproj + 1
        #projant=projatual
        #commitant = 0
    projant = projatual 
    #If it is on the last line of the dataframe
    if row.Index == len(df2) - 1:
        diff=[]
        #Split the list into two lists
        line1,line2 = separate_list(linha)
        #If list 2 is filled
        if len(line2) != 0:
            #Returns the difference between the lists
            diff = list(set(line1).difference(line2))
            #Calculate the position to insert the difference
            pos = len(linha)-len(diff)
            #Check if the DB or DB entry does not exist in list 1 
            diff2 = [int (l) for l in diff if l not in line1 and l/1000 not in line1]#Check again as it may bring up an inBD. ex: 28000
            #If diff2 is not empty
            if len(diff2) != 0:
                #Insert in diff2 the value that is in diff, but not in list2
                diff2 = [int (l) for l in diff if l and l/1000 not in line2]
            else:
                #Insert into diff2 the value that is in diff2, but not in list2
                diff2 = [int (l) for l in diff2 if l and l/1000 not in line2]

            #Cycling through the values ​​of diff2
            for i,l in enumerate (diff2):
                #If it is the first value and the position does not have "-1"
                if i == 0 and linha[pos] != '-1':    #or linha[pos] != -1
                    #Inserts the DB output at position
                    linha.insert(pos,l*100)
                    linhaant.insert(pos,l*100)
                    #print(commitatual, commitant, 'entrou ultimo if', df2.columns.get_loc(col), linha)
                else:
                    #Inserts the DB output in the next position
                    linha.insert(pos+1,l*100) 
                    linhaant.insert(pos+1,l*100)
                    #print(commitatual, commitant, 'entrou ultimo else', df2.columns.get_loc(col), linha)
        #Finish the line with all versions of the project
        linha.append('-1 -2')
        linhaproj.append(projatual)
        coluna.append(linha)
        contproj = contproj + 1
print(len(linha))
#print(len(linhaant),linhaant)
#print(len(linha))
#print(contproj)
#print(coluna)
#print(linhaproj)

with open(SEQ_PATTERNS_DIR + os.sep + 'sequencial_project.txt', "w") as output:
    output.write(str(linhaproj))
# Out:
# 1 1 entrou 1 if [120000, 12, 180000]
# 1 1 total 1 [120000, 12, 180000, 18]
# 1 1 entrou 1 if [120000, 12, 180000, 18, 340000]
# 1 1 total 1 [120000, 12, 180000, 18, 340000, 34]
# 1 1 entrou 1 if [120000, 12, 180000, 18, 340000, 34, 480000]
# 1 1 total 1 [120000, 12, 180000, 18, 340000, 34, 480000, 48]
# 2 2 entrou 1 else [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000]
# 2 2 total 1 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23]
# 2 2 entrou 1 else [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000]
# 2 2 total 1 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41]
# 3 3 entrou 1 else [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000]
# 3 3 total 1 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37]
# 7 7 entrou 1 elif 2 18 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 1800] 1 -1 -1
# 7 7 entrou 1 elif 2 23 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 1800, 2300] 2 -1 -1
# 7 7 entrou 1 elif 2 34 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 1800, 2300, 3400] 3 -1 -1
# 7 7 entrou 1 elif 2 37 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 1800, 2300, 3400, 3700] 4 -1 -1
# 7 7 entrou 1 elif 2 41 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 1800, 2300, 3400, 3700, 4100] 5 -1 -1
# 7 7 entrou 1 elif 2 48 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 1800, 2300, 3400, 3700, 4100, 4800] 6 -1 -1
# 9 0 entrou newlist 12 [120000, 12, 180000, 18, 340000, 34, 480000, 48, '-1', 12, 18, 23000, 23, 34, 41000, 41, 48, '-1', 12, 18, 23, 34, 37000, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 18, 23, 34, 37, 41, 48, '-1', 12, 1800, 2300, 3400, 3700, 4100, 4800, '-1', 12, '-1', 1200]
# 1 1 entrou 1 if [130000]
# 1 1 total 1 [130000, 13]
# 1 1 entrou 1 if [130000, 13, 320000]
# 1 1 total 1 [130000, 13, 320000, 32]
# 1 1 entrou 1 if [130000, 13, 320000, 32, 340000]
# 1 1 total 1 [130000, 13, 320000, 32, 340000, 34]
# 1 1 entrou 1 if [130000, 13, 320000, 32, 340000, 34, 480000]
# 1 1 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48]
# 2 2 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000]
# 2 2 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33]
# 2 2 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000]
# 2 2 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37]
# 3 3 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000]
# 3 3 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18]
# 4 4 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000]
# 4 4 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23]
# 4 4 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000]
# 4 4 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43]
# 5 5 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000]
# 5 5 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20]
# 5 5 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000]
# 5 5 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000, 26]
# 7 7 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000, 26, 32, 33, 34, 37, 43, 48, '-1', 7, 13, 18, 20, 23, 26, 32, 33, 34, 37, 43, 48, '-1', 3000, 3, 7, 13, 16000]
# 7 7 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000, 26, 32, 33, 34, 37, 43, 48, '-1', 7, 13, 18, 20, 23, 26, 32, 33, 34, 37, 43, 48, '-1', 3000, 3, 7, 13, 16000, 16]
# 7 7 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000, 26, 32, 33, 34, 37, 43, 48, '-1', 7, 13, 18, 20, 23, 26, 32, 33, 34, 37, 43, 48, '-1', 3000, 3, 7, 13, 16000, 16, 18, 20, 23, 26, 32, 33, 34, 36000]
# 7 7 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000, 26, 32, 33, 34, 37, 43, 48, '-1', 7, 13, 18, 20, 23, 26, 32, 33, 34, 37, 43, 48, '-1', 3000, 3, 7, 13, 16000, 16, 18, 20, 23, 26, 32, 33, 34, 36000, 36]
# 8 8 entrou 1 else [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000, 26, 32, 33, 34, 37, 43, 48, '-1', 7, 13, 18, 20, 23, 26, 32, 33, 34, 37, 43, 48, '-1', 3000, 3, 7, 13, 16000, 16, 18, 20, 23, 26, 32, 33, 34, 36000, 36, 37, 43, 48, '-1', 3, 7, 10000]
# 8 8 total 1 [130000, 13, 320000, 32, 340000, 34, 480000, 48, '-1', 13, 32, 33000, 33, 34, 37000, 37, 48, '-1', 13, 18000, 18, 32, 33, 34, 37, 48, '-1', 7000, 7, 13, 18, 23000, 23, 32, 33, 34, 37, 43000, 43, 48, '-1', 7, 13, 18, 20000, 20, 23, 26000, 26, 32, 33, 34, 37, 43, 48, '-1', 7, 13, 18, 20, 23, 26, 32, 33, 34, 37, 43, 48, '-1', 3000, 3, 7, 13, 16000, 16, 18, 20, 23, 26, 32, 33, 34, 36000, 36, 37, 43, 48, '-1', 3, 7, 10000, 10]
# 1 1 entrou 1 if [180000]
# 1 1 total 1 [180000, 18]
# 1 1 entrou 1 if [180000, 18, 380000]
# 1 1 total 1 [180000, 18, 380000, 38]
# 2 2 entrou 1 else [180000, 18, 380000, 38, '-1', 18, 38, 48000]
# 2 2 total 1 [180000, 18, 380000, 38, '-1', 18, 38, 48000, 48]
# 3 3 entrou 1 else [180000, 18, 380000, 38, '-1', 18, 38, 48000, 48, '-1', 18, 34000]
# 3 3 total 1 [180000, 18, 380000, 38, '-1', 18, 38, 48000, 48, '-1', 18, 34000, 34]
# 3 3 entrou 1 elif 2 48 [180000, 18, 380000, 38, '-1', 18, 38, 48000, 48, '-1', 18, 34000, 34, 38, 4800] 3 2 -1
# 4 4 entrou 1 else [180000, 18, 380000, 38, '-1', 18, 38, 48000, 48, '-1', 18, 34000, 34, 38, 4800, '-1', 10000, 10, 18, 34, 38, 48000]
# 4 4 total 1 [180000, 18, 380000, 38, '-1', 18, 38, 48000, 48, '-1', 18, 34000, 34, 38, 4800, '-1', 10000, 10, 18, 34, 38, 48000, 48]
# 6 6 entrou 1 elif 2 18 [180000, 18, 380000, 38, '-1', 18, 38, 48000, 48, '-1', 18, 34000, 34, 38, 4800, '-1', 10000, 10, 18, 34, 38, 48000, 48, '-1', 10, 18, 34, 38, 48, '-1', 10, 1800] 1 -1 -1
# 1 1 entrou 1 if [480000]
# 1 1 total 1 [480000, 48]
# 10 10 entrou 1 else [6000, 6, '-1', 6, 38000]
# 10 10 total 1 [6000, 6, '-1', 6, 38000, 38]
# 10 10 entrou 1 else [6000, 6, '-1', 6, 38000, 38, 48000]
# 10 10 total 1 [6000, 6, '-1', 6, 38000, 38, 48000, 48]
# 1 1 entrou 1 if [380000]
# 1 1 total 1 [380000, 38]
# 8 0 entrou newlist 18 [18000, 18, '-1', 18, '-1', 1800]
# 2 2 entrou 1 else [7000, 7, 38000]
# 2 2 total 1 [7000, 7, 38000, 38]
# 3 3 entrou 1 else [7000, 7, 38000, 38, '-1', 2000, 2, 7, 38, 48000]
# 3 3 total 1 [7000, 7, 38000, 38, '-1', 2000, 2, 7, 38, 48000, 48]
# 4 4 entrou 1 elif 2 48 [7000, 7, 38000, 38, '-1', 2000, 2, 7, 38, 48000, 48, '-1', 2, 7, 38, 4800] 5 4 -1
# 6 6 entrou 1 else [7000, 7, 38000, 38, '-1', 2000, 2, 7, 38, 48000, 48, '-1', 2, 7, 38, 4800, '-1', 2, 7, 38, '-1', 2, 7, 38, 47000]
# 6 6 total 1 [7000, 7, 38000, 38, '-1', 2000, 2, 7, 38, 48000, 48, '-1', 2, 7, 38, 4800, '-1', 2, 7, 38, '-1', 2, 7, 38, 47000, 47]
# 1 1 entrou 1 if [70000]
# 1 1 total 1 [70000, 7]
# 1 1 entrou 1 if [70000, 7, 140000]
# 1 1 total 1 [70000, 7, 140000, 14]
# 1 1 entrou 1 if [70000, 7, 140000, 14, 180000]
# 1 1 total 1 [70000, 7, 140000, 14, 180000, 18]
# 1 1 entrou 1 if [70000, 7, 140000, 14, 180000, 18, 480000]
# 1 1 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48]
# 2 2 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000]
# 2 2 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12]
# 2 2 entrou 1 elif 2 14 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400] 3 -1 -1
# 3 3 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000]
# 3 3 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16]
# 3 3 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000]
# 3 3 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26]
# 4 4 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000]
# 4 4 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34]
# 7 7 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000]
# 7 7 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31]
# 8 8 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000]
# 8 8 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36]
# 8 8 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000]
# 8 8 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38]
# 9 9 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000]
# 9 9 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10]
# 9 9 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000]
# 9 9 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14]
# 9 9 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000]
# 9 9 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37]
# 9 9 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000]
# 9 9 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41]
# 10 0 entrou newlist 2 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200]
# 10 10 entrou 1 elif 2 10 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000] 3 2 -1
# 10 10 entrou 1 elif 2 14 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000, 12, 1400] 6 5 -1
# 10 10 entrou 1 elif 2 31 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000, 12, 1400, 16, 18, 26, 3100] 10 -1 -1
# 10 10 entrou 1 elif 2 36 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000, 12, 1400, 16, 18, 26, 3100, 34, 3600] 12 -1 -1
# 10 10 entrou 1 elif 2 38 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000, 12, 1400, 16, 18, 26, 3100, 34, 3600, 37, 3800] 15 -1 -1
# 10 10 entrou 1 elif 2 41 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000, 12, 1400, 16, 18, 26, 3100, 34, 3600, 37, 3800, 4100] 17 16 -1
# 10 10 entrou 1 else [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000, 12, 1400, 16, 18, 26, 3100, 34, 3600, 37, 3800, 4100, 47000]
# 10 10 total 1 [70000, 7, 140000, 14, 180000, 18, 480000, 48, '-1', 7, 12000, 12, 1400, 18, 48, '-1', 7, 12, 16000, 16, 18, 26000, 26, 48, '-1', 2000, 2, 7, 12, 16, 18, 26, 34000, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31000, 31, 34, 48, '-1', 2, 7, 12, 16, 18, 26, 31, 34, 36000, 36, 38000, 38, 48, '-1', 2, 7, 10000, 10, 12, 14000, 14, 16, 18, 26, 31, 34, 36, 37000, 37, 38, 41000, 41, 48, '-1', 200, 7, 1000, 12, 1400, 16, 18, 26, 3100, 34, 3600, 37, 3800, 4100, 47000, 47]
# 3 0 entrou newlist 44 [44000, 44, '-1', 4400]
# 7 7 entrou 1 else [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000]
# 7 7 total 1 [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20]
# 8 8 entrou 1 else [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000]
# 8 8 total 1 [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30]
# 8 8 entrou 1 else [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000]
# 8 8 total 1 [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37]
# 8 8 entrou 1 else [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37, 38, 48000]
# 8 8 total 1 [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37, 38, 48000, 48]
# 9 9 entrou 1 elif 2 30 [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37, 38, 48000, 48, '-1', 14, 20, 3000] 3 2 -1
# 10 10 entrou 1 else [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37, 38, 48000, 48, '-1', 14, 20, 3000, 37, 38, 48, '-1', 14, 20, 31000]
# 10 10 total 1 [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37, 38, 48000, 48, '-1', 14, 20, 3000, 37, 38, 48, '-1', 14, 20, 31000, 31]
# 10 10 entrou 1 else [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37, 38, 48000, 48, '-1', 14, 20, 3000, 37, 38, 48, '-1', 14, 20, 31000, 31, 37, 38, 39000]
# 10 10 total 1 [44000, 44, '-1', 4400, '-1', 38000, 38, '-1', 38, '-1', 38, '-1', 14000, 14, 20000, 20, 38, '-1', 14, 20, 30000, 30, 37000, 37, 38, 48000, 48, '-1', 14, 20, 3000, 37, 38, 48, '-1', 14, 20, 31000, 31, 37, 38, 39000, 39]
# 1 1 entrou 1 if [480000]
# 1 1 total 1 [480000, 48]
# 2 2 entrou 1 else [12000, 12, 48000]
# 2 2 total 1 [12000, 12, 48000, 48]
# 1 1 entrou 1 if [480000]
# 1 1 total 1 [480000, 48]
# 3 0 entrou newlist 48 [480000, 48, '-1', 48, '-1', 4800]
# 4 4 entrou 1 else [7000, 7, 14000]
# 4 4 total 1 [7000, 7, 14000, 14]
# 4 4 entrou 1 else [7000, 7, 14000, 14, 16000]
# 4 4 total 1 [7000, 7, 14000, 14, 16000, 16]
# 4 4 entrou 1 else [7000, 7, 14000, 14, 16000, 16, 20000]
# 4 4 total 1 [7000, 7, 14000, 14, 16000, 16, 20000, 20]
# 4 4 entrou 1 else [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000]
# 4 4 total 1 [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31]
# 4 4 entrou 1 else [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000]
# 4 4 total 1 [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48]
# 5 5 entrou 1 elif 2 20 [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48, '-1', 7, 14, 16, 2000] 7 6 -1
# 5 5 entrou 1 else [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48, '-1', 7, 14, 16, 2000, 31, 36000]
# 5 5 total 1 [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48, '-1', 7, 14, 16, 2000, 31, 36000, 36]
# 6 6 entrou 1 else [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48, '-1', 7, 14, 16, 2000, 31, 36000, 36, 48, '-1', 7, 14, 16, 20000]
# 6 6 total 1 [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48, '-1', 7, 14, 16, 2000, 31, 36000, 36, 48, '-1', 7, 14, 16, 20000, 20]
# 6 6 entrou 1 else [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48, '-1', 7, 14, 16, 2000, 31, 36000, 36, 48, '-1', 7, 14, 16, 20000, 20, 26000]
# 6 6 total 1 [7000, 7, 14000, 14, 16000, 16, 20000, 20, 31000, 31, 48000, 48, '-1', 7, 14, 16, 2000, 31, 36000, 36, 48, '-1', 7, 14, 16, 20000, 20, 26000, 26]
# 1 1 entrou 1 if [60000]
# 1 1 total 1 [60000, 6]
# 1 1 entrou 1 if [60000, 6, 340000]
# 1 1 total 1 [60000, 6, 340000, 34]
# 1 1 entrou 1 if [60000, 6, 340000, 34, 480000]
# 1 1 total 1 [60000, 6, 340000, 34, 480000, 48]
# 2 2 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000]
# 2 2 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18]
# 2 2 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000]
# 2 2 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37]
# 2 2 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000]
# 2 2 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43]
# 3 3 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000]
# 3 3 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12]
# 3 3 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000]
# 3 3 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14]
# 3 3 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14, 18, 23000]
# 3 3 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14, 18, 23000, 23]
# 4 4 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14, 18, 23000, 23, 34, 37, 43, 48, '-1', 6, 7000]
# 4 4 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14, 18, 23000, 23, 34, 37, 43, 48, '-1', 6, 7000, 7]
# 9 9 entrou 1 elif 2 7 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14, 18, 23000, 23, 34, 37, 43, 48, '-1', 6, 7000, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 700] 1 -1 -1
# 10 10 entrou 1 else [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14, 18, 23000, 23, 34, 37, 43, 48, '-1', 6, 7000, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 700, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 12, 14, 18, 23, 34, 37, 38000]
# 10 10 total 1 [60000, 6, 340000, 34, 480000, 48, '-1', 6, 18000, 18, 34, 37000, 37, 43000, 43, 48, '-1', 6, 12000, 12, 14000, 14, 18, 23000, 23, 34, 37, 43, 48, '-1', 6, 7000, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 7, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 700, 12, 14, 18, 23, 34, 37, 43, 48, '-1', 6, 12, 14, 18, 23, 34, 37, 38000, 38]
# 1 1 entrou 1 if [60000]
# 1 1 total 1 [60000, 6]
# 1 1 entrou 1 if [60000, 6, 90000]
# 1 1 total 1 [60000, 6, 90000, 9]
# 2 0 entrou newlist 6 [60000, 6, 90000, 9, '-1', 600]
# 2 2 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000]
# 2 2 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10]
# 2 2 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000]
# 2 2 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34]
# 2 2 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000]
# 2 2 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37]
# 2 2 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000]
# 2 2 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48]
# 3 3 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000]
# 3 3 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7]
# 3 3 entrou 1 elif 2 10 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000] 3 2 -1
# 3 3 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000]
# 3 3 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36]
# 3 3 entrou 1 elif 2 37 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700] 7 6 -1
# 3 3 entrou 1 elif 2 48 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800] 9 8 -1
# 3 3 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000]
# 3 3 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50]
# 4 4 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000]
# 4 4 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12]
# 4 4 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000]
# 4 4 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14]
# 4 4 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000]
# 4 4 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16]
# 4 4 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000]
# 4 4 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33]
# 4 4 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000]
# 4 4 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48]
# 5 5 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000]
# 5 5 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10]
# 6 6 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000]
# 6 6 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000, 26]
# 7 7 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11000]
# 7 7 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11000, 11]
# 8 8 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11000, 11, 12, 14, 16, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11, 12, 14, 16, 26, 27000]
# 8 8 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11000, 11, 12, 14, 16, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11, 12, 14, 16, 26, 27000, 27]
# 9 9 entrou 1 else [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11000, 11, 12, 14, 16, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11, 12, 14, 16, 26, 27000, 27, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11, 12, 14, 16, 26, 27, 29000]
# 9 9 total 1 [60000, 6, 90000, 9, '-1', 600, 9, 10000, 10, 34000, 34, 37000, 37, 48000, 48, '-1', 6000, 6, 7000, 7, 9, 1000, 34, 36000, 36, 3700, 4800, 50000, 50, '-1', 6, 7, 9, 12000, 12, 14000, 14, 16000, 16, 33000, 33, 34, 36, 48000, 48, 50, '-1', 6, 7, 9, 10000, 10, 12, 14, 16, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 12, 14, 16, 26000, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11000, 11, 12, 14, 16, 26, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11, 12, 14, 16, 26, 27000, 27, 33, 34, 36, 48, 50, '-1', 6, 7, 9, 10, 11, 12, 14, 16, 26, 27, 29000, 29]
# 2 2 entrou 1 else [8000, 8, 16000]
# 2 2 total 1 [8000, 8, 16000, 16]
# 2 2 entrou 1 else [8000, 8, 16000, 16, 30000]
# 2 2 total 1 [8000, 8, 16000, 16, 30000, 30]
# 2 2 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000]
# 2 2 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36]
# 2 2 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000]
# 2 2 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48]
# 3 0 entrou newlist 8 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800]
# 3 3 entrou 1 elif 2 16 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600] 3 2 -1
# 3 3 entrou 1 elif 2 30 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000] 5 4 -1
# 3 3 entrou 1 elif 2 36 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600] 7 6 -1
# 3 3 entrou 1 elif 2 48 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800] 9 8 -1
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36]
# 4 4 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000]
# 4 4 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000, 23]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000, 23, 26, 29000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000, 23, 26, 29000, 29]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000, 23, 26, 29000, 29, 30, 31, 32000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000, 23, 26, 29000, 29, 30, 31, 32000, 32]
# 5 5 entrou 1 else [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000, 23, 26, 29000, 29, 30, 31, 32000, 32, 33000]
# 5 5 total 1 [8000, 8, 16000, 16, 30000, 30, 36000, 36, 48000, 48, '-1', 800, 1600, 3000, 3600, 4800, '-1', 7000, 7, 8000, 8, 14000, 14, 16000, 16, 20000, 20, 26000, 26, 30000, 30, 31000, 31, 34000, 34, 36000, 36, 48000, 48, '-1', 7, 8, 10000, 10, 12000, 12, 14, 16, 17000, 17, 18000, 18, 20, 21000, 21, 22000, 22, 23000, 23, 26, 29000, 29, 30, 31, 32000, 32, 33000, 33]
# ...
# 1 1 entrou 1 if [340000]
# 1 1 total 1 [340000, 34]
# 3 0 entrou newlist 34 [340000, 34, '-1', 34, '-1', 3400]
# 3 0 entrou newlist 12 [12000, 12, '-1', 1200]
# 10 10 entrou 1 else [7000, 7, '-1', 7, '-1', 7, 10000]
# 10 10 total 1 [7000, 7, '-1', 7, '-1', 7, 10000, 10]
# 10 10 entrou 1 else [7000, 7, '-1', 7, '-1', 7, 10000, 10, 12000]
# 10 10 total 1 [7000, 7, '-1', 7, '-1', 7, 10000, 10, 12000, 12]
# 1 1 entrou 1 if [480000]
# 1 1 total 1 [480000, 48]
# 3 3 entrou 1 else [480000, 48, '-1', 48, '-1', 12000, 12, 14000]
# 3 3 total 1 [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14]
# 4 0 entrou newlist 12 [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200]
# 4 4 entrou 1 elif 2 14 [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200, 1400] 3 2 -1
# 9 9 entrou 1 else [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200, 1400, 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 12000, 12, 14000]
# 9 9 total 1 [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200, 1400, 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 12000, 12, 14000, 14]
# 9 9 entrou 1 elif 2 48 [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200, 1400, 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 12000, 12, 14000, 14, 4800] 0 -1 -1
# 10 10 entrou 1 elif 2 12 [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200, 1400, 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 12000, 12, 14000, 14, 4800, '-1', 7000, 7, 1200] 1 0 -1
# 10 10 entrou 1 else [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200, 1400, 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 12000, 12, 14000, 14, 4800, '-1', 7000, 7, 1200, 14, 26000]
# 10 10 total 1 [480000, 48, '-1', 48, '-1', 12000, 12, 14000, 14, 48, '-1', 1200, 1400, 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 12000, 12, 14000, 14, 4800, '-1', 7000, 7, 1200, 14, 26000, 26]
# 1 1 entrou 1 if [120000]
# 1 1 total 1 [120000, 12]
# 1 1 entrou 1 if [120000, 12, 340000]
# 1 1 total 1 [120000, 12, 340000, 34]
# 2 2 entrou 1 elif 2 34 [120000, 12, 340000, 34, '-1', 12, 3400] 3 -1 -1
# 2 2 entrou 1 else [120000, 12, 340000, 34, '-1', 12, 3400, 48000]
# 2 2 total 1 [120000, 12, 340000, 34, '-1', 12, 3400, 48000, 48]
# 6 0 entrou newlist 12 [120000, 12, 340000, 34, '-1', 12, 3400, 48000, 48, '-1', 12, 48, '-1', 12, 48, '-1', 12, 48, '-1', 1200]
# 1 1 entrou 1 if [380000]
# 1 1 total 1 [380000, 38]
# 3 3 entrou 1 else [380000, 38, '-1', 38, '-1', 16000, 16, 18000]
# 3 3 total 1 [380000, 38, '-1', 38, '-1', 16000, 16, 18000, 18]
# 7 7 entrou 1 elif 2 18 [380000, 38, '-1', 38, '-1', 16000, 16, 18000, 18, 38, '-1', 16, 18, 38, '-1', 16, 18, 38, '-1', 16, 18, 38, '-1', 16, 1800] 1 -1 -1
# 1 1 entrou 1 if [260000]
# 1 1 total 1 [260000, 26]
# 1 1 entrou 1 if [260000, 26, 480000]
# 1 1 total 1 [260000, 26, 480000, 48]
# 1 1 entrou 1 if [120000]
# 1 1 total 1 [120000, 12]
# 5 0 entrou newlist 12 [120000, 12, '-1', 12, '-1', 12, '-1', 12, '-1', 1200]
# 10 0 entrou newlist 48 [48000, 48, '-1', 4800]
# 9 0 entrou newlist 12 [12000, 12, '-1', 12, '-1', 12, '-1', 12, '-1', 12, '-1', 12, '-1', 12, '-1', 1200]
# 1 1 entrou 1 if [90000]
# 1 1 total 1 [90000, 9]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000, 31]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000, 31, 34000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000, 31, 34000, 34]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000, 31, 34000, 34, 37000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000, 31, 34000, 34, 37000, 37]
# 10 10 entrou 1 else [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000, 31, 34000, 34, 37000, 37, 48000]
# 10 10 total 1 [90000, 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, '-1', 9, 10000, 10, 12000, 12, 18000, 18, 21000, 21, 23000, 23, 31000, 31, 34000, 34, 37000, 37, 48000, 48]
# 1 1 entrou 1 if [180000]
# 1 1 total 1 [180000, 18]
# 1 1 entrou 1 if [180000, 18, 230000]
# 1 1 total 1 [180000, 18, 230000, 23]
# 1 1 entrou 1 if [180000, 18, 230000, 23, 410000]
# 1 1 total 1 [180000, 18, 230000, 23, 410000, 41]
# 1 1 entrou 1 if [180000, 18, 230000, 23, 410000, 41, 480000]
# 1 1 total 1 [180000, 18, 230000, 23, 410000, 41, 480000, 48]
# 4 4 entrou 1 else [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000]
# 4 4 total 1 [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34]
# 4 4 entrou 1 elif 2 41 [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100] 2 -1 -1
# 5 5 entrou 1 elif 2 23 [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300] 1 -1 -1
# 5 5 entrou 1 else [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300, 34, 37000]
# 5 5 total 1 [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300, 34, 37000, 37]
# 5 5 entrou 1 else [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300, 34, 37000, 37, 38000]
# 5 5 total 1 [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300, 34, 37000, 37, 38000, 38]
# 6 6 entrou 1 else [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300, 34, 37000, 37, 38000, 38, 48, '-1', 10, 12000]
# 6 6 total 1 [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300, 34, 37000, 37, 38000, 38, 48, '-1', 10, 12000, 12]
# 7 7 entrou 1 elif 2 12 [180000, 18, 230000, 23, 410000, 41, 480000, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 41, 48, '-1', 18, 23, 34000, 34, 4100, 48, '-1', 10000, 10, 18, 2300, 34, 37000, 37, 38000, 38, 48, '-1', 10, 12000, 12, 18, 34, 37, 38, 48, '-1', 10, 1200] 2 1 -1
# 1 1 entrou 1 if [270000]
# 1 1 total 1 [270000, 27]
# 1 1 entrou 1 if [270000, 27, 340000]
# 1 1 total 1 [270000, 27, 340000, 34]
# 1 1 entrou 1 if [270000, 27, 340000, 34, 360000]
# 1 1 total 1 [270000, 27, 340000, 34, 360000, 36]
# 1 1 entrou 1 if [270000, 27, 340000, 34, 360000, 36, 380000]
# 1 1 total 1 [270000, 27, 340000, 34, 360000, 36, 380000, 38]
# 2 2 entrou 1 else [270000, 27, 340000, 34, 360000, 36, 380000, 38, '-1', 7000, 7, 16000]
# 2 2 total 1 [270000, 27, 340000, 34, 360000, 36, 380000, 38, '-1', 7000, 7, 16000, 16]
# 2 2 entrou 1 elif 2 27 [270000, 27, 340000, 34, 360000, 36, 380000, 38, '-1', 7000, 7, 16000, 16, 2700] 1 -1 -1
# 1 1 entrou 1 if [380000]
# 1 1 total 1 [380000, 38]
# 3 0 entrou newlist 38 [380000, 38, '-1', 38, '-1', 3800]
# 1 1 entrou 1 if [120000]
# 1 1 total 1 [120000, 12]
# 1 1 entrou 1 if [120000, 12, 340000]
# 1 1 total 1 [120000, 12, 340000, 34]
# 1 1 entrou 1 if [120000, 12, 340000, 34, 480000]
# 1 1 total 1 [120000, 12, 340000, 34, 480000, 48]
# 5 5 entrou 1 else [120000, 12, 340000, 34, 480000, 48, '-1', 12, 34, 48, '-1', 12, 34, 48, '-1', 12, 34, 48, '-1', 12, 34, 37000]
# 5 5 total 1 [120000, 12, 340000, 34, 480000, 48, '-1', 12, 34, 48, '-1', 12, 34, 48, '-1', 12, 34, 48, '-1', 12, 34, 37000, 37]
# 10 10 entrou 1 elif 2 34 [120000, 12, 340000, 34, 480000, 48, '-1', 12, 34, 48, '-1', 12, 34, 48, '-1', 12, 34, 48, '-1', 12, 34, 37000, 37, 48, '-1', 12, 34, 37, 48, '-1', 12, 34, 37, 48, '-1', 12, 34, 37, 48, '-1', 12, 34, 37, 48, '-1', 12, 3400] 1 -1 -1
# 1 1 entrou 1 if [180000]
# 1 1 total 1 [180000, 18]
# 1 1 entrou 1 if [180000, 18, 370000]
# 1 1 total 1 [180000, 18, 370000, 37]
# 1 1 entrou 1 if [180000, 18, 370000, 37, 480000]
# 1 1 total 1 [180000, 18, 370000, 37, 480000, 48]
# 9 9 entrou 1 else [180000, 18, 370000, 37, 480000, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 30000]
# 9 9 total 1 [180000, 18, 370000, 37, 480000, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 30000, 30]
# 10 0 entrou newlist 18 [180000, 18, 370000, 37, 480000, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 30000, 30, 37, 48, '-1', 1800]
# 10 10 entrou 1 else [180000, 18, 370000, 37, 480000, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 30000, 30, 37, 48, '-1', 1800, 30, 34000]
# 10 10 total 1 [180000, 18, 370000, 37, 480000, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 30000, 30, 37, 48, '-1', 1800, 30, 34000, 34]
# 10 10 entrou 1 elif 2 37 [180000, 18, 370000, 37, 480000, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 37, 48, '-1', 18, 30000, 30, 37, 48, '-1', 1800, 30, 34000, 34, 3700] 3 -1 -1
# 1 1 entrou 1 if [120000]
# 1 1 total 1 [120000, 12]
# 6 6 entrou 1 else [120000, 12, '-1', 12, '-1', 12, '-1', 12, '-1', 12, '-1', 12, 18000]
# 6 6 total 1 [120000, 12, '-1', 12, '-1', 12, '-1', 12, '-1', 12, '-1', 12, 18000, 18]
# 1 1 entrou 1 if [300000]
# 1 1 total 1 [300000, 30]
# 3 0 entrou newlist 26 [300000, 30, '-1', 26000, 26, 30, '-1', 2600]
# 3 3 entrou 1 elif 2 30 [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000] 2 -1 -1
# 4 4 entrou 1 else [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000, '-1', 26000, 26, 34000]
# 4 4 total 1 [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000, '-1', 26000, 26, 34000, 34]
# 4 4 entrou 1 else [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000, '-1', 26000, 26, 34000, 34, 37000]
# 4 4 total 1 [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000, '-1', 26000, 26, 34000, 34, 37000, 37]
# 4 4 entrou 1 else [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000, '-1', 26000, 26, 34000, 34, 37000, 37, 48000]
# 4 4 total 1 [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000, '-1', 26000, 26, 34000, 34, 37000, 37, 48000, 48]
# 10 10 entrou 1 elif 2 48 [300000, 30, '-1', 26000, 26, 30, '-1', 2600, 3000, '-1', 26000, 26, 34000, 34, 37000, 37, 48000, 48, '-1', 26, 34, 37, 48, '-1', 26, 34, 37, 48, '-1', 26, 34, 37, 48, '-1', 26, 34, 37, 48, '-1', 26, 34, 37, 48, '-1', 10000, 10, 26, 34, 37, 4800] 3 -1 -1
# 1 0 entrou 4 if [20000]
# 1 0 total 4 [20000, 2]
# 1 1 entrou 1 if [20000, 2, 90000]
# 1 1 total 1 [20000, 2, 90000, 9]
# 7 0 entrou newlist 48 [48000, 48, '-1', 4800]
# 7 7 entrou 1 else [10000, 10, 30000]
# 7 7 total 1 [10000, 10, 30000, 30]
# 7 7 entrou 1 else [10000, 10, 30000, 30, 48000]
# 7 7 total 1 [10000, 10, 30000, 30, 48000, 48]
# 8 8 entrou 1 else [10000, 10, 30000, 30, 48000, 48, '-1', 10, 30, 34000]
# 8 8 total 1 [10000, 10, 30000, 30, 48000, 48, '-1', 10, 30, 34000, 34]
# 1 1 entrou 1 if [120000]
# 1 1 total 1 [120000, 12]
# 2 2 entrou 1 else [120000, 12, '-1', 12, 48000]
# 2 2 total 1 [120000, 12, '-1', 12, 48000, 48]
# 3 3 entrou 1 else [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000]
# 3 3 total 1 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18]
# 3 3 entrou 1 else [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000]
# 3 3 total 1 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23]
# 3 3 entrou 1 else [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000]
# 3 3 total 1 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34]
# 3 3 entrou 1 else [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000]
# 3 3 total 1 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37]
# 3 3 entrou 1 else [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37, 41000]
# 3 3 total 1 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37, 41000, 41]
# 4 4 entrou 1 else [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37, 41000, 41, 48, '-1', 12, 18, 23, 34, 37, 38000]
# 4 4 total 1 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37, 41000, 41, 48, '-1', 12, 18, 23, 34, 37, 38000, 38]
# 4 4 entrou 1 else [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37, 41000, 41, 48, '-1', 12, 18, 23, 34, 37, 38000, 38, 40000]
# 4 4 total 1 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37, 41000, 41, 48, '-1', 12, 18, 23, 34, 37, 38000, 38, 40000, 40]
# 5 5 entrou 1 elif 2 40 [120000, 12, '-1', 12, 48000, 48, '-1', 12, 18000, 18, 23000, 23, 34000, 34, 37000, 37, 41000, 41, 48, '-1', 12, 18, 23, 34, 37, 38000, 38, 40000, 40, 41, 48, '-1', 12, 18, 23, 34, 37, 38, 4000] 8 7 -1
# 1 1 entrou 1 if [340000]
# 1 1 total 1 [340000, 34]
# 1 1 entrou 1 if [340000, 34, 480000]
# 1 1 total 1 [340000, 34, 480000, 48]
# 3 3 entrou 1 else [18000, 18, '-1', 18, 30000]
# 3 3 total 1 [18000, 18, '-1', 18, 30000, 30]
# 5 5 entrou 1 else [18000, 18, '-1', 18, 30000, 30, '-1', 18, 30, '-1', 18, 30, 48000]
# 5 5 total 1 [18000, 18, '-1', 18, 30000, 30, '-1', 18, 30, '-1', 18, 30, 48000, 48]
# 8 0 entrou newlist 18 [18000, 18, '-1', 18, 30000, 30, '-1', 18, 30, '-1', 18, 30, 48000, 48, '-1', 18, 30, 48, '-1', 18, 30, 48, '-1', 1800]
# 1 1 entrou 1 if [480000]
# 1 1 total 1 [480000, 48]
# 10 0 entrou newlist 7 [480000, 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 48, '-1', 7000, 7, 48, '-1', 7, 48, '-1', 7, 48, '-1', 700]
# 26

# %%
#df2.to_excel("input_sequencial_init_in_out.txt",index=True)
#file = open('input_sequencial_init_in_out_2.txt', "w")
#file = open( SEQ_PATTERNS_DIR + os.sep + 'testes/input_sequencial_init_in_out_3.txt', "w")
file = open( SEQ_PATTERNS_DIR + os.sep + 'input_sequencial_init_in_out.txt', "w") #'testes/input_sequencial_init_in_out_6.txt', "w")
#dict_col
dict = []
#file = open("input_sequencial_nb_neg.txt", "w")
specialChars = "[',']" # Para retirar estes caracteres que são incluídos pelo array
#for dict in dict_col: # Writes to file
 #   for specialChar in specialChars:
dict = str(dict_col).replace("[['",'')
dict = str(dict).replace("']]",'\n')
file.write(str(dict).replace("', '",'\n'))
#coluna.insert(0,str(dict_col))
for values in coluna: # Writes to file
    for specialChar in specialChars:
        values = str(values).replace(specialChar,'')
    file.write(str(values) + '\n')
file.close()

# %% [markdown]
# Now we have the input file in the format required by the SPMF library. To generate sequential patterns according to our analysis, via the command line, as follows the steps below:: in a folder containing spmf.jar and the output file output__in_out.txt, in this case in /resources/seq_patterns.
#
# a) To generate results in size 1:
#
#  Run "java -jar spmf.jar run PrefixSpan input_sequencial_init_in_out.txt output_tam1.txt 1% 1"
#
# b) To generate results in size 3:
#
# Run "java -jar spmf.jar run PrefixSpan input_sequencial_init_in_out.txt output_tam3.txt 1% 3"
#
# c) To generate results in size 4:
#
# Run "java -jar spmf.jar run PrefixSpan input_sequencial_init_in_out.txt output_tam4_sid.txt 1% 4"
#
# d) Save the three output files in the resources/seq_pattens folder as they will be used by "historical_seqpatterns_filters.ipynb" script.
#
#
# PrefixSpan is one of the fastest sequential pattern mining algorithm (http://www.philippe-fournier-viger.com/spmf/PrefixSpan.php).
# The PrefixSpan implementation allows to specify additional optional parameter(s) :
#
#     "maximum pattern length" allows to specify the maximum number of items that patterns found should contain.
#
#     "show sequences ids?" (true/false) This parameter allows to specify that sequence ids of sequences containing a pattern should be output for each pattern found.
#      For example, if the parameter is set to true, each pattern in the output file will be followed by the keyword #SID followed by a list of sequences ids (integers separated by space).
#      For example, a line terminated by "#SID: 0 2" means that the pattern on this line appears in the first and the third sequences of the sequence database (sequences with ids 0 and 2).
