# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import os
from util import SEQ_PATTERNS_DIR
projectsWithBD = 197

# %% [markdown]
# This script applies filters to search for established replacement patterns and generates some data mining measures.

# %%
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT = SEQ_PATTERNS_DIR + os.sep + 'output_init_tam4_SSID.txt' #add in util.py output_init_tam4_sid_2
HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT = SEQ_PATTERNS_DIR + os.sep + 'output_tam4_sid.txt' #'testes/output_init_tam4_sid_7.txt'
df = pd.read_csv(HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT, sep= '#', header=None) #não funcionou sep=" | , #",  engine = "python",
df
# Out:
#                                                          0        1  \
# 0                                           INInflux_DB |   SUP: 5
# 1                                 INInflux_DB Influx_DB |   SUP: 5
# 2                          INInflux_DB Influx_DB SQLite |   SUP: 2
# 3                       INInflux_DB Influx_DB Snowflake |   SUP: 2
# 4             INInflux_DB Influx_DB Snowflake Cassandra |   SUP: 2
# ...                                                    ...      ...
# 4096444  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | SAPAdapt...  SUP: 2
# 4096445  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | PostgreS...  SUP: 3
# 4096446        OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | H2 |   SUP: 2
# 4096447    OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | Oracle |   SUP: 3
# 4096448   OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | IBM_DB2 |   SUP: 3
#
#                             2
# 0        SID: 16 17 21 37 102
# 1        SID: 16 17 21 37 102
# 2                 SID: 17 102
# 3                  SID: 17 21
# 4                  SID: 17 21
# ...                       ...
# 4096444           SID: 36 192
# 4096445        SID: 36 58 192
# 4096446           SID: 36 192
# 4096447        SID: 36 58 192
# 4096448        SID: 36 58 192
#
# [4096449 rows x 3 columns]

# %%
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df.columns = ['Pattern','SUP_ABCD','SID']
df.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
df.replace({'SID:': ''}, regex=True, inplace=True) #ordf['SID'] = df['SID'].str.replace('SID:','')
df
# Out:
#                                                    Pattern SUP_ABCD  \
# 0                                           INInflux_DB |        5
# 1                                 INInflux_DB Influx_DB |        5
# 2                          INInflux_DB Influx_DB SQLite |        2
# 3                       INInflux_DB Influx_DB Snowflake |        2
# 4             INInflux_DB Influx_DB Snowflake Cassandra |        2
# ...                                                    ...      ...
# 4096444  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | SAPAdapt...       2
# 4096445  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | PostgreS...       3
# 4096446        OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | H2 |        2
# 4096447    OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | Oracle |        3
# 4096448   OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | IBM_DB2 |        3
#
#                       SID
# 0         16 17 21 37 102
# 1         16 17 21 37 102
# 2                  17 102
# 3                   17 21
# 4                   17 21
# ...                   ...
# 4096444            36 192
# 4096445         36 58 192
# 4096446            36 192
# 4096447         36 58 192
# 4096448         36 58 192
#
# [4096449 rows x 3 columns]

# %%
df2 = df.copy()

# %%
select_pattern = df2[(df2['Pattern'].str.contains('IN') & df2['Pattern'].str.contains('OUT'))] #df2['Pattern'].str.contains('INIT') |
select_pattern
# Out:
#                                                    Pattern SUP_ABCD  \
# 6441     MySQL_MariaDB HyperSQL INInformix | OUTHyperSQ...       2
# 6449     MySQL_MariaDB HyperSQL INInformix | OUTSAPAdap...       3
# 6819      MySQL_MariaDB HyperSQL INRedis | OUTCassandra |        2
# 6820       MySQL_MariaDB HyperSQL INRedis | OUTHyperSQL |        7
# 6825     MySQL_MariaDB HyperSQL INRedis | OUTPostgreSQL...       2
# ...                                                    ...      ...
# 4096400  OUTIBM_DB2 | OUTHazelcast | H2 | INSAPAdaptive...       2
# 4096411  OUTIBM_DB2 | OUTHazelcast | Oracle INSAPAdapti...       2
# 4096418  OUTIBM_DB2 | OUTHazelcast | Oracle | INSAPAdap...       2
# 4096431  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 INSAPAdapt...       2
# 4096437  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | INSAPAda...       2
#
#                               SID
# 6441                        17 76
# 6449                     17 36 76
# 6819                       14 118
# 6820      29 40 42 76 128 131 134
# 6825                       42 131
# ...                           ...
# 4096400                    36 192
# 4096411                    36 192
# 4096418                    36 192
# 4096431                    36 192
# 4096437                    36 192
#
# [490753 rows x 3 columns]

# %%
df3 = select_pattern.copy()
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 6441     MySQL_MariaDB HyperSQL INInformix | OUTHyperSQ...       2
# 6449     MySQL_MariaDB HyperSQL INInformix | OUTSAPAdap...       3
# 6819      MySQL_MariaDB HyperSQL INRedis | OUTCassandra |        2
# 6820       MySQL_MariaDB HyperSQL INRedis | OUTHyperSQL |        7
# 6825     MySQL_MariaDB HyperSQL INRedis | OUTPostgreSQL...       2
# ...                                                    ...      ...
# 4096400  OUTIBM_DB2 | OUTHazelcast | H2 | INSAPAdaptive...       2
# 4096411  OUTIBM_DB2 | OUTHazelcast | Oracle INSAPAdapti...       2
# 4096418  OUTIBM_DB2 | OUTHazelcast | Oracle | INSAPAdap...       2
# 4096431  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 INSAPAdapt...       2
# 4096437  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | INSAPAda...       2
#
#                               SID
# 6441                        17 76
# 6449                     17 36 76
# 6819                       14 118
# 6820      29 40 42 76 128 131 134
# 6825                       42 131
# ...                           ...
# 4096400                    36 192
# 4096411                    36 192
# 4096418                    36 192
# 4096431                    36 192
# 4096437                    36 192
#
# [490753 rows x 3 columns]

# %%
df3['Pattern'].replace({r"(?<=\w)\s+(?=\w)": '#/#'}, regex=True, inplace=True)
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 6441     MySQL_MariaDB#/#HyperSQL#/#INInformix | OUTHyp...       2
# 6449     MySQL_MariaDB#/#HyperSQL#/#INInformix | OUTSAP...       3
# 6819     MySQL_MariaDB#/#HyperSQL#/#INRedis | OUTCassan...       2
# 6820     MySQL_MariaDB#/#HyperSQL#/#INRedis | OUTHyperS...       7
# 6825     MySQL_MariaDB#/#HyperSQL#/#INRedis | OUTPostgr...       2
# ...                                                    ...      ...
# 4096400  OUTIBM_DB2 | OUTHazelcast | H2 | INSAPAdaptive...       2
# 4096411  OUTIBM_DB2 | OUTHazelcast | Oracle#/#INSAPAdap...       2
# 4096418  OUTIBM_DB2 | OUTHazelcast | Oracle | INSAPAdap...       2
# 4096431  OUTIBM_DB2 | OUTHazelcast | IBM_DB2#/#INSAPAda...       2
# 4096437  OUTIBM_DB2 | OUTHazelcast | IBM_DB2 | INSAPAda...       2
#
#                               SID
# 6441                        17 76
# 6449                     17 36 76
# 6819                       14 118
# 6820      29 40 42 76 128 131 134
# 6825                       42 131
# ...                           ...
# 4096400                    36 192
# 4096411                    36 192
# 4096418                    36 192
# 4096431                    36 192
# 4096437                    36 192
#
# [490753 rows x 3 columns]

# %%
df3['Pattern'].replace({r"(?<=|)\s+(?=|)": '#'}, regex=True, inplace=True)
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 6441     MySQL_MariaDB#/#HyperSQL#/#INInformix#|#OUTHyp...       2
# 6449     MySQL_MariaDB#/#HyperSQL#/#INInformix#|#OUTSAP...       3
# 6819     MySQL_MariaDB#/#HyperSQL#/#INRedis#|#OUTCassan...       2
# 6820     MySQL_MariaDB#/#HyperSQL#/#INRedis#|#OUTHyperS...       7
# 6825     MySQL_MariaDB#/#HyperSQL#/#INRedis#|#OUTPostgr...       2
# ...                                                    ...      ...
# 4096400  OUTIBM_DB2#|#OUTHazelcast#|#H2#|#INSAPAdaptive...       2
# 4096411  OUTIBM_DB2#|#OUTHazelcast#|#Oracle#/#INSAPAdap...       2
# 4096418  OUTIBM_DB2#|#OUTHazelcast#|#Oracle#|#INSAPAdap...       2
# 4096431  OUTIBM_DB2#|#OUTHazelcast#|#IBM_DB2#/#INSAPAda...       2
# 4096437  OUTIBM_DB2#|#OUTHazelcast#|#IBM_DB2#|#INSAPAda...       2
#
#                               SID
# 6441                        17 76
# 6449                     17 36 76
# 6819                       14 118
# 6820      29 40 42 76 128 131 134
# 6825                       42 131
# ...                           ...
# 4096400                    36 192
# 4096411                    36 192
# 4096418                    36 192
# 4096431                    36 192
# 4096437                    36 192
#
# [490753 rows x 3 columns]

# %%
df3[['A','AB','B','BC','C','CD','D','DE']] = df3['Pattern'].str.split("[#]", expand=True, n=7)
#df2['Pattern'].str.split('|', expand=True)
df3
# Out:
#                                                    Pattern SUP_ABCD  \
# 6441     MySQL_MariaDB#/#HyperSQL#/#INInformix#|#OUTHyp...       2
# 6449     MySQL_MariaDB#/#HyperSQL#/#INInformix#|#OUTSAP...       3
# 6819     MySQL_MariaDB#/#HyperSQL#/#INRedis#|#OUTCassan...       2
# 6820     MySQL_MariaDB#/#HyperSQL#/#INRedis#|#OUTHyperS...       7
# 6825     MySQL_MariaDB#/#HyperSQL#/#INRedis#|#OUTPostgr...       2
# ...                                                    ...      ...
# 4096400  OUTIBM_DB2#|#OUTHazelcast#|#H2#|#INSAPAdaptive...       2
# 4096411  OUTIBM_DB2#|#OUTHazelcast#|#Oracle#/#INSAPAdap...       2
# 4096418  OUTIBM_DB2#|#OUTHazelcast#|#Oracle#|#INSAPAdap...       2
# 4096431  OUTIBM_DB2#|#OUTHazelcast#|#IBM_DB2#/#INSAPAda...       2
# 4096437  OUTIBM_DB2#|#OUTHazelcast#|#IBM_DB2#|#INSAPAda...       2
#
#                               SID              A AB             B BC  \
# 6441                        17 76  MySQL_MariaDB  /      HyperSQL  /
# 6449                     17 36 76  MySQL_MariaDB  /      HyperSQL  /
# 6819                       14 118  MySQL_MariaDB  /      HyperSQL  /
# 6820      29 40 42 76 128 131 134  MySQL_MariaDB  /      HyperSQL  /
# 6825                       42 131  MySQL_MariaDB  /      HyperSQL  /
# ...                           ...            ... ..           ... ..
# 4096400                    36 192     OUTIBM_DB2  |  OUTHazelcast  |
# 4096411                    36 192     OUTIBM_DB2  |  OUTHazelcast  |
# 4096418                    36 192     OUTIBM_DB2  |  OUTHazelcast  |
# 4096431                    36 192     OUTIBM_DB2  |  OUTHazelcast  |
# 4096437                    36 192     OUTIBM_DB2  |  OUTHazelcast  |
#
#                   C CD                          D  DE
# 6441     INInformix  |                OUTHyperSQL  |#
# 6449     INInformix  |       OUTSAPAdaptiveServer  |#
# 6819        INRedis  |               OUTCassandra  |#
# 6820        INRedis  |                OUTHyperSQL  |#
# 6825        INRedis  |  OUTPostgreSQL_CockroachDB  |#
# ...             ... ..                        ...  ..
# 4096400          H2  |        INSAPAdaptiveServer  |#
# 4096411      Oracle  /        INSAPAdaptiveServer  |#
# 4096418      Oracle  |        INSAPAdaptiveServer  |#
# 4096431     IBM_DB2  /        INSAPAdaptiveServer  |#
# 4096437     IBM_DB2  |        INSAPAdaptiveServer  |#
#
# [490753 rows x 11 columns]

# %%
df4 = df3[(df3['AB'].str.startswith('|') & df3['BC'].str.startswith('/') & df3['CD'].str.startswith('|')) 
| (df3['AB'].str.startswith('|') & df3['BC'].str.startswith('|') & df3['CD'].str.startswith('/'))]
df4 #
# Out:
#                                                    Pattern SUP_ABCD  \
# 165143   MySQL_MariaDB#|#MySQL_MariaDB#/#OUTOracle#|#IN...       2
# 165167   MySQL_MariaDB#|#MySQL_MariaDB#/#INInformix#|#O...       2
# 165172   MySQL_MariaDB#|#MySQL_MariaDB#/#INInformix#|#O...       2
# 165180   MySQL_MariaDB#|#MySQL_MariaDB#/#INInformix#|#O...       3
# 165718   MySQL_MariaDB#|#MySQL_MariaDB#/#OUTCassandra#|...       2
# ...                                                    ...      ...
# 4096317  OUTIBM_DB2#|#OUTHazelcast#|#SAPSQLAnywhere#/#I...       2
# 4096345  OUTIBM_DB2#|#OUTHazelcast#|#MSSQLServer_Micros...       2
# 4096393  OUTIBM_DB2#|#OUTHazelcast#|#H2#/#INSAPAdaptive...       2
# 4096411  OUTIBM_DB2#|#OUTHazelcast#|#Oracle#/#INSAPAdap...       2
# 4096431  OUTIBM_DB2#|#OUTHazelcast#|#IBM_DB2#/#INSAPAda...       2
#
#                SID              A AB              B BC  \
# 165143       28 97  MySQL_MariaDB  |  MySQL_MariaDB  /
# 165167      36 128  MySQL_MariaDB  |  MySQL_MariaDB  /
# 165172       17 76  MySQL_MariaDB  |  MySQL_MariaDB  /
# 165180    17 36 76  MySQL_MariaDB  |  MySQL_MariaDB  /
# 165718     130 140  MySQL_MariaDB  |  MySQL_MariaDB  /
# ...            ...            ... ..            ... ..
# 4096317     36 192     OUTIBM_DB2  |   OUTHazelcast  |
# 4096345     36 192     OUTIBM_DB2  |   OUTHazelcast  |
# 4096393     36 192     OUTIBM_DB2  |   OUTHazelcast  |
# 4096411     36 192     OUTIBM_DB2  |   OUTHazelcast  |
# 4096431     36 192     OUTIBM_DB2  |   OUTHazelcast  |
#
#                                              C CD                         D  \
# 165143                               OUTOracle  |  INPostgreSQL_CockroachDB
# 165167                              INInformix  |      OUTJoin_Virtuoso_Sql
# 165172                              INInformix  |               OUTHyperSQL
# 165180                              INInformix  |      OUTSAPAdaptiveServer
# 165718                            OUTCassandra  |               INCassandra
# ...                                        ... ..                       ...
# 4096317                         SAPSQLAnywhere  /       INSAPAdaptiveServer
# 4096345  MSSQLServer_MicrosoftAzureSQLDatabase  /       INSAPAdaptiveServer
# 4096393                                     H2  /       INSAPAdaptiveServer
# 4096411                                 Oracle  /       INSAPAdaptiveServer
# 4096431                                IBM_DB2  /       INSAPAdaptiveServer
#
#          DE
# 165143   |#
# 165167   |#
# 165172   |#
# 165180   |#
# 165718   |#
# ...      ..
# 4096317  |#
# 4096345  |#
# 4096393  |#
# 4096411  |#
# 4096431  |#
#
# [153918 rows x 11 columns]

# %% [markdown]
# Filtering the patterns (X-> INY OUTX -> Y)

# %%
#sel = df4[(df3['BC'] == '/') & (df3['DE'] is None)]
search = 'SQL'
sel =  df4[(df4['C'].str.endswith(search, na=False))]
sel
# Out:
#                                                    Pattern SUP_ABCD  \
# 168206   MySQL_MariaDB#|#MySQL_MariaDB#/#OUTHyperSQL#|#...       2
# 168211   MySQL_MariaDB#|#MySQL_MariaDB#/#OUTHyperSQL#|#...       3
# 172513   MySQL_MariaDB#|#MySQL_MariaDB#|#OUTHyperSQL#/#...       3
# 178474    MySQL_MariaDB#|#HyperSQL#|#OUTHyperSQL#/#INH2#|#       4
# 185542   MySQL_MariaDB#|#OUTOracle#|#HyperSQL#/#INSAPAd...       2
# ...                                                    ...      ...
# 4095739  OUTIBM_DB2#|#INMSSQLServer_MicrosoftAzureSQLDa...       2
# 4095740  OUTIBM_DB2#|#INMSSQLServer_MicrosoftAzureSQLDa...       2
# 4095741  OUTIBM_DB2#|#INMSSQLServer_MicrosoftAzureSQLDa...       2
# 4095966  OUTIBM_DB2#|#OUTHazelcast#/#HyperSQL#|#INSAPAd...       2
# 4096297  OUTIBM_DB2#|#OUTHazelcast#|#HyperSQL#/#INSAPAd...       2
#
#                     SID              A AB  \
# 168206            42 44  MySQL_MariaDB  |
# 168211        22 42 160  MySQL_MariaDB  |
# 172513       40 128 131  MySQL_MariaDB  |
# 178474    40 56 128 131  MySQL_MariaDB  |
# 185542           36 192  MySQL_MariaDB  |
# ...                 ...            ... ..
# 4095739          36 192     OUTIBM_DB2  |
# 4095740          36 192     OUTIBM_DB2  |
# 4095741          36 192     OUTIBM_DB2  |
# 4095966          36 192     OUTIBM_DB2  |
# 4096297          36 192     OUTIBM_DB2  |
#
#                                                B BC            C CD  \
# 168206                             MySQL_MariaDB  /  OUTHyperSQL  |
# 168211                             MySQL_MariaDB  /  OUTHyperSQL  |
# 172513                             MySQL_MariaDB  |  OUTHyperSQL  /
# 178474                                  HyperSQL  |  OUTHyperSQL  /
# 185542                                 OUTOracle  |     HyperSQL  /
# ...                                          ... ..          ... ..
# 4095739  INMSSQLServer_MicrosoftAzureSQLDatabase  |     HyperSQL  /
# 4095740  INMSSQLServer_MicrosoftAzureSQLDatabase  |     HyperSQL  /
# 4095741  INMSSQLServer_MicrosoftAzureSQLDatabase  |     HyperSQL  /
# 4095966                             OUTHazelcast  /     HyperSQL  |
# 4096297                             OUTHazelcast  |     HyperSQL  /
#
#                                 D  DE
# 168206   INPostgreSQL_CockroachDB  |#
# 168211                    INRedis  |#
# 172513                       INH2  |#
# 178474                       INH2  |#
# 185542        INSAPAdaptiveServer  |#
# ...                           ...  ..
# 4095739                        H2  |#
# 4095740                    Oracle  |#
# 4095741                   IBM_DB2  |#
# 4095966       INSAPAdaptiveServer  |#
# 4096297       INSAPAdaptiveServer  |#
#
# [8163 rows x 11 columns]

# %%
select_pattern2 = df4[((df4['BC'] == '/') & (df4['CD'] == '|') & (df4['D'] != '') 
& (~df4['A'].str.startswith('IN') & ~df4['A'].str.startswith('OUT')) 
& (df4['B'].str.startswith('IN')) & (df4['C'].str.startswith('OUT')) 
& df4.apply(lambda x: str(x['A']) in str(x['C']),axis=1) 
& df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))] # & df4.apply(lambda x: str(x['A']) != str(x['B']),axis=1))
select_pattern2
# Out:
#                                                    Pattern SUP_ABCD  \
# 1814997  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#Hazel...       2
# 1814998  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#INHaz...       2
# 1815289  Hazelcast#|#INDynamoDB#/#OUTHazelcast#|#Dynamo...       2
# 1815759  Hazelcast#|#INMSSQLServer_MicrosoftAzureSQLDat...       2
# 2277333  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
# 2277347  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
#
#                    SID                  A AB  \
# 1814997         37 129          Hazelcast  |
# 1814998         37 129          Hazelcast  |
# 1815289          37 43          Hazelcast  |
# 1815759          37 93          Hazelcast  |
# 2277333   17 36 72 192  SAPAdaptiveServer  |
# 2277347   17 36 72 192  SAPAdaptiveServer  |
#
#                                                B BC                     C CD  \
# 1814997                              INHazelcast  /          OUTHazelcast  |
# 1814998                              INHazelcast  /          OUTHazelcast  |
# 1815289                               INDynamoDB  /          OUTHazelcast  |
# 1815759  INMSSQLServer_MicrosoftAzureSQLDatabase  /          OUTHazelcast  |
# 2277333                      INSAPAdaptiveServer  /  OUTSAPAdaptiveServer  |
# 2277347                      INSAPAdaptiveServer  /  OUTSAPAdaptiveServer  |
#
#                                              D  DE
# 1814997                              Hazelcast  |#
# 1814998                            INHazelcast  |#
# 1815289                               DynamoDB  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase  |#
# 2277333                    INSAPAdaptiveServer  |#
# 2277347                      SAPAdaptiveServer  |#

# %% [markdown]
# Filtering the patterns (X-> OUTX INY -> Y)

# %%
select_pattern3 = df4[((df4['BC'] == '/') & (df4['CD'] == '|') & (df4['D'] != '' ) 
& (~df4['A'].str.startswith('IN') & ~df4['A'].str.startswith('OUT')) 
& (df4['B'].str.startswith('OUT')) & (df4['C'].str.startswith('IN')) 
& df4.apply(lambda x: str(x['A']) in str(x['B']),axis=1) 
& df4.apply(lambda x: str(x['D']) in str(x['C']),axis=1))] #& df4.apply(lambda x: str(x['B']) != str(x['C']),axis=1))
select_pattern3
# Out:
#                                                    Pattern SUP_ABCD  \
# 245537   MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INRedis#|#R...       2
# 245752     MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INH2#|#H2#|#       3
# 460431   HyperSQL#|#OUTHyperSQL#/#INPostgreSQL_Cockroac...       2
# 460751               HyperSQL#|#OUTHyperSQL#/#INH2#|#H2#|#       5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase#|#OUTMSS...       2
# 2260005  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260014  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260074  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       2
# 2260093  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INP...       3
# 2260135  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INO...       2
# 2260212  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INI...       2
# 2260303  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INM...       2
#
#                        SID                                      A AB  \
# 245537              16 169                          MySQL_MariaDB  |
# 245752           16 44 169                          MySQL_MariaDB  |
# 460431              81 131                               HyperSQL  |
# 460751    40 44 56 128 131                               HyperSQL  |
# 619092              16 128  MSSQLServer_MicrosoftAzureSQLDatabase  |
# 2260005           0 36 192                      SAPAdaptiveServer  |
# 2260014           0 36 192                      SAPAdaptiveServer  |
# 2260074             36 192                      SAPAdaptiveServer  |
# 2260093         36 178 192                      SAPAdaptiveServer  |
# 2260135             36 192                      SAPAdaptiveServer  |
# 2260212             36 192                      SAPAdaptiveServer  |
# 2260303             36 192                      SAPAdaptiveServer  |
#
#                                                 B BC  \
# 245537                           OUTMySQL_MariaDB  /
# 245752                           OUTMySQL_MariaDB  /
# 460431                                OUTHyperSQL  /
# 460751                                OUTHyperSQL  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase  /
# 2260005                      OUTSAPAdaptiveServer  /
# 2260014                      OUTSAPAdaptiveServer  /
# 2260074                      OUTSAPAdaptiveServer  /
# 2260093                      OUTSAPAdaptiveServer  /
# 2260135                      OUTSAPAdaptiveServer  /
# 2260212                      OUTSAPAdaptiveServer  /
# 2260303                      OUTSAPAdaptiveServer  /
#
#                                                C CD  \
# 245537                                   INRedis  |
# 245752                                      INH2  |
# 460431                  INPostgreSQL_CockroachDB  |
# 460751                                      INH2  |
# 619092                                   INRedis  |
# 2260005                      INSAPAdaptiveServer  |
# 2260014                      INSAPAdaptiveServer  |
# 2260074                         INSAPSQLAnywhere  |
# 2260093                 INPostgreSQL_CockroachDB  |
# 2260135                                 INOracle  |
# 2260212                                INIBM_DB2  |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase  |
#
#                                              D  DE
# 245537                                   Redis  |#
# 245752                                      H2  |#
# 460431                  PostgreSQL_CockroachDB  |#
# 460751                                      H2  |#
# 619092                                   Redis  |#
# 2260005                    INSAPAdaptiveServer  |#
# 2260014                      SAPAdaptiveServer  |#
# 2260074                         SAPSQLAnywhere  |#
# 2260093                 PostgreSQL_CockroachDB  |#
# 2260135                                 Oracle  |#
# 2260212                                IBM_DB2  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase  |#

# %% [markdown]
# Filtering the patterns (X-> INY -> OUTX Y)

# %%
select_pattern4 = df4[((df4['BC'] == '|') & (df4['CD'] == '/') & (df4['D'] != '')
& (~df4['A'].str.startswith('IN') & ~df4['A'].str.startswith('OUT'))
& (df4['B'].str.startswith('IN') & (df4['C'].str.startswith('OUT')))
& df4.apply(lambda x: str(x['A']) in str(x['C']),axis=1)
& df4.apply(lambda x: str(x['D']) in str(x['B']),axis=1))] # & df3.apply(lambda x: str(x['A']) != str(x['B']),axis=1) 
select_pattern4
# Out:
#                                                    Pattern SUP_ABCD  \
# 203866   MySQL_MariaDB#|#INRedis#|#OUTMySQL_MariaDB#/#R...       2
# 278208   MySQL_MariaDB#|#INCassandra#|#OUTMySQL_MariaDB...       2
# 280863     MySQL_MariaDB#|#INH2#|#OUTMySQL_MariaDB#/#H2#|#       2
# 415706         HyperSQL#|#INRedis#|#OUTHyperSQL#/#Redis#|#       4
# 454043     HyperSQL#|#INMongoDB#|#OUTHyperSQL#/#MongoDB#|#       2
# 454873       HyperSQL#|#INOracle#|#OUTHyperSQL#/#Oracle#|#       2
# 457599   HyperSQL#|#INMSSQLServer_MicrosoftAzureSQLData...       3
# 465405               HyperSQL#|#INH2#|#OUTHyperSQL#/#H2#|#       3
# 468143   HyperSQL#|#INPostgreSQL_CockroachDB#|#OUTHyper...       2
# 469592     HyperSQL#|#INIBM_DB2#|#OUTHyperSQL#/#IBM_DB2#|#       2
# 775263   GoogleCloudDatastore#|#INH2#|#OUTGoogleCloudDa...       2
# 776100   GoogleCloudDatastore#|#INPostgreSQL_CockroachD...       2
# 1017944        HBase#|#INDynamoDB#|#OUTHBase#/#DynamoDB#|#       2
# 1019539  HBase#|#INPostgreSQL_CockroachDB#|#OUTHBase#/#...       2
# 1315033          Oracle#|#INSQLite#|#OUTOracle#/#SQLite#|#       2
# 1726797  Couchbase#|#INHazelcast#|#OUTCouchbase#/#Hazel...       2
# 1727273  Couchbase#|#INPostgreSQL_CockroachDB#|#OUTCouc...       2
# 1727545  Couchbase#|#INMicrosoftAzureCosmosDB#|#OUTCouc...       2
# 2278339  SAPAdaptiveServer#|#INPostgreSQL_CockroachDB#|...       2
# 2281904  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       2
#
#                    SID                     A AB  \
# 203866           22 96         MySQL_MariaDB  |
# 278208         109 140         MySQL_MariaDB  |
# 280863          44 111         MySQL_MariaDB  |
# 415706    29 40 81 128              HyperSQL  |
# 454043           27 76              HyperSQL  |
# 454873          29 114              HyperSQL  |
# 457599       10 42 160              HyperSQL  |
# 465405        23 27 42              HyperSQL  |
# 468143         114 128              HyperSQL  |
# 469592          42 114              HyperSQL  |
# 775263          24 113  GoogleCloudDatastore  |
# 776100          24 121  GoogleCloudDatastore  |
# 1017944          10 24                 HBase  |
# 1019539           9 24                 HBase  |
# 1315033        183 194                Oracle  |
# 1726797          28 37             Couchbase  |
# 1727273          28 37             Couchbase  |
# 1727545          28 37             Couchbase  |
# 2278339         36 192     SAPAdaptiveServer  |
# 2281904           0 72     SAPAdaptiveServer  |
#
#                                                B BC                        C  \
# 203866                                   INRedis  |         OUTMySQL_MariaDB
# 278208                               INCassandra  |         OUTMySQL_MariaDB
# 280863                                      INH2  |         OUTMySQL_MariaDB
# 415706                                   INRedis  |              OUTHyperSQL
# 454043                                 INMongoDB  |              OUTHyperSQL
# 454873                                  INOracle  |              OUTHyperSQL
# 457599   INMSSQLServer_MicrosoftAzureSQLDatabase  |              OUTHyperSQL
# 465405                                      INH2  |              OUTHyperSQL
# 468143                  INPostgreSQL_CockroachDB  |              OUTHyperSQL
# 469592                                 INIBM_DB2  |              OUTHyperSQL
# 775263                                      INH2  |  OUTGoogleCloudDatastore
# 776100                  INPostgreSQL_CockroachDB  |  OUTGoogleCloudDatastore
# 1017944                               INDynamoDB  |                 OUTHBase
# 1019539                 INPostgreSQL_CockroachDB  |                 OUTHBase
# 1315033                                 INSQLite  |                OUTOracle
# 1726797                              INHazelcast  |             OUTCouchbase
# 1727273                 INPostgreSQL_CockroachDB  |             OUTCouchbase
# 1727545                 INMicrosoftAzureCosmosDB  |             OUTCouchbase
# 2278339                 INPostgreSQL_CockroachDB  |     OUTSAPAdaptiveServer
# 2281904  INMSSQLServer_MicrosoftAzureSQLDatabase  |     OUTSAPAdaptiveServer
#
#         CD                                      D  DE
# 203866   /                                  Redis  |#
# 278208   /                              Cassandra  |#
# 280863   /                                     H2  |#
# 415706   /                                  Redis  |#
# 454043   /                                MongoDB  |#
# 454873   /                                 Oracle  |#
# 457599   /  MSSQLServer_MicrosoftAzureSQLDatabase  |#
# 465405   /                                     H2  |#
# 468143   /                 PostgreSQL_CockroachDB  |#
# 469592   /                                IBM_DB2  |#
# 775263   /                                     H2  |#
# 776100   /                 PostgreSQL_CockroachDB  |#
# 1017944  /                               DynamoDB  |#
# 1019539  /                 PostgreSQL_CockroachDB  |#
# 1315033  /                                 SQLite  |#
# 1726797  /                              Hazelcast  |#
# 1727273  /                 PostgreSQL_CockroachDB  |#
# 1727545  /                 MicrosoftAzureCosmosDB  |#
# 2278339  /                 PostgreSQL_CockroachDB  |#
# 2281904  /  MSSQLServer_MicrosoftAzureSQLDatabase  |#

# %% [markdown]
# Filtering the patterns (X-> INY -> Y OUTX)

# %%
select_pattern5 = df4[((df3['BC'] == '|') & (df3['CD'] == '/') & (df3['D'] != '') 
& (~df3['A'].str.startswith('IN') & ~df3['A'].str.startswith('OUT')) 
& (df3['B'].str.startswith('IN') & df3['D'].str.startswith('OUT')) 
& df3.apply(lambda x: str(x['B']) != str(x['C']),axis=1) #endswith?
& df3.apply(lambda x: str(x['C']) in str(x['B']),axis=1)
& df3.apply(lambda x: str(x['A']) in str(x['D']),axis=1))] 
#select_pattern5['Pattern'] = select_pattern10['Pattern'].str.replace('#','')
select_pattern5
# Out:
# /var/folders/kc/q64njxfx5xj09h4nrxwncwbw0000gn/T/ipykernel_1968/1154048129.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   select_pattern5 = df4[((df3['BC'] == '|') & (df3['CD'] == '/') & (df3['D'] != '')
#                                                    Pattern SUP_ABCD  \
# 1016190                    HBase#|#INH2#|#H2#/#OUTHBase#|#       2
# 1022891  HBase#|#INMSSQLServer_MicrosoftAzureSQLDatabas...       2
# 1716446  IBM_DB2#|#INMSSQLServer_MicrosoftAzureSQLDatab...       2
# 1809689      Hazelcast#|#INRedis#|#Redis#/#OUTHazelcast#|#       2
# 1878729            SQLite#|#INRedis#|#Redis#/#OUTSQLite#|#       3
# 1910728                  SQLite#|#INH2#|#H2#/#OUTSQLite#|#       2
# 1919424  SQLite#|#INMSSQLServer_MicrosoftAzureSQLDataba...       2
# 2238906  SAPAdaptiveServer#|#INSAPSQLAnywhere#|#SAPSQLA...       2
# 2277944  SAPAdaptiveServer#|#INSAPAdaptiveServer#|#SAPA...       5
# 2279394  SAPAdaptiveServer#|#INOracle#|#Oracle#/#OUTSAP...       2
# 2280448  SAPAdaptiveServer#|#INIBM_DB2#|#IBM_DB2#/#OUTS...       2
# 2281624  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       5
# 2486453  PostgreSQL_CockroachDB#|#INH2#|#H2#/#OUTPostgr...       2
# 2489426  PostgreSQL_CockroachDB#|#INCouchbase#|#Couchba...       2
# 2699216  Join_Ignite_NoSql#|#INNeo4j#|#Neo4j#/#OUTJoin_...       2
#
#                       SID                       A AB  \
# 1016190              9 24                   HBase  |
# 1022891              9 10                   HBase  |
# 1716446           160 178                 IBM_DB2  |
# 1809689             37 93               Hazelcast  |
# 1878729          34 42 76                  SQLite  |
# 1910728            34 129                  SQLite  |
# 1919424            76 160                  SQLite  |
# 2238906            36 192       SAPAdaptiveServer  |
# 2277944    0 17 36 72 192       SAPAdaptiveServer  |
# 2279394            36 192       SAPAdaptiveServer  |
# 2280448            36 192       SAPAdaptiveServer  |
# 2281624   0 36 72 160 192       SAPAdaptiveServer  |
# 2486453            42 111  PostgreSQL_CockroachDB  |
# 2489426             28 37  PostgreSQL_CockroachDB  |
# 2699216             16 28       Join_Ignite_NoSql  |
#
#                                                B BC  \
# 1016190                                     INH2  |
# 1022891  INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 1716446  INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 1809689                                  INRedis  |
# 1878729                                  INRedis  |
# 1910728                                     INH2  |
# 1919424  INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 2238906                         INSAPSQLAnywhere  |
# 2277944                      INSAPAdaptiveServer  |
# 2279394                                 INOracle  |
# 2280448                                INIBM_DB2  |
# 2281624  INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 2486453                                     INH2  |
# 2489426                              INCouchbase  |
# 2699216                                  INNeo4j  |
#
#                                              C CD                          D  \
# 1016190                                     H2  /                   OUTHBase
# 1022891  MSSQLServer_MicrosoftAzureSQLDatabase  /                   OUTHBase
# 1716446  MSSQLServer_MicrosoftAzureSQLDatabase  /                 OUTIBM_DB2
# 1809689                                  Redis  /               OUTHazelcast
# 1878729                                  Redis  /                  OUTSQLite
# 1910728                                     H2  /                  OUTSQLite
# 1919424  MSSQLServer_MicrosoftAzureSQLDatabase  /                  OUTSQLite
# 2238906                         SAPSQLAnywhere  /       OUTSAPAdaptiveServer
# 2277944                      SAPAdaptiveServer  /       OUTSAPAdaptiveServer
# 2279394                                 Oracle  /       OUTSAPAdaptiveServer
# 2280448                                IBM_DB2  /       OUTSAPAdaptiveServer
# 2281624  MSSQLServer_MicrosoftAzureSQLDatabase  /       OUTSAPAdaptiveServer
# 2486453                                     H2  /  OUTPostgreSQL_CockroachDB
# 2489426                              Couchbase  /  OUTPostgreSQL_CockroachDB
# 2699216                                  Neo4j  /       OUTJoin_Ignite_NoSql
#
#          DE
# 1016190  |#
# 1022891  |#
# 1716446  |#
# 1809689  |#
# 1878729  |#
# 1910728  |#
# 1919424  |#
# 2238906  |#
# 2277944  |#
# 2279394  |#
# 2280448  |#
# 2281624  |#
# 2486453  |#
# 2489426  |#
# 2699216  |#

# %% [markdown]
# Join all select patterns

# %%
df_concat = pd.concat([select_pattern2, select_pattern3, select_pattern4, select_pattern5]).drop_duplicates()
df_concat
# Out:
#                                                    Pattern SUP_ABCD  \
# 1814997  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#Hazel...       2
# 1814998  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#INHaz...       2
# 1815289  Hazelcast#|#INDynamoDB#/#OUTHazelcast#|#Dynamo...       2
# 1815759  Hazelcast#|#INMSSQLServer_MicrosoftAzureSQLDat...       2
# 2277333  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
# 2277347  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
# 245537   MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INRedis#|#R...       2
# 245752     MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INH2#|#H2#|#       3
# 460431   HyperSQL#|#OUTHyperSQL#/#INPostgreSQL_Cockroac...       2
# 460751               HyperSQL#|#OUTHyperSQL#/#INH2#|#H2#|#       5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase#|#OUTMSS...       2
# 2260005  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260014  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260074  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       2
# 2260093  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INP...       3
# 2260135  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INO...       2
# 2260212  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INI...       2
# 2260303  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INM...       2
# 203866   MySQL_MariaDB#|#INRedis#|#OUTMySQL_MariaDB#/#R...       2
# 278208   MySQL_MariaDB#|#INCassandra#|#OUTMySQL_MariaDB...       2
# 280863     MySQL_MariaDB#|#INH2#|#OUTMySQL_MariaDB#/#H2#|#       2
# 415706         HyperSQL#|#INRedis#|#OUTHyperSQL#/#Redis#|#       4
# 454043     HyperSQL#|#INMongoDB#|#OUTHyperSQL#/#MongoDB#|#       2
# 454873       HyperSQL#|#INOracle#|#OUTHyperSQL#/#Oracle#|#       2
# 457599   HyperSQL#|#INMSSQLServer_MicrosoftAzureSQLData...       3
# 465405               HyperSQL#|#INH2#|#OUTHyperSQL#/#H2#|#       3
# 468143   HyperSQL#|#INPostgreSQL_CockroachDB#|#OUTHyper...       2
# 469592     HyperSQL#|#INIBM_DB2#|#OUTHyperSQL#/#IBM_DB2#|#       2
# 775263   GoogleCloudDatastore#|#INH2#|#OUTGoogleCloudDa...       2
# 776100   GoogleCloudDatastore#|#INPostgreSQL_CockroachD...       2
# 1017944        HBase#|#INDynamoDB#|#OUTHBase#/#DynamoDB#|#       2
# 1019539  HBase#|#INPostgreSQL_CockroachDB#|#OUTHBase#/#...       2
# 1315033          Oracle#|#INSQLite#|#OUTOracle#/#SQLite#|#       2
# 1726797  Couchbase#|#INHazelcast#|#OUTCouchbase#/#Hazel...       2
# 1727273  Couchbase#|#INPostgreSQL_CockroachDB#|#OUTCouc...       2
# 1727545  Couchbase#|#INMicrosoftAzureCosmosDB#|#OUTCouc...       2
# 2278339  SAPAdaptiveServer#|#INPostgreSQL_CockroachDB#|...       2
# 2281904  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       2
# 1016190                    HBase#|#INH2#|#H2#/#OUTHBase#|#       2
# 1022891  HBase#|#INMSSQLServer_MicrosoftAzureSQLDatabas...       2
# 1716446  IBM_DB2#|#INMSSQLServer_MicrosoftAzureSQLDatab...       2
# 1809689      Hazelcast#|#INRedis#|#Redis#/#OUTHazelcast#|#       2
# 1878729            SQLite#|#INRedis#|#Redis#/#OUTSQLite#|#       3
# 1910728                  SQLite#|#INH2#|#H2#/#OUTSQLite#|#       2
# 1919424  SQLite#|#INMSSQLServer_MicrosoftAzureSQLDataba...       2
# 2238906  SAPAdaptiveServer#|#INSAPSQLAnywhere#|#SAPSQLA...       2
# 2277944  SAPAdaptiveServer#|#INSAPAdaptiveServer#|#SAPA...       5
# 2279394  SAPAdaptiveServer#|#INOracle#|#Oracle#/#OUTSAP...       2
# 2280448  SAPAdaptiveServer#|#INIBM_DB2#|#IBM_DB2#/#OUTS...       2
# 2281624  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       5
# 2486453  PostgreSQL_CockroachDB#|#INH2#|#H2#/#OUTPostgr...       2
# 2489426  PostgreSQL_CockroachDB#|#INCouchbase#|#Couchba...       2
# 2699216  Join_Ignite_NoSql#|#INNeo4j#|#Neo4j#/#OUTJoin_...       2
#
#                        SID                                      A AB  \
# 1814997             37 129                              Hazelcast  |
# 1814998             37 129                              Hazelcast  |
# 1815289              37 43                              Hazelcast  |
# 1815759              37 93                              Hazelcast  |
# 2277333       17 36 72 192                      SAPAdaptiveServer  |
# 2277347       17 36 72 192                      SAPAdaptiveServer  |
# 245537              16 169                          MySQL_MariaDB  |
# 245752           16 44 169                          MySQL_MariaDB  |
# 460431              81 131                               HyperSQL  |
# 460751    40 44 56 128 131                               HyperSQL  |
# 619092              16 128  MSSQLServer_MicrosoftAzureSQLDatabase  |
# 2260005           0 36 192                      SAPAdaptiveServer  |
# 2260014           0 36 192                      SAPAdaptiveServer  |
# 2260074             36 192                      SAPAdaptiveServer  |
# 2260093         36 178 192                      SAPAdaptiveServer  |
# 2260135             36 192                      SAPAdaptiveServer  |
# 2260212             36 192                      SAPAdaptiveServer  |
# 2260303             36 192                      SAPAdaptiveServer  |
# 203866               22 96                          MySQL_MariaDB  |
# 278208             109 140                          MySQL_MariaDB  |
# 280863              44 111                          MySQL_MariaDB  |
# 415706        29 40 81 128                               HyperSQL  |
# 454043               27 76                               HyperSQL  |
# 454873              29 114                               HyperSQL  |
# 457599           10 42 160                               HyperSQL  |
# 465405            23 27 42                               HyperSQL  |
# 468143             114 128                               HyperSQL  |
# 469592              42 114                               HyperSQL  |
# 775263              24 113                   GoogleCloudDatastore  |
# 776100              24 121                   GoogleCloudDatastore  |
# 1017944              10 24                                  HBase  |
# 1019539               9 24                                  HBase  |
# 1315033            183 194                                 Oracle  |
# 1726797              28 37                              Couchbase  |
# 1727273              28 37                              Couchbase  |
# 1727545              28 37                              Couchbase  |
# 2278339             36 192                      SAPAdaptiveServer  |
# 2281904               0 72                      SAPAdaptiveServer  |
# 1016190               9 24                                  HBase  |
# 1022891               9 10                                  HBase  |
# 1716446            160 178                                IBM_DB2  |
# 1809689              37 93                              Hazelcast  |
# 1878729           34 42 76                                 SQLite  |
# 1910728             34 129                                 SQLite  |
# 1919424             76 160                                 SQLite  |
# 2238906             36 192                      SAPAdaptiveServer  |
# 2277944     0 17 36 72 192                      SAPAdaptiveServer  |
# 2279394             36 192                      SAPAdaptiveServer  |
# 2280448             36 192                      SAPAdaptiveServer  |
# 2281624    0 36 72 160 192                      SAPAdaptiveServer  |
# 2486453             42 111                 PostgreSQL_CockroachDB  |
# 2489426              28 37                 PostgreSQL_CockroachDB  |
# 2699216              16 28                      Join_Ignite_NoSql  |
#
#                                                 B BC  \
# 1814997                               INHazelcast  /
# 1814998                               INHazelcast  /
# 1815289                                INDynamoDB  /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase  /
# 2277333                       INSAPAdaptiveServer  /
# 2277347                       INSAPAdaptiveServer  /
# 245537                           OUTMySQL_MariaDB  /
# 245752                           OUTMySQL_MariaDB  /
# 460431                                OUTHyperSQL  /
# 460751                                OUTHyperSQL  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase  /
# 2260005                      OUTSAPAdaptiveServer  /
# 2260014                      OUTSAPAdaptiveServer  /
# 2260074                      OUTSAPAdaptiveServer  /
# 2260093                      OUTSAPAdaptiveServer  /
# 2260135                      OUTSAPAdaptiveServer  /
# 2260212                      OUTSAPAdaptiveServer  /
# 2260303                      OUTSAPAdaptiveServer  /
# 203866                                    INRedis  |
# 278208                                INCassandra  |
# 280863                                       INH2  |
# 415706                                    INRedis  |
# 454043                                  INMongoDB  |
# 454873                                   INOracle  |
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 465405                                       INH2  |
# 468143                   INPostgreSQL_CockroachDB  |
# 469592                                  INIBM_DB2  |
# 775263                                       INH2  |
# 776100                   INPostgreSQL_CockroachDB  |
# 1017944                                INDynamoDB  |
# 1019539                  INPostgreSQL_CockroachDB  |
# 1315033                                  INSQLite  |
# 1726797                               INHazelcast  |
# 1727273                  INPostgreSQL_CockroachDB  |
# 1727545                  INMicrosoftAzureCosmosDB  |
# 2278339                  INPostgreSQL_CockroachDB  |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 1016190                                      INH2  |
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 1809689                                   INRedis  |
# 1878729                                   INRedis  |
# 1910728                                      INH2  |
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 2238906                          INSAPSQLAnywhere  |
# 2277944                       INSAPAdaptiveServer  |
# 2279394                                  INOracle  |
# 2280448                                 INIBM_DB2  |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 2486453                                      INH2  |
# 2489426                               INCouchbase  |
# 2699216                                   INNeo4j  |
#
#                                                C CD  \
# 1814997                             OUTHazelcast  |
# 1814998                             OUTHazelcast  |
# 1815289                             OUTHazelcast  |
# 1815759                             OUTHazelcast  |
# 2277333                     OUTSAPAdaptiveServer  |
# 2277347                     OUTSAPAdaptiveServer  |
# 245537                                   INRedis  |
# 245752                                      INH2  |
# 460431                  INPostgreSQL_CockroachDB  |
# 460751                                      INH2  |
# 619092                                   INRedis  |
# 2260005                      INSAPAdaptiveServer  |
# 2260014                      INSAPAdaptiveServer  |
# 2260074                         INSAPSQLAnywhere  |
# 2260093                 INPostgreSQL_CockroachDB  |
# 2260135                                 INOracle  |
# 2260212                                INIBM_DB2  |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase  |
# 203866                          OUTMySQL_MariaDB  /
# 278208                          OUTMySQL_MariaDB  /
# 280863                          OUTMySQL_MariaDB  /
# 415706                               OUTHyperSQL  /
# 454043                               OUTHyperSQL  /
# 454873                               OUTHyperSQL  /
# 457599                               OUTHyperSQL  /
# 465405                               OUTHyperSQL  /
# 468143                               OUTHyperSQL  /
# 469592                               OUTHyperSQL  /
# 775263                   OUTGoogleCloudDatastore  /
# 776100                   OUTGoogleCloudDatastore  /
# 1017944                                 OUTHBase  /
# 1019539                                 OUTHBase  /
# 1315033                                OUTOracle  /
# 1726797                             OUTCouchbase  /
# 1727273                             OUTCouchbase  /
# 1727545                             OUTCouchbase  /
# 2278339                     OUTSAPAdaptiveServer  /
# 2281904                     OUTSAPAdaptiveServer  /
# 1016190                                       H2  /
# 1022891    MSSQLServer_MicrosoftAzureSQLDatabase  /
# 1716446    MSSQLServer_MicrosoftAzureSQLDatabase  /
# 1809689                                    Redis  /
# 1878729                                    Redis  /
# 1910728                                       H2  /
# 1919424    MSSQLServer_MicrosoftAzureSQLDatabase  /
# 2238906                           SAPSQLAnywhere  /
# 2277944                        SAPAdaptiveServer  /
# 2279394                                   Oracle  /
# 2280448                                  IBM_DB2  /
# 2281624    MSSQLServer_MicrosoftAzureSQLDatabase  /
# 2486453                                       H2  /
# 2489426                                Couchbase  /
# 2699216                                    Neo4j  /
#
#                                              D  DE
# 1814997                              Hazelcast  |#
# 1814998                            INHazelcast  |#
# 1815289                               DynamoDB  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase  |#
# 2277333                    INSAPAdaptiveServer  |#
# 2277347                      SAPAdaptiveServer  |#
# 245537                                   Redis  |#
# 245752                                      H2  |#
# 460431                  PostgreSQL_CockroachDB  |#
# 460751                                      H2  |#
# 619092                                   Redis  |#
# 2260005                    INSAPAdaptiveServer  |#
# 2260014                      SAPAdaptiveServer  |#
# 2260074                         SAPSQLAnywhere  |#
# 2260093                 PostgreSQL_CockroachDB  |#
# 2260135                                 Oracle  |#
# 2260212                                IBM_DB2  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase  |#
# 203866                                   Redis  |#
# 278208                               Cassandra  |#
# 280863                                      H2  |#
# 415706                                   Redis  |#
# 454043                                 MongoDB  |#
# 454873                                  Oracle  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase  |#
# 465405                                      H2  |#
# 468143                  PostgreSQL_CockroachDB  |#
# 469592                                 IBM_DB2  |#
# 775263                                      H2  |#
# 776100                  PostgreSQL_CockroachDB  |#
# 1017944                               DynamoDB  |#
# 1019539                 PostgreSQL_CockroachDB  |#
# 1315033                                 SQLite  |#
# 1726797                              Hazelcast  |#
# 1727273                 PostgreSQL_CockroachDB  |#
# 1727545                 MicrosoftAzureCosmosDB  |#
# 2278339                 PostgreSQL_CockroachDB  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase  |#
# 1016190                               OUTHBase  |#
# 1022891                               OUTHBase  |#
# 1716446                             OUTIBM_DB2  |#
# 1809689                           OUTHazelcast  |#
# 1878729                              OUTSQLite  |#
# 1910728                              OUTSQLite  |#
# 1919424                              OUTSQLite  |#
# 2238906                   OUTSAPAdaptiveServer  |#
# 2277944                   OUTSAPAdaptiveServer  |#
# 2279394                   OUTSAPAdaptiveServer  |#
# 2280448                   OUTSAPAdaptiveServer  |#
# 2281624                   OUTSAPAdaptiveServer  |#
# 2486453              OUTPostgreSQL_CockroachDB  |#
# 2489426              OUTPostgreSQL_CockroachDB  |#
# 2699216                   OUTJoin_Ignite_NoSql  |#

# %% [markdown]
# Open patterns size 1 to research individual supports

# %%
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT_TAM1 = SEQ_PATTERNS_DIR + os.sep + 'output_seq_in_out.txt' #add in util.py
df5 = pd.read_csv(SEQ_PATTERNS_DIR + os.sep + 'output_tam1.txt', sep= '#', header=None) #'testes/output_init_tam1_7.txt'
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df5.columns = ['Pattern_v1','SUP_v1',]
df5.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
df5['Pattern_v1'] = df5['Pattern_v1'].str.replace('[ | ]','')
df5
# Out:
# /var/folders/kc/q64njxfx5xj09h4nrxwncwbw0000gn/T/ipykernel_1968/3117418567.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df5['Pattern_v1'] = df5['Pattern_v1'].str.replace('[ | ]','')
#                      Pattern_v1 SUP_v1
# 0                   INInflux_DB      5
# 1    MicrosoftAzureTableStorage      2
# 2                 MySQL_MariaDB    112
# 3                      HyperSQL     60
# 4                     MarkLogic      8
# ..                          ...    ...
# 125         OUTFirebaseRealtime      5
# 126                   INITHBase      6
# 127                OUTMarkLogic      3
# 128                   INVertica      5
# 129                  OUTIBM_DB2     10
#
# [130 rows x 2 columns]

# %% [markdown]
# Inserting individual support

# %%
df8 = df_concat.copy()
df8.insert(4,"SUP_A",'0',False)#True)
df8.insert(7,"SUP_B",'0',False)#True)
df8.insert(10,"SUP_C",'0',False)#True)
df8.insert(13,"SUP_D",'0',False)#True)
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 1814997  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#Hazel...       2
# 1814998  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#INHaz...       2
# 1815289  Hazelcast#|#INDynamoDB#/#OUTHazelcast#|#Dynamo...       2
# 1815759  Hazelcast#|#INMSSQLServer_MicrosoftAzureSQLDat...       2
# 2277333  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
# 2277347  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
# 245537   MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INRedis#|#R...       2
# 245752     MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INH2#|#H2#|#       3
# 460431   HyperSQL#|#OUTHyperSQL#/#INPostgreSQL_Cockroac...       2
# 460751               HyperSQL#|#OUTHyperSQL#/#INH2#|#H2#|#       5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase#|#OUTMSS...       2
# 2260005  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260014  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260074  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       2
# 2260093  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INP...       3
# 2260135  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INO...       2
# 2260212  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INI...       2
# 2260303  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INM...       2
# 203866   MySQL_MariaDB#|#INRedis#|#OUTMySQL_MariaDB#/#R...       2
# 278208   MySQL_MariaDB#|#INCassandra#|#OUTMySQL_MariaDB...       2
# 280863     MySQL_MariaDB#|#INH2#|#OUTMySQL_MariaDB#/#H2#|#       2
# 415706         HyperSQL#|#INRedis#|#OUTHyperSQL#/#Redis#|#       4
# 454043     HyperSQL#|#INMongoDB#|#OUTHyperSQL#/#MongoDB#|#       2
# 454873       HyperSQL#|#INOracle#|#OUTHyperSQL#/#Oracle#|#       2
# 457599   HyperSQL#|#INMSSQLServer_MicrosoftAzureSQLData...       3
# 465405               HyperSQL#|#INH2#|#OUTHyperSQL#/#H2#|#       3
# 468143   HyperSQL#|#INPostgreSQL_CockroachDB#|#OUTHyper...       2
# 469592     HyperSQL#|#INIBM_DB2#|#OUTHyperSQL#/#IBM_DB2#|#       2
# 775263   GoogleCloudDatastore#|#INH2#|#OUTGoogleCloudDa...       2
# 776100   GoogleCloudDatastore#|#INPostgreSQL_CockroachD...       2
# 1017944        HBase#|#INDynamoDB#|#OUTHBase#/#DynamoDB#|#       2
# 1019539  HBase#|#INPostgreSQL_CockroachDB#|#OUTHBase#/#...       2
# 1315033          Oracle#|#INSQLite#|#OUTOracle#/#SQLite#|#       2
# 1726797  Couchbase#|#INHazelcast#|#OUTCouchbase#/#Hazel...       2
# 1727273  Couchbase#|#INPostgreSQL_CockroachDB#|#OUTCouc...       2
# 1727545  Couchbase#|#INMicrosoftAzureCosmosDB#|#OUTCouc...       2
# 2278339  SAPAdaptiveServer#|#INPostgreSQL_CockroachDB#|...       2
# 2281904  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       2
# 1016190                    HBase#|#INH2#|#H2#/#OUTHBase#|#       2
# 1022891  HBase#|#INMSSQLServer_MicrosoftAzureSQLDatabas...       2
# 1716446  IBM_DB2#|#INMSSQLServer_MicrosoftAzureSQLDatab...       2
# 1809689      Hazelcast#|#INRedis#|#Redis#/#OUTHazelcast#|#       2
# 1878729            SQLite#|#INRedis#|#Redis#/#OUTSQLite#|#       3
# 1910728                  SQLite#|#INH2#|#H2#/#OUTSQLite#|#       2
# 1919424  SQLite#|#INMSSQLServer_MicrosoftAzureSQLDataba...       2
# 2238906  SAPAdaptiveServer#|#INSAPSQLAnywhere#|#SAPSQLA...       2
# 2277944  SAPAdaptiveServer#|#INSAPAdaptiveServer#|#SAPA...       5
# 2279394  SAPAdaptiveServer#|#INOracle#|#Oracle#/#OUTSAP...       2
# 2280448  SAPAdaptiveServer#|#INIBM_DB2#|#IBM_DB2#/#OUTS...       2
# 2281624  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       5
# 2486453  PostgreSQL_CockroachDB#|#INH2#|#H2#/#OUTPostgr...       2
# 2489426  PostgreSQL_CockroachDB#|#INCouchbase#|#Couchba...       2
# 2699216  Join_Ignite_NoSql#|#INNeo4j#|#Neo4j#/#OUTJoin_...       2
#
#                        SID                                      A SUP_A AB  \
# 1814997             37 129                              Hazelcast     0  |
# 1814998             37 129                              Hazelcast     0  |
# 1815289              37 43                              Hazelcast     0  |
# 1815759              37 93                              Hazelcast     0  |
# 2277333       17 36 72 192                      SAPAdaptiveServer     0  |
# 2277347       17 36 72 192                      SAPAdaptiveServer     0  |
# 245537              16 169                          MySQL_MariaDB     0  |
# 245752           16 44 169                          MySQL_MariaDB     0  |
# 460431              81 131                               HyperSQL     0  |
# 460751    40 44 56 128 131                               HyperSQL     0  |
# 619092              16 128  MSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 2260005           0 36 192                      SAPAdaptiveServer     0  |
# 2260014           0 36 192                      SAPAdaptiveServer     0  |
# 2260074             36 192                      SAPAdaptiveServer     0  |
# 2260093         36 178 192                      SAPAdaptiveServer     0  |
# 2260135             36 192                      SAPAdaptiveServer     0  |
# 2260212             36 192                      SAPAdaptiveServer     0  |
# 2260303             36 192                      SAPAdaptiveServer     0  |
# 203866               22 96                          MySQL_MariaDB     0  |
# 278208             109 140                          MySQL_MariaDB     0  |
# 280863              44 111                          MySQL_MariaDB     0  |
# 415706        29 40 81 128                               HyperSQL     0  |
# 454043               27 76                               HyperSQL     0  |
# 454873              29 114                               HyperSQL     0  |
# 457599           10 42 160                               HyperSQL     0  |
# 465405            23 27 42                               HyperSQL     0  |
# 468143             114 128                               HyperSQL     0  |
# 469592              42 114                               HyperSQL     0  |
# 775263              24 113                   GoogleCloudDatastore     0  |
# 776100              24 121                   GoogleCloudDatastore     0  |
# 1017944              10 24                                  HBase     0  |
# 1019539               9 24                                  HBase     0  |
# 1315033            183 194                                 Oracle     0  |
# 1726797              28 37                              Couchbase     0  |
# 1727273              28 37                              Couchbase     0  |
# 1727545              28 37                              Couchbase     0  |
# 2278339             36 192                      SAPAdaptiveServer     0  |
# 2281904               0 72                      SAPAdaptiveServer     0  |
# 1016190               9 24                                  HBase     0  |
# 1022891               9 10                                  HBase     0  |
# 1716446            160 178                                IBM_DB2     0  |
# 1809689              37 93                              Hazelcast     0  |
# 1878729           34 42 76                                 SQLite     0  |
# 1910728             34 129                                 SQLite     0  |
# 1919424             76 160                                 SQLite     0  |
# 2238906             36 192                      SAPAdaptiveServer     0  |
# 2277944     0 17 36 72 192                      SAPAdaptiveServer     0  |
# 2279394             36 192                      SAPAdaptiveServer     0  |
# 2280448             36 192                      SAPAdaptiveServer     0  |
# 2281624    0 36 72 160 192                      SAPAdaptiveServer     0  |
# 2486453             42 111                 PostgreSQL_CockroachDB     0  |
# 2489426              28 37                 PostgreSQL_CockroachDB     0  |
# 2699216              16 28                      Join_Ignite_NoSql     0  |
#
#                                                 B SUP_B BC  \
# 1814997                               INHazelcast     0  /
# 1814998                               INHazelcast     0  /
# 1815289                                INDynamoDB     0  /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase     0  /
# 2277333                       INSAPAdaptiveServer     0  /
# 2277347                       INSAPAdaptiveServer     0  /
# 245537                           OUTMySQL_MariaDB     0  /
# 245752                           OUTMySQL_MariaDB     0  /
# 460431                                OUTHyperSQL     0  /
# 460751                                OUTHyperSQL     0  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase     0  /
# 2260005                      OUTSAPAdaptiveServer     0  /
# 2260014                      OUTSAPAdaptiveServer     0  /
# 2260074                      OUTSAPAdaptiveServer     0  /
# 2260093                      OUTSAPAdaptiveServer     0  /
# 2260135                      OUTSAPAdaptiveServer     0  /
# 2260212                      OUTSAPAdaptiveServer     0  /
# 2260303                      OUTSAPAdaptiveServer     0  /
# 203866                                    INRedis     0  |
# 278208                                INCassandra     0  |
# 280863                                       INH2     0  |
# 415706                                    INRedis     0  |
# 454043                                  INMongoDB     0  |
# 454873                                   INOracle     0  |
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 465405                                       INH2     0  |
# 468143                   INPostgreSQL_CockroachDB     0  |
# 469592                                  INIBM_DB2     0  |
# 775263                                       INH2     0  |
# 776100                   INPostgreSQL_CockroachDB     0  |
# 1017944                                INDynamoDB     0  |
# 1019539                  INPostgreSQL_CockroachDB     0  |
# 1315033                                  INSQLite     0  |
# 1726797                               INHazelcast     0  |
# 1727273                  INPostgreSQL_CockroachDB     0  |
# 1727545                  INMicrosoftAzureCosmosDB     0  |
# 2278339                  INPostgreSQL_CockroachDB     0  |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 1016190                                      INH2     0  |
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 1809689                                   INRedis     0  |
# 1878729                                   INRedis     0  |
# 1910728                                      INH2     0  |
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 2238906                          INSAPSQLAnywhere     0  |
# 2277944                       INSAPAdaptiveServer     0  |
# 2279394                                  INOracle     0  |
# 2280448                                 INIBM_DB2     0  |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 2486453                                      INH2     0  |
# 2489426                               INCouchbase     0  |
# 2699216                                   INNeo4j     0  |
#
#                                                C SUP_C CD  \
# 1814997                             OUTHazelcast     0  |
# 1814998                             OUTHazelcast     0  |
# 1815289                             OUTHazelcast     0  |
# 1815759                             OUTHazelcast     0  |
# 2277333                     OUTSAPAdaptiveServer     0  |
# 2277347                     OUTSAPAdaptiveServer     0  |
# 245537                                   INRedis     0  |
# 245752                                      INH2     0  |
# 460431                  INPostgreSQL_CockroachDB     0  |
# 460751                                      INH2     0  |
# 619092                                   INRedis     0  |
# 2260005                      INSAPAdaptiveServer     0  |
# 2260014                      INSAPAdaptiveServer     0  |
# 2260074                         INSAPSQLAnywhere     0  |
# 2260093                 INPostgreSQL_CockroachDB     0  |
# 2260135                                 INOracle     0  |
# 2260212                                INIBM_DB2     0  |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase     0  |
# 203866                          OUTMySQL_MariaDB     0  /
# 278208                          OUTMySQL_MariaDB     0  /
# 280863                          OUTMySQL_MariaDB     0  /
# 415706                               OUTHyperSQL     0  /
# 454043                               OUTHyperSQL     0  /
# 454873                               OUTHyperSQL     0  /
# 457599                               OUTHyperSQL     0  /
# 465405                               OUTHyperSQL     0  /
# 468143                               OUTHyperSQL     0  /
# 469592                               OUTHyperSQL     0  /
# 775263                   OUTGoogleCloudDatastore     0  /
# 776100                   OUTGoogleCloudDatastore     0  /
# 1017944                                 OUTHBase     0  /
# 1019539                                 OUTHBase     0  /
# 1315033                                OUTOracle     0  /
# 1726797                             OUTCouchbase     0  /
# 1727273                             OUTCouchbase     0  /
# 1727545                             OUTCouchbase     0  /
# 2278339                     OUTSAPAdaptiveServer     0  /
# 2281904                     OUTSAPAdaptiveServer     0  /
# 1016190                                       H2     0  /
# 1022891    MSSQLServer_MicrosoftAzureSQLDatabase     0  /
# 1716446    MSSQLServer_MicrosoftAzureSQLDatabase     0  /
# 1809689                                    Redis     0  /
# 1878729                                    Redis     0  /
# 1910728                                       H2     0  /
# 1919424    MSSQLServer_MicrosoftAzureSQLDatabase     0  /
# 2238906                           SAPSQLAnywhere     0  /
# 2277944                        SAPAdaptiveServer     0  /
# 2279394                                   Oracle     0  /
# 2280448                                  IBM_DB2     0  /
# 2281624    MSSQLServer_MicrosoftAzureSQLDatabase     0  /
# 2486453                                       H2     0  /
# 2489426                                Couchbase     0  /
# 2699216                                    Neo4j     0  /
#
#                                              D SUP_D  DE
# 1814997                              Hazelcast     0  |#
# 1814998                            INHazelcast     0  |#
# 1815289                               DynamoDB     0  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase     0  |#
# 2277333                    INSAPAdaptiveServer     0  |#
# 2277347                      SAPAdaptiveServer     0  |#
# 245537                                   Redis     0  |#
# 245752                                      H2     0  |#
# 460431                  PostgreSQL_CockroachDB     0  |#
# 460751                                      H2     0  |#
# 619092                                   Redis     0  |#
# 2260005                    INSAPAdaptiveServer     0  |#
# 2260014                      SAPAdaptiveServer     0  |#
# 2260074                         SAPSQLAnywhere     0  |#
# 2260093                 PostgreSQL_CockroachDB     0  |#
# 2260135                                 Oracle     0  |#
# 2260212                                IBM_DB2     0  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase     0  |#
# 203866                                   Redis     0  |#
# 278208                               Cassandra     0  |#
# 280863                                      H2     0  |#
# 415706                                   Redis     0  |#
# 454043                                 MongoDB     0  |#
# 454873                                  Oracle     0  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase     0  |#
# 465405                                      H2     0  |#
# 468143                  PostgreSQL_CockroachDB     0  |#
# 469592                                 IBM_DB2     0  |#
# 775263                                      H2     0  |#
# 776100                  PostgreSQL_CockroachDB     0  |#
# 1017944                               DynamoDB     0  |#
# 1019539                 PostgreSQL_CockroachDB     0  |#
# 1315033                                 SQLite     0  |#
# 1726797                              Hazelcast     0  |#
# 1727273                 PostgreSQL_CockroachDB     0  |#
# 1727545                 MicrosoftAzureCosmosDB     0  |#
# 2278339                 PostgreSQL_CockroachDB     0  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase     0  |#
# 1016190                               OUTHBase     0  |#
# 1022891                               OUTHBase     0  |#
# 1716446                             OUTIBM_DB2     0  |#
# 1809689                           OUTHazelcast     0  |#
# 1878729                              OUTSQLite     0  |#
# 1910728                              OUTSQLite     0  |#
# 1919424                              OUTSQLite     0  |#
# 2238906                   OUTSAPAdaptiveServer     0  |#
# 2277944                   OUTSAPAdaptiveServer     0  |#
# 2279394                   OUTSAPAdaptiveServer     0  |#
# 2280448                   OUTSAPAdaptiveServer     0  |#
# 2281624                   OUTSAPAdaptiveServer     0  |#
# 2486453              OUTPostgreSQL_CockroachDB     0  |#
# 2489426              OUTPostgreSQL_CockroachDB     0  |#
# 2699216                   OUTJoin_Ignite_NoSql     0  |#

# %% [markdown]
# Researching and writing the individual support in the collumns A,B,C and D

# %%
for index, row in df8.iterrows():
    for j, rowj in df5.iterrows():
        if row['A'] == rowj['Pattern_v1']:
            df8.loc[index,'SUP_A'] =  df8.loc[index,'SUP_A'].replace(df8.loc[index,'SUP_A'],df5.loc[j,'SUP_v1'])
            #print(row['DB_1'],':', rowj['Pattern_v1'])
        if row['B'] == rowj['Pattern_v1']:
         #   print(row['Pattern_v2'], rowj['Pattern_v1'])
            df8.loc[index,'SUP_B'] =  df8.loc[index,'SUP_B'].replace(df8.loc[index,'SUP_B'],df5.loc[j,'SUP_v1'])
        #print(row['Pattern_v3'],':')
        if row['C'] != ' ' or row['C'] != '':
            #print(row['Pattern_v3'],':', rowj['Pattern_v1'])
            if row['C'] == rowj['Pattern_v1']:
                #print(row['DB_3'],'!', rowj['Pattern_v1'])
                df8.loc[index,'SUP_C'] =  df8.loc[index,'SUP_C'].replace(df8.loc[index,'SUP_C'],df5.loc[j,'SUP_v1'])
        #elif row['DB_3'].isnull():
         #   df8.loc[index,'SUP_DB3'] =  df8.loc[index,'SUP_DB3'].replace(df8.loc[index,'SUP_DB3'], '0')
          #  print('vazio')
        if (row['D'] is not None) or (row['D'] != ' ') or (row['D'] != '') :
            if row['D']  == rowj['Pattern_v1']:
                #print(row['Pattern_v3'],'!', rowj['Pattern_v1'])
                df8.loc[index,'SUP_D'] =  df8.loc[index,'SUP_D'].replace(df8.loc[index,'SUP_D'],df5.loc[j,'SUP_v1'])

# %%
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 1814997  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#Hazel...       2
# 1814998  Hazelcast#|#INHazelcast#/#OUTHazelcast#|#INHaz...       2
# 1815289  Hazelcast#|#INDynamoDB#/#OUTHazelcast#|#Dynamo...       2
# 1815759  Hazelcast#|#INMSSQLServer_MicrosoftAzureSQLDat...       2
# 2277333  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
# 2277347  SAPAdaptiveServer#|#INSAPAdaptiveServer#/#OUTS...       4
# 245537   MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INRedis#|#R...       2
# 245752     MySQL_MariaDB#|#OUTMySQL_MariaDB#/#INH2#|#H2#|#       3
# 460431   HyperSQL#|#OUTHyperSQL#/#INPostgreSQL_Cockroac...       2
# 460751               HyperSQL#|#OUTHyperSQL#/#INH2#|#H2#|#       5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase#|#OUTMSS...       2
# 2260005  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260014  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       3
# 2260074  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INS...       2
# 2260093  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INP...       3
# 2260135  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INO...       2
# 2260212  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INI...       2
# 2260303  SAPAdaptiveServer#|#OUTSAPAdaptiveServer#/#INM...       2
# 203866   MySQL_MariaDB#|#INRedis#|#OUTMySQL_MariaDB#/#R...       2
# 278208   MySQL_MariaDB#|#INCassandra#|#OUTMySQL_MariaDB...       2
# 280863     MySQL_MariaDB#|#INH2#|#OUTMySQL_MariaDB#/#H2#|#       2
# 415706         HyperSQL#|#INRedis#|#OUTHyperSQL#/#Redis#|#       4
# 454043     HyperSQL#|#INMongoDB#|#OUTHyperSQL#/#MongoDB#|#       2
# 454873       HyperSQL#|#INOracle#|#OUTHyperSQL#/#Oracle#|#       2
# 457599   HyperSQL#|#INMSSQLServer_MicrosoftAzureSQLData...       3
# 465405               HyperSQL#|#INH2#|#OUTHyperSQL#/#H2#|#       3
# 468143   HyperSQL#|#INPostgreSQL_CockroachDB#|#OUTHyper...       2
# 469592     HyperSQL#|#INIBM_DB2#|#OUTHyperSQL#/#IBM_DB2#|#       2
# 775263   GoogleCloudDatastore#|#INH2#|#OUTGoogleCloudDa...       2
# 776100   GoogleCloudDatastore#|#INPostgreSQL_CockroachD...       2
# 1017944        HBase#|#INDynamoDB#|#OUTHBase#/#DynamoDB#|#       2
# 1019539  HBase#|#INPostgreSQL_CockroachDB#|#OUTHBase#/#...       2
# 1315033          Oracle#|#INSQLite#|#OUTOracle#/#SQLite#|#       2
# 1726797  Couchbase#|#INHazelcast#|#OUTCouchbase#/#Hazel...       2
# 1727273  Couchbase#|#INPostgreSQL_CockroachDB#|#OUTCouc...       2
# 1727545  Couchbase#|#INMicrosoftAzureCosmosDB#|#OUTCouc...       2
# 2278339  SAPAdaptiveServer#|#INPostgreSQL_CockroachDB#|...       2
# 2281904  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       2
# 1016190                    HBase#|#INH2#|#H2#/#OUTHBase#|#       2
# 1022891  HBase#|#INMSSQLServer_MicrosoftAzureSQLDatabas...       2
# 1716446  IBM_DB2#|#INMSSQLServer_MicrosoftAzureSQLDatab...       2
# 1809689      Hazelcast#|#INRedis#|#Redis#/#OUTHazelcast#|#       2
# 1878729            SQLite#|#INRedis#|#Redis#/#OUTSQLite#|#       3
# 1910728                  SQLite#|#INH2#|#H2#/#OUTSQLite#|#       2
# 1919424  SQLite#|#INMSSQLServer_MicrosoftAzureSQLDataba...       2
# 2238906  SAPAdaptiveServer#|#INSAPSQLAnywhere#|#SAPSQLA...       2
# 2277944  SAPAdaptiveServer#|#INSAPAdaptiveServer#|#SAPA...       5
# 2279394  SAPAdaptiveServer#|#INOracle#|#Oracle#/#OUTSAP...       2
# 2280448  SAPAdaptiveServer#|#INIBM_DB2#|#IBM_DB2#/#OUTS...       2
# 2281624  SAPAdaptiveServer#|#INMSSQLServer_MicrosoftAzu...       5
# 2486453  PostgreSQL_CockroachDB#|#INH2#|#H2#/#OUTPostgr...       2
# 2489426  PostgreSQL_CockroachDB#|#INCouchbase#|#Couchba...       2
# 2699216  Join_Ignite_NoSql#|#INNeo4j#|#Neo4j#/#OUTJoin_...       2
#
#                        SID                                      A SUP_A AB  \
# 1814997             37 129                              Hazelcast    19  |
# 1814998             37 129                              Hazelcast    19  |
# 1815289              37 43                              Hazelcast    19  |
# 1815759              37 93                              Hazelcast    19  |
# 2277333       17 36 72 192                      SAPAdaptiveServer    18  |
# 2277347       17 36 72 192                      SAPAdaptiveServer    18  |
# 245537              16 169                          MySQL_MariaDB   112  |
# 245752           16 44 169                          MySQL_MariaDB   112  |
# 460431              81 131                               HyperSQL    60  |
# 460751    40 44 56 128 131                               HyperSQL    60  |
# 619092              16 128  MSSQLServer_MicrosoftAzureSQLDatabase    42  |
# 2260005           0 36 192                      SAPAdaptiveServer    18  |
# 2260014           0 36 192                      SAPAdaptiveServer    18  |
# 2260074             36 192                      SAPAdaptiveServer    18  |
# 2260093         36 178 192                      SAPAdaptiveServer    18  |
# 2260135             36 192                      SAPAdaptiveServer    18  |
# 2260212             36 192                      SAPAdaptiveServer    18  |
# 2260303             36 192                      SAPAdaptiveServer    18  |
# 203866               22 96                          MySQL_MariaDB   112  |
# 278208             109 140                          MySQL_MariaDB   112  |
# 280863              44 111                          MySQL_MariaDB   112  |
# 415706        29 40 81 128                               HyperSQL    60  |
# 454043               27 76                               HyperSQL    60  |
# 454873              29 114                               HyperSQL    60  |
# 457599           10 42 160                               HyperSQL    60  |
# 465405            23 27 42                               HyperSQL    60  |
# 468143             114 128                               HyperSQL    60  |
# 469592              42 114                               HyperSQL    60  |
# 775263              24 113                   GoogleCloudDatastore    26  |
# 776100              24 121                   GoogleCloudDatastore    26  |
# 1017944              10 24                                  HBase    19  |
# 1019539               9 24                                  HBase    19  |
# 1315033            183 194                                 Oracle    70  |
# 1726797              28 37                              Couchbase     4  |
# 1727273              28 37                              Couchbase     4  |
# 1727545              28 37                              Couchbase     4  |
# 2278339             36 192                      SAPAdaptiveServer    18  |
# 2281904               0 72                      SAPAdaptiveServer    18  |
# 1016190               9 24                                  HBase    19  |
# 1022891               9 10                                  HBase    19  |
# 1716446            160 178                                IBM_DB2    25  |
# 1809689              37 93                              Hazelcast    19  |
# 1878729           34 42 76                                 SQLite    39  |
# 1910728             34 129                                 SQLite    39  |
# 1919424             76 160                                 SQLite    39  |
# 2238906             36 192                      SAPAdaptiveServer    18  |
# 2277944     0 17 36 72 192                      SAPAdaptiveServer    18  |
# 2279394             36 192                      SAPAdaptiveServer    18  |
# 2280448             36 192                      SAPAdaptiveServer    18  |
# 2281624    0 36 72 160 192                      SAPAdaptiveServer    18  |
# 2486453             42 111                 PostgreSQL_CockroachDB    79  |
# 2489426              28 37                 PostgreSQL_CockroachDB    79  |
# 2699216              16 28                      Join_Ignite_NoSql     3  |
#
#                                                 B SUP_B BC  \
# 1814997                               INHazelcast    71  /
# 1814998                               INHazelcast    71  /
# 1815289                                INDynamoDB    22  /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase    34  /
# 2277333                       INSAPAdaptiveServer    33  /
# 2277347                       INSAPAdaptiveServer    33  /
# 245537                           OUTMySQL_MariaDB    40  /
# 245752                           OUTMySQL_MariaDB    40  /
# 460431                                OUTHyperSQL    27  /
# 460751                                OUTHyperSQL    27  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase    15  /
# 2260005                      OUTSAPAdaptiveServer    41  /
# 2260014                      OUTSAPAdaptiveServer    41  /
# 2260074                      OUTSAPAdaptiveServer    41  /
# 2260093                      OUTSAPAdaptiveServer    41  /
# 2260135                      OUTSAPAdaptiveServer    41  /
# 2260212                      OUTSAPAdaptiveServer    41  /
# 2260303                      OUTSAPAdaptiveServer    41  /
# 203866                                    INRedis    59  |
# 278208                                INCassandra    15  |
# 280863                                       INH2    56  |
# 415706                                    INRedis    59  |
# 454043                                  INMongoDB    27  |
# 454873                                   INOracle    44  |
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 465405                                       INH2    56  |
# 468143                   INPostgreSQL_CockroachDB    51  |
# 469592                                  INIBM_DB2    15  |
# 775263                                       INH2    56  |
# 776100                   INPostgreSQL_CockroachDB    51  |
# 1017944                                INDynamoDB    22  |
# 1019539                  INPostgreSQL_CockroachDB    51  |
# 1315033                                  INSQLite    26  |
# 1726797                               INHazelcast    71  |
# 1727273                  INPostgreSQL_CockroachDB    51  |
# 1727545                  INMicrosoftAzureCosmosDB     5  |
# 2278339                  INPostgreSQL_CockroachDB    51  |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1016190                                      INH2    56  |
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1809689                                   INRedis    59  |
# 1878729                                   INRedis    59  |
# 1910728                                      INH2    56  |
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2238906                          INSAPSQLAnywhere    12  |
# 2277944                       INSAPAdaptiveServer    33  |
# 2279394                                  INOracle    44  |
# 2280448                                 INIBM_DB2    15  |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2486453                                      INH2    56  |
# 2489426                               INCouchbase     4  |
# 2699216                                   INNeo4j     5  |
#
#                                                C SUP_C CD  \
# 1814997                             OUTHazelcast    60  |
# 1814998                             OUTHazelcast    60  |
# 1815289                             OUTHazelcast    60  |
# 1815759                             OUTHazelcast    60  |
# 2277333                     OUTSAPAdaptiveServer    41  |
# 2277347                     OUTSAPAdaptiveServer    41  |
# 245537                                   INRedis    59  |
# 245752                                      INH2    56  |
# 460431                  INPostgreSQL_CockroachDB    51  |
# 460751                                      INH2    56  |
# 619092                                   INRedis    59  |
# 2260005                      INSAPAdaptiveServer    33  |
# 2260014                      INSAPAdaptiveServer    33  |
# 2260074                         INSAPSQLAnywhere    12  |
# 2260093                 INPostgreSQL_CockroachDB    51  |
# 2260135                                 INOracle    44  |
# 2260212                                INIBM_DB2    15  |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 203866                          OUTMySQL_MariaDB    40  /
# 278208                          OUTMySQL_MariaDB    40  /
# 280863                          OUTMySQL_MariaDB    40  /
# 415706                               OUTHyperSQL    27  /
# 454043                               OUTHyperSQL    27  /
# 454873                               OUTHyperSQL    27  /
# 457599                               OUTHyperSQL    27  /
# 465405                               OUTHyperSQL    27  /
# 468143                               OUTHyperSQL    27  /
# 469592                               OUTHyperSQL    27  /
# 775263                   OUTGoogleCloudDatastore    10  /
# 776100                   OUTGoogleCloudDatastore    10  /
# 1017944                                 OUTHBase     9  /
# 1019539                                 OUTHBase     9  /
# 1315033                                OUTOracle    23  /
# 1726797                             OUTCouchbase     4  /
# 1727273                             OUTCouchbase     4  /
# 1727545                             OUTCouchbase     4  /
# 2278339                     OUTSAPAdaptiveServer    41  /
# 2281904                     OUTSAPAdaptiveServer    41  /
# 1016190                                       H2    86  /
# 1022891    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1716446    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1809689                                    Redis    71  /
# 1878729                                    Redis    71  /
# 1910728                                       H2    86  /
# 1919424    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2238906                           SAPSQLAnywhere    19  /
# 2277944                        SAPAdaptiveServer    18  /
# 2279394                                   Oracle    70  /
# 2280448                                  IBM_DB2    25  /
# 2281624    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2486453                                       H2    86  /
# 2489426                                Couchbase     4  /
# 2699216                                    Neo4j     5  /
#
#                                              D SUP_D  DE
# 1814997                              Hazelcast    19  |#
# 1814998                            INHazelcast    71  |#
# 1815289                               DynamoDB    22  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 2277333                    INSAPAdaptiveServer    33  |#
# 2277347                      SAPAdaptiveServer    18  |#
# 245537                                   Redis    71  |#
# 245752                                      H2    86  |#
# 460431                  PostgreSQL_CockroachDB    79  |#
# 460751                                      H2    86  |#
# 619092                                   Redis    71  |#
# 2260005                    INSAPAdaptiveServer    33  |#
# 2260014                      SAPAdaptiveServer    18  |#
# 2260074                         SAPSQLAnywhere    19  |#
# 2260093                 PostgreSQL_CockroachDB    79  |#
# 2260135                                 Oracle    70  |#
# 2260212                                IBM_DB2    25  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 203866                                   Redis    71  |#
# 278208                               Cassandra    19  |#
# 280863                                      H2    86  |#
# 415706                                   Redis    71  |#
# 454043                                 MongoDB    36  |#
# 454873                                  Oracle    70  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 465405                                      H2    86  |#
# 468143                  PostgreSQL_CockroachDB    79  |#
# 469592                                 IBM_DB2    25  |#
# 775263                                      H2    86  |#
# 776100                  PostgreSQL_CockroachDB    79  |#
# 1017944                               DynamoDB    22  |#
# 1019539                 PostgreSQL_CockroachDB    79  |#
# 1315033                                 SQLite    39  |#
# 1726797                              Hazelcast    19  |#
# 1727273                 PostgreSQL_CockroachDB    79  |#
# 1727545                 MicrosoftAzureCosmosDB     5  |#
# 2278339                 PostgreSQL_CockroachDB    79  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 1016190                               OUTHBase     9  |#
# 1022891                               OUTHBase     9  |#
# 1716446                             OUTIBM_DB2    10  |#
# 1809689                           OUTHazelcast    60  |#
# 1878729                              OUTSQLite    16  |#
# 1910728                              OUTSQLite    16  |#
# 1919424                              OUTSQLite    16  |#
# 2238906                   OUTSAPAdaptiveServer    41  |#
# 2277944                   OUTSAPAdaptiveServer    41  |#
# 2279394                   OUTSAPAdaptiveServer    41  |#
# 2280448                   OUTSAPAdaptiveServer    41  |#
# 2281624                   OUTSAPAdaptiveServer    41  |#
# 2486453              OUTPostgreSQL_CockroachDB    27  |#
# 2489426              OUTPostgreSQL_CockroachDB    27  |#
# 2699216                   OUTJoin_Ignite_NoSql     2  |#

# %%
#df3['Pattern'].replace({r"|": '#|#'}, regex=True, inplace=True)
df8['Pattern'].replace({'#': ''}, regex=True, inplace=True)
df8
# Out:
#                                                    Pattern SUP_ABCD  \
# 1814997      Hazelcast|INHazelcast/OUTHazelcast|Hazelcast|       2
# 1814998    Hazelcast|INHazelcast/OUTHazelcast|INHazelcast|       2
# 1815289        Hazelcast|INDynamoDB/OUTHazelcast|DynamoDB|       2
# 1815759  Hazelcast|INMSSQLServer_MicrosoftAzureSQLDatab...       2
# 2277333  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...       4
# 2277347  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...       4
# 245537       MySQL_MariaDB|OUTMySQL_MariaDB/INRedis|Redis|       2
# 245752             MySQL_MariaDB|OUTMySQL_MariaDB/INH2|H2|       3
# 460431   HyperSQL|OUTHyperSQL/INPostgreSQL_CockroachDB|...       2
# 460751                       HyperSQL|OUTHyperSQL/INH2|H2|       5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase|OUTMSSQL...       2
# 2260005  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...       3
# 2260014  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...       3
# 2260074  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPSQ...       2
# 2260093  SAPAdaptiveServer|OUTSAPAdaptiveServer/INPostg...       3
# 2260135  SAPAdaptiveServer|OUTSAPAdaptiveServer/INOracl...       2
# 2260212  SAPAdaptiveServer|OUTSAPAdaptiveServer/INIBM_D...       2
# 2260303  SAPAdaptiveServer|OUTSAPAdaptiveServer/INMSSQL...       2
# 203866       MySQL_MariaDB|INRedis|OUTMySQL_MariaDB/Redis|       2
# 278208   MySQL_MariaDB|INCassandra|OUTMySQL_MariaDB/Cas...       2
# 280863             MySQL_MariaDB|INH2|OUTMySQL_MariaDB/H2|       2
# 415706                 HyperSQL|INRedis|OUTHyperSQL/Redis|       4
# 454043             HyperSQL|INMongoDB|OUTHyperSQL/MongoDB|       2
# 454873               HyperSQL|INOracle|OUTHyperSQL/Oracle|       2
# 457599   HyperSQL|INMSSQLServer_MicrosoftAzureSQLDataba...       3
# 465405                       HyperSQL|INH2|OUTHyperSQL/H2|       3
# 468143   HyperSQL|INPostgreSQL_CockroachDB|OUTHyperSQL/...       2
# 469592             HyperSQL|INIBM_DB2|OUTHyperSQL/IBM_DB2|       2
# 775263   GoogleCloudDatastore|INH2|OUTGoogleCloudDatast...       2
# 776100   GoogleCloudDatastore|INPostgreSQL_CockroachDB|...       2
# 1017944                HBase|INDynamoDB|OUTHBase/DynamoDB|       2
# 1019539  HBase|INPostgreSQL_CockroachDB|OUTHBase/Postgr...       2
# 1315033                  Oracle|INSQLite|OUTOracle/SQLite|       2
# 1726797      Couchbase|INHazelcast|OUTCouchbase/Hazelcast|       2
# 1727273  Couchbase|INPostgreSQL_CockroachDB|OUTCouchbas...       2
# 1727545  Couchbase|INMicrosoftAzureCosmosDB|OUTCouchbas...       2
# 2278339  SAPAdaptiveServer|INPostgreSQL_CockroachDB|OUT...       2
# 2281904  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...       2
# 1016190                            HBase|INH2|H2/OUTHBase|       2
# 1022891  HBase|INMSSQLServer_MicrosoftAzureSQLDatabase|...       2
# 1716446  IBM_DB2|INMSSQLServer_MicrosoftAzureSQLDatabas...       2
# 1809689              Hazelcast|INRedis|Redis/OUTHazelcast|       2
# 1878729                    SQLite|INRedis|Redis/OUTSQLite|       3
# 1910728                          SQLite|INH2|H2/OUTSQLite|       2
# 1919424  SQLite|INMSSQLServer_MicrosoftAzureSQLDatabase...       2
# 2238906  SAPAdaptiveServer|INSAPSQLAnywhere|SAPSQLAnywh...       2
# 2277944  SAPAdaptiveServer|INSAPAdaptiveServer|SAPAdapt...       5
# 2279394  SAPAdaptiveServer|INOracle|Oracle/OUTSAPAdapti...       2
# 2280448  SAPAdaptiveServer|INIBM_DB2|IBM_DB2/OUTSAPAdap...       2
# 2281624  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...       5
# 2486453  PostgreSQL_CockroachDB|INH2|H2/OUTPostgreSQL_C...       2
# 2489426  PostgreSQL_CockroachDB|INCouchbase|Couchbase/O...       2
# 2699216  Join_Ignite_NoSql|INNeo4j|Neo4j/OUTJoin_Ignite...       2
#
#                        SID                                      A SUP_A AB  \
# 1814997             37 129                              Hazelcast    19  |
# 1814998             37 129                              Hazelcast    19  |
# 1815289              37 43                              Hazelcast    19  |
# 1815759              37 93                              Hazelcast    19  |
# 2277333       17 36 72 192                      SAPAdaptiveServer    18  |
# 2277347       17 36 72 192                      SAPAdaptiveServer    18  |
# 245537              16 169                          MySQL_MariaDB   112  |
# 245752           16 44 169                          MySQL_MariaDB   112  |
# 460431              81 131                               HyperSQL    60  |
# 460751    40 44 56 128 131                               HyperSQL    60  |
# 619092              16 128  MSSQLServer_MicrosoftAzureSQLDatabase    42  |
# 2260005           0 36 192                      SAPAdaptiveServer    18  |
# 2260014           0 36 192                      SAPAdaptiveServer    18  |
# 2260074             36 192                      SAPAdaptiveServer    18  |
# 2260093         36 178 192                      SAPAdaptiveServer    18  |
# 2260135             36 192                      SAPAdaptiveServer    18  |
# 2260212             36 192                      SAPAdaptiveServer    18  |
# 2260303             36 192                      SAPAdaptiveServer    18  |
# 203866               22 96                          MySQL_MariaDB   112  |
# 278208             109 140                          MySQL_MariaDB   112  |
# 280863              44 111                          MySQL_MariaDB   112  |
# 415706        29 40 81 128                               HyperSQL    60  |
# 454043               27 76                               HyperSQL    60  |
# 454873              29 114                               HyperSQL    60  |
# 457599           10 42 160                               HyperSQL    60  |
# 465405            23 27 42                               HyperSQL    60  |
# 468143             114 128                               HyperSQL    60  |
# 469592              42 114                               HyperSQL    60  |
# 775263              24 113                   GoogleCloudDatastore    26  |
# 776100              24 121                   GoogleCloudDatastore    26  |
# 1017944              10 24                                  HBase    19  |
# 1019539               9 24                                  HBase    19  |
# 1315033            183 194                                 Oracle    70  |
# 1726797              28 37                              Couchbase     4  |
# 1727273              28 37                              Couchbase     4  |
# 1727545              28 37                              Couchbase     4  |
# 2278339             36 192                      SAPAdaptiveServer    18  |
# 2281904               0 72                      SAPAdaptiveServer    18  |
# 1016190               9 24                                  HBase    19  |
# 1022891               9 10                                  HBase    19  |
# 1716446            160 178                                IBM_DB2    25  |
# 1809689              37 93                              Hazelcast    19  |
# 1878729           34 42 76                                 SQLite    39  |
# 1910728             34 129                                 SQLite    39  |
# 1919424             76 160                                 SQLite    39  |
# 2238906             36 192                      SAPAdaptiveServer    18  |
# 2277944     0 17 36 72 192                      SAPAdaptiveServer    18  |
# 2279394             36 192                      SAPAdaptiveServer    18  |
# 2280448             36 192                      SAPAdaptiveServer    18  |
# 2281624    0 36 72 160 192                      SAPAdaptiveServer    18  |
# 2486453             42 111                 PostgreSQL_CockroachDB    79  |
# 2489426              28 37                 PostgreSQL_CockroachDB    79  |
# 2699216              16 28                      Join_Ignite_NoSql     3  |
#
#                                                 B SUP_B BC  \
# 1814997                               INHazelcast    71  /
# 1814998                               INHazelcast    71  /
# 1815289                                INDynamoDB    22  /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase    34  /
# 2277333                       INSAPAdaptiveServer    33  /
# 2277347                       INSAPAdaptiveServer    33  /
# 245537                           OUTMySQL_MariaDB    40  /
# 245752                           OUTMySQL_MariaDB    40  /
# 460431                                OUTHyperSQL    27  /
# 460751                                OUTHyperSQL    27  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase    15  /
# 2260005                      OUTSAPAdaptiveServer    41  /
# 2260014                      OUTSAPAdaptiveServer    41  /
# 2260074                      OUTSAPAdaptiveServer    41  /
# 2260093                      OUTSAPAdaptiveServer    41  /
# 2260135                      OUTSAPAdaptiveServer    41  /
# 2260212                      OUTSAPAdaptiveServer    41  /
# 2260303                      OUTSAPAdaptiveServer    41  /
# 203866                                    INRedis    59  |
# 278208                                INCassandra    15  |
# 280863                                       INH2    56  |
# 415706                                    INRedis    59  |
# 454043                                  INMongoDB    27  |
# 454873                                   INOracle    44  |
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 465405                                       INH2    56  |
# 468143                   INPostgreSQL_CockroachDB    51  |
# 469592                                  INIBM_DB2    15  |
# 775263                                       INH2    56  |
# 776100                   INPostgreSQL_CockroachDB    51  |
# 1017944                                INDynamoDB    22  |
# 1019539                  INPostgreSQL_CockroachDB    51  |
# 1315033                                  INSQLite    26  |
# 1726797                               INHazelcast    71  |
# 1727273                  INPostgreSQL_CockroachDB    51  |
# 1727545                  INMicrosoftAzureCosmosDB     5  |
# 2278339                  INPostgreSQL_CockroachDB    51  |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1016190                                      INH2    56  |
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1809689                                   INRedis    59  |
# 1878729                                   INRedis    59  |
# 1910728                                      INH2    56  |
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2238906                          INSAPSQLAnywhere    12  |
# 2277944                       INSAPAdaptiveServer    33  |
# 2279394                                  INOracle    44  |
# 2280448                                 INIBM_DB2    15  |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2486453                                      INH2    56  |
# 2489426                               INCouchbase     4  |
# 2699216                                   INNeo4j     5  |
#
#                                                C SUP_C CD  \
# 1814997                             OUTHazelcast    60  |
# 1814998                             OUTHazelcast    60  |
# 1815289                             OUTHazelcast    60  |
# 1815759                             OUTHazelcast    60  |
# 2277333                     OUTSAPAdaptiveServer    41  |
# 2277347                     OUTSAPAdaptiveServer    41  |
# 245537                                   INRedis    59  |
# 245752                                      INH2    56  |
# 460431                  INPostgreSQL_CockroachDB    51  |
# 460751                                      INH2    56  |
# 619092                                   INRedis    59  |
# 2260005                      INSAPAdaptiveServer    33  |
# 2260014                      INSAPAdaptiveServer    33  |
# 2260074                         INSAPSQLAnywhere    12  |
# 2260093                 INPostgreSQL_CockroachDB    51  |
# 2260135                                 INOracle    44  |
# 2260212                                INIBM_DB2    15  |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 203866                          OUTMySQL_MariaDB    40  /
# 278208                          OUTMySQL_MariaDB    40  /
# 280863                          OUTMySQL_MariaDB    40  /
# 415706                               OUTHyperSQL    27  /
# 454043                               OUTHyperSQL    27  /
# 454873                               OUTHyperSQL    27  /
# 457599                               OUTHyperSQL    27  /
# 465405                               OUTHyperSQL    27  /
# 468143                               OUTHyperSQL    27  /
# 469592                               OUTHyperSQL    27  /
# 775263                   OUTGoogleCloudDatastore    10  /
# 776100                   OUTGoogleCloudDatastore    10  /
# 1017944                                 OUTHBase     9  /
# 1019539                                 OUTHBase     9  /
# 1315033                                OUTOracle    23  /
# 1726797                             OUTCouchbase     4  /
# 1727273                             OUTCouchbase     4  /
# 1727545                             OUTCouchbase     4  /
# 2278339                     OUTSAPAdaptiveServer    41  /
# 2281904                     OUTSAPAdaptiveServer    41  /
# 1016190                                       H2    86  /
# 1022891    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1716446    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1809689                                    Redis    71  /
# 1878729                                    Redis    71  /
# 1910728                                       H2    86  /
# 1919424    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2238906                           SAPSQLAnywhere    19  /
# 2277944                        SAPAdaptiveServer    18  /
# 2279394                                   Oracle    70  /
# 2280448                                  IBM_DB2    25  /
# 2281624    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2486453                                       H2    86  /
# 2489426                                Couchbase     4  /
# 2699216                                    Neo4j     5  /
#
#                                              D SUP_D  DE
# 1814997                              Hazelcast    19  |#
# 1814998                            INHazelcast    71  |#
# 1815289                               DynamoDB    22  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 2277333                    INSAPAdaptiveServer    33  |#
# 2277347                      SAPAdaptiveServer    18  |#
# 245537                                   Redis    71  |#
# 245752                                      H2    86  |#
# 460431                  PostgreSQL_CockroachDB    79  |#
# 460751                                      H2    86  |#
# 619092                                   Redis    71  |#
# 2260005                    INSAPAdaptiveServer    33  |#
# 2260014                      SAPAdaptiveServer    18  |#
# 2260074                         SAPSQLAnywhere    19  |#
# 2260093                 PostgreSQL_CockroachDB    79  |#
# 2260135                                 Oracle    70  |#
# 2260212                                IBM_DB2    25  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 203866                                   Redis    71  |#
# 278208                               Cassandra    19  |#
# 280863                                      H2    86  |#
# 415706                                   Redis    71  |#
# 454043                                 MongoDB    36  |#
# 454873                                  Oracle    70  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 465405                                      H2    86  |#
# 468143                  PostgreSQL_CockroachDB    79  |#
# 469592                                 IBM_DB2    25  |#
# 775263                                      H2    86  |#
# 776100                  PostgreSQL_CockroachDB    79  |#
# 1017944                               DynamoDB    22  |#
# 1019539                 PostgreSQL_CockroachDB    79  |#
# 1315033                                 SQLite    39  |#
# 1726797                              Hazelcast    19  |#
# 1727273                 PostgreSQL_CockroachDB    79  |#
# 1727545                 MicrosoftAzureCosmosDB     5  |#
# 2278339                 PostgreSQL_CockroachDB    79  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 1016190                               OUTHBase     9  |#
# 1022891                               OUTHBase     9  |#
# 1716446                             OUTIBM_DB2    10  |#
# 1809689                           OUTHazelcast    60  |#
# 1878729                              OUTSQLite    16  |#
# 1910728                              OUTSQLite    16  |#
# 1919424                              OUTSQLite    16  |#
# 2238906                   OUTSAPAdaptiveServer    41  |#
# 2277944                   OUTSAPAdaptiveServer    41  |#
# 2279394                   OUTSAPAdaptiveServer    41  |#
# 2280448                   OUTSAPAdaptiveServer    41  |#
# 2281624                   OUTSAPAdaptiveServer    41  |#
# 2486453              OUTPostgreSQL_CockroachDB    27  |#
# 2489426              OUTPostgreSQL_CockroachDB    27  |#
# 2699216                   OUTJoin_Ignite_NoSql     2  |#

# %%
#Generating excel with all INIT patterns
#df8.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_general_selection10.xlsx",index=True)

# %% [markdown]
# Open patterns size 3 to research combination supports

# %%
#Primeiro tem que gerar saida com INIT tam 3
#HISTORICAL_OUTPUT_SEQUENCIAL_IN_OUT_TAM1 = SEQ_PATTERNS_DIR + os.sep + 'output_seq_in_out.txt' #add in util.py
df10 = pd.read_csv(SEQ_PATTERNS_DIR + os.sep + 'output_tam3.txt', sep= '#', header=None) #'testes/output_init_tam3_7.txt'
#Rename the columns and removing the SUP: and SID: from the corresponding column values
df10.columns = ['Pattern_v2','SUP_v2']
df10.replace({'SUP:': ''}, regex=True, inplace=True) #or df['SUP'] = df['SUP'].str.replace('SUP:','')
df10
# Out:
#                                                Pattern_v2 SUP_v2
# 0                                          INInflux_DB |       5
# 1                                INInflux_DB Influx_DB |       5
# 2                         INInflux_DB Influx_DB SQLite |       2
# 3                      INInflux_DB Influx_DB Snowflake |       2
# 4                      INInflux_DB Influx_DB Cassandra |       4
# ...                                                   ...    ...
# 192466   OUTIBM_DB2 | OUTHazelcast | SAPAdaptiveServer |       2
# 192467  OUTIBM_DB2 | OUTHazelcast | PostgreSQL_Cockroa...      3
# 192468                  OUTIBM_DB2 | OUTHazelcast | H2 |       2
# 192469              OUTIBM_DB2 | OUTHazelcast | Oracle |       3
# 192470             OUTIBM_DB2 | OUTHazelcast | IBM_DB2 |       3
#
# [192471 rows x 2 columns]

# %% [markdown]
# Formating dataframe with support size 3

# %%
df10['Pattern_v2'].replace({r"(?<=\w)\s+(?=\w)": '/'}, regex=True, inplace=True)
df10['Pattern_v2'] = df10['Pattern_v2'].str.replace(' ','')
df10
# Out:
#                                              Pattern_v2 SUP_v2
# 0                                          INInflux_DB|      5
# 1                                INInflux_DB/Influx_DB|      5
# 2                         INInflux_DB/Influx_DB/SQLite|      2
# 3                      INInflux_DB/Influx_DB/Snowflake|      2
# 4                      INInflux_DB/Influx_DB/Cassandra|      4
# ...                                                 ...    ...
# 192466       OUTIBM_DB2|OUTHazelcast|SAPAdaptiveServer|      2
# 192467  OUTIBM_DB2|OUTHazelcast|PostgreSQL_CockroachDB|      3
# 192468                      OUTIBM_DB2|OUTHazelcast|H2|      2
# 192469                  OUTIBM_DB2|OUTHazelcast|Oracle|      3
# 192470                 OUTIBM_DB2|OUTHazelcast|IBM_DB2|      3
#
# [192471 rows x 2 columns]

# %%
df10 =  df10[(df10['Pattern_v2'].str.startswith('IN') & (~df10['Pattern_v2'].str.startswith('INIT'))) | (df10['Pattern_v2'].str.contains('OUT'))] 
df10
# Out:
#                                              Pattern_v2 SUP_v2
# 0                                          INInflux_DB|      5
# 1                                INInflux_DB/Influx_DB|      5
# 2                         INInflux_DB/Influx_DB/SQLite|      2
# 3                      INInflux_DB/Influx_DB/Snowflake|      2
# 4                      INInflux_DB/Influx_DB/Cassandra|      4
# ...                                                 ...    ...
# 192466       OUTIBM_DB2|OUTHazelcast|SAPAdaptiveServer|      2
# 192467  OUTIBM_DB2|OUTHazelcast|PostgreSQL_CockroachDB|      3
# 192468                      OUTIBM_DB2|OUTHazelcast|H2|      2
# 192469                  OUTIBM_DB2|OUTHazelcast|Oracle|      3
# 192470                 OUTIBM_DB2|OUTHazelcast|IBM_DB2|      3
#
# [88283 rows x 2 columns]

# %%
df13 = df8.copy()
#Inserting combination support collumns
df13.insert(3,'SUP_BC','0',False)
df13.insert(4,'SUP_BCD','0',False)

#Removing blank spaces
df13['Pattern'] = df13['Pattern'].str.replace(' ','')

##Removing blank spaces in collumn C
df13['D'] = df13['D'].str.replace(' ','')

#Converting to string because replace
df13['SUP_BC'] = df13['SUP_BC'].astype(str)
df13['SUP_BCD'] = df13['SUP_BCD'].astype(str)

#To resolve "can only concatenate str (not "NoneType") to str" error after suports iteration 
#df13['D'].replace({'None': ''}, regex=True, inplace=True)
#df13['C'].replace({'None': ''}, regex=True, inplace=True)
#df['COL1'] = ['COL1'].fillna(' ')
#df13
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 1814997      Hazelcast|INHazelcast/OUTHazelcast|Hazelcast|       2
# 1814998    Hazelcast|INHazelcast/OUTHazelcast|INHazelcast|       2
# 1815289        Hazelcast|INDynamoDB/OUTHazelcast|DynamoDB|       2
# 1815759  Hazelcast|INMSSQLServer_MicrosoftAzureSQLDatab...       2
# 2277333  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...       4
# 2277347  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...       4
# 245537       MySQL_MariaDB|OUTMySQL_MariaDB/INRedis|Redis|       2
# 245752             MySQL_MariaDB|OUTMySQL_MariaDB/INH2|H2|       3
# 460431   HyperSQL|OUTHyperSQL/INPostgreSQL_CockroachDB|...       2
# 460751                       HyperSQL|OUTHyperSQL/INH2|H2|       5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase|OUTMSSQL...       2
# 2260005  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...       3
# 2260014  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...       3
# 2260074  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPSQ...       2
# 2260093  SAPAdaptiveServer|OUTSAPAdaptiveServer/INPostg...       3
# 2260135  SAPAdaptiveServer|OUTSAPAdaptiveServer/INOracl...       2
# 2260212  SAPAdaptiveServer|OUTSAPAdaptiveServer/INIBM_D...       2
# 2260303  SAPAdaptiveServer|OUTSAPAdaptiveServer/INMSSQL...       2
# 203866       MySQL_MariaDB|INRedis|OUTMySQL_MariaDB/Redis|       2
# 278208   MySQL_MariaDB|INCassandra|OUTMySQL_MariaDB/Cas...       2
# 280863             MySQL_MariaDB|INH2|OUTMySQL_MariaDB/H2|       2
# 415706                 HyperSQL|INRedis|OUTHyperSQL/Redis|       4
# 454043             HyperSQL|INMongoDB|OUTHyperSQL/MongoDB|       2
# 454873               HyperSQL|INOracle|OUTHyperSQL/Oracle|       2
# 457599   HyperSQL|INMSSQLServer_MicrosoftAzureSQLDataba...       3
# 465405                       HyperSQL|INH2|OUTHyperSQL/H2|       3
# 468143   HyperSQL|INPostgreSQL_CockroachDB|OUTHyperSQL/...       2
# 469592             HyperSQL|INIBM_DB2|OUTHyperSQL/IBM_DB2|       2
# 775263   GoogleCloudDatastore|INH2|OUTGoogleCloudDatast...       2
# 776100   GoogleCloudDatastore|INPostgreSQL_CockroachDB|...       2
# 1017944                HBase|INDynamoDB|OUTHBase/DynamoDB|       2
# 1019539  HBase|INPostgreSQL_CockroachDB|OUTHBase/Postgr...       2
# 1315033                  Oracle|INSQLite|OUTOracle/SQLite|       2
# 1726797      Couchbase|INHazelcast|OUTCouchbase/Hazelcast|       2
# 1727273  Couchbase|INPostgreSQL_CockroachDB|OUTCouchbas...       2
# 1727545  Couchbase|INMicrosoftAzureCosmosDB|OUTCouchbas...       2
# 2278339  SAPAdaptiveServer|INPostgreSQL_CockroachDB|OUT...       2
# 2281904  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...       2
# 1016190                            HBase|INH2|H2/OUTHBase|       2
# 1022891  HBase|INMSSQLServer_MicrosoftAzureSQLDatabase|...       2
# 1716446  IBM_DB2|INMSSQLServer_MicrosoftAzureSQLDatabas...       2
# 1809689              Hazelcast|INRedis|Redis/OUTHazelcast|       2
# 1878729                    SQLite|INRedis|Redis/OUTSQLite|       3
# 1910728                          SQLite|INH2|H2/OUTSQLite|       2
# 1919424  SQLite|INMSSQLServer_MicrosoftAzureSQLDatabase...       2
# 2238906  SAPAdaptiveServer|INSAPSQLAnywhere|SAPSQLAnywh...       2
# 2277944  SAPAdaptiveServer|INSAPAdaptiveServer|SAPAdapt...       5
# 2279394  SAPAdaptiveServer|INOracle|Oracle/OUTSAPAdapti...       2
# 2280448  SAPAdaptiveServer|INIBM_DB2|IBM_DB2/OUTSAPAdap...       2
# 2281624  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...       5
# 2486453  PostgreSQL_CockroachDB|INH2|H2/OUTPostgreSQL_C...       2
# 2489426  PostgreSQL_CockroachDB|INCouchbase|Couchbase/O...       2
# 2699216  Join_Ignite_NoSql|INNeo4j|Neo4j/OUTJoin_Ignite...       2
#
#                        SID SUP_BC SUP_BCD  \
# 1814997             37 129      0       0
# 1814998             37 129      0       0
# 1815289              37 43      0       0
# 1815759              37 93      0       0
# 2277333       17 36 72 192      0       0
# 2277347       17 36 72 192      0       0
# 245537              16 169      0       0
# 245752           16 44 169      0       0
# 460431              81 131      0       0
# 460751    40 44 56 128 131      0       0
# 619092              16 128      0       0
# 2260005           0 36 192      0       0
# 2260014           0 36 192      0       0
# 2260074             36 192      0       0
# 2260093         36 178 192      0       0
# 2260135             36 192      0       0
# 2260212             36 192      0       0
# 2260303             36 192      0       0
# 203866               22 96      0       0
# 278208             109 140      0       0
# 280863              44 111      0       0
# 415706        29 40 81 128      0       0
# 454043               27 76      0       0
# 454873              29 114      0       0
# 457599           10 42 160      0       0
# 465405            23 27 42      0       0
# 468143             114 128      0       0
# 469592              42 114      0       0
# 775263              24 113      0       0
# 776100              24 121      0       0
# 1017944              10 24      0       0
# 1019539               9 24      0       0
# 1315033            183 194      0       0
# 1726797              28 37      0       0
# 1727273              28 37      0       0
# 1727545              28 37      0       0
# 2278339             36 192      0       0
# 2281904               0 72      0       0
# 1016190               9 24      0       0
# 1022891               9 10      0       0
# 1716446            160 178      0       0
# 1809689              37 93      0       0
# 1878729           34 42 76      0       0
# 1910728             34 129      0       0
# 1919424             76 160      0       0
# 2238906             36 192      0       0
# 2277944     0 17 36 72 192      0       0
# 2279394             36 192      0       0
# 2280448             36 192      0       0
# 2281624    0 36 72 160 192      0       0
# 2486453             42 111      0       0
# 2489426              28 37      0       0
# 2699216              16 28      0       0
#
#                                              A SUP_A AB  \
# 1814997                              Hazelcast    19  |
# 1814998                              Hazelcast    19  |
# 1815289                              Hazelcast    19  |
# 1815759                              Hazelcast    19  |
# 2277333                      SAPAdaptiveServer    18  |
# 2277347                      SAPAdaptiveServer    18  |
# 245537                           MySQL_MariaDB   112  |
# 245752                           MySQL_MariaDB   112  |
# 460431                                HyperSQL    60  |
# 460751                                HyperSQL    60  |
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase    42  |
# 2260005                      SAPAdaptiveServer    18  |
# 2260014                      SAPAdaptiveServer    18  |
# 2260074                      SAPAdaptiveServer    18  |
# 2260093                      SAPAdaptiveServer    18  |
# 2260135                      SAPAdaptiveServer    18  |
# 2260212                      SAPAdaptiveServer    18  |
# 2260303                      SAPAdaptiveServer    18  |
# 203866                           MySQL_MariaDB   112  |
# 278208                           MySQL_MariaDB   112  |
# 280863                           MySQL_MariaDB   112  |
# 415706                                HyperSQL    60  |
# 454043                                HyperSQL    60  |
# 454873                                HyperSQL    60  |
# 457599                                HyperSQL    60  |
# 465405                                HyperSQL    60  |
# 468143                                HyperSQL    60  |
# 469592                                HyperSQL    60  |
# 775263                    GoogleCloudDatastore    26  |
# 776100                    GoogleCloudDatastore    26  |
# 1017944                                  HBase    19  |
# 1019539                                  HBase    19  |
# 1315033                                 Oracle    70  |
# 1726797                              Couchbase     4  |
# 1727273                              Couchbase     4  |
# 1727545                              Couchbase     4  |
# 2278339                      SAPAdaptiveServer    18  |
# 2281904                      SAPAdaptiveServer    18  |
# 1016190                                  HBase    19  |
# 1022891                                  HBase    19  |
# 1716446                                IBM_DB2    25  |
# 1809689                              Hazelcast    19  |
# 1878729                                 SQLite    39  |
# 1910728                                 SQLite    39  |
# 1919424                                 SQLite    39  |
# 2238906                      SAPAdaptiveServer    18  |
# 2277944                      SAPAdaptiveServer    18  |
# 2279394                      SAPAdaptiveServer    18  |
# 2280448                      SAPAdaptiveServer    18  |
# 2281624                      SAPAdaptiveServer    18  |
# 2486453                 PostgreSQL_CockroachDB    79  |
# 2489426                 PostgreSQL_CockroachDB    79  |
# 2699216                      Join_Ignite_NoSql     3  |
#
#                                                 B SUP_B BC  \
# 1814997                               INHazelcast    71  /
# 1814998                               INHazelcast    71  /
# 1815289                                INDynamoDB    22  /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase    34  /
# 2277333                       INSAPAdaptiveServer    33  /
# 2277347                       INSAPAdaptiveServer    33  /
# 245537                           OUTMySQL_MariaDB    40  /
# 245752                           OUTMySQL_MariaDB    40  /
# 460431                                OUTHyperSQL    27  /
# 460751                                OUTHyperSQL    27  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase    15  /
# 2260005                      OUTSAPAdaptiveServer    41  /
# 2260014                      OUTSAPAdaptiveServer    41  /
# 2260074                      OUTSAPAdaptiveServer    41  /
# 2260093                      OUTSAPAdaptiveServer    41  /
# 2260135                      OUTSAPAdaptiveServer    41  /
# 2260212                      OUTSAPAdaptiveServer    41  /
# 2260303                      OUTSAPAdaptiveServer    41  /
# 203866                                    INRedis    59  |
# 278208                                INCassandra    15  |
# 280863                                       INH2    56  |
# 415706                                    INRedis    59  |
# 454043                                  INMongoDB    27  |
# 454873                                   INOracle    44  |
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 465405                                       INH2    56  |
# 468143                   INPostgreSQL_CockroachDB    51  |
# 469592                                  INIBM_DB2    15  |
# 775263                                       INH2    56  |
# 776100                   INPostgreSQL_CockroachDB    51  |
# 1017944                                INDynamoDB    22  |
# 1019539                  INPostgreSQL_CockroachDB    51  |
# 1315033                                  INSQLite    26  |
# 1726797                               INHazelcast    71  |
# 1727273                  INPostgreSQL_CockroachDB    51  |
# 1727545                  INMicrosoftAzureCosmosDB     5  |
# 2278339                  INPostgreSQL_CockroachDB    51  |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1016190                                      INH2    56  |
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1809689                                   INRedis    59  |
# 1878729                                   INRedis    59  |
# 1910728                                      INH2    56  |
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2238906                          INSAPSQLAnywhere    12  |
# 2277944                       INSAPAdaptiveServer    33  |
# 2279394                                  INOracle    44  |
# 2280448                                 INIBM_DB2    15  |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2486453                                      INH2    56  |
# 2489426                               INCouchbase     4  |
# 2699216                                   INNeo4j     5  |
#
#                                                C SUP_C CD  \
# 1814997                             OUTHazelcast    60  |
# 1814998                             OUTHazelcast    60  |
# 1815289                             OUTHazelcast    60  |
# 1815759                             OUTHazelcast    60  |
# 2277333                     OUTSAPAdaptiveServer    41  |
# 2277347                     OUTSAPAdaptiveServer    41  |
# 245537                                   INRedis    59  |
# 245752                                      INH2    56  |
# 460431                  INPostgreSQL_CockroachDB    51  |
# 460751                                      INH2    56  |
# 619092                                   INRedis    59  |
# 2260005                      INSAPAdaptiveServer    33  |
# 2260014                      INSAPAdaptiveServer    33  |
# 2260074                         INSAPSQLAnywhere    12  |
# 2260093                 INPostgreSQL_CockroachDB    51  |
# 2260135                                 INOracle    44  |
# 2260212                                INIBM_DB2    15  |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 203866                          OUTMySQL_MariaDB    40  /
# 278208                          OUTMySQL_MariaDB    40  /
# 280863                          OUTMySQL_MariaDB    40  /
# 415706                               OUTHyperSQL    27  /
# 454043                               OUTHyperSQL    27  /
# 454873                               OUTHyperSQL    27  /
# 457599                               OUTHyperSQL    27  /
# 465405                               OUTHyperSQL    27  /
# 468143                               OUTHyperSQL    27  /
# 469592                               OUTHyperSQL    27  /
# 775263                   OUTGoogleCloudDatastore    10  /
# 776100                   OUTGoogleCloudDatastore    10  /
# 1017944                                 OUTHBase     9  /
# 1019539                                 OUTHBase     9  /
# 1315033                                OUTOracle    23  /
# 1726797                             OUTCouchbase     4  /
# 1727273                             OUTCouchbase     4  /
# 1727545                             OUTCouchbase     4  /
# 2278339                     OUTSAPAdaptiveServer    41  /
# 2281904                     OUTSAPAdaptiveServer    41  /
# 1016190                                       H2    86  /
# 1022891    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1716446    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1809689                                    Redis    71  /
# 1878729                                    Redis    71  /
# 1910728                                       H2    86  /
# 1919424    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2238906                           SAPSQLAnywhere    19  /
# 2277944                        SAPAdaptiveServer    18  /
# 2279394                                   Oracle    70  /
# 2280448                                  IBM_DB2    25  /
# 2281624    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2486453                                       H2    86  /
# 2489426                                Couchbase     4  /
# 2699216                                    Neo4j     5  /
#
#                                              D SUP_D  DE
# 1814997                              Hazelcast    19  |#
# 1814998                            INHazelcast    71  |#
# 1815289                               DynamoDB    22  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 2277333                    INSAPAdaptiveServer    33  |#
# 2277347                      SAPAdaptiveServer    18  |#
# 245537                                   Redis    71  |#
# 245752                                      H2    86  |#
# 460431                  PostgreSQL_CockroachDB    79  |#
# 460751                                      H2    86  |#
# 619092                                   Redis    71  |#
# 2260005                    INSAPAdaptiveServer    33  |#
# 2260014                      SAPAdaptiveServer    18  |#
# 2260074                         SAPSQLAnywhere    19  |#
# 2260093                 PostgreSQL_CockroachDB    79  |#
# 2260135                                 Oracle    70  |#
# 2260212                                IBM_DB2    25  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 203866                                   Redis    71  |#
# 278208                               Cassandra    19  |#
# 280863                                      H2    86  |#
# 415706                                   Redis    71  |#
# 454043                                 MongoDB    36  |#
# 454873                                  Oracle    70  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 465405                                      H2    86  |#
# 468143                  PostgreSQL_CockroachDB    79  |#
# 469592                                 IBM_DB2    25  |#
# 775263                                      H2    86  |#
# 776100                  PostgreSQL_CockroachDB    79  |#
# 1017944                               DynamoDB    22  |#
# 1019539                 PostgreSQL_CockroachDB    79  |#
# 1315033                                 SQLite    39  |#
# 1726797                              Hazelcast    19  |#
# 1727273                 PostgreSQL_CockroachDB    79  |#
# 1727545                 MicrosoftAzureCosmosDB     5  |#
# 2278339                 PostgreSQL_CockroachDB    79  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 1016190                               OUTHBase     9  |#
# 1022891                               OUTHBase     9  |#
# 1716446                             OUTIBM_DB2    10  |#
# 1809689                           OUTHazelcast    60  |#
# 1878729                              OUTSQLite    16  |#
# 1910728                              OUTSQLite    16  |#
# 1919424                              OUTSQLite    16  |#
# 2238906                   OUTSAPAdaptiveServer    41  |#
# 2277944                   OUTSAPAdaptiveServer    41  |#
# 2279394                   OUTSAPAdaptiveServer    41  |#
# 2280448                   OUTSAPAdaptiveServer    41  |#
# 2281624                   OUTSAPAdaptiveServer    41  |#
# 2486453              OUTPostgreSQL_CockroachDB    27  |#
# 2489426              OUTPostgreSQL_CockroachDB    27  |#
# 2699216                   OUTJoin_Ignite_NoSql     2  |#

# %% [markdown]
# Researching and writing the combinations support in the collumns SUP_BC and SUP_BCD

# %%
#Ajuste lift 2
for index, row in df13.iterrows():   
    for j, rowj in df10.iterrows():
        #if (row['C'] is None) or (row['C'] == ''):#(row['C'] is NoneType):
            #print('entrou1', row['A'], row['B'], row['C'], row['D'])
        if (row['C'] is not None) or (row['C'] != ' ') or (row['C'] != ''): #and ((row['DB_4'] is None) or (row['DB_4'] == ' ') or (row['DB_4'] == '')):
            #print('entrou1')
            #print('entrou1', row['A'], row['B'], row['C'], row['D'])
            if (row['B']+'|'+row['C'])+'|' == rowj['Pattern_v2'] and (row['B']+'|'+row['C']+'|' in row['Pattern']) :
            #df9.loc[index,'LiftA->BC'] = (df9.loc[index,'SUP']/200)/((df9.loc[index,'SUP_DB1']/200)*((df10.loc[,'SUP_v2']/200)
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'|' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'/' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])  
            if (row['B']+'|'+row['C']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'/' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BC'] = df13.loc[index,'SUP_BC'].replace(df13.loc[index,'SUP_BC'], df10.loc[j,'SUP_v2'])  
        if (row['D'] is not None) or (row['D'] != ' ') or (row['D'] != ''):
            #print('entrou2')
            if (row['B']+'|'+row['C']+'|'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'|'+row['D']+'|' in row['Pattern']):
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'|'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'|'+row['D']+'|' in row['Pattern']):
                #row['SUP_BC'] = rowj['SUP_v2']
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'|'+row['C']+'/'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'|'+row['C']+'/'+row['D']+'|' in row['Pattern']):
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])
            if (row['B']+'/'+row['C']+'/'+row['D']+'|' == rowj['Pattern_v2']) and (row['B']+'/'+row['C']+'/'+row['D']+'|' in row['Pattern']):
                #print('entrou1', row['A'], row['B'], row['C'], row['D'])
                df13.loc[index,'SUP_BCD'] = df13.loc[index,'SUP_BCD'].replace(df13.loc[index,'SUP_BCD'], df10.loc[j,'SUP_v2'])

# %%
df13
# Out:
#                                                    Pattern SUP_ABCD  \
# 1814997      Hazelcast|INHazelcast/OUTHazelcast|Hazelcast|       2
# 1814998    Hazelcast|INHazelcast/OUTHazelcast|INHazelcast|       2
# 1815289        Hazelcast|INDynamoDB/OUTHazelcast|DynamoDB|       2
# 1815759  Hazelcast|INMSSQLServer_MicrosoftAzureSQLDatab...       2
# 2277333  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...       4
# 2277347  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...       4
# 245537       MySQL_MariaDB|OUTMySQL_MariaDB/INRedis|Redis|       2
# 245752             MySQL_MariaDB|OUTMySQL_MariaDB/INH2|H2|       3
# 460431   HyperSQL|OUTHyperSQL/INPostgreSQL_CockroachDB|...       2
# 460751                       HyperSQL|OUTHyperSQL/INH2|H2|       5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase|OUTMSSQL...       2
# 2260005  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...       3
# 2260014  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...       3
# 2260074  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPSQ...       2
# 2260093  SAPAdaptiveServer|OUTSAPAdaptiveServer/INPostg...       3
# 2260135  SAPAdaptiveServer|OUTSAPAdaptiveServer/INOracl...       2
# 2260212  SAPAdaptiveServer|OUTSAPAdaptiveServer/INIBM_D...       2
# 2260303  SAPAdaptiveServer|OUTSAPAdaptiveServer/INMSSQL...       2
# 203866       MySQL_MariaDB|INRedis|OUTMySQL_MariaDB/Redis|       2
# 278208   MySQL_MariaDB|INCassandra|OUTMySQL_MariaDB/Cas...       2
# 280863             MySQL_MariaDB|INH2|OUTMySQL_MariaDB/H2|       2
# 415706                 HyperSQL|INRedis|OUTHyperSQL/Redis|       4
# 454043             HyperSQL|INMongoDB|OUTHyperSQL/MongoDB|       2
# 454873               HyperSQL|INOracle|OUTHyperSQL/Oracle|       2
# 457599   HyperSQL|INMSSQLServer_MicrosoftAzureSQLDataba...       3
# 465405                       HyperSQL|INH2|OUTHyperSQL/H2|       3
# 468143   HyperSQL|INPostgreSQL_CockroachDB|OUTHyperSQL/...       2
# 469592             HyperSQL|INIBM_DB2|OUTHyperSQL/IBM_DB2|       2
# 775263   GoogleCloudDatastore|INH2|OUTGoogleCloudDatast...       2
# 776100   GoogleCloudDatastore|INPostgreSQL_CockroachDB|...       2
# 1017944                HBase|INDynamoDB|OUTHBase/DynamoDB|       2
# 1019539  HBase|INPostgreSQL_CockroachDB|OUTHBase/Postgr...       2
# 1315033                  Oracle|INSQLite|OUTOracle/SQLite|       2
# 1726797      Couchbase|INHazelcast|OUTCouchbase/Hazelcast|       2
# 1727273  Couchbase|INPostgreSQL_CockroachDB|OUTCouchbas...       2
# 1727545  Couchbase|INMicrosoftAzureCosmosDB|OUTCouchbas...       2
# 2278339  SAPAdaptiveServer|INPostgreSQL_CockroachDB|OUT...       2
# 2281904  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...       2
# 1016190                            HBase|INH2|H2/OUTHBase|       2
# 1022891  HBase|INMSSQLServer_MicrosoftAzureSQLDatabase|...       2
# 1716446  IBM_DB2|INMSSQLServer_MicrosoftAzureSQLDatabas...       2
# 1809689              Hazelcast|INRedis|Redis/OUTHazelcast|       2
# 1878729                    SQLite|INRedis|Redis/OUTSQLite|       3
# 1910728                          SQLite|INH2|H2/OUTSQLite|       2
# 1919424  SQLite|INMSSQLServer_MicrosoftAzureSQLDatabase...       2
# 2238906  SAPAdaptiveServer|INSAPSQLAnywhere|SAPSQLAnywh...       2
# 2277944  SAPAdaptiveServer|INSAPAdaptiveServer|SAPAdapt...       5
# 2279394  SAPAdaptiveServer|INOracle|Oracle/OUTSAPAdapti...       2
# 2280448  SAPAdaptiveServer|INIBM_DB2|IBM_DB2/OUTSAPAdap...       2
# 2281624  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...       5
# 2486453  PostgreSQL_CockroachDB|INH2|H2/OUTPostgreSQL_C...       2
# 2489426  PostgreSQL_CockroachDB|INCouchbase|Couchbase/O...       2
# 2699216  Join_Ignite_NoSql|INNeo4j|Neo4j/OUTJoin_Ignite...       2
#
#                        SID SUP_BC SUP_BCD  \
# 1814997             37 129      2       2
# 1814998             37 129      2       2
# 1815289              37 43      2       2
# 1815759              37 93      2       2
# 2277333       17 36 72 192      5       4
# 2277347       17 36 72 192      5       4
# 245537              16 169      2       2
# 245752           16 44 169      3       3
# 460431              81 131      2       2
# 460751    40 44 56 128 131      5       5
# 619092              16 128      2       2
# 2260005           0 36 192      4       4
# 2260014           0 36 192      4       4
# 2260074             36 192      3       3
# 2260093         36 178 192      8       7
# 2260135             36 192      7       6
# 2260212             36 192      6       5
# 2260303             36 192      4       3
# 203866               22 96      4       2
# 278208             109 140      2       2
# 280863              44 111      9       3
# 415706        29 40 81 128      9       7
# 454043               27 76      4       3
# 454873              29 114      7       4
# 457599           10 42 160      9       4
# 465405            23 27 42      8       3
# 468143             114 128      6       4
# 469592              42 114      6       2
# 775263              24 113      3       3
# 776100              24 121      2       2
# 1017944              10 24      2       2
# 1019539               9 24      2       2
# 1315033            183 194      3       2
# 1726797              28 37      3       2
# 1727273              28 37      2       2
# 1727545              28 37      2       2
# 2278339             36 192      6       5
# 2281904               0 72      9       5
# 1016190               9 24     49       3
# 1022891               9 10     28       3
# 1716446            160 178     28       2
# 1809689              37 93     48       3
# 1878729           34 42 76     48       3
# 1910728             34 129     49       3
# 1919424             76 160     28       2
# 2238906             36 192     11       4
# 2277944     0 17 36 72 192     16       5
# 2279394             36 192     33       3
# 2280448             36 192     14       4
# 2281624    0 36 72 160 192     28       7
# 2486453             42 111     49       3
# 2489426              28 37      3       2
# 2699216              16 28      3       2
#
#                                              A SUP_A AB  \
# 1814997                              Hazelcast    19  |
# 1814998                              Hazelcast    19  |
# 1815289                              Hazelcast    19  |
# 1815759                              Hazelcast    19  |
# 2277333                      SAPAdaptiveServer    18  |
# 2277347                      SAPAdaptiveServer    18  |
# 245537                           MySQL_MariaDB   112  |
# 245752                           MySQL_MariaDB   112  |
# 460431                                HyperSQL    60  |
# 460751                                HyperSQL    60  |
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase    42  |
# 2260005                      SAPAdaptiveServer    18  |
# 2260014                      SAPAdaptiveServer    18  |
# 2260074                      SAPAdaptiveServer    18  |
# 2260093                      SAPAdaptiveServer    18  |
# 2260135                      SAPAdaptiveServer    18  |
# 2260212                      SAPAdaptiveServer    18  |
# 2260303                      SAPAdaptiveServer    18  |
# 203866                           MySQL_MariaDB   112  |
# 278208                           MySQL_MariaDB   112  |
# 280863                           MySQL_MariaDB   112  |
# 415706                                HyperSQL    60  |
# 454043                                HyperSQL    60  |
# 454873                                HyperSQL    60  |
# 457599                                HyperSQL    60  |
# 465405                                HyperSQL    60  |
# 468143                                HyperSQL    60  |
# 469592                                HyperSQL    60  |
# 775263                    GoogleCloudDatastore    26  |
# 776100                    GoogleCloudDatastore    26  |
# 1017944                                  HBase    19  |
# 1019539                                  HBase    19  |
# 1315033                                 Oracle    70  |
# 1726797                              Couchbase     4  |
# 1727273                              Couchbase     4  |
# 1727545                              Couchbase     4  |
# 2278339                      SAPAdaptiveServer    18  |
# 2281904                      SAPAdaptiveServer    18  |
# 1016190                                  HBase    19  |
# 1022891                                  HBase    19  |
# 1716446                                IBM_DB2    25  |
# 1809689                              Hazelcast    19  |
# 1878729                                 SQLite    39  |
# 1910728                                 SQLite    39  |
# 1919424                                 SQLite    39  |
# 2238906                      SAPAdaptiveServer    18  |
# 2277944                      SAPAdaptiveServer    18  |
# 2279394                      SAPAdaptiveServer    18  |
# 2280448                      SAPAdaptiveServer    18  |
# 2281624                      SAPAdaptiveServer    18  |
# 2486453                 PostgreSQL_CockroachDB    79  |
# 2489426                 PostgreSQL_CockroachDB    79  |
# 2699216                      Join_Ignite_NoSql     3  |
#
#                                                 B SUP_B BC  \
# 1814997                               INHazelcast    71  /
# 1814998                               INHazelcast    71  /
# 1815289                                INDynamoDB    22  /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase    34  /
# 2277333                       INSAPAdaptiveServer    33  /
# 2277347                       INSAPAdaptiveServer    33  /
# 245537                           OUTMySQL_MariaDB    40  /
# 245752                           OUTMySQL_MariaDB    40  /
# 460431                                OUTHyperSQL    27  /
# 460751                                OUTHyperSQL    27  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase    15  /
# 2260005                      OUTSAPAdaptiveServer    41  /
# 2260014                      OUTSAPAdaptiveServer    41  /
# 2260074                      OUTSAPAdaptiveServer    41  /
# 2260093                      OUTSAPAdaptiveServer    41  /
# 2260135                      OUTSAPAdaptiveServer    41  /
# 2260212                      OUTSAPAdaptiveServer    41  /
# 2260303                      OUTSAPAdaptiveServer    41  /
# 203866                                    INRedis    59  |
# 278208                                INCassandra    15  |
# 280863                                       INH2    56  |
# 415706                                    INRedis    59  |
# 454043                                  INMongoDB    27  |
# 454873                                   INOracle    44  |
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 465405                                       INH2    56  |
# 468143                   INPostgreSQL_CockroachDB    51  |
# 469592                                  INIBM_DB2    15  |
# 775263                                       INH2    56  |
# 776100                   INPostgreSQL_CockroachDB    51  |
# 1017944                                INDynamoDB    22  |
# 1019539                  INPostgreSQL_CockroachDB    51  |
# 1315033                                  INSQLite    26  |
# 1726797                               INHazelcast    71  |
# 1727273                  INPostgreSQL_CockroachDB    51  |
# 1727545                  INMicrosoftAzureCosmosDB     5  |
# 2278339                  INPostgreSQL_CockroachDB    51  |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1016190                                      INH2    56  |
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 1809689                                   INRedis    59  |
# 1878729                                   INRedis    59  |
# 1910728                                      INH2    56  |
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2238906                          INSAPSQLAnywhere    12  |
# 2277944                       INSAPAdaptiveServer    33  |
# 2279394                                  INOracle    44  |
# 2280448                                 INIBM_DB2    15  |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 2486453                                      INH2    56  |
# 2489426                               INCouchbase     4  |
# 2699216                                   INNeo4j     5  |
#
#                                                C SUP_C CD  \
# 1814997                             OUTHazelcast    60  |
# 1814998                             OUTHazelcast    60  |
# 1815289                             OUTHazelcast    60  |
# 1815759                             OUTHazelcast    60  |
# 2277333                     OUTSAPAdaptiveServer    41  |
# 2277347                     OUTSAPAdaptiveServer    41  |
# 245537                                   INRedis    59  |
# 245752                                      INH2    56  |
# 460431                  INPostgreSQL_CockroachDB    51  |
# 460751                                      INH2    56  |
# 619092                                   INRedis    59  |
# 2260005                      INSAPAdaptiveServer    33  |
# 2260014                      INSAPAdaptiveServer    33  |
# 2260074                         INSAPSQLAnywhere    12  |
# 2260093                 INPostgreSQL_CockroachDB    51  |
# 2260135                                 INOracle    44  |
# 2260212                                INIBM_DB2    15  |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase    34  |
# 203866                          OUTMySQL_MariaDB    40  /
# 278208                          OUTMySQL_MariaDB    40  /
# 280863                          OUTMySQL_MariaDB    40  /
# 415706                               OUTHyperSQL    27  /
# 454043                               OUTHyperSQL    27  /
# 454873                               OUTHyperSQL    27  /
# 457599                               OUTHyperSQL    27  /
# 465405                               OUTHyperSQL    27  /
# 468143                               OUTHyperSQL    27  /
# 469592                               OUTHyperSQL    27  /
# 775263                   OUTGoogleCloudDatastore    10  /
# 776100                   OUTGoogleCloudDatastore    10  /
# 1017944                                 OUTHBase     9  /
# 1019539                                 OUTHBase     9  /
# 1315033                                OUTOracle    23  /
# 1726797                             OUTCouchbase     4  /
# 1727273                             OUTCouchbase     4  /
# 1727545                             OUTCouchbase     4  /
# 2278339                     OUTSAPAdaptiveServer    41  /
# 2281904                     OUTSAPAdaptiveServer    41  /
# 1016190                                       H2    86  /
# 1022891    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1716446    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 1809689                                    Redis    71  /
# 1878729                                    Redis    71  /
# 1910728                                       H2    86  /
# 1919424    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2238906                           SAPSQLAnywhere    19  /
# 2277944                        SAPAdaptiveServer    18  /
# 2279394                                   Oracle    70  /
# 2280448                                  IBM_DB2    25  /
# 2281624    MSSQLServer_MicrosoftAzureSQLDatabase    42  /
# 2486453                                       H2    86  /
# 2489426                                Couchbase     4  /
# 2699216                                    Neo4j     5  /
#
#                                              D SUP_D  DE
# 1814997                              Hazelcast    19  |#
# 1814998                            INHazelcast    71  |#
# 1815289                               DynamoDB    22  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 2277333                    INSAPAdaptiveServer    33  |#
# 2277347                      SAPAdaptiveServer    18  |#
# 245537                                   Redis    71  |#
# 245752                                      H2    86  |#
# 460431                  PostgreSQL_CockroachDB    79  |#
# 460751                                      H2    86  |#
# 619092                                   Redis    71  |#
# 2260005                    INSAPAdaptiveServer    33  |#
# 2260014                      SAPAdaptiveServer    18  |#
# 2260074                         SAPSQLAnywhere    19  |#
# 2260093                 PostgreSQL_CockroachDB    79  |#
# 2260135                                 Oracle    70  |#
# 2260212                                IBM_DB2    25  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 203866                                   Redis    71  |#
# 278208                               Cassandra    19  |#
# 280863                                      H2    86  |#
# 415706                                   Redis    71  |#
# 454043                                 MongoDB    36  |#
# 454873                                  Oracle    70  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 465405                                      H2    86  |#
# 468143                  PostgreSQL_CockroachDB    79  |#
# 469592                                 IBM_DB2    25  |#
# 775263                                      H2    86  |#
# 776100                  PostgreSQL_CockroachDB    79  |#
# 1017944                               DynamoDB    22  |#
# 1019539                 PostgreSQL_CockroachDB    79  |#
# 1315033                                 SQLite    39  |#
# 1726797                              Hazelcast    19  |#
# 1727273                 PostgreSQL_CockroachDB    79  |#
# 1727545                 MicrosoftAzureCosmosDB     5  |#
# 2278339                 PostgreSQL_CockroachDB    79  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase    42  |#
# 1016190                               OUTHBase     9  |#
# 1022891                               OUTHBase     9  |#
# 1716446                             OUTIBM_DB2    10  |#
# 1809689                           OUTHazelcast    60  |#
# 1878729                              OUTSQLite    16  |#
# 1910728                              OUTSQLite    16  |#
# 1919424                              OUTSQLite    16  |#
# 2238906                   OUTSAPAdaptiveServer    41  |#
# 2277944                   OUTSAPAdaptiveServer    41  |#
# 2279394                   OUTSAPAdaptiveServer    41  |#
# 2280448                   OUTSAPAdaptiveServer    41  |#
# 2281624                   OUTSAPAdaptiveServer    41  |#
# 2486453              OUTPostgreSQL_CockroachDB    27  |#
# 2489426              OUTPostgreSQL_CockroachDB    27  |#
# 2699216                   OUTJoin_Ignite_NoSql     2  |#

# %% [markdown]
# Calculateding confidence and lift to each pattern generated.

# %%
#Converting to integer
df13['SUP_A'] = df13['SUP_A'].astype(int)
df13['SUP_B'] = df13['SUP_B'].astype(int)
df13['SUP_C'] = df13['SUP_C'].astype(int)
df13['SUP_D'] = df13['SUP_D'].astype(int)
df13['SUP_BC'] = df13['SUP_BC'].astype(int)
df13['SUP_BCD'] = df13['SUP_BCD'].astype(int)
df13['SUP_ABCD'] = df13['SUP_ABCD'].astype(int)

#Inserting collums to confidence measure
df13.insert(7,'ConfA->_BCD','0',False) 
df13.insert(11,'ConfB->A_CD','0',False)
df13.insert(15,'ConfC->AB_D','0',False)
df13.insert(19,'ConfD->ABC_','0',False)

#Converting to integer
df13['ConfA->_BCD'] = df13['ConfA->_BCD'].astype(int)
df13['ConfB->A_CD'] = df13['ConfB->A_CD'].astype(int)
df13['ConfC->AB_D'] = df13['ConfC->AB_D'].astype(int)
df13['ConfD->ABC_'] = df13['ConfD->ABC_'].astype(int)
#df13['SUP_ABCD'] = df13['SUP_ABCD'].astype(int)

df13['ConfA->_BCD'] = (df13['SUP_ABCD'])/df13['SUP_A']
df13['ConfB->A_CD'] = (df13['SUP_ABCD'])/df13['SUP_B']
df13['ConfC->AB_D'] = (df13['SUP_ABCD'])/df13['SUP_C']
df13['ConfD->ABC_'] = (df13['SUP_ABCD'])/df13['SUP_D']
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 1814997      Hazelcast|INHazelcast/OUTHazelcast|Hazelcast|         2
# 1814998    Hazelcast|INHazelcast/OUTHazelcast|INHazelcast|         2
# 1815289        Hazelcast|INDynamoDB/OUTHazelcast|DynamoDB|         2
# 1815759  Hazelcast|INMSSQLServer_MicrosoftAzureSQLDatab...         2
# 2277333  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...         4
# 2277347  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...         4
# 245537       MySQL_MariaDB|OUTMySQL_MariaDB/INRedis|Redis|         2
# 245752             MySQL_MariaDB|OUTMySQL_MariaDB/INH2|H2|         3
# 460431   HyperSQL|OUTHyperSQL/INPostgreSQL_CockroachDB|...         2
# 460751                       HyperSQL|OUTHyperSQL/INH2|H2|         5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase|OUTMSSQL...         2
# 2260005  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...         3
# 2260014  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...         3
# 2260074  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPSQ...         2
# 2260093  SAPAdaptiveServer|OUTSAPAdaptiveServer/INPostg...         3
# 2260135  SAPAdaptiveServer|OUTSAPAdaptiveServer/INOracl...         2
# 2260212  SAPAdaptiveServer|OUTSAPAdaptiveServer/INIBM_D...         2
# 2260303  SAPAdaptiveServer|OUTSAPAdaptiveServer/INMSSQL...         2
# 203866       MySQL_MariaDB|INRedis|OUTMySQL_MariaDB/Redis|         2
# 278208   MySQL_MariaDB|INCassandra|OUTMySQL_MariaDB/Cas...         2
# 280863             MySQL_MariaDB|INH2|OUTMySQL_MariaDB/H2|         2
# 415706                 HyperSQL|INRedis|OUTHyperSQL/Redis|         4
# 454043             HyperSQL|INMongoDB|OUTHyperSQL/MongoDB|         2
# 454873               HyperSQL|INOracle|OUTHyperSQL/Oracle|         2
# 457599   HyperSQL|INMSSQLServer_MicrosoftAzureSQLDataba...         3
# 465405                       HyperSQL|INH2|OUTHyperSQL/H2|         3
# 468143   HyperSQL|INPostgreSQL_CockroachDB|OUTHyperSQL/...         2
# 469592             HyperSQL|INIBM_DB2|OUTHyperSQL/IBM_DB2|         2
# 775263   GoogleCloudDatastore|INH2|OUTGoogleCloudDatast...         2
# 776100   GoogleCloudDatastore|INPostgreSQL_CockroachDB|...         2
# 1017944                HBase|INDynamoDB|OUTHBase/DynamoDB|         2
# 1019539  HBase|INPostgreSQL_CockroachDB|OUTHBase/Postgr...         2
# 1315033                  Oracle|INSQLite|OUTOracle/SQLite|         2
# 1726797      Couchbase|INHazelcast|OUTCouchbase/Hazelcast|         2
# 1727273  Couchbase|INPostgreSQL_CockroachDB|OUTCouchbas...         2
# 1727545  Couchbase|INMicrosoftAzureCosmosDB|OUTCouchbas...         2
# 2278339  SAPAdaptiveServer|INPostgreSQL_CockroachDB|OUT...         2
# 2281904  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...         2
# 1016190                            HBase|INH2|H2/OUTHBase|         2
# 1022891  HBase|INMSSQLServer_MicrosoftAzureSQLDatabase|...         2
# 1716446  IBM_DB2|INMSSQLServer_MicrosoftAzureSQLDatabas...         2
# 1809689              Hazelcast|INRedis|Redis/OUTHazelcast|         2
# 1878729                    SQLite|INRedis|Redis/OUTSQLite|         3
# 1910728                          SQLite|INH2|H2/OUTSQLite|         2
# 1919424  SQLite|INMSSQLServer_MicrosoftAzureSQLDatabase...         2
# 2238906  SAPAdaptiveServer|INSAPSQLAnywhere|SAPSQLAnywh...         2
# 2277944  SAPAdaptiveServer|INSAPAdaptiveServer|SAPAdapt...         5
# 2279394  SAPAdaptiveServer|INOracle|Oracle/OUTSAPAdapti...         2
# 2280448  SAPAdaptiveServer|INIBM_DB2|IBM_DB2/OUTSAPAdap...         2
# 2281624  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...         5
# 2486453  PostgreSQL_CockroachDB|INH2|H2/OUTPostgreSQL_C...         2
# 2489426  PostgreSQL_CockroachDB|INCouchbase|Couchbase/O...         2
# 2699216  Join_Ignite_NoSql|INNeo4j|Neo4j/OUTJoin_Ignite...         2
#
#                        SID  SUP_BC  SUP_BCD  \
# 1814997             37 129       2        2
# 1814998             37 129       2        2
# 1815289              37 43       2        2
# 1815759              37 93       2        2
# 2277333       17 36 72 192       5        4
# 2277347       17 36 72 192       5        4
# 245537              16 169       2        2
# 245752           16 44 169       3        3
# 460431              81 131       2        2
# 460751    40 44 56 128 131       5        5
# 619092              16 128       2        2
# 2260005           0 36 192       4        4
# 2260014           0 36 192       4        4
# 2260074             36 192       3        3
# 2260093         36 178 192       8        7
# 2260135             36 192       7        6
# 2260212             36 192       6        5
# 2260303             36 192       4        3
# 203866               22 96       4        2
# 278208             109 140       2        2
# 280863              44 111       9        3
# 415706        29 40 81 128       9        7
# 454043               27 76       4        3
# 454873              29 114       7        4
# 457599           10 42 160       9        4
# 465405            23 27 42       8        3
# 468143             114 128       6        4
# 469592              42 114       6        2
# 775263              24 113       3        3
# 776100              24 121       2        2
# 1017944              10 24       2        2
# 1019539               9 24       2        2
# 1315033            183 194       3        2
# 1726797              28 37       3        2
# 1727273              28 37       2        2
# 1727545              28 37       2        2
# 2278339             36 192       6        5
# 2281904               0 72       9        5
# 1016190               9 24      49        3
# 1022891               9 10      28        3
# 1716446            160 178      28        2
# 1809689              37 93      48        3
# 1878729           34 42 76      48        3
# 1910728             34 129      49        3
# 1919424             76 160      28        2
# 2238906             36 192      11        4
# 2277944     0 17 36 72 192      16        5
# 2279394             36 192      33        3
# 2280448             36 192      14        4
# 2281624    0 36 72 160 192      28        7
# 2486453             42 111      49        3
# 2489426              28 37       3        2
# 2699216              16 28       3        2
#
#                                              A  SUP_A  ConfA->_BCD AB  \
# 1814997                              Hazelcast     19     0.105263  |
# 1814998                              Hazelcast     19     0.105263  |
# 1815289                              Hazelcast     19     0.105263  |
# 1815759                              Hazelcast     19     0.105263  |
# 2277333                      SAPAdaptiveServer     18     0.222222  |
# 2277347                      SAPAdaptiveServer     18     0.222222  |
# 245537                           MySQL_MariaDB    112     0.017857  |
# 245752                           MySQL_MariaDB    112     0.026786  |
# 460431                                HyperSQL     60     0.033333  |
# 460751                                HyperSQL     60     0.083333  |
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |
# 2260005                      SAPAdaptiveServer     18     0.166667  |
# 2260014                      SAPAdaptiveServer     18     0.166667  |
# 2260074                      SAPAdaptiveServer     18     0.111111  |
# 2260093                      SAPAdaptiveServer     18     0.166667  |
# 2260135                      SAPAdaptiveServer     18     0.111111  |
# 2260212                      SAPAdaptiveServer     18     0.111111  |
# 2260303                      SAPAdaptiveServer     18     0.111111  |
# 203866                           MySQL_MariaDB    112     0.017857  |
# 278208                           MySQL_MariaDB    112     0.017857  |
# 280863                           MySQL_MariaDB    112     0.017857  |
# 415706                                HyperSQL     60     0.066667  |
# 454043                                HyperSQL     60     0.033333  |
# 454873                                HyperSQL     60     0.033333  |
# 457599                                HyperSQL     60     0.050000  |
# 465405                                HyperSQL     60     0.050000  |
# 468143                                HyperSQL     60     0.033333  |
# 469592                                HyperSQL     60     0.033333  |
# 775263                    GoogleCloudDatastore     26     0.076923  |
# 776100                    GoogleCloudDatastore     26     0.076923  |
# 1017944                                  HBase     19     0.105263  |
# 1019539                                  HBase     19     0.105263  |
# 1315033                                 Oracle     70     0.028571  |
# 1726797                              Couchbase      4     0.500000  |
# 1727273                              Couchbase      4     0.500000  |
# 1727545                              Couchbase      4     0.500000  |
# 2278339                      SAPAdaptiveServer     18     0.111111  |
# 2281904                      SAPAdaptiveServer     18     0.111111  |
# 1016190                                  HBase     19     0.105263  |
# 1022891                                  HBase     19     0.105263  |
# 1716446                                IBM_DB2     25     0.080000  |
# 1809689                              Hazelcast     19     0.105263  |
# 1878729                                 SQLite     39     0.076923  |
# 1910728                                 SQLite     39     0.051282  |
# 1919424                                 SQLite     39     0.051282  |
# 2238906                      SAPAdaptiveServer     18     0.111111  |
# 2277944                      SAPAdaptiveServer     18     0.277778  |
# 2279394                      SAPAdaptiveServer     18     0.111111  |
# 2280448                      SAPAdaptiveServer     18     0.111111  |
# 2281624                      SAPAdaptiveServer     18     0.277778  |
# 2486453                 PostgreSQL_CockroachDB     79     0.025316  |
# 2489426                 PostgreSQL_CockroachDB     79     0.025316  |
# 2699216                      Join_Ignite_NoSql      3     0.666667  |
#
#                                                 B  ...  ConfB->A_CD  BC  \
# 1814997                               INHazelcast  ...     0.028169   /
# 1814998                               INHazelcast  ...     0.028169   /
# 1815289                                INDynamoDB  ...     0.090909   /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.058824   /
# 2277333                       INSAPAdaptiveServer  ...     0.121212   /
# 2277347                       INSAPAdaptiveServer  ...     0.121212   /
# 245537                           OUTMySQL_MariaDB  ...     0.050000   /
# 245752                           OUTMySQL_MariaDB  ...     0.075000   /
# 460431                                OUTHyperSQL  ...     0.074074   /
# 460751                                OUTHyperSQL  ...     0.185185   /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.133333   /
# 2260005                      OUTSAPAdaptiveServer  ...     0.073171   /
# 2260014                      OUTSAPAdaptiveServer  ...     0.073171   /
# 2260074                      OUTSAPAdaptiveServer  ...     0.048780   /
# 2260093                      OUTSAPAdaptiveServer  ...     0.073171   /
# 2260135                      OUTSAPAdaptiveServer  ...     0.048780   /
# 2260212                      OUTSAPAdaptiveServer  ...     0.048780   /
# 2260303                      OUTSAPAdaptiveServer  ...     0.048780   /
# 203866                                    INRedis  ...     0.033898   |
# 278208                                INCassandra  ...     0.133333   |
# 280863                                       INH2  ...     0.035714   |
# 415706                                    INRedis  ...     0.067797   |
# 454043                                  INMongoDB  ...     0.074074   |
# 454873                                   INOracle  ...     0.045455   |
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.088235   |
# 465405                                       INH2  ...     0.053571   |
# 468143                   INPostgreSQL_CockroachDB  ...     0.039216   |
# 469592                                  INIBM_DB2  ...     0.133333   |
# 775263                                       INH2  ...     0.035714   |
# 776100                   INPostgreSQL_CockroachDB  ...     0.039216   |
# 1017944                                INDynamoDB  ...     0.090909   |
# 1019539                  INPostgreSQL_CockroachDB  ...     0.039216   |
# 1315033                                  INSQLite  ...     0.076923   |
# 1726797                               INHazelcast  ...     0.028169   |
# 1727273                  INPostgreSQL_CockroachDB  ...     0.039216   |
# 1727545                  INMicrosoftAzureCosmosDB  ...     0.400000   |
# 2278339                  INPostgreSQL_CockroachDB  ...     0.039216   |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.058824   |
# 1016190                                      INH2  ...     0.035714   |
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.058824   |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.058824   |
# 1809689                                   INRedis  ...     0.033898   |
# 1878729                                   INRedis  ...     0.050847   |
# 1910728                                      INH2  ...     0.035714   |
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.058824   |
# 2238906                          INSAPSQLAnywhere  ...     0.166667   |
# 2277944                       INSAPAdaptiveServer  ...     0.151515   |
# 2279394                                  INOracle  ...     0.045455   |
# 2280448                                 INIBM_DB2  ...     0.133333   |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     0.147059   |
# 2486453                                      INH2  ...     0.035714   |
# 2489426                               INCouchbase  ...     0.500000   |
# 2699216                                   INNeo4j  ...     0.400000   |
#
#                                                C SUP_C  ConfC->AB_D  CD  \
# 1814997                             OUTHazelcast    60     0.033333   |
# 1814998                             OUTHazelcast    60     0.033333   |
# 1815289                             OUTHazelcast    60     0.033333   |
# 1815759                             OUTHazelcast    60     0.033333   |
# 2277333                     OUTSAPAdaptiveServer    41     0.097561   |
# 2277347                     OUTSAPAdaptiveServer    41     0.097561   |
# 245537                                   INRedis    59     0.033898   |
# 245752                                      INH2    56     0.053571   |
# 460431                  INPostgreSQL_CockroachDB    51     0.039216   |
# 460751                                      INH2    56     0.089286   |
# 619092                                   INRedis    59     0.033898   |
# 2260005                      INSAPAdaptiveServer    33     0.090909   |
# 2260014                      INSAPAdaptiveServer    33     0.090909   |
# 2260074                         INSAPSQLAnywhere    12     0.166667   |
# 2260093                 INPostgreSQL_CockroachDB    51     0.058824   |
# 2260135                                 INOracle    44     0.045455   |
# 2260212                                INIBM_DB2    15     0.133333   |
# 2260303  INMSSQLServer_MicrosoftAzureSQLDatabase    34     0.058824   |
# 203866                          OUTMySQL_MariaDB    40     0.050000   /
# 278208                          OUTMySQL_MariaDB    40     0.050000   /
# 280863                          OUTMySQL_MariaDB    40     0.050000   /
# 415706                               OUTHyperSQL    27     0.148148   /
# 454043                               OUTHyperSQL    27     0.074074   /
# 454873                               OUTHyperSQL    27     0.074074   /
# 457599                               OUTHyperSQL    27     0.111111   /
# 465405                               OUTHyperSQL    27     0.111111   /
# 468143                               OUTHyperSQL    27     0.074074   /
# 469592                               OUTHyperSQL    27     0.074074   /
# 775263                   OUTGoogleCloudDatastore    10     0.200000   /
# 776100                   OUTGoogleCloudDatastore    10     0.200000   /
# 1017944                                 OUTHBase     9     0.222222   /
# 1019539                                 OUTHBase     9     0.222222   /
# 1315033                                OUTOracle    23     0.086957   /
# 1726797                             OUTCouchbase     4     0.500000   /
# 1727273                             OUTCouchbase     4     0.500000   /
# 1727545                             OUTCouchbase     4     0.500000   /
# 2278339                     OUTSAPAdaptiveServer    41     0.048780   /
# 2281904                     OUTSAPAdaptiveServer    41     0.048780   /
# 1016190                                       H2    86     0.023256   /
# 1022891    MSSQLServer_MicrosoftAzureSQLDatabase    42     0.047619   /
# 1716446    MSSQLServer_MicrosoftAzureSQLDatabase    42     0.047619   /
# 1809689                                    Redis    71     0.028169   /
# 1878729                                    Redis    71     0.042254   /
# 1910728                                       H2    86     0.023256   /
# 1919424    MSSQLServer_MicrosoftAzureSQLDatabase    42     0.047619   /
# 2238906                           SAPSQLAnywhere    19     0.105263   /
# 2277944                        SAPAdaptiveServer    18     0.277778   /
# 2279394                                   Oracle    70     0.028571   /
# 2280448                                  IBM_DB2    25     0.080000   /
# 2281624    MSSQLServer_MicrosoftAzureSQLDatabase    42     0.119048   /
# 2486453                                       H2    86     0.023256   /
# 2489426                                Couchbase     4     0.500000   /
# 2699216                                    Neo4j     5     0.400000   /
#
#                                              D SUP_D  ConfD->ABC_  DE
# 1814997                              Hazelcast    19     0.105263  |#
# 1814998                            INHazelcast    71     0.028169  |#
# 1815289                               DynamoDB    22     0.090909  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase    42     0.047619  |#
# 2277333                    INSAPAdaptiveServer    33     0.121212  |#
# 2277347                      SAPAdaptiveServer    18     0.222222  |#
# 245537                                   Redis    71     0.028169  |#
# 245752                                      H2    86     0.034884  |#
# 460431                  PostgreSQL_CockroachDB    79     0.025316  |#
# 460751                                      H2    86     0.058140  |#
# 619092                                   Redis    71     0.028169  |#
# 2260005                    INSAPAdaptiveServer    33     0.090909  |#
# 2260014                      SAPAdaptiveServer    18     0.166667  |#
# 2260074                         SAPSQLAnywhere    19     0.105263  |#
# 2260093                 PostgreSQL_CockroachDB    79     0.037975  |#
# 2260135                                 Oracle    70     0.028571  |#
# 2260212                                IBM_DB2    25     0.080000  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase    42     0.047619  |#
# 203866                                   Redis    71     0.028169  |#
# 278208                               Cassandra    19     0.105263  |#
# 280863                                      H2    86     0.023256  |#
# 415706                                   Redis    71     0.056338  |#
# 454043                                 MongoDB    36     0.055556  |#
# 454873                                  Oracle    70     0.028571  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase    42     0.071429  |#
# 465405                                      H2    86     0.034884  |#
# 468143                  PostgreSQL_CockroachDB    79     0.025316  |#
# 469592                                 IBM_DB2    25     0.080000  |#
# 775263                                      H2    86     0.023256  |#
# 776100                  PostgreSQL_CockroachDB    79     0.025316  |#
# 1017944                               DynamoDB    22     0.090909  |#
# 1019539                 PostgreSQL_CockroachDB    79     0.025316  |#
# 1315033                                 SQLite    39     0.051282  |#
# 1726797                              Hazelcast    19     0.105263  |#
# 1727273                 PostgreSQL_CockroachDB    79     0.025316  |#
# 1727545                 MicrosoftAzureCosmosDB     5     0.400000  |#
# 2278339                 PostgreSQL_CockroachDB    79     0.025316  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase    42     0.047619  |#
# 1016190                               OUTHBase     9     0.222222  |#
# 1022891                               OUTHBase     9     0.222222  |#
# 1716446                             OUTIBM_DB2    10     0.200000  |#
# 1809689                           OUTHazelcast    60     0.033333  |#
# 1878729                              OUTSQLite    16     0.187500  |#
# 1910728                              OUTSQLite    16     0.125000  |#
# 1919424                              OUTSQLite    16     0.125000  |#
# 2238906                   OUTSAPAdaptiveServer    41     0.048780  |#
# 2277944                   OUTSAPAdaptiveServer    41     0.121951  |#
# 2279394                   OUTSAPAdaptiveServer    41     0.048780  |#
# 2280448                   OUTSAPAdaptiveServer    41     0.048780  |#
# 2281624                   OUTSAPAdaptiveServer    41     0.121951  |#
# 2486453              OUTPostgreSQL_CockroachDB    27     0.074074  |#
# 2489426              OUTPostgreSQL_CockroachDB    27     0.074074  |#
# 2699216                   OUTJoin_Ignite_NoSql     2     1.000000  |#
#
# [53 rows x 21 columns]

# %% [markdown]
# Calculeting the lift measures

# %%
df13['LiftA->B'] = (df13['SUP_ABCD']/projectsWithBD)/((df13['SUP_A']/projectsWithBD)*(df13['SUP_B']/projectsWithBD))
df13['LiftA->BC'] = (df13['SUP_ABCD']/projectsWithBD)/((df13['SUP_A']/projectsWithBD)*(df13['SUP_BC']/projectsWithBD))
df13['LiftA->BCD'] = (df13['SUP_ABCD']/projectsWithBD)/((df13['SUP_A']/projectsWithBD)*(df13['SUP_BCD']/projectsWithBD))
df13
# Out:
#                                                    Pattern  SUP_ABCD  \
# 1814997      Hazelcast|INHazelcast/OUTHazelcast|Hazelcast|         2
# 1814998    Hazelcast|INHazelcast/OUTHazelcast|INHazelcast|         2
# 1815289        Hazelcast|INDynamoDB/OUTHazelcast|DynamoDB|         2
# 1815759  Hazelcast|INMSSQLServer_MicrosoftAzureSQLDatab...         2
# 2277333  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...         4
# 2277347  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...         4
# 245537       MySQL_MariaDB|OUTMySQL_MariaDB/INRedis|Redis|         2
# 245752             MySQL_MariaDB|OUTMySQL_MariaDB/INH2|H2|         3
# 460431   HyperSQL|OUTHyperSQL/INPostgreSQL_CockroachDB|...         2
# 460751                       HyperSQL|OUTHyperSQL/INH2|H2|         5
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase|OUTMSSQL...         2
# 2260005  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...         3
# 2260014  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...         3
# 2260074  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPSQ...         2
# 2260093  SAPAdaptiveServer|OUTSAPAdaptiveServer/INPostg...         3
# 2260135  SAPAdaptiveServer|OUTSAPAdaptiveServer/INOracl...         2
# 2260212  SAPAdaptiveServer|OUTSAPAdaptiveServer/INIBM_D...         2
# 2260303  SAPAdaptiveServer|OUTSAPAdaptiveServer/INMSSQL...         2
# 203866       MySQL_MariaDB|INRedis|OUTMySQL_MariaDB/Redis|         2
# 278208   MySQL_MariaDB|INCassandra|OUTMySQL_MariaDB/Cas...         2
# 280863             MySQL_MariaDB|INH2|OUTMySQL_MariaDB/H2|         2
# 415706                 HyperSQL|INRedis|OUTHyperSQL/Redis|         4
# 454043             HyperSQL|INMongoDB|OUTHyperSQL/MongoDB|         2
# 454873               HyperSQL|INOracle|OUTHyperSQL/Oracle|         2
# 457599   HyperSQL|INMSSQLServer_MicrosoftAzureSQLDataba...         3
# 465405                       HyperSQL|INH2|OUTHyperSQL/H2|         3
# 468143   HyperSQL|INPostgreSQL_CockroachDB|OUTHyperSQL/...         2
# 469592             HyperSQL|INIBM_DB2|OUTHyperSQL/IBM_DB2|         2
# 775263   GoogleCloudDatastore|INH2|OUTGoogleCloudDatast...         2
# 776100   GoogleCloudDatastore|INPostgreSQL_CockroachDB|...         2
# 1017944                HBase|INDynamoDB|OUTHBase/DynamoDB|         2
# 1019539  HBase|INPostgreSQL_CockroachDB|OUTHBase/Postgr...         2
# 1315033                  Oracle|INSQLite|OUTOracle/SQLite|         2
# 1726797      Couchbase|INHazelcast|OUTCouchbase/Hazelcast|         2
# 1727273  Couchbase|INPostgreSQL_CockroachDB|OUTCouchbas...         2
# 1727545  Couchbase|INMicrosoftAzureCosmosDB|OUTCouchbas...         2
# 2278339  SAPAdaptiveServer|INPostgreSQL_CockroachDB|OUT...         2
# 2281904  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...         2
# 1016190                            HBase|INH2|H2/OUTHBase|         2
# 1022891  HBase|INMSSQLServer_MicrosoftAzureSQLDatabase|...         2
# 1716446  IBM_DB2|INMSSQLServer_MicrosoftAzureSQLDatabas...         2
# 1809689              Hazelcast|INRedis|Redis/OUTHazelcast|         2
# 1878729                    SQLite|INRedis|Redis/OUTSQLite|         3
# 1910728                          SQLite|INH2|H2/OUTSQLite|         2
# 1919424  SQLite|INMSSQLServer_MicrosoftAzureSQLDatabase...         2
# 2238906  SAPAdaptiveServer|INSAPSQLAnywhere|SAPSQLAnywh...         2
# 2277944  SAPAdaptiveServer|INSAPAdaptiveServer|SAPAdapt...         5
# 2279394  SAPAdaptiveServer|INOracle|Oracle/OUTSAPAdapti...         2
# 2280448  SAPAdaptiveServer|INIBM_DB2|IBM_DB2/OUTSAPAdap...         2
# 2281624  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...         5
# 2486453  PostgreSQL_CockroachDB|INH2|H2/OUTPostgreSQL_C...         2
# 2489426  PostgreSQL_CockroachDB|INCouchbase|Couchbase/O...         2
# 2699216  Join_Ignite_NoSql|INNeo4j|Neo4j/OUTJoin_Ignite...         2
#
#                        SID  SUP_BC  SUP_BCD  \
# 1814997             37 129       2        2
# 1814998             37 129       2        2
# 1815289              37 43       2        2
# 1815759              37 93       2        2
# 2277333       17 36 72 192       5        4
# 2277347       17 36 72 192       5        4
# 245537              16 169       2        2
# 245752           16 44 169       3        3
# 460431              81 131       2        2
# 460751    40 44 56 128 131       5        5
# 619092              16 128       2        2
# 2260005           0 36 192       4        4
# 2260014           0 36 192       4        4
# 2260074             36 192       3        3
# 2260093         36 178 192       8        7
# 2260135             36 192       7        6
# 2260212             36 192       6        5
# 2260303             36 192       4        3
# 203866               22 96       4        2
# 278208             109 140       2        2
# 280863              44 111       9        3
# 415706        29 40 81 128       9        7
# 454043               27 76       4        3
# 454873              29 114       7        4
# 457599           10 42 160       9        4
# 465405            23 27 42       8        3
# 468143             114 128       6        4
# 469592              42 114       6        2
# 775263              24 113       3        3
# 776100              24 121       2        2
# 1017944              10 24       2        2
# 1019539               9 24       2        2
# 1315033            183 194       3        2
# 1726797              28 37       3        2
# 1727273              28 37       2        2
# 1727545              28 37       2        2
# 2278339             36 192       6        5
# 2281904               0 72       9        5
# 1016190               9 24      49        3
# 1022891               9 10      28        3
# 1716446            160 178      28        2
# 1809689              37 93      48        3
# 1878729           34 42 76      48        3
# 1910728             34 129      49        3
# 1919424             76 160      28        2
# 2238906             36 192      11        4
# 2277944     0 17 36 72 192      16        5
# 2279394             36 192      33        3
# 2280448             36 192      14        4
# 2281624    0 36 72 160 192      28        7
# 2486453             42 111      49        3
# 2489426              28 37       3        2
# 2699216              16 28       3        2
#
#                                              A  SUP_A  ConfA->_BCD AB  \
# 1814997                              Hazelcast     19     0.105263  |
# 1814998                              Hazelcast     19     0.105263  |
# 1815289                              Hazelcast     19     0.105263  |
# 1815759                              Hazelcast     19     0.105263  |
# 2277333                      SAPAdaptiveServer     18     0.222222  |
# 2277347                      SAPAdaptiveServer     18     0.222222  |
# 245537                           MySQL_MariaDB    112     0.017857  |
# 245752                           MySQL_MariaDB    112     0.026786  |
# 460431                                HyperSQL     60     0.033333  |
# 460751                                HyperSQL     60     0.083333  |
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |
# 2260005                      SAPAdaptiveServer     18     0.166667  |
# 2260014                      SAPAdaptiveServer     18     0.166667  |
# 2260074                      SAPAdaptiveServer     18     0.111111  |
# 2260093                      SAPAdaptiveServer     18     0.166667  |
# 2260135                      SAPAdaptiveServer     18     0.111111  |
# 2260212                      SAPAdaptiveServer     18     0.111111  |
# 2260303                      SAPAdaptiveServer     18     0.111111  |
# 203866                           MySQL_MariaDB    112     0.017857  |
# 278208                           MySQL_MariaDB    112     0.017857  |
# 280863                           MySQL_MariaDB    112     0.017857  |
# 415706                                HyperSQL     60     0.066667  |
# 454043                                HyperSQL     60     0.033333  |
# 454873                                HyperSQL     60     0.033333  |
# 457599                                HyperSQL     60     0.050000  |
# 465405                                HyperSQL     60     0.050000  |
# 468143                                HyperSQL     60     0.033333  |
# 469592                                HyperSQL     60     0.033333  |
# 775263                    GoogleCloudDatastore     26     0.076923  |
# 776100                    GoogleCloudDatastore     26     0.076923  |
# 1017944                                  HBase     19     0.105263  |
# 1019539                                  HBase     19     0.105263  |
# 1315033                                 Oracle     70     0.028571  |
# 1726797                              Couchbase      4     0.500000  |
# 1727273                              Couchbase      4     0.500000  |
# 1727545                              Couchbase      4     0.500000  |
# 2278339                      SAPAdaptiveServer     18     0.111111  |
# 2281904                      SAPAdaptiveServer     18     0.111111  |
# 1016190                                  HBase     19     0.105263  |
# 1022891                                  HBase     19     0.105263  |
# 1716446                                IBM_DB2     25     0.080000  |
# 1809689                              Hazelcast     19     0.105263  |
# 1878729                                 SQLite     39     0.076923  |
# 1910728                                 SQLite     39     0.051282  |
# 1919424                                 SQLite     39     0.051282  |
# 2238906                      SAPAdaptiveServer     18     0.111111  |
# 2277944                      SAPAdaptiveServer     18     0.277778  |
# 2279394                      SAPAdaptiveServer     18     0.111111  |
# 2280448                      SAPAdaptiveServer     18     0.111111  |
# 2281624                      SAPAdaptiveServer     18     0.277778  |
# 2486453                 PostgreSQL_CockroachDB     79     0.025316  |
# 2489426                 PostgreSQL_CockroachDB     79     0.025316  |
# 2699216                      Join_Ignite_NoSql      3     0.666667  |
#
#                                                 B  ...  SUP_C  ConfC->AB_D CD  \
# 1814997                               INHazelcast  ...     60     0.033333  |
# 1814998                               INHazelcast  ...     60     0.033333  |
# 1815289                                INDynamoDB  ...     60     0.033333  |
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     60     0.033333  |
# 2277333                       INSAPAdaptiveServer  ...     41     0.097561  |
# 2277347                       INSAPAdaptiveServer  ...     41     0.097561  |
# 245537                           OUTMySQL_MariaDB  ...     59     0.033898  |
# 245752                           OUTMySQL_MariaDB  ...     56     0.053571  |
# 460431                                OUTHyperSQL  ...     51     0.039216  |
# 460751                                OUTHyperSQL  ...     56     0.089286  |
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase  ...     59     0.033898  |
# 2260005                      OUTSAPAdaptiveServer  ...     33     0.090909  |
# 2260014                      OUTSAPAdaptiveServer  ...     33     0.090909  |
# 2260074                      OUTSAPAdaptiveServer  ...     12     0.166667  |
# 2260093                      OUTSAPAdaptiveServer  ...     51     0.058824  |
# 2260135                      OUTSAPAdaptiveServer  ...     44     0.045455  |
# 2260212                      OUTSAPAdaptiveServer  ...     15     0.133333  |
# 2260303                      OUTSAPAdaptiveServer  ...     34     0.058824  |
# 203866                                    INRedis  ...     40     0.050000  /
# 278208                                INCassandra  ...     40     0.050000  /
# 280863                                       INH2  ...     40     0.050000  /
# 415706                                    INRedis  ...     27     0.148148  /
# 454043                                  INMongoDB  ...     27     0.074074  /
# 454873                                   INOracle  ...     27     0.074074  /
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase  ...     27     0.111111  /
# 465405                                       INH2  ...     27     0.111111  /
# 468143                   INPostgreSQL_CockroachDB  ...     27     0.074074  /
# 469592                                  INIBM_DB2  ...     27     0.074074  /
# 775263                                       INH2  ...     10     0.200000  /
# 776100                   INPostgreSQL_CockroachDB  ...     10     0.200000  /
# 1017944                                INDynamoDB  ...      9     0.222222  /
# 1019539                  INPostgreSQL_CockroachDB  ...      9     0.222222  /
# 1315033                                  INSQLite  ...     23     0.086957  /
# 1726797                               INHazelcast  ...      4     0.500000  /
# 1727273                  INPostgreSQL_CockroachDB  ...      4     0.500000  /
# 1727545                  INMicrosoftAzureCosmosDB  ...      4     0.500000  /
# 2278339                  INPostgreSQL_CockroachDB  ...     41     0.048780  /
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     41     0.048780  /
# 1016190                                      INH2  ...     86     0.023256  /
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.047619  /
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.047619  /
# 1809689                                   INRedis  ...     71     0.028169  /
# 1878729                                   INRedis  ...     71     0.042254  /
# 1910728                                      INH2  ...     86     0.023256  /
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.047619  /
# 2238906                          INSAPSQLAnywhere  ...     19     0.105263  /
# 2277944                       INSAPAdaptiveServer  ...     18     0.277778  /
# 2279394                                  INOracle  ...     70     0.028571  /
# 2280448                                 INIBM_DB2  ...     25     0.080000  /
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.119048  /
# 2486453                                      INH2  ...     86     0.023256  /
# 2489426                               INCouchbase  ...      4     0.500000  /
# 2699216                                   INNeo4j  ...      5     0.400000  /
#
#                                              D  SUP_D  ConfD->ABC_  DE  \
# 1814997                              Hazelcast     19     0.105263  |#
# 1814998                            INHazelcast     71     0.028169  |#
# 1815289                               DynamoDB     22     0.090909  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |#
# 2277333                    INSAPAdaptiveServer     33     0.121212  |#
# 2277347                      SAPAdaptiveServer     18     0.222222  |#
# 245537                                   Redis     71     0.028169  |#
# 245752                                      H2     86     0.034884  |#
# 460431                  PostgreSQL_CockroachDB     79     0.025316  |#
# 460751                                      H2     86     0.058140  |#
# 619092                                   Redis     71     0.028169  |#
# 2260005                    INSAPAdaptiveServer     33     0.090909  |#
# 2260014                      SAPAdaptiveServer     18     0.166667  |#
# 2260074                         SAPSQLAnywhere     19     0.105263  |#
# 2260093                 PostgreSQL_CockroachDB     79     0.037975  |#
# 2260135                                 Oracle     70     0.028571  |#
# 2260212                                IBM_DB2     25     0.080000  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |#
# 203866                                   Redis     71     0.028169  |#
# 278208                               Cassandra     19     0.105263  |#
# 280863                                      H2     86     0.023256  |#
# 415706                                   Redis     71     0.056338  |#
# 454043                                 MongoDB     36     0.055556  |#
# 454873                                  Oracle     70     0.028571  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase     42     0.071429  |#
# 465405                                      H2     86     0.034884  |#
# 468143                  PostgreSQL_CockroachDB     79     0.025316  |#
# 469592                                 IBM_DB2     25     0.080000  |#
# 775263                                      H2     86     0.023256  |#
# 776100                  PostgreSQL_CockroachDB     79     0.025316  |#
# 1017944                               DynamoDB     22     0.090909  |#
# 1019539                 PostgreSQL_CockroachDB     79     0.025316  |#
# 1315033                                 SQLite     39     0.051282  |#
# 1726797                              Hazelcast     19     0.105263  |#
# 1727273                 PostgreSQL_CockroachDB     79     0.025316  |#
# 1727545                 MicrosoftAzureCosmosDB      5     0.400000  |#
# 2278339                 PostgreSQL_CockroachDB     79     0.025316  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |#
# 1016190                               OUTHBase      9     0.222222  |#
# 1022891                               OUTHBase      9     0.222222  |#
# 1716446                             OUTIBM_DB2     10     0.200000  |#
# 1809689                           OUTHazelcast     60     0.033333  |#
# 1878729                              OUTSQLite     16     0.187500  |#
# 1910728                              OUTSQLite     16     0.125000  |#
# 1919424                              OUTSQLite     16     0.125000  |#
# 2238906                   OUTSAPAdaptiveServer     41     0.048780  |#
# 2277944                   OUTSAPAdaptiveServer     41     0.121951  |#
# 2279394                   OUTSAPAdaptiveServer     41     0.048780  |#
# 2280448                   OUTSAPAdaptiveServer     41     0.048780  |#
# 2281624                   OUTSAPAdaptiveServer     41     0.121951  |#
# 2486453              OUTPostgreSQL_CockroachDB     27     0.074074  |#
# 2489426              OUTPostgreSQL_CockroachDB     27     0.074074  |#
# 2699216                   OUTJoin_Ignite_NoSql      2     1.000000  |#
#
#           LiftA->B  LiftA->BC  LiftA->BCD
# 1814997   0.292068  10.368421   10.368421
# 1814998   0.292068  10.368421   10.368421
# 1815289   0.942584  10.368421   10.368421
# 1815759   0.609907  10.368421   10.368421
# 2277333   1.326599   8.755556   10.944444
# 2277347   1.326599   8.755556   10.944444
# 245537    0.087946   1.758929    1.758929
# 245752    0.131920   1.758929    1.758929
# 460431    0.243210   3.283333    3.283333
# 460751    0.608025   3.283333    3.283333
# 619092    0.625397   4.690476    4.690476
# 2260005   0.800813   8.208333    8.208333
# 2260014   0.800813   8.208333    8.208333
# 2260074   0.533875   7.296296    7.296296
# 2260093   0.800813   4.104167    4.690476
# 2260135   0.533875   3.126984    3.648148
# 2260212   0.533875   3.648148    4.377778
# 2260303   0.533875   5.472222    7.296296
# 203866    0.059625   0.879464    1.758929
# 278208    0.234524   1.758929    1.758929
# 280863    0.062819   0.390873    1.172619
# 415706    0.222599   1.459259    1.876190
# 454043    0.243210   1.641667    2.188889
# 454873    0.149242   0.938095    1.641667
# 457599    0.289706   1.094444    2.462500
# 465405    0.175893   1.231250    3.283333
# 468143    0.128758   1.094444    1.641667
# 469592    0.437778   1.094444    3.283333
# 775263    0.270604   5.051282    5.051282
# 776100    0.297134   7.576923    7.576923
# 1017944   0.942584  10.368421   10.368421
# 1019539   0.406605  10.368421   10.368421
# 1315033   0.216484   1.876190    2.814286
# 1726797   1.387324  32.833333   49.250000
# 1727273   1.931373  49.250000   49.250000
# 1727545  19.700000  49.250000   49.250000
# 2278339   0.429194   3.648148    4.377778
# 2281904   0.643791   2.432099    4.377778
# 1016190   0.370301   0.423201    6.912281
# 1022891   0.609907   0.740602    6.912281
# 1716446   0.463529   0.562857    7.880000
# 1809689   0.351472   0.432018    6.912281
# 1878729   0.256845   0.315705    5.051282
# 1910728   0.180403   0.206175    3.367521
# 1919424   0.297134   0.360806    5.051282
# 2238906   1.824074   1.989899    5.472222
# 2277944   1.658249   3.420139   10.944444
# 2279394   0.497475   0.663300    7.296296
# 2280448   1.459259   1.563492    5.472222
# 2281624   1.609477   1.954365    7.817460
# 2486453   0.089060   0.101782    1.662447
# 2489426   1.246835   1.662447    2.493671
# 2699216  26.266667  43.777778   65.666667
#
# [53 rows x 24 columns]

# %%
#df13.to_excel(SEQ_PATTERNS_DIR + os.sep +"testes/pattern_supABCD_initin_selection_measure10.xlsx",index=True) #"testes/pattern_supABCD_initin_selection_measure2.xlsx
df13 = df13.sort_values(by='A')
df13
#df13.to_excel(SEQ_PATTERNS_DIR + os.sep +'pattern_selection_measures.xlsx',index=True)
#A tabela gerada aqui é a tabelas de número 9 do artigo
# Out:
#                                                    Pattern  SUP_ABCD  \
# 1726797      Couchbase|INHazelcast|OUTCouchbase/Hazelcast|         2
# 1727545  Couchbase|INMicrosoftAzureCosmosDB|OUTCouchbas...         2
# 1727273  Couchbase|INPostgreSQL_CockroachDB|OUTCouchbas...         2
# 775263   GoogleCloudDatastore|INH2|OUTGoogleCloudDatast...         2
# 776100   GoogleCloudDatastore|INPostgreSQL_CockroachDB|...         2
# 1017944                HBase|INDynamoDB|OUTHBase/DynamoDB|         2
# 1019539  HBase|INPostgreSQL_CockroachDB|OUTHBase/Postgr...         2
# 1022891  HBase|INMSSQLServer_MicrosoftAzureSQLDatabase|...         2
# 1016190                            HBase|INH2|H2/OUTHBase|         2
# 1814997      Hazelcast|INHazelcast/OUTHazelcast|Hazelcast|         2
# 1809689              Hazelcast|INRedis|Redis/OUTHazelcast|         2
# 1815759  Hazelcast|INMSSQLServer_MicrosoftAzureSQLDatab...         2
# 1815289        Hazelcast|INDynamoDB/OUTHazelcast|DynamoDB|         2
# 1814998    Hazelcast|INHazelcast/OUTHazelcast|INHazelcast|         2
# 469592             HyperSQL|INIBM_DB2|OUTHyperSQL/IBM_DB2|         2
# 465405                       HyperSQL|INH2|OUTHyperSQL/H2|         3
# 457599   HyperSQL|INMSSQLServer_MicrosoftAzureSQLDataba...         3
# 454873               HyperSQL|INOracle|OUTHyperSQL/Oracle|         2
# 454043             HyperSQL|INMongoDB|OUTHyperSQL/MongoDB|         2
# 415706                 HyperSQL|INRedis|OUTHyperSQL/Redis|         4
# 468143   HyperSQL|INPostgreSQL_CockroachDB|OUTHyperSQL/...         2
# 460431   HyperSQL|OUTHyperSQL/INPostgreSQL_CockroachDB|...         2
# 460751                       HyperSQL|OUTHyperSQL/INH2|H2|         5
# 1716446  IBM_DB2|INMSSQLServer_MicrosoftAzureSQLDatabas...         2
# 2699216  Join_Ignite_NoSql|INNeo4j|Neo4j/OUTJoin_Ignite...         2
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase|OUTMSSQL...         2
# 245537       MySQL_MariaDB|OUTMySQL_MariaDB/INRedis|Redis|         2
# 280863             MySQL_MariaDB|INH2|OUTMySQL_MariaDB/H2|         2
# 245752             MySQL_MariaDB|OUTMySQL_MariaDB/INH2|H2|         3
# 278208   MySQL_MariaDB|INCassandra|OUTMySQL_MariaDB/Cas...         2
# 203866       MySQL_MariaDB|INRedis|OUTMySQL_MariaDB/Redis|         2
# 1315033                  Oracle|INSQLite|OUTOracle/SQLite|         2
# 2486453  PostgreSQL_CockroachDB|INH2|H2/OUTPostgreSQL_C...         2
# 2489426  PostgreSQL_CockroachDB|INCouchbase|Couchbase/O...         2
# 2260005  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...         3
# 2281624  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...         5
# 2280448  SAPAdaptiveServer|INIBM_DB2|IBM_DB2/OUTSAPAdap...         2
# 2279394  SAPAdaptiveServer|INOracle|Oracle/OUTSAPAdapti...         2
# 2277944  SAPAdaptiveServer|INSAPAdaptiveServer|SAPAdapt...         5
# 2238906  SAPAdaptiveServer|INSAPSQLAnywhere|SAPSQLAnywh...         2
# 2260014  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPAd...         3
# 2277333  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...         4
# 2260303  SAPAdaptiveServer|OUTSAPAdaptiveServer/INMSSQL...         2
# 2281904  SAPAdaptiveServer|INMSSQLServer_MicrosoftAzure...         2
# 2260212  SAPAdaptiveServer|OUTSAPAdaptiveServer/INIBM_D...         2
# 2260135  SAPAdaptiveServer|OUTSAPAdaptiveServer/INOracl...         2
# 2260093  SAPAdaptiveServer|OUTSAPAdaptiveServer/INPostg...         3
# 2260074  SAPAdaptiveServer|OUTSAPAdaptiveServer/INSAPSQ...         2
# 2277347  SAPAdaptiveServer|INSAPAdaptiveServer/OUTSAPAd...         4
# 2278339  SAPAdaptiveServer|INPostgreSQL_CockroachDB|OUT...         2
# 1878729                    SQLite|INRedis|Redis/OUTSQLite|         3
# 1910728                          SQLite|INH2|H2/OUTSQLite|         2
# 1919424  SQLite|INMSSQLServer_MicrosoftAzureSQLDatabase...         2
#
#                        SID  SUP_BC  SUP_BCD  \
# 1726797              28 37       3        2
# 1727545              28 37       2        2
# 1727273              28 37       2        2
# 775263              24 113       3        3
# 776100              24 121       2        2
# 1017944              10 24       2        2
# 1019539               9 24       2        2
# 1022891               9 10      28        3
# 1016190               9 24      49        3
# 1814997             37 129       2        2
# 1809689              37 93      48        3
# 1815759              37 93       2        2
# 1815289              37 43       2        2
# 1814998             37 129       2        2
# 469592              42 114       6        2
# 465405            23 27 42       8        3
# 457599           10 42 160       9        4
# 454873              29 114       7        4
# 454043               27 76       4        3
# 415706        29 40 81 128       9        7
# 468143             114 128       6        4
# 460431              81 131       2        2
# 460751    40 44 56 128 131       5        5
# 1716446            160 178      28        2
# 2699216              16 28       3        2
# 619092              16 128       2        2
# 245537              16 169       2        2
# 280863              44 111       9        3
# 245752           16 44 169       3        3
# 278208             109 140       2        2
# 203866               22 96       4        2
# 1315033            183 194       3        2
# 2486453             42 111      49        3
# 2489426              28 37       3        2
# 2260005           0 36 192       4        4
# 2281624    0 36 72 160 192      28        7
# 2280448             36 192      14        4
# 2279394             36 192      33        3
# 2277944     0 17 36 72 192      16        5
# 2238906             36 192      11        4
# 2260014           0 36 192       4        4
# 2277333       17 36 72 192       5        4
# 2260303             36 192       4        3
# 2281904               0 72       9        5
# 2260212             36 192       6        5
# 2260135             36 192       7        6
# 2260093         36 178 192       8        7
# 2260074             36 192       3        3
# 2277347       17 36 72 192       5        4
# 2278339             36 192       6        5
# 1878729           34 42 76      48        3
# 1910728             34 129      49        3
# 1919424             76 160      28        2
#
#                                              A  SUP_A  ConfA->_BCD AB  \
# 1726797                              Couchbase      4     0.500000  |
# 1727545                              Couchbase      4     0.500000  |
# 1727273                              Couchbase      4     0.500000  |
# 775263                    GoogleCloudDatastore     26     0.076923  |
# 776100                    GoogleCloudDatastore     26     0.076923  |
# 1017944                                  HBase     19     0.105263  |
# 1019539                                  HBase     19     0.105263  |
# 1022891                                  HBase     19     0.105263  |
# 1016190                                  HBase     19     0.105263  |
# 1814997                              Hazelcast     19     0.105263  |
# 1809689                              Hazelcast     19     0.105263  |
# 1815759                              Hazelcast     19     0.105263  |
# 1815289                              Hazelcast     19     0.105263  |
# 1814998                              Hazelcast     19     0.105263  |
# 469592                                HyperSQL     60     0.033333  |
# 465405                                HyperSQL     60     0.050000  |
# 457599                                HyperSQL     60     0.050000  |
# 454873                                HyperSQL     60     0.033333  |
# 454043                                HyperSQL     60     0.033333  |
# 415706                                HyperSQL     60     0.066667  |
# 468143                                HyperSQL     60     0.033333  |
# 460431                                HyperSQL     60     0.033333  |
# 460751                                HyperSQL     60     0.083333  |
# 1716446                                IBM_DB2     25     0.080000  |
# 2699216                      Join_Ignite_NoSql      3     0.666667  |
# 619092   MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |
# 245537                           MySQL_MariaDB    112     0.017857  |
# 280863                           MySQL_MariaDB    112     0.017857  |
# 245752                           MySQL_MariaDB    112     0.026786  |
# 278208                           MySQL_MariaDB    112     0.017857  |
# 203866                           MySQL_MariaDB    112     0.017857  |
# 1315033                                 Oracle     70     0.028571  |
# 2486453                 PostgreSQL_CockroachDB     79     0.025316  |
# 2489426                 PostgreSQL_CockroachDB     79     0.025316  |
# 2260005                      SAPAdaptiveServer     18     0.166667  |
# 2281624                      SAPAdaptiveServer     18     0.277778  |
# 2280448                      SAPAdaptiveServer     18     0.111111  |
# 2279394                      SAPAdaptiveServer     18     0.111111  |
# 2277944                      SAPAdaptiveServer     18     0.277778  |
# 2238906                      SAPAdaptiveServer     18     0.111111  |
# 2260014                      SAPAdaptiveServer     18     0.166667  |
# 2277333                      SAPAdaptiveServer     18     0.222222  |
# 2260303                      SAPAdaptiveServer     18     0.111111  |
# 2281904                      SAPAdaptiveServer     18     0.111111  |
# 2260212                      SAPAdaptiveServer     18     0.111111  |
# 2260135                      SAPAdaptiveServer     18     0.111111  |
# 2260093                      SAPAdaptiveServer     18     0.166667  |
# 2260074                      SAPAdaptiveServer     18     0.111111  |
# 2277347                      SAPAdaptiveServer     18     0.222222  |
# 2278339                      SAPAdaptiveServer     18     0.111111  |
# 1878729                                 SQLite     39     0.076923  |
# 1910728                                 SQLite     39     0.051282  |
# 1919424                                 SQLite     39     0.051282  |
#
#                                                 B  ...  SUP_C  ConfC->AB_D CD  \
# 1726797                               INHazelcast  ...      4     0.500000  /
# 1727545                  INMicrosoftAzureCosmosDB  ...      4     0.500000  /
# 1727273                  INPostgreSQL_CockroachDB  ...      4     0.500000  /
# 775263                                       INH2  ...     10     0.200000  /
# 776100                   INPostgreSQL_CockroachDB  ...     10     0.200000  /
# 1017944                                INDynamoDB  ...      9     0.222222  /
# 1019539                  INPostgreSQL_CockroachDB  ...      9     0.222222  /
# 1022891   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.047619  /
# 1016190                                      INH2  ...     86     0.023256  /
# 1814997                               INHazelcast  ...     60     0.033333  |
# 1809689                                   INRedis  ...     71     0.028169  /
# 1815759   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     60     0.033333  |
# 1815289                                INDynamoDB  ...     60     0.033333  |
# 1814998                               INHazelcast  ...     60     0.033333  |
# 469592                                  INIBM_DB2  ...     27     0.074074  /
# 465405                                       INH2  ...     27     0.111111  /
# 457599    INMSSQLServer_MicrosoftAzureSQLDatabase  ...     27     0.111111  /
# 454873                                   INOracle  ...     27     0.074074  /
# 454043                                  INMongoDB  ...     27     0.074074  /
# 415706                                    INRedis  ...     27     0.148148  /
# 468143                   INPostgreSQL_CockroachDB  ...     27     0.074074  /
# 460431                                OUTHyperSQL  ...     51     0.039216  |
# 460751                                OUTHyperSQL  ...     56     0.089286  |
# 1716446   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.047619  /
# 2699216                                   INNeo4j  ...      5     0.400000  /
# 619092   OUTMSSQLServer_MicrosoftAzureSQLDatabase  ...     59     0.033898  |
# 245537                           OUTMySQL_MariaDB  ...     59     0.033898  |
# 280863                                       INH2  ...     40     0.050000  /
# 245752                           OUTMySQL_MariaDB  ...     56     0.053571  |
# 278208                                INCassandra  ...     40     0.050000  /
# 203866                                    INRedis  ...     40     0.050000  /
# 1315033                                  INSQLite  ...     23     0.086957  /
# 2486453                                      INH2  ...     86     0.023256  /
# 2489426                               INCouchbase  ...      4     0.500000  /
# 2260005                      OUTSAPAdaptiveServer  ...     33     0.090909  |
# 2281624   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.119048  /
# 2280448                                 INIBM_DB2  ...     25     0.080000  /
# 2279394                                  INOracle  ...     70     0.028571  /
# 2277944                       INSAPAdaptiveServer  ...     18     0.277778  /
# 2238906                          INSAPSQLAnywhere  ...     19     0.105263  /
# 2260014                      OUTSAPAdaptiveServer  ...     33     0.090909  |
# 2277333                       INSAPAdaptiveServer  ...     41     0.097561  |
# 2260303                      OUTSAPAdaptiveServer  ...     34     0.058824  |
# 2281904   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     41     0.048780  /
# 2260212                      OUTSAPAdaptiveServer  ...     15     0.133333  |
# 2260135                      OUTSAPAdaptiveServer  ...     44     0.045455  |
# 2260093                      OUTSAPAdaptiveServer  ...     51     0.058824  |
# 2260074                      OUTSAPAdaptiveServer  ...     12     0.166667  |
# 2277347                       INSAPAdaptiveServer  ...     41     0.097561  |
# 2278339                  INPostgreSQL_CockroachDB  ...     41     0.048780  /
# 1878729                                   INRedis  ...     71     0.042254  /
# 1910728                                      INH2  ...     86     0.023256  /
# 1919424   INMSSQLServer_MicrosoftAzureSQLDatabase  ...     42     0.047619  /
#
#                                              D  SUP_D  ConfD->ABC_  DE  \
# 1726797                              Hazelcast     19     0.105263  |#
# 1727545                 MicrosoftAzureCosmosDB      5     0.400000  |#
# 1727273                 PostgreSQL_CockroachDB     79     0.025316  |#
# 775263                                      H2     86     0.023256  |#
# 776100                  PostgreSQL_CockroachDB     79     0.025316  |#
# 1017944                               DynamoDB     22     0.090909  |#
# 1019539                 PostgreSQL_CockroachDB     79     0.025316  |#
# 1022891                               OUTHBase      9     0.222222  |#
# 1016190                               OUTHBase      9     0.222222  |#
# 1814997                              Hazelcast     19     0.105263  |#
# 1809689                           OUTHazelcast     60     0.033333  |#
# 1815759  MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |#
# 1815289                               DynamoDB     22     0.090909  |#
# 1814998                            INHazelcast     71     0.028169  |#
# 469592                                 IBM_DB2     25     0.080000  |#
# 465405                                      H2     86     0.034884  |#
# 457599   MSSQLServer_MicrosoftAzureSQLDatabase     42     0.071429  |#
# 454873                                  Oracle     70     0.028571  |#
# 454043                                 MongoDB     36     0.055556  |#
# 415706                                   Redis     71     0.056338  |#
# 468143                  PostgreSQL_CockroachDB     79     0.025316  |#
# 460431                  PostgreSQL_CockroachDB     79     0.025316  |#
# 460751                                      H2     86     0.058140  |#
# 1716446                             OUTIBM_DB2     10     0.200000  |#
# 2699216                   OUTJoin_Ignite_NoSql      2     1.000000  |#
# 619092                                   Redis     71     0.028169  |#
# 245537                                   Redis     71     0.028169  |#
# 280863                                      H2     86     0.023256  |#
# 245752                                      H2     86     0.034884  |#
# 278208                               Cassandra     19     0.105263  |#
# 203866                                   Redis     71     0.028169  |#
# 1315033                                 SQLite     39     0.051282  |#
# 2486453              OUTPostgreSQL_CockroachDB     27     0.074074  |#
# 2489426              OUTPostgreSQL_CockroachDB     27     0.074074  |#
# 2260005                    INSAPAdaptiveServer     33     0.090909  |#
# 2281624                   OUTSAPAdaptiveServer     41     0.121951  |#
# 2280448                   OUTSAPAdaptiveServer     41     0.048780  |#
# 2279394                   OUTSAPAdaptiveServer     41     0.048780  |#
# 2277944                   OUTSAPAdaptiveServer     41     0.121951  |#
# 2238906                   OUTSAPAdaptiveServer     41     0.048780  |#
# 2260014                      SAPAdaptiveServer     18     0.166667  |#
# 2277333                    INSAPAdaptiveServer     33     0.121212  |#
# 2260303  MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |#
# 2281904  MSSQLServer_MicrosoftAzureSQLDatabase     42     0.047619  |#
# 2260212                                IBM_DB2     25     0.080000  |#
# 2260135                                 Oracle     70     0.028571  |#
# 2260093                 PostgreSQL_CockroachDB     79     0.037975  |#
# 2260074                         SAPSQLAnywhere     19     0.105263  |#
# 2277347                      SAPAdaptiveServer     18     0.222222  |#
# 2278339                 PostgreSQL_CockroachDB     79     0.025316  |#
# 1878729                              OUTSQLite     16     0.187500  |#
# 1910728                              OUTSQLite     16     0.125000  |#
# 1919424                              OUTSQLite     16     0.125000  |#
#
#           LiftA->B  LiftA->BC  LiftA->BCD
# 1726797   1.387324  32.833333   49.250000
# 1727545  19.700000  49.250000   49.250000
# 1727273   1.931373  49.250000   49.250000
# 775263    0.270604   5.051282    5.051282
# 776100    0.297134   7.576923    7.576923
# 1017944   0.942584  10.368421   10.368421
# 1019539   0.406605  10.368421   10.368421
# 1022891   0.609907   0.740602    6.912281
# 1016190   0.370301   0.423201    6.912281
# 1814997   0.292068  10.368421   10.368421
# 1809689   0.351472   0.432018    6.912281
# 1815759   0.609907  10.368421   10.368421
# 1815289   0.942584  10.368421   10.368421
# 1814998   0.292068  10.368421   10.368421
# 469592    0.437778   1.094444    3.283333
# 465405    0.175893   1.231250    3.283333
# 457599    0.289706   1.094444    2.462500
# 454873    0.149242   0.938095    1.641667
# 454043    0.243210   1.641667    2.188889
# 415706    0.222599   1.459259    1.876190
# 468143    0.128758   1.094444    1.641667
# 460431    0.243210   3.283333    3.283333
# 460751    0.608025   3.283333    3.283333
# 1716446   0.463529   0.562857    7.880000
# 2699216  26.266667  43.777778   65.666667
# 619092    0.625397   4.690476    4.690476
# 245537    0.087946   1.758929    1.758929
# 280863    0.062819   0.390873    1.172619
# 245752    0.131920   1.758929    1.758929
# 278208    0.234524   1.758929    1.758929
# 203866    0.059625   0.879464    1.758929
# 1315033   0.216484   1.876190    2.814286
# 2486453   0.089060   0.101782    1.662447
# 2489426   1.246835   1.662447    2.493671
# 2260005   0.800813   8.208333    8.208333
# 2281624   1.609477   1.954365    7.817460
# 2280448   1.459259   1.563492    5.472222
# 2279394   0.497475   0.663300    7.296296
# 2277944   1.658249   3.420139   10.944444
# 2238906   1.824074   1.989899    5.472222
# 2260014   0.800813   8.208333    8.208333
# 2277333   1.326599   8.755556   10.944444
# 2260303   0.533875   5.472222    7.296296
# 2281904   0.643791   2.432099    4.377778
# 2260212   0.533875   3.648148    4.377778
# 2260135   0.533875   3.126984    3.648148
# 2260093   0.800813   4.104167    4.690476
# 2260074   0.533875   7.296296    7.296296
# 2277347   1.326599   8.755556   10.944444
# 2278339   0.429194   3.648148    4.377778
# 1878729   0.256845   0.315705    5.051282
# 1910728   0.180403   0.206175    3.367521
# 1919424   0.297134   0.360806    5.051282
#
# [53 rows x 24 columns]

# %%
df13['A'].value_counts()
# Out:
# SAPAdaptiveServer                        16
# HyperSQL                                  9
# Hazelcast                                 5
# MySQL_MariaDB                             5
# HBase                                     4
# Couchbase                                 3
# SQLite                                    3
# GoogleCloudDatastore                      2
# PostgreSQL_CockroachDB                    2
# IBM_DB2                                   1
# Join_Ignite_NoSql                         1
# MSSQLServer_MicrosoftAzureSQLDatabase     1
# Oracle                                    1
# Name: A, dtype: int64

# %%
df13['B'].value_counts()
#filtrar por só in
# Out:
# INMSSQLServer_MicrosoftAzureSQLDatabase     7
# OUTSAPAdaptiveServer                        7
# INH2                                        6
# INPostgreSQL_CockroachDB                    5
# INRedis                                     4
# INHazelcast                                 3
# INSAPAdaptiveServer                         3
# OUTMySQL_MariaDB                            2
# OUTHyperSQL                                 2
# INOracle                                    2
# INIBM_DB2                                   2
# INDynamoDB                                  2
# INMongoDB                                   1
# INMicrosoftAzureCosmosDB                    1
# INNeo4j                                     1
# OUTMSSQLServer_MicrosoftAzureSQLDatabase    1
# INCassandra                                 1
# INSQLite                                    1
# INCouchbase                                 1
# INSAPSQLAnywhere                            1
# Name: B, dtype: int64

# %%
PATTERN_SELECTION_MEASURES = SEQ_PATTERNS_DIR + os.sep + 'pattern_selection_measures.xlsx'
df = pd.ExcelFile(PATTERN_SELECTION_MEASURES, engine='openpyxl')
df = df.parse("Sheet1")

SEQUENTIAL_PROJECTS = SEQ_PATTERNS_DIR + os.sep + 'sequencial_project.txt'
projects = pd.read_csv(SEQUENTIAL_PROJECTS, sep='\t', header='infer', names=None)

df_projects = pd.DataFrame(projects)
list_projects = df_projects.columns.tolist()
#print(list_projects)
nomes_list = eval(list_projects[0])
#print(nomes_list)
new_sid=[]

for index, row in df.iterrows():
    list_projects_sid = row['SID'].split(' ')
    projectsNames=""
    for project in list_projects_sid:
        if(project.strip() != ''):
            if(projectsNames == ''):
                projectsNames = nomes_list[int(project)]
            else:
                projectsNames = projectsNames + " , " + nomes_list[int(project)]
    new_sid.append(projectsNames)

#print(new_sid)

df['SID'] = new_sid
df.to_excel(SEQ_PATTERNS_DIR + os.sep +'pattern_selection_measures_names.xlsx',index=False)        
    
    
#tem SID =0
